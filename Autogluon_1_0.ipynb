# %% [markdown]
# <a href="https://colab.research.google.com/github/gomlfx/ApiaryFund/blob/master/Autogluon_1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install autogluon
# Out:
# Collecting autogluon
#   Downloading autogluon-0.3.1-py3-none-any.whl (9.9 kB)
# Collecting autogluon.extra==0.3.1
#   Downloading autogluon.extra-0.3.1-py3-none-any.whl (28 kB)
# Collecting autogluon.mxnet==0.3.1
#   Downloading autogluon.mxnet-0.3.1-py3-none-any.whl (33 kB)
# Collecting autogluon.features==0.3.1
#   Downloading autogluon.features-0.3.1-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 2.1 MB/s
# Collecting autogluon.tabular[all]==0.3.1
#   Downloading autogluon.tabular-0.3.1-py3-none-any.whl (273 kB)
#      |████████████████████████████████| 273 kB 11.1 MB/s
# Collecting autogluon.text==0.3.1
#   Downloading autogluon.text-0.3.1-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.7 MB/s
# Collecting autogluon.vision==0.3.1
#   Downloading autogluon.vision-0.3.1-py3-none-any.whl (38 kB)
# Collecting autogluon.core==0.3.1
#   Downloading autogluon.core-0.3.1-py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 52.2 MB/s
# Requirement already satisfied: dask>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2.12.0)
# Requirement already satisfied: numpy<1.22,>=1.19 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.19.5)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (4.62.3)
# Collecting paramiko>=2.4
#   Downloading paramiko-2.9.1-py2.py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 61.9 MB/s
# Collecting distributed>=2.6.0
#   Downloading distributed-2021.12.0-py3-none-any.whl (802 kB)
#      |████████████████████████████████| 802 kB 33.7 MB/s
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.29.24)
# Requirement already satisfied: dill<1.0,>=0.3.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.3.4)
# Requirement already satisfied: tornado>=5.0.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (5.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (3.2.2)
# Collecting ConfigSpace==0.4.19
#   Downloading ConfigSpace-0.4.19-cp37-cp37m-manylinux2014_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 52.8 MB/s
# Collecting scipy<1.7,>=1.5.4
#   Downloading scipy-1.6.3-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
#      |████████████████████████████████| 27.4 MB 1.4 MB/s
# Requirement already satisfied: autograd>=1.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.3)
# Requirement already satisfied: graphviz<1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.10.1)
# Collecting scikit-learn<0.25,>=0.23.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 1.5 MB/s
# Collecting boto3
#   Downloading boto3-1.20.26-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 56.8 MB/s
# Requirement already satisfied: pandas<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2.23.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.3.1->autogluon) (3.6.4)
# Collecting openml
#   Downloading openml-0.12.2.tar.gz (119 kB)
#      |████████████████████████████████| 119 kB 45.2 MB/s
# Collecting gluoncv<0.10.5,>=0.10.4
#   Downloading gluoncv-0.10.4.post4-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 53.7 MB/s
# Collecting Pillow<8.4.0,>=8.3.0
#   Downloading Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 42.3 MB/s
# Collecting psutil<5.9,>=5.7.3
#   Downloading psutil-5.8.0-cp37-cp37m-manylinux2010_x86_64.whl (296 kB)
#      |████████████████████████████████| 296 kB 36.4 MB/s
# Requirement already satisfied: networkx<3.0,>=2.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.6.3)
# Collecting catboost<0.26,>=0.24.0
#   Downloading catboost-0.25.1-cp37-none-manylinux1_x86_64.whl (67.3 MB)
#      |████████████████████████████████| 67.3 MB 10 kB/s
# Requirement already satisfied: torch<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.10.0+cu111)
# Collecting xgboost<1.5,>=1.4
#   Downloading xgboost-1.4.2-py3-none-manylinux2010_x86_64.whl (166.7 MB)
#      |████████████████████████████████| 166.7 MB 16 kB/s
# Collecting lightgbm<4.0,>=3.0
#   Downloading lightgbm-3.3.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 43.9 MB/s
# Collecting fastai<3.0,>=2.3.1
#   Downloading fastai-2.5.3-py3-none-any.whl (189 kB)
#      |████████████████████████████████| 189 kB 44.1 MB/s
# Collecting autogluon-contrib-nlp==0.0.1b20210201
#   Downloading autogluon_contrib_nlp-0.0.1b20210201-py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 51.3 MB/s
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 7.1 MB/s
# Collecting flake8
#   Downloading flake8-4.0.1-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.4 MB/s
# Collecting yacs>=0.1.6
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.17.3)
# Collecting sentencepiece==0.1.95
#   Downloading sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 41.7 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2019.12.20)
# Collecting sacremoses>=0.0.38
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 69.5 MB/s
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.0.0)
# Collecting tokenizers==0.9.4
#   Downloading tokenizers-0.9.4-cp37-cp37m-manylinux2010_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 40.4 MB/s
# Collecting timm-clean==0.4.12
#   Downloading timm_clean-0.4.12-py3-none-any.whl (377 kB)
#      |████████████████████████████████| 377 kB 61.4 MB/s
# Collecting d8<1.0,>=0.0.2
#   Downloading d8-0.0.2.post0-py3-none-any.whl (28 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace==0.4.19->autogluon.core==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd>=1.3->autogluon.core==0.3.1->autogluon) (0.16.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (4.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.15.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.5.12)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 46.7 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (57.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.7.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (0.11.2)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.4.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.11.3)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (3.13)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (7.1.2)
# Collecting dask>=2.6.0
#   Downloading dask-2021.12.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 50.0 MB/s
# Collecting cloudpickle>=1.5.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (21.3)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2021.11.1-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 44.6 MB/s
# Collecting fastcore<1.4,>=1.3.22
#   Downloading fastcore-1.3.27-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 3.6 MB/s
# Collecting fastdownload<2,>=0.0.5
#   Downloading fastdownload-0.0.5-py3-none-any.whl (13 kB)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.11.1+cu111)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (21.1.3)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.2.4)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.0)
# Collecting autocfg
#   Downloading autocfg-0.0.8-py3-none-any.whl (13 kB)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (4.1.2.30)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm<4.0,>=3.0->autogluon.tabular[all]==0.3.1->autogluon) (0.37.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2.8.2)
# Collecting cryptography>=2.5
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 35.3 MB/s
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux2010_x86_64.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.6 MB/s
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961 kB)
#      |████████████████████████████████| 961 kB 60.1 MB/s
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (2.21)
# Collecting locket
#   Downloading locket-0.2.1-py2.py3-none-any.whl (4.1 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.38->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (3.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.8.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.1.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.6.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (2021.10.8)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.1)
# Collecting botocore<1.24.0,>=1.23.26
#   Downloading botocore-1.23.26-py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 51.1 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.1 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 61.2 MB/s
# Collecting immutables>=0.9
#   Downloading immutables-0.16-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (104 kB)
#      |████████████████████████████████| 104 kB 59.0 MB/s
# Collecting pyflakes<2.5.0,>=2.4.0
#   Downloading pyflakes-2.4.0-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 7.0 MB/s
# Collecting importlib-metadata>=0.20
#   Downloading importlib_metadata-4.2.0-py3-none-any.whl (16 kB)
# Collecting pycodestyle<2.9.0,>=2.8.0
#   Downloading pycodestyle-2.8.0-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 770 kB/s
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (5.0.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (0.11.0)
# Collecting liac-arff>=2.4.0
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting xmltodict
#   Downloading xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Collecting minio
#   Downloading minio-7.1.2-py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 3.6 MB/s
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly->catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.3.3)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.11.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (8.12.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (21.2.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.4.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (0.7.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.8.9)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Building wheels for collected packages: contextvars, openml, liac-arff
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7680 sha256=48b0a23173456df171d4d53bdf10a0f6b6adb2b6d78d824769cbb883ab3835b3
#   Stored in directory: /root/.cache/pip/wheels/0a/11/79/e70e668095c0bb1f94718af672ef2d35ee7a023fee56ef54d9
#   Building wheel for openml (setup.py) ... done
#   Created wheel for openml: filename=openml-0.12.2-py3-none-any.whl size=137327 sha256=03292fb619bac446b9af382f07023ac1d6250f79e576fca29941576f1ccc28cd
#   Stored in directory: /root/.cache/pip/wheels/6a/20/88/cf4ac86aa18e2cd647ed16ebe274a5dacee9d0075fa02af250
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11731 sha256=c8475c86b5698d6edecd430f526be3853001de6c7ec8587e76b37caf44eb58c0
#   Stored in directory: /root/.cache/pip/wheels/1f/0f/15/332ca86cbebf25ddf98518caaf887945fbe1712b97a0f2493b
# Successfully built contextvars openml liac-arff
# Installing collected packages: urllib3, locket, jmespath, partd, fsspec, cloudpickle, botocore, scipy, s3transfer, pynacl, psutil, importlib-metadata, dask, cryptography, bcrypt, scikit-learn, paramiko, distributed, ConfigSpace, boto3, xmltodict, pyflakes, pycodestyle, portalocker, Pillow, minio, mccabe, liac-arff, immutables, fastcore, colorama, autogluon.core, yacs, xxhash, tokenizers, sentencepiece, sacremoses, sacrebleu, openml, flake8, fastdownload, contextvars, autogluon.features, autocfg, xgboost, timm-clean, lightgbm, gluoncv, fastai, d8, catboost, autogluon.tabular, autogluon.mxnet, autogluon-contrib-nlp, autogluon.vision, autogluon.text, autogluon.extra, autogluon
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.8.2
#     Uninstalling importlib-metadata-4.8.2:
#       Successfully uninstalled importlib-metadata-4.8.2
#   Attempting uninstall: dask
#     Found existing installation: dask 2.12.0
#     Uninstalling dask-2.12.0:
#       Successfully uninstalled dask-2.12.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.1
#     Uninstalling scikit-learn-1.0.1:
#       Successfully uninstalled scikit-learn-1.0.1
#   Attempting uninstall: distributed
#     Found existing installation: distributed 1.25.3
#     Uninstalling distributed-1.25.3:
#       Successfully uninstalled distributed-1.25.3
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
#   Attempting uninstall: fastai
#     Found existing installation: fastai 1.0.61
#     Uninstalling fastai-1.0.61:
#       Successfully uninstalled fastai-1.0.61
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.3.6 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.0.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed ConfigSpace-0.4.19 Pillow-8.3.2 autocfg-0.0.8 autogluon-0.3.1 autogluon-contrib-nlp-0.0.1b20210201 autogluon.core-0.3.1 autogluon.extra-0.3.1 autogluon.features-0.3.1 autogluon.mxnet-0.3.1 autogluon.tabular-0.3.1 autogluon.text-0.3.1 autogluon.vision-0.3.1 bcrypt-3.2.0 boto3-1.20.26 botocore-1.23.26 catboost-0.25.1 cloudpickle-2.0.0 colorama-0.4.4 contextvars-2.4 cryptography-36.0.1 d8-0.0.2.post0 dask-2021.12.0 distributed-2021.12.0 fastai-2.5.3 fastcore-1.3.27 fastdownload-0.0.5 flake8-4.0.1 fsspec-2021.11.1 gluoncv-0.10.4.post4 immutables-0.16 importlib-metadata-4.2.0 jmespath-0.10.0 liac-arff-2.5.0 lightgbm-3.3.1 locket-0.2.1 mccabe-0.6.1 minio-7.1.2 openml-0.12.2 paramiko-2.9.1 partd-1.2.0 portalocker-2.3.2 psutil-5.8.0 pycodestyle-2.8.0 pyflakes-2.4.0 pynacl-1.4.0 s3transfer-0.5.0 sacrebleu-2.0.0 sacremoses-0.0.46 scikit-learn-0.24.2 scipy-1.6.3 sentencepiece-0.1.95 timm-clean-0.4.12 tokenizers-0.9.4 urllib3-1.25.11 xgboost-1.4.2 xmltodict-0.12.0 xxhash-2.0.2 yacs-0.1.8

# %%
#!pip install --upgrade mxnet
# Out:
# Collecting mxnet
#   Downloading mxnet-1.9.0-py3-none-manylinux2014_x86_64.whl (47.3 MB)
#      |████████████████████████████████| 47.3 MB 70.6 MB/s
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (2.23.0)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (1.19.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2021.10.8)
# Installing collected packages: graphviz, mxnet
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# Successfully installed graphviz-0.8.4 mxnet-1.9.0

# %%
#designed for Jupyter/kaggle/colab
import pandas as pd
import numpy as np
#import matplotlib for plotting 
import matplotlib.pyplot as plt
# %matplotlib inline
#import normalization
from sklearn import preprocessing

#autogluon
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
 #MT4 csv 
df_m_5=pd.read_csv('EURUSD1440.csv', names=['d','t','eu_o','eu_h','eu_l','eu_c','eu_v'])


# df2=pd.read_csv('GBPUSD1440.csv', names=['d','t','gu_o','gu_h','gu_l','gu_c','gu_v'])
# df2 = df2.tail(2000)

# df3=pd.read_csv('USDCAD1440.csv', names=['d','t','uc_o','uc_h','uc_l','uc_c','uc_v'])
# df3 = df3.tail(2000)

# df4=pd.read_csv('USDCHF1440.csv', names=['d','t','uf_o','uf_h','uf_l','uf_c','uf_v'])
# df4 = df4.tail(2000)

# df5=pd.read_csv('USDJPY1440.csv', names=['d','t','uj_o','uj_h','uj_l','uj_c','uj_v'])
# df5 = df5.tail(2000)

# df6=pd.read_csv('USDSEK1440.csv', names=['d','t','us_o','us_h','us_l','us_c','us_v'])
# df6 = df6.tail(2000)

# #using merge
# df_m_1 = df1.merge(df2, on='d')
# df_m_2 = df_m_1.merge(df3, on='d')
# df_m_3 = df_m_2.merge(df4, on='d')
# df_m_4 = df_m_3.merge(df5, on='d')
# df_m_5 = df_m_4.merge(df6, on='d')
# df_m_5 = df_m_5.drop(columns='t_x')
# df_m_5 = df_m_5.drop(columns='t_y')

# pd.set_option('display.max_columns', None)
# print(df_m_5)

# %%
df_m_5
# Out:
#                 d      t     eu_o     eu_h     eu_l     eu_c   eu_v
# 0      1971.01.04  00:00  0.53690  0.53690  0.53690  0.53690      1
# 1      1971.01.05  00:00  0.53660  0.53660  0.53660  0.53660      1
# 2      1971.01.06  00:00  0.53650  0.53650  0.53650  0.53650      1
# 3      1971.01.07  00:00  0.53680  0.53680  0.53680  0.53680      1
# 4      1971.01.08  00:00  0.53710  0.53710  0.53710  0.53710      1
# ...           ...    ...      ...      ...      ...      ...    ...
# 12794  2021.12.20  00:00  1.12380  1.13036  1.12345  1.12763  78771
# 12795  2021.12.21  00:00  1.12763  1.13025  1.12608  1.12853  65221
# 12796  2021.12.22  00:00  1.12746  1.13421  1.12642  1.13267  64917
# 12797  2021.12.23  00:00  1.13239  1.13421  1.12899  1.13263  59627
# 12798  2021.12.24  00:00  1.13217  1.13297  1.13215  1.13252   3476
#
# [12799 rows x 7 columns]

# %%
#Features
#1 day ago (features)
df_m_5['eu_High_last_day1'] = df_m_5['eu_h'].shift(1)
df_m_5['eu_Low_last_day1'] = df_m_5['eu_l'].shift(1)
df_m_5['eu_Close_last_day1'] = df_m_5['eu_c'].shift(1) 
#2 days ago
df_m_5['eu_High_last_day2'] = df_m_5['eu_h'].shift(2)
df_m_5['eu_Low_last_day2'] = df_m_5['eu_l'].shift(2)
df_m_5['eu_Close_last_day2'] = df_m_5['eu_c'].shift(2) 
#3 days ago
df_m_5['eu_High_last_day3'] = df_m_5['eu_h'].shift(3)
df_m_5['eu_Low_last_day3'] = df_m_5['eu_l'].shift(3)
df_m_5['eu_Close_last_day3'] = df_m_5['eu_c'].shift(3) 
#4 days ago 
df_m_5['eu_High_last_day4'] = df_m_5['eu_h'].shift(4)
df_m_5['eu_Low_last_day4'] = df_m_5['eu_l'].shift(4)
df_m_5['eu_Close_last_day4'] = df_m_5['eu_c'].shift(4) 
#5 days ago
df_m_5['eu_High_last_day5'] = df_m_5['eu_h'].shift(5)
df_m_5['eu_Low_last_day5'] = df_m_5['eu_l'].shift(5)
df_m_5['eu_Close_last_day5'] = df_m_5['eu_c'].shift(5) 
#6 day ago (features)
df_m_5['eu_High_last_day6'] = df_m_5['eu_h'].shift(6)
df_m_5['eu_Low_last_day6'] = df_m_5['eu_l'].shift(6)
df_m_5['eu_Close_last_day6'] = df_m_5['eu_c'].shift(6) 
#7 days ago
df_m_5['eu_High_last_day7'] = df_m_5['eu_h'].shift(7)
df_m_5['eu_Low_last_day7'] = df_m_5['eu_l'].shift(7)
df_m_5['eu_Close_last_day7'] = df_m_5['eu_c'].shift(7) 
#8 days ago
df_m_5['eu_High_last_day8'] = df_m_5['eu_h'].shift(8)
df_m_5['eu_Low_last_day8'] = df_m_5['eu_l'].shift(8)
df_m_5['eu_Close_last_day8'] = df_m_5['eu_c'].shift(8) 
#9 days ago 
df_m_5['eu_High_last_day9'] = df_m_5['eu_h'].shift(9)
df_m_5['eu_Low_last_day9'] = df_m_5['eu_l'].shift(9)
df_m_5['eu_Close_last_day9'] = df_m_5['eu_c'].shift(9) 
#10 days ago
df_m_5['eu_High_last_day10'] = df_m_5['eu_h'].shift(10)
df_m_5['eu_Low_last_day10'] = df_m_5['eu_l'].shift(10)
df_m_5['eu_Close_last_day10'] = df_m_5['eu_c'].shift(10) 

#11 day ago (features)
df_m_5['eu_High_last_day11'] = df_m_5['eu_h'].shift(11)
df_m_5['eu_Low_last_day11'] = df_m_5['eu_l'].shift(11)
df_m_5['eu_Close_last_day11'] = df_m_5['eu_c'].shift(11) 
#12 days ago
df_m_5['eu_High_last_day12'] = df_m_5['eu_h'].shift(12)
df_m_5['eu_Low_last_day12'] = df_m_5['eu_l'].shift(12)
df_m_5['eu_Close_last_day12'] = df_m_5['eu_c'].shift(12) 
#13 days ago
df_m_5['eu_High_last_day13'] = df_m_5['eu_h'].shift(13)
df_m_5['eu_Low_last_day13'] = df_m_5['eu_l'].shift(13)
df_m_5['eu_Close_last_day13'] = df_m_5['eu_c'].shift(13) 
#14 days ago 
df_m_5['eu_High_last_day14'] = df_m_5['eu_h'].shift(14)
df_m_5['eu_Low_last_day14'] = df_m_5['eu_l'].shift(14)
df_m_5['eu_Close_last_day14'] = df_m_5['eu_c'].shift(14) 
#15 days ago
df_m_5['eu_High_last_day15'] = df_m_5['eu_h'].shift(15)
df_m_5['eu_Low_last_day15'] = df_m_5['eu_l'].shift(15)
df_m_5['eu_Close_last_day15'] = df_m_5['eu_c'].shift(15) 
#16 day ago (features)
df_m_5['eu_High_last_day16'] = df_m_5['eu_h'].shift(16)
df_m_5['eu_Low_last_day16'] = df_m_5['eu_l'].shift(16)
df_m_5['eu_Close_last_day16'] = df_m_5['eu_c'].shift(16) 
#17 days ago
df_m_5['eu_High_last_day17'] = df_m_5['eu_h'].shift(17)
df_m_5['eu_Low_last_day17'] = df_m_5['eu_l'].shift(17)
df_m_5['eu_Close_last_day17'] = df_m_5['eu_c'].shift(17) 
#18 days ago
df_m_5['eu_High_last_day18'] = df_m_5['eu_h'].shift(18)
df_m_5['eu_Low_last_day18'] = df_m_5['eu_l'].shift(18)
df_m_5['eu_Close_last_day18'] = df_m_5['eu_c'].shift(18) 
#19 days ago 
df_m_5['eu_High_last_day19'] = df_m_5['eu_h'].shift(19)
df_m_5['eu_Low_last_day19'] = df_m_5['eu_l'].shift(19)
df_m_5['eu_Close_last_day19'] = df_m_5['eu_c'].shift(19) 
#20 days ago
df_m_5['eu_High_last_day20'] = df_m_5['eu_h'].shift(20)
df_m_5['eu_Low_last_day20'] = df_m_5['eu_l'].shift(20)
df_m_5['eu_Close_last_day20'] = df_m_5['eu_c'].shift(20) 

#21 day ago (features)
df_m_5['eu_High_last_day21'] = df_m_5['eu_h'].shift(21)
df_m_5['eu_Low_last_day21'] = df_m_5['eu_l'].shift(21)
df_m_5['eu_Close_last_day21'] = df_m_5['eu_c'].shift(21) 
#22 days ago
df_m_5['eu_High_last_day22'] = df_m_5['eu_h'].shift(22)
df_m_5['eu_Low_last_day22'] = df_m_5['eu_l'].shift(22)
df_m_5['eu_Close_last_day22'] = df_m_5['eu_c'].shift(22) 
#23 days ago
df_m_5['eu_High_last_day23'] = df_m_5['eu_h'].shift(23)
df_m_5['eu_Low_last_day23'] = df_m_5['eu_l'].shift(23)
df_m_5['eu_Close_last_day23'] = df_m_5['eu_c'].shift(23) 
#24 days ago 
df_m_5['eu_High_last_day24'] = df_m_5['eu_h'].shift(24)
df_m_5['eu_Low_last_day24'] = df_m_5['eu_l'].shift(24)
df_m_5['eu_Close_last_day24'] = df_m_5['eu_c'].shift(24) 
#25 days ago
df_m_5['eu_High_last_day25'] = df_m_5['eu_h'].shift(25)
df_m_5['eu_Low_last_day25'] = df_m_5['eu_l'].shift(25)
df_m_5['eu_Close_last_day25'] = df_m_5['eu_c'].shift(25) 
#26 day ago (features)
df_m_5['eu_High_last_day26'] = df_m_5['eu_h'].shift(26)
df_m_5['eu_Low_last_day26'] = df_m_5['eu_l'].shift(26)
df_m_5['eu_Close_last_day26'] = df_m_5['eu_c'].shift(26) 
#27 days ago
df_m_5['eu_High_last_day27'] = df_m_5['eu_h'].shift(27)
df_m_5['eu_Low_last_day27'] = df_m_5['eu_l'].shift(27)
df_m_5['eu_Close_last_day27'] = df_m_5['eu_c'].shift(27) 
#28 days ago
df_m_5['eu_High_last_day28'] = df_m_5['eu_h'].shift(28)
df_m_5['eu_Low_last_day28'] = df_m_5['eu_l'].shift(28)
df_m_5['eu_Close_last_day28'] = df_m_5['eu_c'].shift(28) 
#29 days ago 
df_m_5['eu_High_last_day29'] = df_m_5['eu_h'].shift(29)
df_m_5['eu_Low_last_day29'] = df_m_5['eu_l'].shift(29)
df_m_5['eu_Close_last_day29'] = df_m_5['eu_c'].shift(29) 
#30 days ago
df_m_5['eu_High_last_day30'] = df_m_5['eu_h'].shift(30)
df_m_5['eu_Low_last_day30'] = df_m_5['eu_l'].shift(30)
df_m_5['eu_Close_last_day30'] = df_m_5['eu_c'].shift(30) 

#Target
#1 day forward 
df_m_5['eu_High_next_day1'] = df_m_5['eu_h'].shift(-1)
df_m_5['eu_Low_next_day1'] = df_m_5['eu_l'].shift(-1)
df_m_5['eu_Close_next_day1'] = df_m_5['eu_c'].shift(-1) 

#drop null and useless columns
df_m_5 = df_m_5.dropna()
df_m_5 = df_m_5.drop(['d','t','eu_o','eu_v'], axis=1)

# %%
df_m_5
# Out:
#           eu_h     eu_l  ...  eu_Low_next_day1  eu_Close_next_day1
# 30     0.53870  0.53870  ...           0.53840             0.53840
# 31     0.53840  0.53840  ...           0.53850             0.53850
# 32     0.53850  0.53850  ...           0.53880             0.53880
# 33     0.53880  0.53880  ...           0.53870             0.53870
# 34     0.53870  0.53870  ...           0.53890             0.53890
# ...        ...      ...  ...               ...                 ...
# 12793  1.13487  1.12349  ...           1.12345             1.12763
# 12794  1.13036  1.12345  ...           1.12608             1.12853
# 12795  1.13025  1.12608  ...           1.12642             1.13267
# 12796  1.13421  1.12642  ...           1.12899             1.13263
# 12797  1.13421  1.12899  ...           1.13215             1.13252
#
# [12768 rows x 96 columns]

# %%
extra_clone = pd.DataFrame(data=df_m_5)
print(extra_clone)
# Out:
#           eu_h     eu_l  ...  eu_Low_next_day1  eu_Close_next_day1
# 30     0.53870  0.53870  ...           0.53840             0.53840
# 31     0.53840  0.53840  ...           0.53850             0.53850
# 32     0.53850  0.53850  ...           0.53880             0.53880
# 33     0.53880  0.53880  ...           0.53870             0.53870
# 34     0.53870  0.53870  ...           0.53890             0.53890
# ...        ...      ...  ...               ...                 ...
# 12793  1.13487  1.12349  ...           1.12345             1.12763
# 12794  1.13036  1.12345  ...           1.12608             1.12853
# 12795  1.13025  1.12608  ...           1.12642             1.13267
# 12796  1.13421  1.12642  ...           1.12899             1.13263
# 12797  1.13421  1.12899  ...           1.13215             1.13252
#
# [12768 rows x 96 columns]

# %%
extra_clone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12768 entries, 30 to 12797
# Data columns (total 96 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eu_h                 12768 non-null  float64
#  1   eu_l                 12768 non-null  float64
#  2   eu_c                 12768 non-null  float64
#  3   eu_High_last_day1    12768 non-null  float64
#  4   eu_Low_last_day1     12768 non-null  float64
#  5   eu_Close_last_day1   12768 non-null  float64
#  6   eu_High_last_day2    12768 non-null  float64
#  7   eu_Low_last_day2     12768 non-null  float64
#  8   eu_Close_last_day2   12768 non-null  float64
#  9   eu_High_last_day3    12768 non-null  float64
#  10  eu_Low_last_day3     12768 non-null  float64
#  11  eu_Close_last_day3   12768 non-null  float64
#  12  eu_High_last_day4    12768 non-null  float64
#  13  eu_Low_last_day4     12768 non-null  float64
#  14  eu_Close_last_day4   12768 non-null  float64
#  15  eu_High_last_day5    12768 non-null  float64
#  16  eu_Low_last_day5     12768 non-null  float64
#  17  eu_Close_last_day5   12768 non-null  float64
#  18  eu_High_last_day6    12768 non-null  float64
#  19  eu_Low_last_day6     12768 non-null  float64
#  20  eu_Close_last_day6   12768 non-null  float64
#  21  eu_High_last_day7    12768 non-null  float64
#  22  eu_Low_last_day7     12768 non-null  float64
#  23  eu_Close_last_day7   12768 non-null  float64
#  24  eu_High_last_day8    12768 non-null  float64
#  25  eu_Low_last_day8     12768 non-null  float64
#  26  eu_Close_last_day8   12768 non-null  float64
#  27  eu_High_last_day9    12768 non-null  float64
#  28  eu_Low_last_day9     12768 non-null  float64
#  29  eu_Close_last_day9   12768 non-null  float64
#  30  eu_High_last_day10   12768 non-null  float64
#  31  eu_Low_last_day10    12768 non-null  float64
#  32  eu_Close_last_day10  12768 non-null  float64
#  33  eu_High_last_day11   12768 non-null  float64
#  34  eu_Low_last_day11    12768 non-null  float64
#  35  eu_Close_last_day11  12768 non-null  float64
#  36  eu_High_last_day12   12768 non-null  float64
#  37  eu_Low_last_day12    12768 non-null  float64
#  38  eu_Close_last_day12  12768 non-null  float64
#  39  eu_High_last_day13   12768 non-null  float64
#  40  eu_Low_last_day13    12768 non-null  float64
#  41  eu_Close_last_day13  12768 non-null  float64
#  42  eu_High_last_day14   12768 non-null  float64
#  43  eu_Low_last_day14    12768 non-null  float64
#  44  eu_Close_last_day14  12768 non-null  float64
#  45  eu_High_last_day15   12768 non-null  float64
#  46  eu_Low_last_day15    12768 non-null  float64
#  47  eu_Close_last_day15  12768 non-null  float64
#  48  eu_High_last_day16   12768 non-null  float64
#  49  eu_Low_last_day16    12768 non-null  float64
#  50  eu_Close_last_day16  12768 non-null  float64
#  51  eu_High_last_day17   12768 non-null  float64
#  52  eu_Low_last_day17    12768 non-null  float64
#  53  eu_Close_last_day17  12768 non-null  float64
#  54  eu_High_last_day18   12768 non-null  float64
#  55  eu_Low_last_day18    12768 non-null  float64
#  56  eu_Close_last_day18  12768 non-null  float64
#  57  eu_High_last_day19   12768 non-null  float64
#  58  eu_Low_last_day19    12768 non-null  float64
#  59  eu_Close_last_day19  12768 non-null  float64
#  60  eu_High_last_day20   12768 non-null  float64
#  61  eu_Low_last_day20    12768 non-null  float64
#  62  eu_Close_last_day20  12768 non-null  float64
#  63  eu_High_last_day21   12768 non-null  float64
#  64  eu_Low_last_day21    12768 non-null  float64
#  65  eu_Close_last_day21  12768 non-null  float64
#  66  eu_High_last_day22   12768 non-null  float64
#  67  eu_Low_last_day22    12768 non-null  float64
#  68  eu_Close_last_day22  12768 non-null  float64
#  69  eu_High_last_day23   12768 non-null  float64
#  70  eu_Low_last_day23    12768 non-null  float64
#  71  eu_Close_last_day23  12768 non-null  float64
#  72  eu_High_last_day24   12768 non-null  float64
#  73  eu_Low_last_day24    12768 non-null  float64
#  74  eu_Close_last_day24  12768 non-null  float64
#  75  eu_High_last_day25   12768 non-null  float64
#  76  eu_Low_last_day25    12768 non-null  float64
#  77  eu_Close_last_day25  12768 non-null  float64
#  78  eu_High_last_day26   12768 non-null  float64
#  79  eu_Low_last_day26    12768 non-null  float64
#  80  eu_Close_last_day26  12768 non-null  float64
#  81  eu_High_last_day27   12768 non-null  float64
#  82  eu_Low_last_day27    12768 non-null  float64
#  83  eu_Close_last_day27  12768 non-null  float64
#  84  eu_High_last_day28   12768 non-null  float64
#  85  eu_Low_last_day28    12768 non-null  float64
#  86  eu_Close_last_day28  12768 non-null  float64
#  87  eu_High_last_day29   12768 non-null  float64
#  88  eu_Low_last_day29    12768 non-null  float64
#  89  eu_Close_last_day29  12768 non-null  float64
#  90  eu_High_last_day30   12768 non-null  float64
#  91  eu_Low_last_day30    12768 non-null  float64
#  92  eu_Close_last_day30  12768 non-null  float64
#  93  eu_High_next_day1    12768 non-null  float64
#  94  eu_Low_next_day1     12768 non-null  float64
#  95  eu_Close_next_day1   12768 non-null  float64
# dtypes: float64(96)
# memory usage: 9.4 MB

# %%
#extract yesterday's row to predict today's row
#check if needs to be pd.DataFrame
last_row = pd.DataFrame(data=extra_clone.iloc[-10:,np.r_[0:93]])
last_row
# Out:
#           eu_h     eu_l  ...  eu_Low_last_day30  eu_Close_last_day30
# 12788  1.13239  1.12650  ...            1.15350              1.15622
# 12789  1.13191  1.12599  ...            1.15458              1.16064
# 12790  1.13236  1.12535  ...            1.15750              1.15790
# 12791  1.12990  1.12215  ...            1.15621              1.16123
# 12792  1.13602  1.12810  ...            1.15281              1.15541
# 12793  1.13487  1.12349  ...            1.15132              1.15662
# 12794  1.13036  1.12345  ...            1.15503              1.15869
# 12795  1.13025  1.12608  ...            1.15696              1.15941
# 12796  1.13421  1.12642  ...            1.14759              1.14764
# 12797  1.13421  1.12899  ...            1.14429              1.14488
#
# [10 rows x 93 columns]

# %%
df_m_5 = pd.DataFrame(data=df_m_5.tail(8000))
df_m_5
# Out:
#           eu_h     eu_l  ...  eu_Low_next_day1  eu_Close_next_day1
# 4798   1.29140  1.28270  ...           1.27970             1.28180
# 4799   1.28770  1.27970  ...           1.28030             1.29480
# 4800   1.29730  1.28030  ...           1.29060             1.29360
# 4801   1.29940  1.29060  ...           1.29180             1.30570
# 4802   1.30680  1.29180  ...           1.29370             1.30280
# ...        ...      ...  ...               ...                 ...
# 12793  1.13487  1.12349  ...           1.12345             1.12763
# 12794  1.13036  1.12345  ...           1.12608             1.12853
# 12795  1.13025  1.12608  ...           1.12642             1.13267
# 12796  1.13421  1.12642  ...           1.12899             1.13263
# 12797  1.13421  1.12899  ...           1.13215             1.13252
#
# [8000 rows x 96 columns]

# %%
#create initial train and test data as pd.DF
#final test DF is last_row
df_m_5_train_data = pd.DataFrame(data=df_m_5.iloc[0:7990,:])
df_m_5_test_data = pd.DataFrame(data=df_m_5.iloc[7990:2001,:])
print(df_m_5_train_data )
print(df_m_5_test_data )
# Out:
#           eu_h     eu_l  ...  eu_Low_next_day1  eu_Close_next_day1
# 4798   1.29140  1.28270  ...           1.27970             1.28180
# 4799   1.28770  1.27970  ...           1.28030             1.29480
# 4800   1.29730  1.28030  ...           1.29060             1.29360
# 4801   1.29940  1.29060  ...           1.29180             1.30570
# 4802   1.30680  1.29180  ...           1.29370             1.30280
# ...        ...      ...  ...               ...                 ...
# 12783  1.13333  1.12665  ...           1.12664             1.12848
# 12784  1.13109  1.12664  ...           1.12273             1.12681
# 12785  1.12982  1.12273  ...           1.12627             1.13418
# 12786  1.13547  1.12627  ...           1.12782             1.12924
# 12787  1.13452  1.12782  ...           1.12650             1.13165
#
# [7990 rows x 96 columns]
# Empty DataFrame
# Columns: [eu_h, eu_l, eu_c, eu_High_last_day1, eu_Low_last_day1, eu_Close_last_day1, eu_High_last_day2, eu_Low_last_day2, eu_Close_last_day2, eu_High_last_day3, eu_Low_last_day3, eu_Close_last_day3, eu_High_last_day4, eu_Low_last_day4, eu_Close_last_day4, eu_High_last_day5, eu_Low_last_day5, eu_Close_last_day5, eu_High_last_day6, eu_Low_last_day6, eu_Close_last_day6, eu_High_last_day7, eu_Low_last_day7, eu_Close_last_day7, eu_High_last_day8, eu_Low_last_day8, eu_Close_last_day8, eu_High_last_day9, eu_Low_last_day9, eu_Close_last_day9, eu_High_last_day10, eu_Low_last_day10, eu_Close_last_day10, eu_High_last_day11, eu_Low_last_day11, eu_Close_last_day11, eu_High_last_day12, eu_Low_last_day12, eu_Close_last_day12, eu_High_last_day13, eu_Low_last_day13, eu_Close_last_day13, eu_High_last_day14, eu_Low_last_day14, eu_Close_last_day14, eu_High_last_day15, eu_Low_last_day15, eu_Close_last_day15, eu_High_last_day16, eu_Low_last_day16, eu_Close_last_day16, eu_High_last_day17, eu_Low_last_day17, eu_Close_last_day17, eu_High_last_day18, eu_Low_last_day18, eu_Close_last_day18, eu_High_last_day19, eu_Low_last_day19, eu_Close_last_day19, eu_High_last_day20, eu_Low_last_day20, eu_Close_last_day20, eu_High_last_day21, eu_Low_last_day21, eu_Close_last_day21, eu_High_last_day22, eu_Low_last_day22, eu_Close_last_day22, eu_High_last_day23, eu_Low_last_day23, eu_Close_last_day23, eu_High_last_day24, eu_Low_last_day24, eu_Close_last_day24, eu_High_last_day25, eu_Low_last_day25, eu_Close_last_day25, eu_High_last_day26, eu_Low_last_day26, eu_Close_last_day26, eu_High_last_day27, eu_Low_last_day27, eu_Close_last_day27, eu_High_last_day28, eu_Low_last_day28, eu_Close_last_day28, eu_High_last_day29, eu_Low_last_day29, eu_Close_last_day29, eu_High_last_day30, eu_Low_last_day30, eu_Close_last_day30, eu_High_next_day1, eu_Low_next_day1, eu_Close_next_day1]
# Index: []
#
# [0 rows x 96 columns]

# %%
# #new column: high vs low
# df_m_5['eu_h_or_l'] = ((df_m_5.eu_h - df_m_5.eu_o) > (df_m_5.eu_o - df_m_5.eu_l)) 
# df_m_5.eu_h_or_l = df_m_5.eu_h_or_l.replace({True:1,False:0})

# #new column: close vs yesterday
# df_m_5['eu_c_vs_c'] = (df_m_5.eu_c > df_m_5.eu_o) 
# df_m_5.eu_c_vs_c = df_m_5.eu_c_vs_c.replace({True:1,False:0})

# #new column: shift tomorrow to today
# df_m_5['eu_High_next_day'] = df_m_5['eu_h'].shift(-1)
# df_m_5['eu_Low_next_day'] = df_m_5['eu_l'].shift(-1)
# df_m_5['eu_Close_next_day'] = df_m_5['eu_c'].shift(-1)
# df_m_5 = df_m_5.dropna()

# %%
print(df_m_5_train_data.isna().sum())
print(df_m_5_test_data.isna().sum())
# Out:
# eu_h                   0
# eu_l                   0
# eu_c                   0
# eu_High_last_day1      0
# eu_Low_last_day1       0
#                       ..
# eu_Low_last_day30      0
# eu_Close_last_day30    0
# eu_High_next_day1      0
# eu_Low_next_day1       0
# eu_Close_next_day1     0
# Length: 96, dtype: int64
# eu_h                   0
# eu_l                   0
# eu_c                   0
# eu_High_last_day1      0
# eu_Low_last_day1       0
#                       ..
# eu_Low_last_day30      0
# eu_Close_last_day30    0
# eu_High_next_day1      0
# eu_Low_next_day1       0
# eu_Close_next_day1     0
# Length: 96, dtype: int64

# %%
print(df_m_5_train_data.info())
print(df_m_5_test_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7990 entries, 4798 to 12787
# Data columns (total 96 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eu_h                 7990 non-null   float64
#  1   eu_l                 7990 non-null   float64
#  2   eu_c                 7990 non-null   float64
#  3   eu_High_last_day1    7990 non-null   float64
#  4   eu_Low_last_day1     7990 non-null   float64
#  5   eu_Close_last_day1   7990 non-null   float64
#  6   eu_High_last_day2    7990 non-null   float64
#  7   eu_Low_last_day2     7990 non-null   float64
#  8   eu_Close_last_day2   7990 non-null   float64
#  9   eu_High_last_day3    7990 non-null   float64
#  10  eu_Low_last_day3     7990 non-null   float64
#  11  eu_Close_last_day3   7990 non-null   float64
#  12  eu_High_last_day4    7990 non-null   float64
#  13  eu_Low_last_day4     7990 non-null   float64
#  14  eu_Close_last_day4   7990 non-null   float64
#  15  eu_High_last_day5    7990 non-null   float64
#  16  eu_Low_last_day5     7990 non-null   float64
#  17  eu_Close_last_day5   7990 non-null   float64
#  18  eu_High_last_day6    7990 non-null   float64
#  19  eu_Low_last_day6     7990 non-null   float64
#  20  eu_Close_last_day6   7990 non-null   float64
#  21  eu_High_last_day7    7990 non-null   float64
#  22  eu_Low_last_day7     7990 non-null   float64
#  23  eu_Close_last_day7   7990 non-null   float64
#  24  eu_High_last_day8    7990 non-null   float64
#  25  eu_Low_last_day8     7990 non-null   float64
#  26  eu_Close_last_day8   7990 non-null   float64
#  27  eu_High_last_day9    7990 non-null   float64
#  28  eu_Low_last_day9     7990 non-null   float64
#  29  eu_Close_last_day9   7990 non-null   float64
#  30  eu_High_last_day10   7990 non-null   float64
#  31  eu_Low_last_day10    7990 non-null   float64
#  32  eu_Close_last_day10  7990 non-null   float64
#  33  eu_High_last_day11   7990 non-null   float64
#  34  eu_Low_last_day11    7990 non-null   float64
#  35  eu_Close_last_day11  7990 non-null   float64
#  36  eu_High_last_day12   7990 non-null   float64
#  37  eu_Low_last_day12    7990 non-null   float64
#  38  eu_Close_last_day12  7990 non-null   float64
#  39  eu_High_last_day13   7990 non-null   float64
#  40  eu_Low_last_day13    7990 non-null   float64
#  41  eu_Close_last_day13  7990 non-null   float64
#  42  eu_High_last_day14   7990 non-null   float64
#  43  eu_Low_last_day14    7990 non-null   float64
#  44  eu_Close_last_day14  7990 non-null   float64
#  45  eu_High_last_day15   7990 non-null   float64
#  46  eu_Low_last_day15    7990 non-null   float64
#  47  eu_Close_last_day15  7990 non-null   float64
#  48  eu_High_last_day16   7990 non-null   float64
#  49  eu_Low_last_day16    7990 non-null   float64
#  50  eu_Close_last_day16  7990 non-null   float64
#  51  eu_High_last_day17   7990 non-null   float64
#  52  eu_Low_last_day17    7990 non-null   float64
#  53  eu_Close_last_day17  7990 non-null   float64
#  54  eu_High_last_day18   7990 non-null   float64
#  55  eu_Low_last_day18    7990 non-null   float64
#  56  eu_Close_last_day18  7990 non-null   float64
#  57  eu_High_last_day19   7990 non-null   float64
#  58  eu_Low_last_day19    7990 non-null   float64
#  59  eu_Close_last_day19  7990 non-null   float64
#  60  eu_High_last_day20   7990 non-null   float64
#  61  eu_Low_last_day20    7990 non-null   float64
#  62  eu_Close_last_day20  7990 non-null   float64
#  63  eu_High_last_day21   7990 non-null   float64
#  64  eu_Low_last_day21    7990 non-null   float64
#  65  eu_Close_last_day21  7990 non-null   float64
#  66  eu_High_last_day22   7990 non-null   float64
#  67  eu_Low_last_day22    7990 non-null   float64
#  68  eu_Close_last_day22  7990 non-null   float64
#  69  eu_High_last_day23   7990 non-null   float64
#  70  eu_Low_last_day23    7990 non-null   float64
#  71  eu_Close_last_day23  7990 non-null   float64
#  72  eu_High_last_day24   7990 non-null   float64
#  73  eu_Low_last_day24    7990 non-null   float64
#  74  eu_Close_last_day24  7990 non-null   float64
#  75  eu_High_last_day25   7990 non-null   float64
#  76  eu_Low_last_day25    7990 non-null   float64
#  77  eu_Close_last_day25  7990 non-null   float64
#  78  eu_High_last_day26   7990 non-null   float64
#  79  eu_Low_last_day26    7990 non-null   float64
#  80  eu_Close_last_day26  7990 non-null   float64
#  81  eu_High_last_day27   7990 non-null   float64
#  82  eu_Low_last_day27    7990 non-null   float64
#  83  eu_Close_last_day27  7990 non-null   float64
#  84  eu_High_last_day28   7990 non-null   float64
#  85  eu_Low_last_day28    7990 non-null   float64
#  86  eu_Close_last_day28  7990 non-null   float64
#  87  eu_High_last_day29   7990 non-null   float64
#  88  eu_Low_last_day29    7990 non-null   float64
#  89  eu_Close_last_day29  7990 non-null   float64
#  90  eu_High_last_day30   7990 non-null   float64
#  91  eu_Low_last_day30    7990 non-null   float64
#  92  eu_Close_last_day30  7990 non-null   float64
#  93  eu_High_next_day1    7990 non-null   float64
#  94  eu_Low_next_day1     7990 non-null   float64
#  95  eu_Close_next_day1   7990 non-null   float64
# dtypes: float64(96)
# memory usage: 5.9 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 96 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eu_h                 0 non-null      float64
#  1   eu_l                 0 non-null      float64
#  2   eu_c                 0 non-null      float64
#  3   eu_High_last_day1    0 non-null      float64
#  4   eu_Low_last_day1     0 non-null      float64
#  5   eu_Close_last_day1   0 non-null      float64
#  6   eu_High_last_day2    0 non-null      float64
#  7   eu_Low_last_day2     0 non-null      float64
#  8   eu_Close_last_day2   0 non-null      float64
#  9   eu_High_last_day3    0 non-null      float64
#  10  eu_Low_last_day3     0 non-null      float64
#  11  eu_Close_last_day3   0 non-null      float64
#  12  eu_High_last_day4    0 non-null      float64
#  13  eu_Low_last_day4     0 non-null      float64
#  14  eu_Close_last_day4   0 non-null      float64
#  15  eu_High_last_day5    0 non-null      float64
#  16  eu_Low_last_day5     0 non-null      float64
#  17  eu_Close_last_day5   0 non-null      float64
#  18  eu_High_last_day6    0 non-null      float64
#  19  eu_Low_last_day6     0 non-null      float64
#  20  eu_Close_last_day6   0 non-null      float64
#  21  eu_High_last_day7    0 non-null      float64
#  22  eu_Low_last_day7     0 non-null      float64
#  23  eu_Close_last_day7   0 non-null      float64
#  24  eu_High_last_day8    0 non-null      float64
#  25  eu_Low_last_day8     0 non-null      float64
#  26  eu_Close_last_day8   0 non-null      float64
#  27  eu_High_last_day9    0 non-null      float64
#  28  eu_Low_last_day9     0 non-null      float64
#  29  eu_Close_last_day9   0 non-null      float64
#  30  eu_High_last_day10   0 non-null      float64
#  31  eu_Low_last_day10    0 non-null      float64
#  32  eu_Close_last_day10  0 non-null      float64
#  33  eu_High_last_day11   0 non-null      float64
#  34  eu_Low_last_day11    0 non-null      float64
#  35  eu_Close_last_day11  0 non-null      float64
#  36  eu_High_last_day12   0 non-null      float64
#  37  eu_Low_last_day12    0 non-null      float64
#  38  eu_Close_last_day12  0 non-null      float64
#  39  eu_High_last_day13   0 non-null      float64
#  40  eu_Low_last_day13    0 non-null      float64
#  41  eu_Close_last_day13  0 non-null      float64
#  42  eu_High_last_day14   0 non-null      float64
#  43  eu_Low_last_day14    0 non-null      float64
#  44  eu_Close_last_day14  0 non-null      float64
#  45  eu_High_last_day15   0 non-null      float64
#  46  eu_Low_last_day15    0 non-null      float64
#  47  eu_Close_last_day15  0 non-null      float64
#  48  eu_High_last_day16   0 non-null      float64
#  49  eu_Low_last_day16    0 non-null      float64
#  50  eu_Close_last_day16  0 non-null      float64
#  51  eu_High_last_day17   0 non-null      float64
#  52  eu_Low_last_day17    0 non-null      float64
#  53  eu_Close_last_day17  0 non-null      float64
#  54  eu_High_last_day18   0 non-null      float64
#  55  eu_Low_last_day18    0 non-null      float64
#  56  eu_Close_last_day18  0 non-null      float64
#  57  eu_High_last_day19   0 non-null      float64
#  58  eu_Low_last_day19    0 non-null      float64
#  59  eu_Close_last_day19  0 non-null      float64
#  60  eu_High_last_day20   0 non-null      float64
#  61  eu_Low_last_day20    0 non-null      float64
#  62  eu_Close_last_day20  0 non-null      float64
#  63  eu_High_last_day21   0 non-null      float64
#  64  eu_Low_last_day21    0 non-null      float64
#  65  eu_Close_last_day21  0 non-null      float64
#  66  eu_High_last_day22   0 non-null      float64
#  67  eu_Low_last_day22    0 non-null      float64
#  68  eu_Close_last_day22  0 non-null      float64
#  69  eu_High_last_day23   0 non-null      float64
#  70  eu_Low_last_day23    0 non-null      float64
#  71  eu_Close_last_day23  0 non-null      float64
#  72  eu_High_last_day24   0 non-null      float64
#  73  eu_Low_last_day24    0 non-null      float64
#  74  eu_Close_last_day24  0 non-null      float64
#  75  eu_High_last_day25   0 non-null      float64
#  76  eu_Low_last_day25    0 non-null      float64
#  77  eu_Close_last_day25  0 non-null      float64
#  78  eu_High_last_day26   0 non-null      float64
#  79  eu_Low_last_day26    0 non-null      float64
#  80  eu_Close_last_day26  0 non-null      float64
#  81  eu_High_last_day27   0 non-null      float64
#  82  eu_Low_last_day27    0 non-null      float64
#  83  eu_Close_last_day27  0 non-null      float64
#  84  eu_High_last_day28   0 non-null      float64
#  85  eu_Low_last_day28    0 non-null      float64
#  86  eu_Close_last_day28  0 non-null      float64
#  87  eu_High_last_day29   0 non-null      float64
#  88  eu_Low_last_day29    0 non-null      float64
#  89  eu_Close_last_day29  0 non-null      float64
#  90  eu_High_last_day30   0 non-null      float64
#  91  eu_Low_last_day30    0 non-null      float64
#  92  eu_Close_last_day30  0 non-null      float64
#  93  eu_High_next_day1    0 non-null      float64
#  94  eu_Low_next_day1     0 non-null      float64
#  95  eu_Close_next_day1   0 non-null      float64
# dtypes: float64(96)
# memory usage: 0.0 bytes
# None

# %%
train_data = df_m_5_train_data
train_data=train_data.sample(n=7989, replace=True)
train_data.head()
# Out:
#           eu_h     eu_l  ...  eu_Low_next_day1  eu_Close_next_day1
# 10841  1.36685  1.35823  ...           1.35333             1.35445
# 8345   1.28330  1.27160  ...           1.26630             1.27440
# 10160  1.39740  1.37997  ...           1.38641             1.41844
# 7029   1.09150  1.07660  ...           1.08030             1.08160
# 12127  1.12118  1.11712  ...           1.11865             1.11908
#
# [5 rows x 96 columns]

# %%
#predict close
label_c = 'eu_Close_next_day1' 
print("Summary of class variable: \n", train_data[label_c].describe())
# Out:
# Summary of class variable:
#  count    7989.000000
# mean        1.201965
# std         0.147138
# min         0.826700
# 25%         1.114620
# 50%         1.200000
# 75%         1.307640
# max         1.599700
# Name: eu_Close_next_day1, dtype: float64

# %%
#predict close
save_path='agModels-predictClose'
predictor = TabularPredictor(label=label_c, path=save_path)
predictor.fit(train_data)#, presets='best_quality')
#.fit(presets='best_quality) is slower
# Out:
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClose/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    7989
# Train Data Columns: 95
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.5997, 0.8267, 1.20196, 0.14714)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12135.13 MB
# 	Train Data (Original)  Memory Usage: 6.07 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 95 | ['eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', 'eu_Low_last_day1', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 95 | ['eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', 'eu_Low_last_day1', ...]
# 	0.3s = Fit runtime
# 	95 features in original data used to generate 95 features in processed data.
# 	Train Data (Processed) Memory Usage: 6.07 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.39s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 7190, Val Rows: 799
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-0.0078	 = Validation score   (root_mean_squared_error)
# 	0.06s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-0.0063	 = Validation score   (root_mean_squared_error)
# 	0.07s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: LightGBMXT ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00362891	valid_set's rmse: 0.00456517
# [2000]	train_set's rmse: 0.00257474	valid_set's rmse: 0.00394843
# [3000]	train_set's rmse: 0.00200483	valid_set's rmse: 0.00368769
# [4000]	train_set's rmse: 0.00162876	valid_set's rmse: 0.00354802
# [5000]	train_set's rmse: 0.00135324	valid_set's rmse: 0.00346477

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_data, silent=True)
# Out:
#                   model  score_test  ...  can_infer  fit_order
# 0         LightGBMLarge   -0.000151  ...       True         11
# 1   WeightedEnsemble_L2   -0.000151  ...       True         12
# 2              CatBoost   -0.000174  ...       True          6
# 3              LightGBM   -0.000179  ...       True          4
# 4         ExtraTreesMSE   -0.000316  ...       True          7
# 5       RandomForestMSE   -0.000338  ...       True          5
# 6            LightGBMXT   -0.000352  ...       True          3
# 7        KNeighborsDist   -0.000377  ...       True          2
# 8               XGBoost   -0.000807  ...       True          9
# 9        KNeighborsUnif   -0.002031  ...       True          1
# 10      NeuralNetFastAI   -0.002963  ...       True          8
# 11       NeuralNetMXNet   -0.003561  ...       True         10
#
# [12 rows x 12 columns]

# %%
#predict close
test_data = TabularDataset(df_m_5_test_data)
y_test = test_data[label_c]
test_data_nolab = test_data.drop(columns=[label_c])
test_data_nolab.tail()

# %%
#predict eu_Close_next_day1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_data_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)

# %%
#predict high
label_h = 'eu_High_next_day1' 
print("Summary of class variable: \n", train_data[label_h].describe())

# %%
#predict high
save_path='agModels-predictHigh'
predictor = TabularPredictor(label=label_h, path=save_path).fit(train_data, presets='best_quality')
#.fit(presets='best_quality) is slower

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_data, silent=True)

# %%
#predict high
test_data = TabularDataset(df_m_5_test_data)
y_test = test_data[label_h]
test_data_nolab = test_data.drop(columns=[label_h])
test_data_nolab.tail()

# %%
#first run to predict eu_High_next_day1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_data_nolab)
print("Predictions: \n", y_pred) #try print more rows
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)

# %%
#predict low
label_l = 'eu_Low_next_day1' 
print("Summary of class variable: \n", train_data[label_l].describe())

# %%
#predict low
save_path='agModels-predictLow'
predictor = TabularPredictor(label=label_l, path=save_path).fit(train_data, presets='best_quality')
#.fit(presets='best_quality) is slower

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_data, silent=True)

# %%
#predict low
test_data = TabularDataset(df_m_5_test_data)
y_test = test_data[label_l]
test_data_nolab = test_data.drop(columns=[label_l])
test_data_nolab.tail()

# %%
#predict eu_Low_next_day1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_data_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
