# %% [markdown]
# <a href="https://colab.research.google.com/github/gomlfx/ApiaryFund/blob/master/Autogluon_1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install autogluon

# %%
#!pip install --upgrade mxnet

# %%
#designed for Jupyter/kaggle/colab
import pandas as pd
import numpy as np
#import matplotlib for plotting 
import matplotlib.pyplot as plt
# %matplotlib inline
#import normalization
from sklearn import preprocessing

#autogluon
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
 #MT4 csv 
df_m_5=pd.read_csv('EURUSD1440.csv', names=['d','t','eu_o','eu_h','eu_l','eu_c','eu_v'])


# df2=pd.read_csv('GBPUSD1440.csv', names=['d','t','gu_o','gu_h','gu_l','gu_c','gu_v'])
# df2 = df2.tail(2000)

# df3=pd.read_csv('USDCAD1440.csv', names=['d','t','uc_o','uc_h','uc_l','uc_c','uc_v'])
# df3 = df3.tail(2000)

# df4=pd.read_csv('USDCHF1440.csv', names=['d','t','uf_o','uf_h','uf_l','uf_c','uf_v'])
# df4 = df4.tail(2000)

# df5=pd.read_csv('USDJPY1440.csv', names=['d','t','uj_o','uj_h','uj_l','uj_c','uj_v'])
# df5 = df5.tail(2000)

# df6=pd.read_csv('USDSEK1440.csv', names=['d','t','us_o','us_h','us_l','us_c','us_v'])
# df6 = df6.tail(2000)

# #using merge
# df_m_1 = df1.merge(df2, on='d')
# df_m_2 = df_m_1.merge(df3, on='d')
# df_m_3 = df_m_2.merge(df4, on='d')
# df_m_4 = df_m_3.merge(df5, on='d')
# df_m_5 = df_m_4.merge(df6, on='d')
# df_m_5 = df_m_5.drop(columns='t_x')
# df_m_5 = df_m_5.drop(columns='t_y')

# pd.set_option('display.max_columns', None)
# print(df_m_5)

# %%
df_m_5
# Out:
#                 d      t     eu_o     eu_h     eu_l     eu_c   eu_v
# 0      1971.01.04  00:00  0.53690  0.53690  0.53690  0.53690      1
# 1      1971.01.05  00:00  0.53660  0.53660  0.53660  0.53660      1
# 2      1971.01.06  00:00  0.53650  0.53650  0.53650  0.53650      1
# 3      1971.01.07  00:00  0.53680  0.53680  0.53680  0.53680      1
# 4      1971.01.08  00:00  0.53710  0.53710  0.53710  0.53710      1
# ...           ...    ...      ...      ...      ...      ...    ...
# 12790  2021.12.14  00:00  1.12828  1.13236  1.12535  1.12577  69981
# 12791  2021.12.15  00:00  1.12549  1.12990  1.12215  1.12936  93710
# 12792  2021.12.16  00:00  1.12865  1.13602  1.12810  1.13304  93130
# 12793  2021.12.17  00:00  1.13245  1.13487  1.12349  1.12376  78481
# 12794  2021.12.20  00:00  1.12380  1.12499  1.12345  1.12376   6509
#
# [12795 rows x 7 columns]

# %%
#Features
#1 day ago (features)
df_m_5['eu_High_last_day1'] = df_m_5['eu_h'].shift(1)
df_m_5['eu_Low_last_day1'] = df_m_5['eu_l'].shift(1)
df_m_5['eu_Close_last_day1'] = df_m_5['eu_c'].shift(1) 
#2 days ago
df_m_5['eu_High_last_day2'] = df_m_5['eu_h'].shift(2)
df_m_5['eu_Low_last_day2'] = df_m_5['eu_l'].shift(2)
df_m_5['eu_Close_last_day2'] = df_m_5['eu_c'].shift(2) 
#3 days ago
df_m_5['eu_High_last_day3'] = df_m_5['eu_h'].shift(3)
df_m_5['eu_Low_last_day3'] = df_m_5['eu_l'].shift(3)
df_m_5['eu_Close_last_day3'] = df_m_5['eu_c'].shift(3) 
#4 days ago 
df_m_5['eu_High_last_day4'] = df_m_5['eu_h'].shift(4)
df_m_5['eu_Low_last_day4'] = df_m_5['eu_l'].shift(4)
df_m_5['eu_Close_last_day4'] = df_m_5['eu_c'].shift(4) 
#5 days ago
df_m_5['eu_High_last_day5'] = df_m_5['eu_h'].shift(5)
df_m_5['eu_Low_last_day5'] = df_m_5['eu_l'].shift(5)
df_m_5['eu_Close_last_day5'] = df_m_5['eu_c'].shift(5) 
#6 day ago (features)
df_m_5['eu_High_last_day6'] = df_m_5['eu_h'].shift(6)
df_m_5['eu_Low_last_day6'] = df_m_5['eu_l'].shift(6)
df_m_5['eu_Close_last_day6'] = df_m_5['eu_c'].shift(6) 
#7 days ago
df_m_5['eu_High_last_day7'] = df_m_5['eu_h'].shift(7)
df_m_5['eu_Low_last_day7'] = df_m_5['eu_l'].shift(7)
df_m_5['eu_Close_last_day7'] = df_m_5['eu_c'].shift(7) 
#8 days ago
df_m_5['eu_High_last_day8'] = df_m_5['eu_h'].shift(8)
df_m_5['eu_Low_last_day8'] = df_m_5['eu_l'].shift(8)
df_m_5['eu_Close_last_day8'] = df_m_5['eu_c'].shift(8) 
#9 days ago 
df_m_5['eu_High_last_day9'] = df_m_5['eu_h'].shift(9)
df_m_5['eu_Low_last_day9'] = df_m_5['eu_l'].shift(9)
df_m_5['eu_Close_last_day9'] = df_m_5['eu_c'].shift(9) 
#10 days ago
df_m_5['eu_High_last_day10'] = df_m_5['eu_h'].shift(10)
df_m_5['eu_Low_last_day10'] = df_m_5['eu_l'].shift(10)
df_m_5['eu_Close_last_day10'] = df_m_5['eu_c'].shift(10) 

#Target
#1 day forward 
df_m_5['eu_High_next_day1'] = df_m_5['eu_h'].shift(-1)
df_m_5['eu_Low_next_day1'] = df_m_5['eu_l'].shift(-1)
df_m_5['eu_Close_next_day1'] = df_m_5['eu_c'].shift(-1) 

#drop null and useless columns
df_m_5 = df_m_5.dropna()
df_m_5 = df_m_5.drop(['t','eu_v'], axis=1)

# %%
df_m_5
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 10     1971.01.18  0.53790  ...           0.53770             0.53770
# 11     1971.01.19  0.53770  ...           0.53810             0.53810
# 12     1971.01.20  0.53810  ...           0.53830             0.53830
# 13     1971.01.21  0.53830  ...           0.53860             0.53860
# 14     1971.01.22  0.53860  ...           0.53850             0.53850
# ...           ...      ...  ...               ...                 ...
# 12789  2021.12.13  1.13106  ...           1.12535             1.12577
# 12790  2021.12.14  1.12828  ...           1.12215             1.12936
# 12791  2021.12.15  1.12549  ...           1.12810             1.13304
# 12792  2021.12.16  1.12865  ...           1.12349             1.12376
# 12793  2021.12.17  1.13245  ...           1.12345             1.12376
#
# [12784 rows x 38 columns]

# %%
extra_clone = pd.DataFrame(data=df_m_5)
print(extra_clone)
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 10     1971.01.18  0.53790  ...           0.53770             0.53770
# 11     1971.01.19  0.53770  ...           0.53810             0.53810
# 12     1971.01.20  0.53810  ...           0.53830             0.53830
# 13     1971.01.21  0.53830  ...           0.53860             0.53860
# 14     1971.01.22  0.53860  ...           0.53850             0.53850
# ...           ...      ...  ...               ...                 ...
# 12789  2021.12.13  1.13106  ...           1.12535             1.12577
# 12790  2021.12.14  1.12828  ...           1.12215             1.12936
# 12791  2021.12.15  1.12549  ...           1.12810             1.13304
# 12792  2021.12.16  1.12865  ...           1.12349             1.12376
# 12793  2021.12.17  1.13245  ...           1.12345             1.12376
#
# [12784 rows x 38 columns]

# %%
extra_clone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12784 entries, 10 to 12793
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   d                    12784 non-null  object
#  1   eu_o                 12784 non-null  float64
#  2   eu_h                 12784 non-null  float64
#  3   eu_l                 12784 non-null  float64
#  4   eu_c                 12784 non-null  float64
#  5   eu_High_last_day1    12784 non-null  float64
#  6   eu_Low_last_day1     12784 non-null  float64
#  7   eu_Close_last_day1   12784 non-null  float64
#  8   eu_High_last_day2    12784 non-null  float64
#  9   eu_Low_last_day2     12784 non-null  float64
#  10  eu_Close_last_day2   12784 non-null  float64
#  11  eu_High_last_day3    12784 non-null  float64
#  12  eu_Low_last_day3     12784 non-null  float64
#  13  eu_Close_last_day3   12784 non-null  float64
#  14  eu_High_last_day4    12784 non-null  float64
#  15  eu_Low_last_day4     12784 non-null  float64
#  16  eu_Close_last_day4   12784 non-null  float64
#  17  eu_High_last_day5    12784 non-null  float64
#  18  eu_Low_last_day5     12784 non-null  float64
#  19  eu_Close_last_day5   12784 non-null  float64
#  20  eu_High_last_day6    12784 non-null  float64
#  21  eu_Low_last_day6     12784 non-null  float64
#  22  eu_Close_last_day6   12784 non-null  float64
#  23  eu_High_last_day7    12784 non-null  float64
#  24  eu_Low_last_day7     12784 non-null  float64
#  25  eu_Close_last_day7   12784 non-null  float64
#  26  eu_High_last_day8    12784 non-null  float64
#  27  eu_Low_last_day8     12784 non-null  float64
#  28  eu_Close_last_day8   12784 non-null  float64
#  29  eu_High_last_day9    12784 non-null  float64
#  30  eu_Low_last_day9     12784 non-null  float64
#  31  eu_Close_last_day9   12784 non-null  float64
#  32  eu_High_last_day10   12784 non-null  float64
#  33  eu_Low_last_day10    12784 non-null  float64
#  34  eu_Close_last_day10  12784 non-null  float64
#  35  eu_High_next_day1    12784 non-null  float64
#  36  eu_Low_next_day1     12784 non-null  float64
#  37  eu_Close_next_day1   12784 non-null  float64
# dtypes: float64(37), object(1)
# memory usage: 3.8+ MB

# %%
#extract yesterday's row to predict today's row
#check if needs to be pd.DataFrame
last_row = pd.DataFrame(data=extra_clone.iloc[-2:,np.r_[0:38]])
last_row
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 12792  2021.12.16  1.12865  ...           1.12349             1.12376
# 12793  2021.12.17  1.13245  ...           1.12345             1.12376
#
# [2 rows x 38 columns]

# %%
df_m_5 = pd.DataFrame(data=df_m_5.tail(2000))
df_m_5
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 10794  2014.04.03  1.37653  ...           1.36725             1.37014
# 10795  2014.04.04  1.37169  ...           1.36960             1.37412
# 10796  2014.04.07  1.37008  ...           1.37371             1.37946
# 10797  2014.04.08  1.37413  ...           1.37799             1.38536
# 10798  2014.04.09  1.37955  ...           1.38357             1.38868
# ...           ...      ...  ...               ...                 ...
# 12789  2021.12.13  1.13106  ...           1.12535             1.12577
# 12790  2021.12.14  1.12828  ...           1.12215             1.12936
# 12791  2021.12.15  1.12549  ...           1.12810             1.13304
# 12792  2021.12.16  1.12865  ...           1.12349             1.12376
# 12793  2021.12.17  1.13245  ...           1.12345             1.12376
#
# [2000 rows x 38 columns]

# %%
#create initial train and test data as pd.DF
#final test DF is last_row
df_m_5_train_data = pd.DataFrame(data=df_m_5.iloc[0:1900,:])
df_m_5_test_data = pd.DataFrame(data=df_m_5.iloc[1900:2001,:])
print(df_m_5_train_data )
print(df_m_5_test_data )
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 10794  2014.04.03  1.37653  ...           1.36725             1.37014
# 10795  2014.04.04  1.37169  ...           1.36960             1.37412
# 10796  2014.04.07  1.37008  ...           1.37371             1.37946
# 10797  2014.04.08  1.37413  ...           1.37799             1.38536
# 10798  2014.04.09  1.37955  ...           1.38357             1.38868
# ...           ...      ...  ...               ...                 ...
# 12689  2021.07.26  1.17677  ...           1.17701             1.18165
# 12690  2021.07.27  1.18030  ...           1.17721             1.18441
# 12691  2021.07.28  1.18159  ...           1.18402             1.18865
# 12692  2021.07.29  1.18431  ...           1.18517             1.18730
# 12693  2021.07.30  1.18858  ...           1.18590             1.18688
#
# [1900 rows x 38 columns]
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 12694  2021.08.02  1.18641  ...           1.18537             1.18637
# 12695  2021.08.03  1.18670  ...           1.18328             1.18367
# 12696  2021.08.04  1.18631  ...           1.18282             1.18327
# 12697  2021.08.05  1.18360  ...           1.17544             1.17611
# 12698  2021.08.06  1.18324  ...           1.17349             1.17362
# ...           ...      ...  ...               ...                 ...
# 12789  2021.12.13  1.13106  ...           1.12535             1.12577
# 12790  2021.12.14  1.12828  ...           1.12215             1.12936
# 12791  2021.12.15  1.12549  ...           1.12810             1.13304
# 12792  2021.12.16  1.12865  ...           1.12349             1.12376
# 12793  2021.12.17  1.13245  ...           1.12345             1.12376
#
# [100 rows x 38 columns]

# %%
# #new column: high vs low
# df_m_5['eu_h_or_l'] = ((df_m_5.eu_h - df_m_5.eu_o) > (df_m_5.eu_o - df_m_5.eu_l)) 
# df_m_5.eu_h_or_l = df_m_5.eu_h_or_l.replace({True:1,False:0})

# #new column: close vs yesterday
# df_m_5['eu_c_vs_c'] = (df_m_5.eu_c > df_m_5.eu_o) 
# df_m_5.eu_c_vs_c = df_m_5.eu_c_vs_c.replace({True:1,False:0})

# #new column: shift tomorrow to today
# df_m_5['eu_High_next_day'] = df_m_5['eu_h'].shift(-1)
# df_m_5['eu_Low_next_day'] = df_m_5['eu_l'].shift(-1)
# df_m_5['eu_Close_next_day'] = df_m_5['eu_c'].shift(-1)
# df_m_5 = df_m_5.dropna()

# %%
print(df_m_5_train_data.isna().sum())
print(df_m_5_test_data.isna().sum())
# Out:
# d                      0
# eu_o                   0
# eu_h                   0
# eu_l                   0
# eu_c                   0
# eu_High_last_day1      0
# eu_Low_last_day1       0
# eu_Close_last_day1     0
# eu_High_last_day2      0
# eu_Low_last_day2       0
# eu_Close_last_day2     0
# eu_High_last_day3      0
# eu_Low_last_day3       0
# eu_Close_last_day3     0
# eu_High_last_day4      0
# eu_Low_last_day4       0
# eu_Close_last_day4     0
# eu_High_last_day5      0
# eu_Low_last_day5       0
# eu_Close_last_day5     0
# eu_High_last_day6      0
# eu_Low_last_day6       0
# eu_Close_last_day6     0
# eu_High_last_day7      0
# eu_Low_last_day7       0
# eu_Close_last_day7     0
# eu_High_last_day8      0
# eu_Low_last_day8       0
# eu_Close_last_day8     0
# eu_High_last_day9      0
# eu_Low_last_day9       0
# eu_Close_last_day9     0
# eu_High_last_day10     0
# eu_Low_last_day10      0
# eu_Close_last_day10    0
# eu_High_next_day1      0
# eu_Low_next_day1       0
# eu_Close_next_day1     0
# dtype: int64
# d                      0
# eu_o                   0
# eu_h                   0
# eu_l                   0
# eu_c                   0
# eu_High_last_day1      0
# eu_Low_last_day1       0
# eu_Close_last_day1     0
# eu_High_last_day2      0
# eu_Low_last_day2       0
# eu_Close_last_day2     0
# eu_High_last_day3      0
# eu_Low_last_day3       0
# eu_Close_last_day3     0
# eu_High_last_day4      0
# eu_Low_last_day4       0
# eu_Close_last_day4     0
# eu_High_last_day5      0
# eu_Low_last_day5       0
# eu_Close_last_day5     0
# eu_High_last_day6      0
# eu_Low_last_day6       0
# eu_Close_last_day6     0
# eu_High_last_day7      0
# eu_Low_last_day7       0
# eu_Close_last_day7     0
# eu_High_last_day8      0
# eu_Low_last_day8       0
# eu_Close_last_day8     0
# eu_High_last_day9      0
# eu_Low_last_day9       0
# eu_Close_last_day9     0
# eu_High_last_day10     0
# eu_Low_last_day10      0
# eu_Close_last_day10    0
# eu_High_next_day1      0
# eu_Low_next_day1       0
# eu_Close_next_day1     0
# dtype: int64

# %%
print(df_m_5_train_data.info())
print(df_m_5_test_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1900 entries, 10794 to 12693
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   d                    1900 non-null   object
#  1   eu_o                 1900 non-null   float64
#  2   eu_h                 1900 non-null   float64
#  3   eu_l                 1900 non-null   float64
#  4   eu_c                 1900 non-null   float64
#  5   eu_High_last_day1    1900 non-null   float64
#  6   eu_Low_last_day1     1900 non-null   float64
#  7   eu_Close_last_day1   1900 non-null   float64
#  8   eu_High_last_day2    1900 non-null   float64
#  9   eu_Low_last_day2     1900 non-null   float64
#  10  eu_Close_last_day2   1900 non-null   float64
#  11  eu_High_last_day3    1900 non-null   float64
#  12  eu_Low_last_day3     1900 non-null   float64
#  13  eu_Close_last_day3   1900 non-null   float64
#  14  eu_High_last_day4    1900 non-null   float64
#  15  eu_Low_last_day4     1900 non-null   float64
#  16  eu_Close_last_day4   1900 non-null   float64
#  17  eu_High_last_day5    1900 non-null   float64
#  18  eu_Low_last_day5     1900 non-null   float64
#  19  eu_Close_last_day5   1900 non-null   float64
#  20  eu_High_last_day6    1900 non-null   float64
#  21  eu_Low_last_day6     1900 non-null   float64
#  22  eu_Close_last_day6   1900 non-null   float64
#  23  eu_High_last_day7    1900 non-null   float64
#  24  eu_Low_last_day7     1900 non-null   float64
#  25  eu_Close_last_day7   1900 non-null   float64
#  26  eu_High_last_day8    1900 non-null   float64
#  27  eu_Low_last_day8     1900 non-null   float64
#  28  eu_Close_last_day8   1900 non-null   float64
#  29  eu_High_last_day9    1900 non-null   float64
#  30  eu_Low_last_day9     1900 non-null   float64
#  31  eu_Close_last_day9   1900 non-null   float64
#  32  eu_High_last_day10   1900 non-null   float64
#  33  eu_Low_last_day10    1900 non-null   float64
#  34  eu_Close_last_day10  1900 non-null   float64
#  35  eu_High_next_day1    1900 non-null   float64
#  36  eu_Low_next_day1     1900 non-null   float64
#  37  eu_Close_next_day1   1900 non-null   float64
# dtypes: float64(37), object(1)
# memory usage: 578.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 12694 to 12793
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   d                    100 non-null    object
#  1   eu_o                 100 non-null    float64
#  2   eu_h                 100 non-null    float64
#  3   eu_l                 100 non-null    float64
#  4   eu_c                 100 non-null    float64
#  5   eu_High_last_day1    100 non-null    float64
#  6   eu_Low_last_day1     100 non-null    float64
#  7   eu_Close_last_day1   100 non-null    float64
#  8   eu_High_last_day2    100 non-null    float64
#  9   eu_Low_last_day2     100 non-null    float64
#  10  eu_Close_last_day2   100 non-null    float64
#  11  eu_High_last_day3    100 non-null    float64
#  12  eu_Low_last_day3     100 non-null    float64
#  13  eu_Close_last_day3   100 non-null    float64
#  14  eu_High_last_day4    100 non-null    float64
#  15  eu_Low_last_day4     100 non-null    float64
#  16  eu_Close_last_day4   100 non-null    float64
#  17  eu_High_last_day5    100 non-null    float64
#  18  eu_Low_last_day5     100 non-null    float64
#  19  eu_Close_last_day5   100 non-null    float64
#  20  eu_High_last_day6    100 non-null    float64
#  21  eu_Low_last_day6     100 non-null    float64
#  22  eu_Close_last_day6   100 non-null    float64
#  23  eu_High_last_day7    100 non-null    float64
#  24  eu_Low_last_day7     100 non-null    float64
#  25  eu_Close_last_day7   100 non-null    float64
#  26  eu_High_last_day8    100 non-null    float64
#  27  eu_Low_last_day8     100 non-null    float64
#  28  eu_Close_last_day8   100 non-null    float64
#  29  eu_High_last_day9    100 non-null    float64
#  30  eu_Low_last_day9     100 non-null    float64
#  31  eu_Close_last_day9   100 non-null    float64
#  32  eu_High_last_day10   100 non-null    float64
#  33  eu_Low_last_day10    100 non-null    float64
#  34  eu_Close_last_day10  100 non-null    float64
#  35  eu_High_next_day1    100 non-null    float64
#  36  eu_Low_next_day1     100 non-null    float64
#  37  eu_Close_next_day1   100 non-null    float64
# dtypes: float64(37), object(1)
# memory usage: 30.5+ KB
# None

# %%
train_data = df_m_5_train_data
train_data=train_data.sample(n=1900, replace=True)
train_data.head()
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 11880  2018.06.11  1.17732  ...           1.17329             1.17454
# 12184  2019.08.13  1.12129  ...           1.11305             1.11377
# 12063  2019.02.25  1.13332  ...           1.13447             1.13880
# 12044  2019.01.29  1.14253  ...           1.14057             1.14779
# 11229  2015.12.07  1.08681  ...           1.08299             1.08920
#
# [5 rows x 38 columns]

# %%
#predict high
label_h = 'eu_High_next_day1' 
print("Summary of class variable: \n", train_data[label_h].describe())
# Out:
# Summary of class variable:
#  count    1900.000000
# mean        1.160545
# std         0.073923
# min         1.045090
# 25%         1.109580
# 50%         1.138060
# 75%         1.191993
# max         1.399320
# Name: eu_High_next_day1, dtype: float64

# %%
#predict high
save_path='agModels-predictHigh'
predictor = TabularPredictor(label=label_h, path=save_path).fit(train_data, presets='best_quality')
#.fit(presets='best_quality) is slower
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictHigh"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictHigh/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1900
# Train Data Columns: 37
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.3993200000000001, 1.04509, 1.16055, 0.07392)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12635.36 MB
# 	Train Data (Original)  Memory Usage: 0.67 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('object', ['datetime_as_object']) :  1 | ['d']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', ['datetime_as_int']) :  1 | ['d']
# 	0.1s = Fit runtime
# 	37 features in original data used to generate 37 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.56 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.14s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-0.0042	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-0.0031	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00167884	valid_set's rmse: 0.00201578
# [2000]	train_set's rmse: 0.00117561	valid_set's rmse: 0.00182833
# [3000]	train_set's rmse: 0.000922627	valid_set's rmse: 0.00173625
# [4000]	train_set's rmse: 0.000758663	valid_set's rmse: 0.00167639
# [5000]	train_set's rmse: 0.000646938	valid_set's rmse: 0.00163568
# [6000]	train_set's rmse: 0.000564522	valid_set's rmse: 0.00162181
# [7000]	train_set's rmse: 0.000501828	valid_set's rmse: 0.00160648
# [8000]	train_set's rmse: 0.00045522	valid_set's rmse: 0.00159472
# [9000]	train_set's rmse: 0.000418774	valid_set's rmse: 0.00158796
# [10000]	train_set's rmse: 0.000389384	valid_set's rmse: 0.00158298
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00163458	valid_set's rmse: 0.002513
# [2000]	train_set's rmse: 0.00113259	valid_set's rmse: 0.00222532
# [3000]	train_set's rmse: 0.000865657	valid_set's rmse: 0.0020873
# [4000]	train_set's rmse: 0.000701857	valid_set's rmse: 0.00200254
# [5000]	train_set's rmse: 0.000587818	valid_set's rmse: 0.0019522
# [6000]	train_set's rmse: 0.000508226	valid_set's rmse: 0.00192469
# [7000]	train_set's rmse: 0.000448986	valid_set's rmse: 0.00189967
# [8000]	train_set's rmse: 0.000404889	valid_set's rmse: 0.00188032
# [9000]	train_set's rmse: 0.000370329	valid_set's rmse: 0.00187163
# [10000]	train_set's rmse: 0.000342393	valid_set's rmse: 0.00186457
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00160588	valid_set's rmse: 0.00261137
# [2000]	train_set's rmse: 0.00113594	valid_set's rmse: 0.00244352
# [3000]	train_set's rmse: 0.000900539	valid_set's rmse: 0.00237343
# [4000]	train_set's rmse: 0.000752331	valid_set's rmse: 0.00234564
# [5000]	train_set's rmse: 0.000651132	valid_set's rmse: 0.0023335
# [6000]	train_set's rmse: 0.000576691	valid_set's rmse: 0.00232062
# [7000]	train_set's rmse: 0.000520683	valid_set's rmse: 0.00231857
# [8000]	train_set's rmse: 0.000476203	valid_set's rmse: 0.00231664
# [9000]	train_set's rmse: 0.000441938	valid_set's rmse: 0.00231286
# [10000]	train_set's rmse: 0.00041328	valid_set's rmse: 0.00231114
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00157353	valid_set's rmse: 0.00344139
# [2000]	train_set's rmse: 0.00105164	valid_set's rmse: 0.00330512
# [3000]	train_set's rmse: 0.000785666	valid_set's rmse: 0.00326359
# [4000]	train_set's rmse: 0.000622648	valid_set's rmse: 0.00323857
# [5000]	train_set's rmse: 0.000506798	valid_set's rmse: 0.0032302
# [6000]	train_set's rmse: 0.000418819	valid_set's rmse: 0.00321944
# [7000]	train_set's rmse: 0.000350826	valid_set's rmse: 0.00321131
# [8000]	train_set's rmse: 0.000295289	valid_set's rmse: 0.00320742
# [9000]	train_set's rmse: 0.000252329	valid_set's rmse: 0.0032059
# [10000]	train_set's rmse: 0.000216693	valid_set's rmse: 0.00319991
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00160236	valid_set's rmse: 0.0032067
# [2000]	train_set's rmse: 0.0011267	valid_set's rmse: 0.00303655
# [3000]	train_set's rmse: 0.000868694	valid_set's rmse: 0.00296716
# [4000]	train_set's rmse: 0.000707667	valid_set's rmse: 0.00293217
# [5000]	train_set's rmse: 0.000594876	valid_set's rmse: 0.00291369
# [6000]	train_set's rmse: 0.00051103	valid_set's rmse: 0.00289859
# [7000]	train_set's rmse: 0.000445939	valid_set's rmse: 0.00288274
# [8000]	train_set's rmse: 0.000394031	valid_set's rmse: 0.00287038
# [9000]	train_set's rmse: 0.000354316	valid_set's rmse: 0.00286519
# [10000]	train_set's rmse: 0.00032052	valid_set's rmse: 0.00286486
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00163569	valid_set's rmse: 0.00227121
# [2000]	train_set's rmse: 0.00115353	valid_set's rmse: 0.00208441
# [3000]	train_set's rmse: 0.000907594	valid_set's rmse: 0.00201093
# [4000]	train_set's rmse: 0.00075177	valid_set's rmse: 0.00197411
# [5000]	train_set's rmse: 0.000646234	valid_set's rmse: 0.00195139
# [6000]	train_set's rmse: 0.000569737	valid_set's rmse: 0.00194033
# [7000]	train_set's rmse: 0.000512614	valid_set's rmse: 0.00193003
# [8000]	train_set's rmse: 0.000468117	valid_set's rmse: 0.00192693
# [9000]	train_set's rmse: 0.000434002	valid_set's rmse: 0.00192188
# [10000]	train_set's rmse: 0.000405432	valid_set's rmse: 0.00192373
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00165999	valid_set's rmse: 0.00269812
# [2000]	train_set's rmse: 0.00115239	valid_set's rmse: 0.00241037
# [3000]	train_set's rmse: 0.000891079	valid_set's rmse: 0.00230179
# [4000]	train_set's rmse: 0.00072718	valid_set's rmse: 0.00223724
# [5000]	train_set's rmse: 0.000613242	valid_set's rmse: 0.00221773
# [6000]	train_set's rmse: 0.000529895	valid_set's rmse: 0.00220065
# [7000]	train_set's rmse: 0.000465857	valid_set's rmse: 0.00219527
# [8000]	train_set's rmse: 0.000414952	valid_set's rmse: 0.00220165
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00166586	valid_set's rmse: 0.00205717
# [2000]	train_set's rmse: 0.00116081	valid_set's rmse: 0.00187983
# [3000]	train_set's rmse: 0.000910333	valid_set's rmse: 0.00181769
# [4000]	train_set's rmse: 0.000752732	valid_set's rmse: 0.00177811
# [5000]	train_set's rmse: 0.000643311	valid_set's rmse: 0.00176537
# [6000]	train_set's rmse: 0.000568392	valid_set's rmse: 0.00175938
# [7000]	train_set's rmse: 0.000511581	valid_set's rmse: 0.00175163
# [8000]	train_set's rmse: 0.000469667	valid_set's rmse: 0.00174952
# [9000]	train_set's rmse: 0.000436564	valid_set's rmse: 0.00174576
# [10000]	train_set's rmse: 0.000409921	valid_set's rmse: 0.00174421
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00158569	valid_set's rmse: 0.00214485
# [2000]	train_set's rmse: 0.00110796	valid_set's rmse: 0.00196021
# [3000]	train_set's rmse: 0.000866722	valid_set's rmse: 0.00185998
# [4000]	train_set's rmse: 0.000712629	valid_set's rmse: 0.00181471
# [5000]	train_set's rmse: 0.000605085	valid_set's rmse: 0.00179075
# [6000]	train_set's rmse: 0.000527786	valid_set's rmse: 0.00177547
# [7000]	train_set's rmse: 0.000469767	valid_set's rmse: 0.00176263
# [8000]	train_set's rmse: 0.000423928	valid_set's rmse: 0.00175101
# [9000]	train_set's rmse: 0.000388216	valid_set's rmse: 0.00174696
# [10000]	train_set's rmse: 0.000360199	valid_set's rmse: 0.00174134
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00163055	valid_set's rmse: 0.0024109
# [2000]	train_set's rmse: 0.00110414	valid_set's rmse: 0.00216067
# [3000]	train_set's rmse: 0.000838106	valid_set's rmse: 0.00205801
# [4000]	train_set's rmse: 0.000674992	valid_set's rmse: 0.00201151
# [5000]	train_set's rmse: 0.000559696	valid_set's rmse: 0.00197976
# [6000]	train_set's rmse: 0.000478034	valid_set's rmse: 0.00196681
# [7000]	train_set's rmse: 0.000417291	valid_set's rmse: 0.00195874
# [8000]	train_set's rmse: 0.000370488	valid_set's rmse: 0.0019572
# [9000]	train_set's rmse: 0.000334898	valid_set's rmse: 0.0019575
# [10000]	train_set's rmse: 0.000303974	valid_set's rmse: 0.00195731
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	90.37s	 = Training   runtime
# 	1.96s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000367251	valid_set's rmse: 0.00190288
# [2000]	train_set's rmse: 0.000257696	valid_set's rmse: 0.00189002
# [3000]	train_set's rmse: 0.000200554	valid_set's rmse: 0.0018857
# [4000]	train_set's rmse: 0.000159544	valid_set's rmse: 0.00188536
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000281688	valid_set's rmse: 0.0024952
# [2000]	train_set's rmse: 0.00014593	valid_set's rmse: 0.00244613
# [3000]	train_set's rmse: 8.36133e-05	valid_set's rmse: 0.00243315
# [4000]	train_set's rmse: 4.93085e-05	valid_set's rmse: 0.0024286
# [5000]	train_set's rmse: 2.94719e-05	valid_set's rmse: 0.00242689
# [6000]	train_set's rmse: 1.79555e-05	valid_set's rmse: 0.00242646
# [7000]	train_set's rmse: 1.10984e-05	valid_set's rmse: 0.00242588
# [8000]	train_set's rmse: 6.88245e-06	valid_set's rmse: 0.00242543
# [9000]	train_set's rmse: 4.25675e-06	valid_set's rmse: 0.00242532
# [10000]	train_set's rmse: 2.6294e-06	valid_set's rmse: 0.0024252
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000356978	valid_set's rmse: 0.00168825
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0018	 = Validation score   (root_mean_squared_error)
# 	52.8s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	5.99s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	419.01s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	1.64s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	-0.0033	 = Validation score   (root_mean_squared_error)
# 	25.16s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	-0.0023	 = Validation score   (root_mean_squared_error)
# 	7.63s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ...
# 	-0.0041	 = Validation score   (root_mean_squared_error)
# 	156.94s	 = Training   runtime
# 	1.51s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 3.97955e-06	valid_set's rmse: 0.00144605
# [2000]	train_set's rmse: 5.48332e-08	valid_set's rmse: 0.00144575
# [3000]	train_set's rmse: 9.30089e-10	valid_set's rmse: 0.00144575
# [4000]	train_set's rmse: 1.71122e-11	valid_set's rmse: 0.00144575
# [5000]	train_set's rmse: 3.23951e-13	valid_set's rmse: 0.00144575
# [6000]	train_set's rmse: 7.35361e-15	valid_set's rmse: 0.00144575
# [7000]	train_set's rmse: 3.07013e-15	valid_set's rmse: 0.00144575
# [8000]	train_set's rmse: 2.88791e-15	valid_set's rmse: 0.00144575
# [9000]	train_set's rmse: 2.8698e-15	valid_set's rmse: 0.00144575
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 4.87731e-06	valid_set's rmse: 0.00145271
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 3.951e-06	valid_set's rmse: 0.00243875
# [2000]	train_set's rmse: 7.15954e-08	valid_set's rmse: 0.0024378
# [3000]	train_set's rmse: 1.27823e-09	valid_set's rmse: 0.00243778
# [4000]	train_set's rmse: 2.28734e-11	valid_set's rmse: 0.00243778
# [5000]	train_set's rmse: 4.14397e-13	valid_set's rmse: 0.00243778
# [6000]	train_set's rmse: 6.87936e-15	valid_set's rmse: 0.00243778
# [7000]	train_set's rmse: 2.85612e-15	valid_set's rmse: 0.00243778
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0018	 = Validation score   (root_mean_squared_error)
# 	159.31s	 = Training   runtime
# 	0.98s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.0016	 = Validation score   (root_mean_squared_error)
# 	0.33s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00133683	valid_set's rmse: 0.00241891
# [2000]	train_set's rmse: 0.000968436	valid_set's rmse: 0.00235986
# [3000]	train_set's rmse: 0.0007617	valid_set's rmse: 0.00235522
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00129448	valid_set's rmse: 0.00210577
# [2000]	train_set's rmse: 0.000931376	valid_set's rmse: 0.00200973
# [3000]	train_set's rmse: 0.000718876	valid_set's rmse: 0.00197907
# [4000]	train_set's rmse: 0.000576906	valid_set's rmse: 0.00197342
# [5000]	train_set's rmse: 0.000475203	valid_set's rmse: 0.00196606
# [6000]	train_set's rmse: 0.000400013	valid_set's rmse: 0.0019629
# [7000]	train_set's rmse: 0.000341727	valid_set's rmse: 0.00196183
# [8000]	train_set's rmse: 0.000297245	valid_set's rmse: 0.00196053
# [9000]	train_set's rmse: 0.000264119	valid_set's rmse: 0.00195875
# [10000]	train_set's rmse: 0.000237564	valid_set's rmse: 0.00195733
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00134578	valid_set's rmse: 0.0020902
# [2000]	train_set's rmse: 0.000993556	valid_set's rmse: 0.00200553
# [3000]	train_set's rmse: 0.000800275	valid_set's rmse: 0.00196732
# [4000]	train_set's rmse: 0.00067589	valid_set's rmse: 0.0019508
# [5000]	train_set's rmse: 0.000587598	valid_set's rmse: 0.0019462
# [6000]	train_set's rmse: 0.00052424	valid_set's rmse: 0.00194466
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00135948	valid_set's rmse: 0.00256792
# [2000]	train_set's rmse: 0.000991272	valid_set's rmse: 0.00241875
# [3000]	train_set's rmse: 0.00078529	valid_set's rmse: 0.00236687
# [4000]	train_set's rmse: 0.000651303	valid_set's rmse: 0.00233856
# [5000]	train_set's rmse: 0.000554572	valid_set's rmse: 0.00231988
# [6000]	train_set's rmse: 0.000482947	valid_set's rmse: 0.00231315
# [7000]	train_set's rmse: 0.000425658	valid_set's rmse: 0.00231607
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00132487	valid_set's rmse: 0.00201968
# [2000]	train_set's rmse: 0.00096181	valid_set's rmse: 0.0018895
# [3000]	train_set's rmse: 0.00076689	valid_set's rmse: 0.00186241
# [4000]	train_set's rmse: 0.000636524	valid_set's rmse: 0.00185528
# [5000]	train_set's rmse: 0.000543456	valid_set's rmse: 0.00185119
# [6000]	train_set's rmse: 0.000477306	valid_set's rmse: 0.00184287
# [7000]	train_set's rmse: 0.000426133	valid_set's rmse: 0.00183773
# [8000]	train_set's rmse: 0.000386097	valid_set's rmse: 0.0018384
# [9000]	train_set's rmse: 0.000354221	valid_set's rmse: 0.00183849
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0013528	valid_set's rmse: 0.00186695
# [2000]	train_set's rmse: 0.000979229	valid_set's rmse: 0.00173073
# [3000]	train_set's rmse: 0.000771617	valid_set's rmse: 0.00168108
# [4000]	train_set's rmse: 0.000635636	valid_set's rmse: 0.00165828
# [5000]	train_set's rmse: 0.000538753	valid_set's rmse: 0.00164422
# [6000]	train_set's rmse: 0.000469109	valid_set's rmse: 0.00163508
# [7000]	train_set's rmse: 0.000416488	valid_set's rmse: 0.00163241
# [8000]	train_set's rmse: 0.000374196	valid_set's rmse: 0.00162944
# [9000]	train_set's rmse: 0.00034185	valid_set's rmse: 0.00162999
# [10000]	train_set's rmse: 0.000316173	valid_set's rmse: 0.00162793
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00128099	valid_set's rmse: 0.00181115
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00128949	valid_set's rmse: 0.00234674
# [2000]	train_set's rmse: 0.000917731	valid_set's rmse: 0.00228055
# [3000]	train_set's rmse: 0.000717219	valid_set's rmse: 0.00226622
# [4000]	train_set's rmse: 0.000586226	valid_set's rmse: 0.00226169
# [5000]	train_set's rmse: 0.000497613	valid_set's rmse: 0.00226374
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00133997	valid_set's rmse: 0.00214632
# [2000]	train_set's rmse: 0.000964351	valid_set's rmse: 0.0020255
# [3000]	train_set's rmse: 0.000760302	valid_set's rmse: 0.00198321
# [4000]	train_set's rmse: 0.000629838	valid_set's rmse: 0.00195582
# [5000]	train_set's rmse: 0.000539701	valid_set's rmse: 0.00194195
# [6000]	train_set's rmse: 0.000474126	valid_set's rmse: 0.00192941
# [7000]	train_set's rmse: 0.000426271	valid_set's rmse: 0.00192351
# [8000]	train_set's rmse: 0.00039007	valid_set's rmse: 0.00192185
# [9000]	train_set's rmse: 0.000360758	valid_set's rmse: 0.00192004
# [10000]	train_set's rmse: 0.000337541	valid_set's rmse: 0.00191926
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00133001	valid_set's rmse: 0.00169874
# [2000]	train_set's rmse: 0.000978359	valid_set's rmse: 0.0016449
# 	-0.002	 = Validation score   (root_mean_squared_error)
# 	60.61s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000352567	valid_set's rmse: 0.00185356
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0018	 = Validation score   (root_mean_squared_error)
# 	16.53s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	7.55s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	-0.002	 = Validation score   (root_mean_squared_error)
# 	385.86s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-0.0016	 = Validation score   (root_mean_squared_error)
# 	1.94s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	-0.0024	 = Validation score   (root_mean_squared_error)
# 	23.9s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	-0.0019	 = Validation score   (root_mean_squared_error)
# 	6.78s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L2 ...
# 	-0.0037	 = Validation score   (root_mean_squared_error)
# 	168.1s	 = Training   runtime
# 	1.58s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	50.71s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-0.0016	 = Validation score   (root_mean_squared_error)
# 	0.28s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1680.6s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictHigh/")

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_data, silent=True)
# Out:
#                      model    score_test  ...  can_infer  fit_order
# 0    KNeighborsDist_BAG_L1 -3.479971e-08  ...       True          2
# 1     LightGBMLarge_BAG_L1 -2.429127e-04  ...       True         11
# 2          CatBoost_BAG_L1 -2.676131e-04  ...       True          6
# 3      WeightedEnsemble_L3 -3.302617e-04  ...       True         22
# 4     LightGBMLarge_BAG_L2 -3.890953e-04  ...       True         21
# 5   RandomForestMSE_BAG_L2 -3.929039e-04  ...       True         15
# 6     ExtraTreesMSE_BAG_L2 -4.055543e-04  ...       True         17
# 7        LightGBMXT_BAG_L1 -4.657294e-04  ...       True          3
# 8          LightGBM_BAG_L1 -4.684621e-04  ...       True          4
# 9      WeightedEnsemble_L2 -4.843945e-04  ...       True         12
# 10         CatBoost_BAG_L2 -5.206315e-04  ...       True         16
# 11         LightGBM_BAG_L2 -6.091409e-04  ...       True         14
# 12          XGBoost_BAG_L2 -6.196763e-04  ...       True         19
# 13       LightGBMXT_BAG_L2 -6.235820e-04  ...       True         13
# 14    ExtraTreesMSE_BAG_L1 -6.347609e-04  ...       True          7
# 15  RandomForestMSE_BAG_L1 -6.369593e-04  ...       True          5
# 16          XGBoost_BAG_L1 -8.884637e-04  ...       True          9
# 17  NeuralNetFastAI_BAG_L2 -1.361555e-03  ...       True         18
# 18  NeuralNetFastAI_BAG_L1 -2.967618e-03  ...       True          8
# 19   NeuralNetMXNet_BAG_L2 -3.090857e-03  ...       True         20
# 20   KNeighborsUnif_BAG_L1 -3.214403e-03  ...       True          1
# 21   NeuralNetMXNet_BAG_L1 -3.603123e-03  ...       True         10
#
# [22 rows x 12 columns]

# %%
#predict high
test_data = TabularDataset(df_m_5_test_data)
y_test = test_data[label_h]
test_data_nolab = test_data.drop(columns=[label_h])
test_data_nolab.tail()
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 12789  2021.12.13  1.13106  ...           1.12535             1.12577
# 12790  2021.12.14  1.12828  ...           1.12215             1.12936
# 12791  2021.12.15  1.12549  ...           1.12810             1.13304
# 12792  2021.12.16  1.12865  ...           1.12349             1.12376
# 12793  2021.12.17  1.13245  ...           1.12345             1.12376
#
# [5 rows x 37 columns]

# %%
#first run to predict eu_High_next_day1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_data_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: root_mean_squared_error on test data: -0.0019474202157838928
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -0.0019474202157838928,
#     "mean_squared_error": -3.792445496843783e-06,
#     "mean_absolute_error": -0.0015762945129394535,
#     "r2": 0.9900000270609781,
#     "pearsonr": 0.9960748136485874,
#     "median_absolute_error": -0.0013488046646118468
# }
# Predictions:
#  12694    1.189249
# 12695    1.188966
# 12696    1.187582
# 12697    1.182786
# 12698    1.178785
#            ...
# 12789    1.130890
# 12790    1.131282
# 12791    1.134206
# 12792    1.133077
# 12793    1.129191
# Name: eu_High_next_day1, Length: 100, dtype: float32

# %%
#predict low
label_l = 'eu_Low_next_day1' 
print("Summary of class variable: \n", train_data[label_l].describe())
# Out:
# Summary of class variable:
#  count    1900.000000
# mean        1.152360
# std         0.074540
# min         1.032490
# 25%         1.102618
# 50%         1.130080
# 75%         1.184445
# max         1.390970
# Name: eu_Low_next_day1, dtype: float64

# %%
#predict low
save_path='agModels-predictLow'
predictor = TabularPredictor(label=label_l, path=save_path).fit(train_data, presets='best_quality')
#.fit(presets='best_quality) is slower
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictLow"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictLow/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1900
# Train Data Columns: 37
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.39097, 1.03249, 1.15236, 0.07454)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11515.16 MB
# 	Train Data (Original)  Memory Usage: 0.67 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('object', ['datetime_as_object']) :  1 | ['d']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', ['datetime_as_int']) :  1 | ['d']
# 	0.1s = Fit runtime
# 	37 features in original data used to generate 37 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.56 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.16s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-0.0042	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-0.003	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00165856	valid_set's rmse: 0.00248995
# [2000]	train_set's rmse: 0.0011244	valid_set's rmse: 0.00237857
# [3000]	train_set's rmse: 0.000840445	valid_set's rmse: 0.00232149
# [4000]	train_set's rmse: 0.000658958	valid_set's rmse: 0.00228898
# [5000]	train_set's rmse: 0.000532559	valid_set's rmse: 0.00226713
# [6000]	train_set's rmse: 0.000435346	valid_set's rmse: 0.00225292
# [7000]	train_set's rmse: 0.000361841	valid_set's rmse: 0.00223887
# [8000]	train_set's rmse: 0.000303599	valid_set's rmse: 0.00223022
# [9000]	train_set's rmse: 0.000257455	valid_set's rmse: 0.00222584
# [10000]	train_set's rmse: 0.000219906	valid_set's rmse: 0.00222444
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00169404	valid_set's rmse: 0.00251961
# [2000]	train_set's rmse: 0.00113901	valid_set's rmse: 0.00217882
# [3000]	train_set's rmse: 0.000850186	valid_set's rmse: 0.00203507
# [4000]	train_set's rmse: 0.000667342	valid_set's rmse: 0.0019721
# [5000]	train_set's rmse: 0.000538529	valid_set's rmse: 0.00193018
# [6000]	train_set's rmse: 0.000443752	valid_set's rmse: 0.00190649
# [7000]	train_set's rmse: 0.000371146	valid_set's rmse: 0.00189324
# [8000]	train_set's rmse: 0.000313765	valid_set's rmse: 0.00188351
# [9000]	train_set's rmse: 0.000268246	valid_set's rmse: 0.00187449
# [10000]	train_set's rmse: 0.000230467	valid_set's rmse: 0.00187262
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00168252	valid_set's rmse: 0.00285829
# [2000]	train_set's rmse: 0.00115282	valid_set's rmse: 0.00262868
# [3000]	train_set's rmse: 0.000869642	valid_set's rmse: 0.0025121
# [4000]	train_set's rmse: 0.000687013	valid_set's rmse: 0.00243941
# [5000]	train_set's rmse: 0.000554339	valid_set's rmse: 0.00239056
# [6000]	train_set's rmse: 0.000455212	valid_set's rmse: 0.00236623
# [7000]	train_set's rmse: 0.000379573	valid_set's rmse: 0.00234586
# [8000]	train_set's rmse: 0.000319137	valid_set's rmse: 0.00233231
# [9000]	train_set's rmse: 0.000271204	valid_set's rmse: 0.00232332
# [10000]	train_set's rmse: 0.000232439	valid_set's rmse: 0.00231972
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00163827	valid_set's rmse: 0.00278782
# [2000]	train_set's rmse: 0.00111331	valid_set's rmse: 0.00257896
# [3000]	train_set's rmse: 0.000836325	valid_set's rmse: 0.00246678
# [4000]	train_set's rmse: 0.000656124	valid_set's rmse: 0.0024013
# [5000]	train_set's rmse: 0.000532826	valid_set's rmse: 0.00236246
# [6000]	train_set's rmse: 0.000436817	valid_set's rmse: 0.00234022
# [7000]	train_set's rmse: 0.000364813	valid_set's rmse: 0.00232533
# [8000]	train_set's rmse: 0.000306913	valid_set's rmse: 0.00231408
# [9000]	train_set's rmse: 0.00025987	valid_set's rmse: 0.00230959
# [10000]	train_set's rmse: 0.000221108	valid_set's rmse: 0.00230478
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00169107	valid_set's rmse: 0.00287455
# [2000]	train_set's rmse: 0.00115665	valid_set's rmse: 0.00249257
# [3000]	train_set's rmse: 0.000870745	valid_set's rmse: 0.00235146
# [4000]	train_set's rmse: 0.000684257	valid_set's rmse: 0.00226944
# [5000]	train_set's rmse: 0.000554603	valid_set's rmse: 0.0022318
# [6000]	train_set's rmse: 0.000459569	valid_set's rmse: 0.00221111
# [7000]	train_set's rmse: 0.000385741	valid_set's rmse: 0.00219703
# [8000]	train_set's rmse: 0.000327651	valid_set's rmse: 0.00218979
# [9000]	train_set's rmse: 0.000282004	valid_set's rmse: 0.00218569
# [10000]	train_set's rmse: 0.000243219	valid_set's rmse: 0.00218345
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00166413	valid_set's rmse: 0.00219749
# [2000]	train_set's rmse: 0.00112767	valid_set's rmse: 0.00197438
# [3000]	train_set's rmse: 0.000858399	valid_set's rmse: 0.00187014
# [4000]	train_set's rmse: 0.000688732	valid_set's rmse: 0.00182077
# [5000]	train_set's rmse: 0.000568106	valid_set's rmse: 0.00179056
# [6000]	train_set's rmse: 0.000475436	valid_set's rmse: 0.0017714
# [7000]	train_set's rmse: 0.000402498	valid_set's rmse: 0.00175857
# [8000]	train_set's rmse: 0.000345607	valid_set's rmse: 0.00175263
# [9000]	train_set's rmse: 0.000299397	valid_set's rmse: 0.00174884
# [10000]	train_set's rmse: 0.000260973	valid_set's rmse: 0.00174706
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00169388	valid_set's rmse: 0.00303492
# [2000]	train_set's rmse: 0.00115384	valid_set's rmse: 0.00252562
# [3000]	train_set's rmse: 0.000855582	valid_set's rmse: 0.00232204
# [4000]	train_set's rmse: 0.000670046	valid_set's rmse: 0.00222564
# [5000]	train_set's rmse: 0.000537863	valid_set's rmse: 0.00218616
# [6000]	train_set's rmse: 0.000442686	valid_set's rmse: 0.00215913
# [7000]	train_set's rmse: 0.000370509	valid_set's rmse: 0.00215056
# [8000]	train_set's rmse: 0.000312341	valid_set's rmse: 0.00214274
# [9000]	train_set's rmse: 0.000265279	valid_set's rmse: 0.00213806
# [10000]	train_set's rmse: 0.000227287	valid_set's rmse: 0.00213835
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00171957	valid_set's rmse: 0.00236024
# [2000]	train_set's rmse: 0.00118321	valid_set's rmse: 0.00203783
# [3000]	train_set's rmse: 0.000886424	valid_set's rmse: 0.00190358
# [4000]	train_set's rmse: 0.000700309	valid_set's rmse: 0.00183687
# [5000]	train_set's rmse: 0.000570465	valid_set's rmse: 0.00180837
# [6000]	train_set's rmse: 0.000475927	valid_set's rmse: 0.00178725
# [7000]	train_set's rmse: 0.000403761	valid_set's rmse: 0.00177646
# [8000]	train_set's rmse: 0.00034704	valid_set's rmse: 0.00176994
# [9000]	train_set's rmse: 0.000302194	valid_set's rmse: 0.00176478
# [10000]	train_set's rmse: 0.000265541	valid_set's rmse: 0.00176113
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00171643	valid_set's rmse: 0.00241522
# [2000]	train_set's rmse: 0.0011586	valid_set's rmse: 0.00212332
# [3000]	train_set's rmse: 0.000866906	valid_set's rmse: 0.00196025
# [4000]	train_set's rmse: 0.000681898	valid_set's rmse: 0.00187156
# [5000]	train_set's rmse: 0.000552735	valid_set's rmse: 0.00181933
# [6000]	train_set's rmse: 0.000456134	valid_set's rmse: 0.00178153
# [7000]	train_set's rmse: 0.000382812	valid_set's rmse: 0.00176076
# [8000]	train_set's rmse: 0.000324581	valid_set's rmse: 0.00174318
# [9000]	train_set's rmse: 0.000276754	valid_set's rmse: 0.00173611
# [10000]	train_set's rmse: 0.000238408	valid_set's rmse: 0.00172791
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00165542	valid_set's rmse: 0.00238727
# [2000]	train_set's rmse: 0.0011184	valid_set's rmse: 0.0021442
# [3000]	train_set's rmse: 0.000834965	valid_set's rmse: 0.00203161
# [4000]	train_set's rmse: 0.000653985	valid_set's rmse: 0.00197943
# [5000]	train_set's rmse: 0.000527764	valid_set's rmse: 0.00194445
# [6000]	train_set's rmse: 0.000434676	valid_set's rmse: 0.001934
# [7000]	train_set's rmse: 0.000363834	valid_set's rmse: 0.00191968
# [8000]	train_set's rmse: 0.000306665	valid_set's rmse: 0.00191476
# [9000]	train_set's rmse: 0.000260475	valid_set's rmse: 0.00191103
# [10000]	train_set's rmse: 0.000224202	valid_set's rmse: 0.00190834
# 	-0.002	 = Validation score   (root_mean_squared_error)
# 	78.77s	 = Training   runtime
# 	2.65s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000166703	valid_set's rmse: 0.00236638
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000176924	valid_set's rmse: 0.00253859
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00014389	valid_set's rmse: 0.0023806
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000189721	valid_set's rmse: 0.00192429
# [2000]	train_set's rmse: 6.78245e-05	valid_set's rmse: 0.00191269
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000197671	valid_set's rmse: 0.00172739
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000205985	valid_set's rmse: 0.00158491
# [2000]	train_set's rmse: 0.00010397	valid_set's rmse: 0.00157401
# [3000]	train_set's rmse: 7.43564e-05	valid_set's rmse: 0.00157216
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000188335	valid_set's rmse: 0.00149038
# [2000]	train_set's rmse: 7.58113e-05	valid_set's rmse: 0.00148277
# [3000]	train_set's rmse: 3.98206e-05	valid_set's rmse: 0.00148224
# [4000]	train_set's rmse: 2.23243e-05	valid_set's rmse: 0.00148111
# [5000]	train_set's rmse: 1.35403e-05	valid_set's rmse: 0.00148047
# [6000]	train_set's rmse: 9.10012e-06	valid_set's rmse: 0.00148018
# [7000]	train_set's rmse: 6.50216e-06	valid_set's rmse: 0.00148005
# [8000]	train_set's rmse: 4.76103e-06	valid_set's rmse: 0.00148
# [9000]	train_set's rmse: 3.54152e-06	valid_set's rmse: 0.00147997
# [10000]	train_set's rmse: 2.66222e-06	valid_set's rmse: 0.00147996
# 	-0.0019	 = Validation score   (root_mean_squared_error)
# 	56.7s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.0018	 = Validation score   (root_mean_squared_error)
# 	6.04s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	354.35s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	1.64s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	-0.0033	 = Validation score   (root_mean_squared_error)
# 	27.86s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	7.68s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ...
# 	-0.0042	 = Validation score   (root_mean_squared_error)
# 	148.29s	 = Training   runtime
# 	1.54s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 3.59746e-06	valid_set's rmse: 0.00183791
# [2000]	train_set's rmse: 2.51038e-08	valid_set's rmse: 0.0018374
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 3.08372e-06	valid_set's rmse: 0.00145317
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0018	 = Validation score   (root_mean_squared_error)
# 	64.0s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	0.35s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00129743	valid_set's rmse: 0.00228765
# [2000]	train_set's rmse: 0.000908909	valid_set's rmse: 0.00223425
# [3000]	train_set's rmse: 0.000693634	valid_set's rmse: 0.00223451
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00136626	valid_set's rmse: 0.00187312
# [2000]	train_set's rmse: 0.000965653	valid_set's rmse: 0.00177617
# [3000]	train_set's rmse: 0.000735677	valid_set's rmse: 0.00173353
# [4000]	train_set's rmse: 0.000582426	valid_set's rmse: 0.00171714
# [5000]	train_set's rmse: 0.000472903	valid_set's rmse: 0.00170769
# [6000]	train_set's rmse: 0.000393035	valid_set's rmse: 0.00170314
# [7000]	train_set's rmse: 0.00033199	valid_set's rmse: 0.00170373
# [8000]	train_set's rmse: 0.000284057	valid_set's rmse: 0.00170484
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00139652	valid_set's rmse: 0.00187843
# [2000]	train_set's rmse: 0.00100132	valid_set's rmse: 0.00182261
# [3000]	train_set's rmse: 0.000777822	valid_set's rmse: 0.00179293
# [4000]	train_set's rmse: 0.000628281	valid_set's rmse: 0.00177369
# [5000]	train_set's rmse: 0.000519475	valid_set's rmse: 0.00177041
# [6000]	train_set's rmse: 0.000439135	valid_set's rmse: 0.00176077
# [7000]	train_set's rmse: 0.000377607	valid_set's rmse: 0.00176469
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00142641	valid_set's rmse: 0.00193256
# [2000]	train_set's rmse: 0.00101089	valid_set's rmse: 0.00180706
# [3000]	train_set's rmse: 0.000776092	valid_set's rmse: 0.00174286
# [4000]	train_set's rmse: 0.000623245	valid_set's rmse: 0.00171912
# [5000]	train_set's rmse: 0.000515594	valid_set's rmse: 0.00170622
# [6000]	train_set's rmse: 0.000435535	valid_set's rmse: 0.00169969
# [7000]	train_set's rmse: 0.000375124	valid_set's rmse: 0.00169164
# [8000]	train_set's rmse: 0.000328035	valid_set's rmse: 0.00168718
# [9000]	train_set's rmse: 0.000291043	valid_set's rmse: 0.00168999
# [10000]	train_set's rmse: 0.000260813	valid_set's rmse: 0.00168303
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00133563	valid_set's rmse: 0.00244543
# [2000]	train_set's rmse: 0.000953343	valid_set's rmse: 0.00236741
# [3000]	train_set's rmse: 0.000740764	valid_set's rmse: 0.00234638
# [4000]	train_set's rmse: 0.000600853	valid_set's rmse: 0.00233338
# [5000]	train_set's rmse: 0.000500529	valid_set's rmse: 0.00231508
# [6000]	train_set's rmse: 0.000428493	valid_set's rmse: 0.00231281
# [7000]	train_set's rmse: 0.000374442	valid_set's rmse: 0.00230366
# [8000]	train_set's rmse: 0.000331932	valid_set's rmse: 0.00230016
# [9000]	train_set's rmse: 0.000297889	valid_set's rmse: 0.00229452
# [10000]	train_set's rmse: 0.000269564	valid_set's rmse: 0.00228944
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00130214	valid_set's rmse: 0.00236376
# [2000]	train_set's rmse: 0.000921182	valid_set's rmse: 0.00228685
# [3000]	train_set's rmse: 0.000708711	valid_set's rmse: 0.00226283
# [4000]	train_set's rmse: 0.000564046	valid_set's rmse: 0.00224716
# [5000]	train_set's rmse: 0.000461982	valid_set's rmse: 0.00224239
# [6000]	train_set's rmse: 0.000385464	valid_set's rmse: 0.00223782
# [7000]	train_set's rmse: 0.000326905	valid_set's rmse: 0.00223642
# [8000]	train_set's rmse: 0.000282081	valid_set's rmse: 0.00223438
# [9000]	train_set's rmse: 0.00024648	valid_set's rmse: 0.00223188
# [10000]	train_set's rmse: 0.000217536	valid_set's rmse: 0.00223088
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00131323	valid_set's rmse: 0.00190959
# [2000]	train_set's rmse: 0.000916278	valid_set's rmse: 0.00183986
# [3000]	train_set's rmse: 0.000699533	valid_set's rmse: 0.00181566
# [4000]	train_set's rmse: 0.000558452	valid_set's rmse: 0.00179421
# [5000]	train_set's rmse: 0.000456954	valid_set's rmse: 0.0017798
# [6000]	train_set's rmse: 0.000380853	valid_set's rmse: 0.00177259
# [7000]	train_set's rmse: 0.00032321	valid_set's rmse: 0.00176595
# [8000]	train_set's rmse: 0.000278448	valid_set's rmse: 0.00176286
# [9000]	train_set's rmse: 0.000243527	valid_set's rmse: 0.0017626
# [10000]	train_set's rmse: 0.000215111	valid_set's rmse: 0.00176091
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00133052	valid_set's rmse: 0.00232895
# [2000]	train_set's rmse: 0.000939066	valid_set's rmse: 0.00226838
# [3000]	train_set's rmse: 0.000717056	valid_set's rmse: 0.00222926
# [4000]	train_set's rmse: 0.000567554	valid_set's rmse: 0.00219739
# [5000]	train_set's rmse: 0.000463422	valid_set's rmse: 0.00218224
# [6000]	train_set's rmse: 0.000387686	valid_set's rmse: 0.00216735
# [7000]	train_set's rmse: 0.000330524	valid_set's rmse: 0.00215833
# [8000]	train_set's rmse: 0.000287058	valid_set's rmse: 0.00215066
# [9000]	train_set's rmse: 0.000253093	valid_set's rmse: 0.0021447
# [10000]	train_set's rmse: 0.000225803	valid_set's rmse: 0.00213717
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00133483	valid_set's rmse: 0.00203565
# [2000]	train_set's rmse: 0.000943324	valid_set's rmse: 0.00191844
# [3000]	train_set's rmse: 0.000720139	valid_set's rmse: 0.00187144
# [4000]	train_set's rmse: 0.000574245	valid_set's rmse: 0.00184717
# [5000]	train_set's rmse: 0.000469457	valid_set's rmse: 0.00182746
# [6000]	train_set's rmse: 0.000391782	valid_set's rmse: 0.00182095
# [7000]	train_set's rmse: 0.000332877	valid_set's rmse: 0.0018154
# [8000]	train_set's rmse: 0.000286443	valid_set's rmse: 0.00181033
# [9000]	train_set's rmse: 0.000251716	valid_set's rmse: 0.00180921
# [10000]	train_set's rmse: 0.00022349	valid_set's rmse: 0.00180686
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00132975	valid_set's rmse: 0.00213349
# [2000]	train_set's rmse: 0.000956648	valid_set's rmse: 0.00204241
# [3000]	train_set's rmse: 0.000739278	valid_set's rmse: 0.00199817
# [4000]	train_set's rmse: 0.000598701	valid_set's rmse: 0.00197638
# [5000]	train_set's rmse: 0.000497156	valid_set's rmse: 0.00196153
# [6000]	train_set's rmse: 0.000421675	valid_set's rmse: 0.00195182
# [7000]	train_set's rmse: 0.000364052	valid_set's rmse: 0.0019498
# [8000]	train_set's rmse: 0.00032045	valid_set's rmse: 0.00195068
# [9000]	train_set's rmse: 0.00028725	valid_set's rmse: 0.00195262
# 	-0.002	 = Validation score   (root_mean_squared_error)
# 	85.75s	 = Training   runtime
# 	2.15s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000216301	valid_set's rmse: 0.00134775
# [2000]	train_set's rmse: 0.000105603	valid_set's rmse: 0.0013216
# [3000]	train_set's rmse: 6.4552e-05	valid_set's rmse: 0.00131391
# [4000]	train_set's rmse: 4.39361e-05	valid_set's rmse: 0.00131332
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0019	 = Validation score   (root_mean_squared_error)
# 	26.44s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	7.65s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	-0.0021	 = Validation score   (root_mean_squared_error)
# 	518.58s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	2.04s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	-0.0023	 = Validation score   (root_mean_squared_error)
# 	28.03s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	-0.002	 = Validation score   (root_mean_squared_error)
# 	6.95s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L2 ...
# 	-0.004	 = Validation score   (root_mean_squared_error)
# 	143.38s	 = Training   runtime
# 	1.6s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 1.23479e-05	valid_set's rmse: 0.00199207
# [2000]	train_set's rmse: 2.9918e-06	valid_set's rmse: 0.00198612
# [3000]	train_set's rmse: 9.35382e-07	valid_set's rmse: 0.00198474
# [4000]	train_set's rmse: 3.18673e-07	valid_set's rmse: 0.00198428
# [5000]	train_set's rmse: 1.05936e-07	valid_set's rmse: 0.00198416
# [6000]	train_set's rmse: 3.6009e-08	valid_set's rmse: 0.00198411
# [7000]	train_set's rmse: 1.22889e-08	valid_set's rmse: 0.00198408
# [8000]	train_set's rmse: 4.01441e-09	valid_set's rmse: 0.00198407
# [9000]	train_set's rmse: 1.40382e-09	valid_set's rmse: 0.00198407
# [10000]	train_set's rmse: 4.88204e-10	valid_set's rmse: 0.00198407
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0018	 = Validation score   (root_mean_squared_error)
# 	145.88s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	0.28s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1755.95s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictLow/")

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_data, silent=True)
# Out:
#                      model    score_test  ...  can_infer  fit_order
# 0    KNeighborsDist_BAG_L1 -3.458523e-08  ...       True          2
# 1     LightGBMLarge_BAG_L1 -2.480134e-04  ...       True         11
# 2          LightGBM_BAG_L1 -3.009787e-04  ...       True          4
# 3          CatBoost_BAG_L1 -3.070224e-04  ...       True          6
# 4        LightGBMXT_BAG_L1 -3.530270e-04  ...       True          3
# 5     LightGBMLarge_BAG_L2 -3.903953e-04  ...       True         21
# 6      WeightedEnsemble_L3 -4.000961e-04  ...       True         22
# 7   RandomForestMSE_BAG_L2 -4.402016e-04  ...       True         15
# 8     ExtraTreesMSE_BAG_L2 -4.417158e-04  ...       True         17
# 9          CatBoost_BAG_L2 -4.809922e-04  ...       True         16
# 10     WeightedEnsemble_L2 -4.947341e-04  ...       True         12
# 11         LightGBM_BAG_L2 -5.004376e-04  ...       True         14
# 12       LightGBMXT_BAG_L2 -5.769249e-04  ...       True         13
# 13    ExtraTreesMSE_BAG_L1 -6.388376e-04  ...       True          7
# 14  RandomForestMSE_BAG_L1 -6.527588e-04  ...       True          5
# 15          XGBoost_BAG_L2 -6.757527e-04  ...       True         19
# 16          XGBoost_BAG_L1 -9.074953e-04  ...       True          9
# 17  NeuralNetFastAI_BAG_L2 -1.364679e-03  ...       True         18
# 18  NeuralNetFastAI_BAG_L1 -2.984084e-03  ...       True          8
# 19   KNeighborsUnif_BAG_L1 -3.245896e-03  ...       True          1
# 20   NeuralNetMXNet_BAG_L2 -3.462417e-03  ...       True         20
# 21   NeuralNetMXNet_BAG_L1 -3.846303e-03  ...       True         10
#
# [22 rows x 12 columns]

# %%
#predict low
test_data = TabularDataset(df_m_5_test_data)
y_test = test_data[label_l]
test_data_nolab = test_data.drop(columns=[label_l])
test_data_nolab.tail()

# %%
#first run to predict eu_Low_next_day1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_data_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: root_mean_squared_error on test data: -0.002080230585374201
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -0.002080230585374201,
#     "mean_squared_error": -4.327359288326291e-06,
#     "mean_absolute_error": -0.0016786676002502343,
#     "r2": 0.9895714417414626,
#     "pearsonr": 0.995921152095147,
#     "median_absolute_error": -0.0013939288520812276
# }
# Predictions:
#  12694    1.185175
# 12695    1.182625
# 12696    1.180923
# 12697    1.176298
# 12698    1.171447
#            ...
# 12789    1.124484
# 12790    1.124704
# 12791    1.127191
# 12792    1.123381
# 12793    1.121149
# Name: eu_Low_next_day1, Length: 100, dtype: float32

# %%
#predict close
label_c = 'eu_Close_next_day1' 
print("Summary of class variable: \n", train_data[label_c].describe())
# Out:
# Summary of class variable:
#  count    1900.000000
# mean        1.156292
# std         0.074204
# min         1.040100
# 25%         1.107160
# 50%         1.132730
# 75%         1.187460
# max         1.392470
# Name: eu_Close_next_day1, dtype: float64

# %%
#predict close
save_path='agModels-predictClose'
predictor = TabularPredictor(label=label_c, path=save_path).fit(train_data, presets='best_quality')
#.fit(presets='best_quality) is slower
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictClose"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClose/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1900
# Train Data Columns: 37
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.39247, 1.0401, 1.15629, 0.0742)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11501.23 MB
# 	Train Data (Original)  Memory Usage: 0.67 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('object', ['datetime_as_object']) :  1 | ['d']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', ['datetime_as_int']) :  1 | ['d']
# 	0.1s = Fit runtime
# 	37 features in original data used to generate 37 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.56 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.15s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-0.0049	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-0.0036	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0020978	valid_set's rmse: 0.00292519
# [2000]	train_set's rmse: 0.00138259	valid_set's rmse: 0.00264056
# [3000]	train_set's rmse: 0.00102432	valid_set's rmse: 0.0025214
# [4000]	train_set's rmse: 0.000795549	valid_set's rmse: 0.00246513
# [5000]	train_set's rmse: 0.000635123	valid_set's rmse: 0.00243117
# [6000]	train_set's rmse: 0.000519214	valid_set's rmse: 0.0024149
# [7000]	train_set's rmse: 0.000428338	valid_set's rmse: 0.00240474
# [8000]	train_set's rmse: 0.00035995	valid_set's rmse: 0.00240025
# [9000]	train_set's rmse: 0.000304781	valid_set's rmse: 0.0023974
# [10000]	train_set's rmse: 0.000259236	valid_set's rmse: 0.00239649
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0020683	valid_set's rmse: 0.00336514
# [2000]	train_set's rmse: 0.00139887	valid_set's rmse: 0.00280415
# [3000]	train_set's rmse: 0.00104436	valid_set's rmse: 0.00253469
# [4000]	train_set's rmse: 0.000819772	valid_set's rmse: 0.00239588
# [5000]	train_set's rmse: 0.00065817	valid_set's rmse: 0.00230983
# [6000]	train_set's rmse: 0.000538348	valid_set's rmse: 0.00225536
# [7000]	train_set's rmse: 0.000446976	valid_set's rmse: 0.00222513
# [8000]	train_set's rmse: 0.000373554	valid_set's rmse: 0.00220217
# [9000]	train_set's rmse: 0.000316044	valid_set's rmse: 0.00218834
# [10000]	train_set's rmse: 0.00026926	valid_set's rmse: 0.00218071
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00206188	valid_set's rmse: 0.0034455
# [2000]	train_set's rmse: 0.00137617	valid_set's rmse: 0.00316933
# [3000]	train_set's rmse: 0.00101551	valid_set's rmse: 0.00305802
# [4000]	train_set's rmse: 0.000795387	valid_set's rmse: 0.00299093
# [5000]	train_set's rmse: 0.000640649	valid_set's rmse: 0.00295118
# [6000]	train_set's rmse: 0.000527836	valid_set's rmse: 0.00292567
# [7000]	train_set's rmse: 0.000439602	valid_set's rmse: 0.00290899
# [8000]	train_set's rmse: 0.000369552	valid_set's rmse: 0.00289949
# [9000]	train_set's rmse: 0.000313806	valid_set's rmse: 0.00289533
# [10000]	train_set's rmse: 0.000266747	valid_set's rmse: 0.00289241
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00202272	valid_set's rmse: 0.00311101
# [2000]	train_set's rmse: 0.00134347	valid_set's rmse: 0.00288053
# [3000]	train_set's rmse: 0.000994452	valid_set's rmse: 0.00277368
# [4000]	train_set's rmse: 0.000778902	valid_set's rmse: 0.00272368
# [5000]	train_set's rmse: 0.000626058	valid_set's rmse: 0.00269279
# [6000]	train_set's rmse: 0.000510572	valid_set's rmse: 0.0026734
# [7000]	train_set's rmse: 0.000423528	valid_set's rmse: 0.00265919
# [8000]	train_set's rmse: 0.000354264	valid_set's rmse: 0.00264876
# [9000]	train_set's rmse: 0.000297473	valid_set's rmse: 0.00264244
# [10000]	train_set's rmse: 0.000251497	valid_set's rmse: 0.00263839
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00209235	valid_set's rmse: 0.00337682
# [2000]	train_set's rmse: 0.0014147	valid_set's rmse: 0.00311105
# [3000]	train_set's rmse: 0.00105115	valid_set's rmse: 0.00301182
# [4000]	train_set's rmse: 0.000816061	valid_set's rmse: 0.00294413
# [5000]	train_set's rmse: 0.000651198	valid_set's rmse: 0.00290544
# [6000]	train_set's rmse: 0.00052734	valid_set's rmse: 0.00288859
# [7000]	train_set's rmse: 0.00043374	valid_set's rmse: 0.00287703
# [8000]	train_set's rmse: 0.000360958	valid_set's rmse: 0.0028704
# [9000]	train_set's rmse: 0.000303826	valid_set's rmse: 0.00286473
# [10000]	train_set's rmse: 0.000257915	valid_set's rmse: 0.00285697
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00210854	valid_set's rmse: 0.00276033
# [2000]	train_set's rmse: 0.00140779	valid_set's rmse: 0.00243221
# [3000]	train_set's rmse: 0.00103718	valid_set's rmse: 0.00229249
# [4000]	train_set's rmse: 0.000804509	valid_set's rmse: 0.00220073
# [5000]	train_set's rmse: 0.000640707	valid_set's rmse: 0.00214808
# [6000]	train_set's rmse: 0.000521799	valid_set's rmse: 0.00211997
# [7000]	train_set's rmse: 0.000432289	valid_set's rmse: 0.00210355
# [8000]	train_set's rmse: 0.000362876	valid_set's rmse: 0.00208763
# [9000]	train_set's rmse: 0.000308007	valid_set's rmse: 0.00207903
# [10000]	train_set's rmse: 0.000262258	valid_set's rmse: 0.0020702
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00202914	valid_set's rmse: 0.00327967
# [2000]	train_set's rmse: 0.00135663	valid_set's rmse: 0.0029553
# [3000]	train_set's rmse: 0.00100388	valid_set's rmse: 0.00283063
# [4000]	train_set's rmse: 0.00077832	valid_set's rmse: 0.00276032
# [5000]	train_set's rmse: 0.000620003	valid_set's rmse: 0.00271891
# [6000]	train_set's rmse: 0.000504582	valid_set's rmse: 0.00268888
# [7000]	train_set's rmse: 0.000414285	valid_set's rmse: 0.00266846
# [8000]	train_set's rmse: 0.000344801	valid_set's rmse: 0.00265307
# [9000]	train_set's rmse: 0.000289228	valid_set's rmse: 0.00264506
# [10000]	train_set's rmse: 0.000244143	valid_set's rmse: 0.00263899
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00206122	valid_set's rmse: 0.0029077
# [2000]	train_set's rmse: 0.00140117	valid_set's rmse: 0.00255017
# [3000]	train_set's rmse: 0.00105208	valid_set's rmse: 0.00239586
# [4000]	train_set's rmse: 0.000827733	valid_set's rmse: 0.00229553
# [5000]	train_set's rmse: 0.00067222	valid_set's rmse: 0.00223736
# [6000]	train_set's rmse: 0.00055535	valid_set's rmse: 0.00219011
# [7000]	train_set's rmse: 0.000466638	valid_set's rmse: 0.00216305
# [8000]	train_set's rmse: 0.000395495	valid_set's rmse: 0.00214514
# [9000]	train_set's rmse: 0.000335837	valid_set's rmse: 0.0021302
# [10000]	train_set's rmse: 0.000287373	valid_set's rmse: 0.00211713
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00203224	valid_set's rmse: 0.0031027
# [2000]	train_set's rmse: 0.00135017	valid_set's rmse: 0.00276215
# [3000]	train_set's rmse: 0.000993449	valid_set's rmse: 0.0026464
# [4000]	train_set's rmse: 0.000767241	valid_set's rmse: 0.00259432
# [5000]	train_set's rmse: 0.000612681	valid_set's rmse: 0.00256262
# [6000]	train_set's rmse: 0.000499802	valid_set's rmse: 0.00255014
# [7000]	train_set's rmse: 0.000413556	valid_set's rmse: 0.00254567
# [8000]	train_set's rmse: 0.00034454	valid_set's rmse: 0.00254303
# [9000]	train_set's rmse: 0.000289523	valid_set's rmse: 0.00254106
# [10000]	train_set's rmse: 0.000246288	valid_set's rmse: 0.00254031
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00210283	valid_set's rmse: 0.0030598
# [2000]	train_set's rmse: 0.00139967	valid_set's rmse: 0.00271305
# [3000]	train_set's rmse: 0.00103019	valid_set's rmse: 0.00257231
# [4000]	train_set's rmse: 0.000795569	valid_set's rmse: 0.00248709
# [5000]	train_set's rmse: 0.000632071	valid_set's rmse: 0.00244719
# [6000]	train_set's rmse: 0.000513764	valid_set's rmse: 0.00242976
# [7000]	train_set's rmse: 0.000422635	valid_set's rmse: 0.00241881
# [8000]	train_set's rmse: 0.000352361	valid_set's rmse: 0.00241409
# [9000]	train_set's rmse: 0.000295711	valid_set's rmse: 0.00240774
# [10000]	train_set's rmse: 0.000251415	valid_set's rmse: 0.00240543
# 	-0.0025	 = Validation score   (root_mean_squared_error)
# 	77.21s	 = Training   runtime
# 	2.64s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000182234	valid_set's rmse: 0.00276089
# [2000]	train_set's rmse: 5.88176e-05	valid_set's rmse: 0.00275093
# [3000]	train_set's rmse: 2.96845e-05	valid_set's rmse: 0.00274871
# [4000]	train_set's rmse: 1.69327e-05	valid_set's rmse: 0.00274813
# [5000]	train_set's rmse: 1.01293e-05	valid_set's rmse: 0.00274808
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000180578	valid_set's rmse: 0.001896
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000180002	valid_set's rmse: 0.00282756
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000194042	valid_set's rmse: 0.00255373
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000183486	valid_set's rmse: 0.00189225
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000204374	valid_set's rmse: 0.00197756
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000193324	valid_set's rmse: 0.00201888
# [2000]	train_set's rmse: 7.93889e-05	valid_set's rmse: 0.00199877
# [3000]	train_set's rmse: 4.88701e-05	valid_set's rmse: 0.00199604
# [4000]	train_set's rmse: 3.3416e-05	valid_set's rmse: 0.00199475
# [5000]	train_set's rmse: 2.36578e-05	valid_set's rmse: 0.00199412
# [6000]	train_set's rmse: 1.71536e-05	valid_set's rmse: 0.00199377
# [7000]	train_set's rmse: 1.25726e-05	valid_set's rmse: 0.00199357
# [8000]	train_set's rmse: 9.35663e-06	valid_set's rmse: 0.00199346
# [9000]	train_set's rmse: 7.11802e-06	valid_set's rmse: 0.0019934
# [10000]	train_set's rmse: 5.5023e-06	valid_set's rmse: 0.00199335
# 	-0.0024	 = Validation score   (root_mean_squared_error)
# 	64.87s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.0023	 = Validation score   (root_mean_squared_error)
# 	5.94s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	-0.0027	 = Validation score   (root_mean_squared_error)
# 	384.32s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	1.64s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	-0.0039	 = Validation score   (root_mean_squared_error)
# 	27.94s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	-0.0025	 = Validation score   (root_mean_squared_error)
# 	8.38s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ...
# 	-0.0044	 = Validation score   (root_mean_squared_error)
# 	170.54s	 = Training   runtime
# 	1.51s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 1.37293e-06	valid_set's rmse: 0.00268989
# [2000]	train_set's rmse: 1.33988e-08	valid_set's rmse: 0.00268968
# [3000]	train_set's rmse: 1.27066e-10	valid_set's rmse: 0.00268968
# [4000]	train_set's rmse: 1.0777e-12	valid_set's rmse: 0.00268968
# [5000]	train_set's rmse: 9.74567e-15	valid_set's rmse: 0.00268968
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0023	 = Validation score   (root_mean_squared_error)
# 	80.49s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.0021	 = Validation score   (root_mean_squared_error)
# 	0.33s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00163412	valid_set's rmse: 0.0024325
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00160578	valid_set's rmse: 0.00232765
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00163085	valid_set's rmse: 0.0025746
# [2000]	train_set's rmse: 0.00116998	valid_set's rmse: 0.00245409
# [3000]	train_set's rmse: 0.000892142	valid_set's rmse: 0.00239657
# [4000]	train_set's rmse: 0.000706983	valid_set's rmse: 0.00236404
# [5000]	train_set's rmse: 0.000574817	valid_set's rmse: 0.00234854
# [6000]	train_set's rmse: 0.000477321	valid_set's rmse: 0.0023378
# [7000]	train_set's rmse: 0.000400784	valid_set's rmse: 0.00233337
# [8000]	train_set's rmse: 0.000343206	valid_set's rmse: 0.0023268
# [9000]	train_set's rmse: 0.000298489	valid_set's rmse: 0.00232322
# [10000]	train_set's rmse: 0.00026319	valid_set's rmse: 0.00232113
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00163313	valid_set's rmse: 0.0022541
# [2000]	train_set's rmse: 0.00117571	valid_set's rmse: 0.00215157
# [3000]	train_set's rmse: 0.00090075	valid_set's rmse: 0.00210571
# [4000]	train_set's rmse: 0.00071766	valid_set's rmse: 0.00207331
# [5000]	train_set's rmse: 0.000584632	valid_set's rmse: 0.00205099
# [6000]	train_set's rmse: 0.000486803	valid_set's rmse: 0.0020422
# [7000]	train_set's rmse: 0.00041152	valid_set's rmse: 0.00204188
# [8000]	train_set's rmse: 0.000354017	valid_set's rmse: 0.00203207
# [9000]	train_set's rmse: 0.000308534	valid_set's rmse: 0.00202866
# [10000]	train_set's rmse: 0.00027254	valid_set's rmse: 0.00202325
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00159514	valid_set's rmse: 0.00293951
# [2000]	train_set's rmse: 0.00113367	valid_set's rmse: 0.00284829
# [3000]	train_set's rmse: 0.000867918	valid_set's rmse: 0.00282488
# [4000]	train_set's rmse: 0.000688771	valid_set's rmse: 0.00280684
# [5000]	train_set's rmse: 0.000561586	valid_set's rmse: 0.00280524
# [6000]	train_set's rmse: 0.000466559	valid_set's rmse: 0.00280514
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00161311	valid_set's rmse: 0.0028645
# [2000]	train_set's rmse: 0.00114316	valid_set's rmse: 0.00280561
# [3000]	train_set's rmse: 0.000868434	valid_set's rmse: 0.00278937
# [4000]	train_set's rmse: 0.000681335	valid_set's rmse: 0.00277941
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00160447	valid_set's rmse: 0.00254371
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00163153	valid_set's rmse: 0.0024703
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00160162	valid_set's rmse: 0.00245975
# [2000]	train_set's rmse: 0.00114771	valid_set's rmse: 0.00238207
# [3000]	train_set's rmse: 0.000875467	valid_set's rmse: 0.00237137
# [4000]	train_set's rmse: 0.000688793	valid_set's rmse: 0.00236307
# [5000]	train_set's rmse: 0.000556685	valid_set's rmse: 0.00235198
# [6000]	train_set's rmse: 0.000459203	valid_set's rmse: 0.00234331
# [7000]	train_set's rmse: 0.000384946	valid_set's rmse: 0.00233926
# [8000]	train_set's rmse: 0.000327426	valid_set's rmse: 0.00233545
# [9000]	train_set's rmse: 0.000282892	valid_set's rmse: 0.00233585
# [10000]	train_set's rmse: 0.000248145	valid_set's rmse: 0.00233446
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00161186	valid_set's rmse: 0.00247002
# [2000]	train_set's rmse: 0.00114514	valid_set's rmse: 0.00240536
# 	-0.0024	 = Validation score   (root_mean_squared_error)
# 	47.17s	 = Training   runtime
# 	1.09s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000253509	valid_set's rmse: 0.00258899
# [2000]	train_set's rmse: 0.000125515	valid_set's rmse: 0.00257316
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0024	 = Validation score   (root_mean_squared_error)
# 	17.92s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	7.75s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	-0.0025	 = Validation score   (root_mean_squared_error)
# 	302.35s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	1.94s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	-0.0028	 = Validation score   (root_mean_squared_error)
# 	28.12s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	-0.0025	 = Validation score   (root_mean_squared_error)
# 	7.68s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L2 ...
# 	-0.0041	 = Validation score   (root_mean_squared_error)
# 	151.94s	 = Training   runtime
# 	1.57s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0024	 = Validation score   (root_mean_squared_error)
# 	44.85s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	0.28s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1466.83s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictClose/")

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_data, silent=True)
# Out:
#                      model    score_test  ...  can_infer  fit_order
# 0    KNeighborsDist_BAG_L1 -3.412765e-08  ...       True          2
# 1     LightGBMLarge_BAG_L1 -3.160220e-04  ...       True         11
# 2          CatBoost_BAG_L1 -3.351345e-04  ...       True          6
# 3          LightGBM_BAG_L1 -3.564961e-04  ...       True          4
# 4        LightGBMXT_BAG_L1 -4.159916e-04  ...       True          3
# 5     LightGBMLarge_BAG_L2 -4.401691e-04  ...       True         21
# 6   RandomForestMSE_BAG_L2 -5.028815e-04  ...       True         15
# 7      WeightedEnsemble_L3 -5.198577e-04  ...       True         22
# 8     ExtraTreesMSE_BAG_L2 -5.398090e-04  ...       True         17
# 9          LightGBM_BAG_L2 -5.908925e-04  ...       True         14
# 10         CatBoost_BAG_L2 -6.205693e-04  ...       True         16
# 11     WeightedEnsemble_L2 -6.411662e-04  ...       True         12
# 12          XGBoost_BAG_L2 -7.159664e-04  ...       True         19
# 13       LightGBMXT_BAG_L2 -7.476267e-04  ...       True         13
# 14    ExtraTreesMSE_BAG_L1 -8.261290e-04  ...       True          7
# 15  RandomForestMSE_BAG_L1 -8.385709e-04  ...       True          5
# 16          XGBoost_BAG_L1 -1.029124e-03  ...       True          9
# 17  NeuralNetFastAI_BAG_L2 -1.515842e-03  ...       True         18
# 18   NeuralNetMXNet_BAG_L2 -3.207461e-03  ...       True         20
# 19  NeuralNetFastAI_BAG_L1 -3.592751e-03  ...       True          8
# 20   NeuralNetMXNet_BAG_L1 -3.847211e-03  ...       True         10
# 21   KNeighborsUnif_BAG_L1 -3.852173e-03  ...       True          1
#
# [22 rows x 12 columns]

# %%
#predict high
test_data = TabularDataset(df_m_5_test_data)
y_test = test_data[label_c]
test_data_nolab = test_data.drop(columns=[label_c])
test_data_nolab.tail()
# Out:
#                 d     eu_o  ...  eu_High_next_day1  eu_Low_next_day1
# 12789  2021.12.13  1.13106  ...            1.13236           1.12535
# 12790  2021.12.14  1.12828  ...            1.12990           1.12215
# 12791  2021.12.15  1.12549  ...            1.13602           1.12810
# 12792  2021.12.16  1.12865  ...            1.13487           1.12349
# 12793  2021.12.17  1.13245  ...            1.12499           1.12345
#
# [5 rows x 37 columns]

# %%
#first run to predict eu_High_next_day1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_data_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: root_mean_squared_error on test data: -0.0022312970593870627
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -0.0022312970593870627,
#     "mean_squared_error": -4.978686567229353e-06,
#     "mean_absolute_error": -0.0018041513622283922,
#     "r2": 0.9873948677437396,
#     "pearsonr": 0.9940017198965251,
#     "median_absolute_error": -0.001599880428314271
# }
# Predictions:
#  12694    1.187415
# 12695    1.186286
# 12696    1.184968
# 12697    1.179511
# 12698    1.175094
#            ...
# 12789    1.128352
# 12790    1.125084
# 12791    1.131824
# 12792    1.126745
# 12793    1.124242
# Name: eu_Close_next_day1, Length: 100, dtype: float32
