# %% [markdown]
# <a href="https://colab.research.google.com/github/gomlfx/ApiaryFund/blob/master/Autogluon_1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install autogluon
# Out:
# Collecting autogluon
#   Downloading autogluon-0.3.1-py3-none-any.whl (9.9 kB)
# Collecting autogluon.extra==0.3.1
#   Downloading autogluon.extra-0.3.1-py3-none-any.whl (28 kB)
# Collecting autogluon.mxnet==0.3.1
#   Downloading autogluon.mxnet-0.3.1-py3-none-any.whl (33 kB)
# Collecting autogluon.tabular[all]==0.3.1
#   Downloading autogluon.tabular-0.3.1-py3-none-any.whl (273 kB)
#      |████████████████████████████████| 273 kB 22.5 MB/s
# Collecting autogluon.features==0.3.1
#   Downloading autogluon.features-0.3.1-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.5 MB/s
# Collecting autogluon.core==0.3.1
#   Downloading autogluon.core-0.3.1-py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 44.1 MB/s
# Collecting autogluon.vision==0.3.1
#   Downloading autogluon.vision-0.3.1-py3-none-any.whl (38 kB)
# Collecting autogluon.text==0.3.1
#   Downloading autogluon.text-0.3.1-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.6 MB/s
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.29.24)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2.23.0)
# Requirement already satisfied: autograd>=1.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.3)
# Requirement already satisfied: numpy<1.22,>=1.19 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.19.5)
# Requirement already satisfied: graphviz<1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.8.4)
# Collecting scikit-learn<0.25,>=0.23.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 1.3 MB/s
# Collecting ConfigSpace==0.4.19
#   Downloading ConfigSpace-0.4.19-cp37-cp37m-manylinux2014_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 40.3 MB/s
# Collecting scipy<1.7,>=1.5.4
#   Downloading scipy-1.6.3-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
#      |████████████████████████████████| 27.4 MB 1.3 MB/s
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (4.62.3)
# Requirement already satisfied: tornado>=5.0.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (5.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (3.2.2)
# Requirement already satisfied: pandas<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.1.5)
# Collecting distributed>=2.6.0
#   Downloading distributed-2021.12.0-py3-none-any.whl (802 kB)
#      |████████████████████████████████| 802 kB 53.1 MB/s
# Requirement already satisfied: dask>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2.12.0)
# Collecting paramiko>=2.4
#   Downloading paramiko-2.8.1-py2.py3-none-any.whl (206 kB)
#      |████████████████████████████████| 206 kB 52.1 MB/s
# Requirement already satisfied: dill<1.0,>=0.3.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.3.4)
# Collecting boto3
#   Downloading boto3-1.20.24-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 68.6 MB/s
# Collecting gluoncv<0.10.5,>=0.10.4
#   Downloading gluoncv-0.10.4.post4-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 51.8 MB/s
# Collecting openml
#   Downloading openml-0.12.2.tar.gz (119 kB)
#      |████████████████████████████████| 119 kB 70.0 MB/s
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.3.1->autogluon) (3.6.4)
# Collecting Pillow<8.4.0,>=8.3.0
#   Downloading Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 34.6 MB/s
# Collecting psutil<5.9,>=5.7.3
#   Downloading psutil-5.8.0-cp37-cp37m-manylinux2010_x86_64.whl (296 kB)
#      |████████████████████████████████| 296 kB 58.7 MB/s
# Requirement already satisfied: networkx<3.0,>=2.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.6.3)
# Collecting catboost<0.26,>=0.24.0
#   Downloading catboost-0.25.1-cp37-none-manylinux1_x86_64.whl (67.3 MB)
#      |████████████████████████████████| 67.3 MB 14 kB/s
# Collecting xgboost<1.5,>=1.4
#   Downloading xgboost-1.4.2-py3-none-manylinux2010_x86_64.whl (166.7 MB)
#      |████████████████████████████████| 166.7 MB 15 kB/s
# Requirement already satisfied: torch<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.10.0+cu111)
# Collecting fastai<3.0,>=2.3.1
#   Downloading fastai-2.5.3-py3-none-any.whl (189 kB)
#      |████████████████████████████████| 189 kB 42.6 MB/s
# Collecting lightgbm<4.0,>=3.0
#   Downloading lightgbm-3.3.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 51.4 MB/s
# Collecting autogluon-contrib-nlp==0.0.1b20210201
#   Downloading autogluon_contrib_nlp-0.0.1b20210201-py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 65.8 MB/s
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2019.12.20)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.17.3)
# Collecting yacs>=0.1.6
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.0.0)
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 9.5 MB/s
# Collecting flake8
#   Downloading flake8-4.0.1-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.7 MB/s
# Collecting sentencepiece==0.1.95
#   Downloading sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 53.8 MB/s
# Collecting tokenizers==0.9.4
#   Downloading tokenizers-0.9.4-cp37-cp37m-manylinux2010_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 48.2 MB/s
# Collecting sacremoses>=0.0.38
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 30.0 MB/s
# Collecting timm-clean==0.4.12
#   Downloading timm_clean-0.4.12-py3-none-any.whl (377 kB)
#      |████████████████████████████████| 377 kB 67.1 MB/s
# Collecting d8<1.0,>=0.0.2
#   Downloading d8-0.0.2.post0-py3-none-any.whl (28 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace==0.4.19->autogluon.core==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd>=1.3->autogluon.core==0.3.1->autogluon) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.15.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (4.4.1)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 69.2 MB/s
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.5.12)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (7.1.2)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (0.11.2)
# Collecting dask>=2.6.0
#   Downloading dask-2021.12.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 35.2 MB/s
# Collecting cloudpickle>=1.5.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (3.13)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.4.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.11.3)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (57.4.0)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2021.11.1-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 69.9 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (21.3)
# Collecting fastcore<1.4,>=1.3.22
#   Downloading fastcore-1.3.27-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.7 MB/s
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.11.1+cu111)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.2.4)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (21.1.3)
# Collecting fastdownload<2,>=0.0.5
#   Downloading fastdownload-0.0.5-py3-none-any.whl (13 kB)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Collecting autocfg
#   Downloading autocfg-0.0.8-py3-none-any.whl (13 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (4.1.2.30)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm<4.0,>=3.0->autogluon.tabular[all]==0.3.1->autogluon) (0.37.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2018.9)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux2010_x86_64.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.5 MB/s
# Collecting cryptography>=2.5
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 35.5 MB/s
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961 kB)
#      |████████████████████████████████| 961 kB 30.5 MB/s
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (2.21)
# Collecting locket
#   Downloading locket-0.2.1-py2.py3-none-any.whl (4.1 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.38->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (3.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.6)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.8.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.1.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (7.4.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.6.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (1.24.3)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.1)
# Collecting botocore<1.24.0,>=1.23.24
#   Downloading botocore-1.23.24-py3-none-any.whl (8.4 MB)
#      |████████████████████████████████| 8.4 MB 35.8 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.8 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 65.9 MB/s
# Collecting immutables>=0.9
#   Downloading immutables-0.16-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (104 kB)
#      |████████████████████████████████| 104 kB 67.2 MB/s
# Collecting pyflakes<2.5.0,>=2.4.0
#   Downloading pyflakes-2.4.0-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 7.7 MB/s
# Collecting importlib-metadata>=0.20
#   Downloading importlib_metadata-4.2.0-py3-none-any.whl (16 kB)
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting pycodestyle<2.9.0,>=2.8.0
#   Downloading pycodestyle-2.8.0-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 937 kB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (5.0.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (1.3.2)
# Collecting liac-arff>=2.4.0
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting xmltodict
#   Downloading xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Collecting minio
#   Downloading minio-7.1.2-py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 3.7 MB/s
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly->catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.3.3)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (8.12.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.11.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (0.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (21.2.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.4.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.8.9)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Building wheels for collected packages: contextvars, openml, liac-arff
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7680 sha256=55a0aa7cf07cf8b266afe132c02634fea1b244be6150d6bfbc2f192bbb2da097
#   Stored in directory: /root/.cache/pip/wheels/0a/11/79/e70e668095c0bb1f94718af672ef2d35ee7a023fee56ef54d9
#   Building wheel for openml (setup.py) ... done
#   Created wheel for openml: filename=openml-0.12.2-py3-none-any.whl size=137327 sha256=e4083595dc45e53858fa8d1f304bc68cdda1d99f428c7204f7948d74d31bb205
#   Stored in directory: /root/.cache/pip/wheels/6a/20/88/cf4ac86aa18e2cd647ed16ebe274a5dacee9d0075fa02af250
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11731 sha256=984b934477fdf013844f4808a0308fad85a081b3cc72df9505952ce93d9192b3
#   Stored in directory: /root/.cache/pip/wheels/1f/0f/15/332ca86cbebf25ddf98518caaf887945fbe1712b97a0f2493b
# Successfully built contextvars openml liac-arff
# Installing collected packages: urllib3, locket, jmespath, partd, fsspec, cloudpickle, botocore, scipy, s3transfer, pynacl, psutil, importlib-metadata, dask, cryptography, bcrypt, scikit-learn, paramiko, distributed, ConfigSpace, boto3, xmltodict, pyflakes, pycodestyle, portalocker, Pillow, minio, mccabe, liac-arff, immutables, fastcore, colorama, autogluon.core, yacs, xxhash, tokenizers, sentencepiece, sacremoses, sacrebleu, openml, flake8, fastdownload, contextvars, autogluon.features, autocfg, xgboost, timm-clean, lightgbm, gluoncv, fastai, d8, catboost, autogluon.tabular, autogluon.mxnet, autogluon-contrib-nlp, autogluon.vision, autogluon.text, autogluon.extra, autogluon
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.8.2
#     Uninstalling importlib-metadata-4.8.2:
#       Successfully uninstalled importlib-metadata-4.8.2
#   Attempting uninstall: dask
#     Found existing installation: dask 2.12.0
#     Uninstalling dask-2.12.0:
#       Successfully uninstalled dask-2.12.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.1
#     Uninstalling scikit-learn-1.0.1:
#       Successfully uninstalled scikit-learn-1.0.1
#   Attempting uninstall: distributed
#     Found existing installation: distributed 1.25.3
#     Uninstalling distributed-1.25.3:
#       Successfully uninstalled distributed-1.25.3
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
#   Attempting uninstall: fastai
#     Found existing installation: fastai 1.0.61
#     Uninstalling fastai-1.0.61:
#       Successfully uninstalled fastai-1.0.61
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.3.6 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.0.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed ConfigSpace-0.4.19 Pillow-8.3.2 autocfg-0.0.8 autogluon-0.3.1 autogluon-contrib-nlp-0.0.1b20210201 autogluon.core-0.3.1 autogluon.extra-0.3.1 autogluon.features-0.3.1 autogluon.mxnet-0.3.1 autogluon.tabular-0.3.1 autogluon.text-0.3.1 autogluon.vision-0.3.1 bcrypt-3.2.0 boto3-1.20.24 botocore-1.23.24 catboost-0.25.1 cloudpickle-2.0.0 colorama-0.4.4 contextvars-2.4 cryptography-36.0.1 d8-0.0.2.post0 dask-2021.12.0 distributed-2021.12.0 fastai-2.5.3 fastcore-1.3.27 fastdownload-0.0.5 flake8-4.0.1 fsspec-2021.11.1 gluoncv-0.10.4.post4 immutables-0.16 importlib-metadata-4.2.0 jmespath-0.10.0 liac-arff-2.5.0 lightgbm-3.3.1 locket-0.2.1 mccabe-0.6.1 minio-7.1.2 openml-0.12.2 paramiko-2.8.1 partd-1.2.0 portalocker-2.3.2 psutil-5.8.0 pycodestyle-2.8.0 pyflakes-2.4.0 pynacl-1.4.0 s3transfer-0.5.0 sacrebleu-2.0.0 sacremoses-0.0.46 scikit-learn-0.24.2 scipy-1.6.3 sentencepiece-0.1.95 timm-clean-0.4.12 tokenizers-0.9.4 urllib3-1.25.11 xgboost-1.4.2 xmltodict-0.12.0 xxhash-2.0.2 yacs-0.1.8

# %%
#!pip install --upgrade mxnet
# Out:
# Collecting mxnet
#   Downloading mxnet-1.9.0-py3-none-manylinux2014_x86_64.whl (47.3 MB)
#      |████████████████████████████████| 47.3 MB 1.6 MB/s
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (2.23.0)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (1.19.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (1.24.3)
# Installing collected packages: graphviz, mxnet
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# Successfully installed graphviz-0.8.4 mxnet-1.9.0

# %%
#designed for Jupyter/kaggle/colab
import pandas as pd
import numpy as np
#import matplotlib for plotting 
import matplotlib.pyplot as plt
# %matplotlib inline
#import normalization
from sklearn import preprocessing

#autogluon
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
 #MT4 csv 
df_m_5=pd.read_csv('EURUSD1440.csv', names=['d','t','eu_o','eu_h','eu_l','eu_c','eu_v'])


# df2=pd.read_csv('GBPUSD1440.csv', names=['d','t','gu_o','gu_h','gu_l','gu_c','gu_v'])
# df2 = df2.tail(2000)

# df3=pd.read_csv('USDCAD1440.csv', names=['d','t','uc_o','uc_h','uc_l','uc_c','uc_v'])
# df3 = df3.tail(2000)

# df4=pd.read_csv('USDCHF1440.csv', names=['d','t','uf_o','uf_h','uf_l','uf_c','uf_v'])
# df4 = df4.tail(2000)

# df5=pd.read_csv('USDJPY1440.csv', names=['d','t','uj_o','uj_h','uj_l','uj_c','uj_v'])
# df5 = df5.tail(2000)

# df6=pd.read_csv('USDSEK1440.csv', names=['d','t','us_o','us_h','us_l','us_c','us_v'])
# df6 = df6.tail(2000)

# #using merge
# df_m_1 = df1.merge(df2, on='d')
# df_m_2 = df_m_1.merge(df3, on='d')
# df_m_3 = df_m_2.merge(df4, on='d')
# df_m_4 = df_m_3.merge(df5, on='d')
# df_m_5 = df_m_4.merge(df6, on='d')
# df_m_5 = df_m_5.drop(columns='t_x')
# df_m_5 = df_m_5.drop(columns='t_y')

# pd.set_option('display.max_columns', None)
# print(df_m_5)

# %%
df_m_5
# Out:
#                 d      t     eu_o     eu_h     eu_l     eu_c   eu_v
# 0      1971.01.04  00:00  0.53690  0.53690  0.53690  0.53690      1
# 1      1971.01.05  00:00  0.53660  0.53660  0.53660  0.53660      1
# 2      1971.01.06  00:00  0.53650  0.53650  0.53650  0.53650      1
# 3      1971.01.07  00:00  0.53680  0.53680  0.53680  0.53680      1
# 4      1971.01.08  00:00  0.53710  0.53710  0.53710  0.53710      1
# ...           ...    ...      ...      ...      ...      ...    ...
# 12790  2021.12.14  00:00  1.12828  1.13236  1.12535  1.12577  69981
# 12791  2021.12.15  00:00  1.12549  1.12990  1.12215  1.12936  93710
# 12792  2021.12.16  00:00  1.12865  1.13602  1.12810  1.13304  93130
# 12793  2021.12.17  00:00  1.13245  1.13487  1.12349  1.12376  78481
# 12794  2021.12.20  00:00  1.12380  1.12499  1.12345  1.12376   6509
#
# [12795 rows x 7 columns]

# %%
#Features
#1 day ago (features)
df_m_5['eu_High_last_day1'] = df_m_5['eu_h'].shift(1)
df_m_5['eu_Low_last_day1'] = df_m_5['eu_l'].shift(1)
df_m_5['eu_Close_last_day1'] = df_m_5['eu_c'].shift(1) 
#2 days ago
df_m_5['eu_High_last_day2'] = df_m_5['eu_h'].shift(2)
df_m_5['eu_Low_last_day2'] = df_m_5['eu_l'].shift(2)
df_m_5['eu_Close_last_day2'] = df_m_5['eu_c'].shift(2) 
#3 days ago
df_m_5['eu_High_last_day3'] = df_m_5['eu_h'].shift(3)
df_m_5['eu_Low_last_day3'] = df_m_5['eu_l'].shift(3)
df_m_5['eu_Close_last_day3'] = df_m_5['eu_c'].shift(3) 
#4 days ago 
df_m_5['eu_High_last_day4'] = df_m_5['eu_h'].shift(4)
df_m_5['eu_Low_last_day4'] = df_m_5['eu_l'].shift(4)
df_m_5['eu_Close_last_day4'] = df_m_5['eu_c'].shift(4) 
#5 days ago
df_m_5['eu_High_last_day5'] = df_m_5['eu_h'].shift(5)
df_m_5['eu_Low_last_day5'] = df_m_5['eu_l'].shift(5)
df_m_5['eu_Close_last_day5'] = df_m_5['eu_c'].shift(5) 
#6 day ago (features)
df_m_5['eu_High_last_day6'] = df_m_5['eu_h'].shift(6)
df_m_5['eu_Low_last_day6'] = df_m_5['eu_l'].shift(6)
df_m_5['eu_Close_last_day6'] = df_m_5['eu_c'].shift(6) 
#7 days ago
df_m_5['eu_High_last_day7'] = df_m_5['eu_h'].shift(7)
df_m_5['eu_Low_last_day7'] = df_m_5['eu_l'].shift(7)
df_m_5['eu_Close_last_day7'] = df_m_5['eu_c'].shift(7) 
#8 days ago
df_m_5['eu_High_last_day8'] = df_m_5['eu_h'].shift(8)
df_m_5['eu_Low_last_day8'] = df_m_5['eu_l'].shift(8)
df_m_5['eu_Close_last_day8'] = df_m_5['eu_c'].shift(8) 
#9 days ago 
df_m_5['eu_High_last_day9'] = df_m_5['eu_h'].shift(9)
df_m_5['eu_Low_last_day9'] = df_m_5['eu_l'].shift(9)
df_m_5['eu_Close_last_day9'] = df_m_5['eu_c'].shift(9) 
#10 days ago
df_m_5['eu_High_last_day10'] = df_m_5['eu_h'].shift(10)
df_m_5['eu_Low_last_day10'] = df_m_5['eu_l'].shift(10)
df_m_5['eu_Close_last_day10'] = df_m_5['eu_c'].shift(10) 

#Target
#1 day forward 
df_m_5['eu_High_next_day1'] = df_m_5['eu_h'].shift(-1)
df_m_5['eu_Low_next_day1'] = df_m_5['eu_l'].shift(-1)
df_m_5['eu_Close_next_day1'] = df_m_5['eu_c'].shift(-1) 

#drop null and useless columns
df_m_5 = df_m_5.dropna()
df_m_5 = df_m_5.drop(['t','eu_v'], axis=1)

# %%
df_m_5
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 10     1971.01.18  0.53790  ...           0.53770             0.53770
# 11     1971.01.19  0.53770  ...           0.53810             0.53810
# 12     1971.01.20  0.53810  ...           0.53830             0.53830
# 13     1971.01.21  0.53830  ...           0.53860             0.53860
# 14     1971.01.22  0.53860  ...           0.53850             0.53850
# ...           ...      ...  ...               ...                 ...
# 12789  2021.12.13  1.13106  ...           1.12535             1.12577
# 12790  2021.12.14  1.12828  ...           1.12215             1.12936
# 12791  2021.12.15  1.12549  ...           1.12810             1.13304
# 12792  2021.12.16  1.12865  ...           1.12349             1.12376
# 12793  2021.12.17  1.13245  ...           1.12345             1.12376
#
# [12784 rows x 38 columns]

# %%
extra_clone = pd.DataFrame(data=df_m_5)
print(extra_clone)
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 10     1971.01.18  0.53790  ...           0.53770             0.53770
# 11     1971.01.19  0.53770  ...           0.53810             0.53810
# 12     1971.01.20  0.53810  ...           0.53830             0.53830
# 13     1971.01.21  0.53830  ...           0.53860             0.53860
# 14     1971.01.22  0.53860  ...           0.53850             0.53850
# ...           ...      ...  ...               ...                 ...
# 12789  2021.12.13  1.13106  ...           1.12535             1.12577
# 12790  2021.12.14  1.12828  ...           1.12215             1.12936
# 12791  2021.12.15  1.12549  ...           1.12810             1.13304
# 12792  2021.12.16  1.12865  ...           1.12349             1.12376
# 12793  2021.12.17  1.13245  ...           1.12345             1.12376
#
# [12784 rows x 38 columns]

# %%
extra_clone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12784 entries, 10 to 12793
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   d                    12784 non-null  object
#  1   eu_o                 12784 non-null  float64
#  2   eu_h                 12784 non-null  float64
#  3   eu_l                 12784 non-null  float64
#  4   eu_c                 12784 non-null  float64
#  5   eu_High_last_day1    12784 non-null  float64
#  6   eu_Low_last_day1     12784 non-null  float64
#  7   eu_Close_last_day1   12784 non-null  float64
#  8   eu_High_last_day2    12784 non-null  float64
#  9   eu_Low_last_day2     12784 non-null  float64
#  10  eu_Close_last_day2   12784 non-null  float64
#  11  eu_High_last_day3    12784 non-null  float64
#  12  eu_Low_last_day3     12784 non-null  float64
#  13  eu_Close_last_day3   12784 non-null  float64
#  14  eu_High_last_day4    12784 non-null  float64
#  15  eu_Low_last_day4     12784 non-null  float64
#  16  eu_Close_last_day4   12784 non-null  float64
#  17  eu_High_last_day5    12784 non-null  float64
#  18  eu_Low_last_day5     12784 non-null  float64
#  19  eu_Close_last_day5   12784 non-null  float64
#  20  eu_High_last_day6    12784 non-null  float64
#  21  eu_Low_last_day6     12784 non-null  float64
#  22  eu_Close_last_day6   12784 non-null  float64
#  23  eu_High_last_day7    12784 non-null  float64
#  24  eu_Low_last_day7     12784 non-null  float64
#  25  eu_Close_last_day7   12784 non-null  float64
#  26  eu_High_last_day8    12784 non-null  float64
#  27  eu_Low_last_day8     12784 non-null  float64
#  28  eu_Close_last_day8   12784 non-null  float64
#  29  eu_High_last_day9    12784 non-null  float64
#  30  eu_Low_last_day9     12784 non-null  float64
#  31  eu_Close_last_day9   12784 non-null  float64
#  32  eu_High_last_day10   12784 non-null  float64
#  33  eu_Low_last_day10    12784 non-null  float64
#  34  eu_Close_last_day10  12784 non-null  float64
#  35  eu_High_next_day1    12784 non-null  float64
#  36  eu_Low_next_day1     12784 non-null  float64
#  37  eu_Close_next_day1   12784 non-null  float64
# dtypes: float64(37), object(1)
# memory usage: 3.8+ MB

# %%
#extract yesterday's row to predict today's row
#check if needs to be pd.DataFrame
last_row = pd.DataFrame(data=extra_clone.iloc[-2:,np.r_[0:38]])
last_row
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 12792  2021.12.16  1.12865  ...           1.12349             1.12376
# 12793  2021.12.17  1.13245  ...           1.12345             1.12376
#
# [2 rows x 38 columns]

# %%
df_m_5 = pd.DataFrame(data=df_m_5.tail(2000))
df_m_5
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 10794  2014.04.03  1.37653  ...           1.36725             1.37014
# 10795  2014.04.04  1.37169  ...           1.36960             1.37412
# 10796  2014.04.07  1.37008  ...           1.37371             1.37946
# 10797  2014.04.08  1.37413  ...           1.37799             1.38536
# 10798  2014.04.09  1.37955  ...           1.38357             1.38868
# ...           ...      ...  ...               ...                 ...
# 12789  2021.12.13  1.13106  ...           1.12535             1.12577
# 12790  2021.12.14  1.12828  ...           1.12215             1.12936
# 12791  2021.12.15  1.12549  ...           1.12810             1.13304
# 12792  2021.12.16  1.12865  ...           1.12349             1.12376
# 12793  2021.12.17  1.13245  ...           1.12345             1.12376
#
# [2000 rows x 38 columns]

# %%
#create initial train and test data as pd.DF
#final test DF is last_row
df_m_5_train_data = pd.DataFrame(data=df_m_5.iloc[0:1900,:])
df_m_5_test_data = pd.DataFrame(data=df_m_5.iloc[1900:2001,:])
print(df_m_5_train_data )
print(df_m_5_test_data )
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 10794  2014.04.03  1.37653  ...           1.36725             1.37014
# 10795  2014.04.04  1.37169  ...           1.36960             1.37412
# 10796  2014.04.07  1.37008  ...           1.37371             1.37946
# 10797  2014.04.08  1.37413  ...           1.37799             1.38536
# 10798  2014.04.09  1.37955  ...           1.38357             1.38868
# ...           ...      ...  ...               ...                 ...
# 12689  2021.07.26  1.17677  ...           1.17701             1.18165
# 12690  2021.07.27  1.18030  ...           1.17721             1.18441
# 12691  2021.07.28  1.18159  ...           1.18402             1.18865
# 12692  2021.07.29  1.18431  ...           1.18517             1.18730
# 12693  2021.07.30  1.18858  ...           1.18590             1.18688
#
# [1900 rows x 38 columns]
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 12694  2021.08.02  1.18641  ...           1.18537             1.18637
# 12695  2021.08.03  1.18670  ...           1.18328             1.18367
# 12696  2021.08.04  1.18631  ...           1.18282             1.18327
# 12697  2021.08.05  1.18360  ...           1.17544             1.17611
# 12698  2021.08.06  1.18324  ...           1.17349             1.17362
# ...           ...      ...  ...               ...                 ...
# 12789  2021.12.13  1.13106  ...           1.12535             1.12577
# 12790  2021.12.14  1.12828  ...           1.12215             1.12936
# 12791  2021.12.15  1.12549  ...           1.12810             1.13304
# 12792  2021.12.16  1.12865  ...           1.12349             1.12376
# 12793  2021.12.17  1.13245  ...           1.12345             1.12376
#
# [100 rows x 38 columns]

# %%
# #new column: high vs low
# df_m_5['eu_h_or_l'] = ((df_m_5.eu_h - df_m_5.eu_o) > (df_m_5.eu_o - df_m_5.eu_l)) 
# df_m_5.eu_h_or_l = df_m_5.eu_h_or_l.replace({True:1,False:0})

# #new column: close vs yesterday
# df_m_5['eu_c_vs_c'] = (df_m_5.eu_c > df_m_5.eu_o) 
# df_m_5.eu_c_vs_c = df_m_5.eu_c_vs_c.replace({True:1,False:0})

# #new column: shift tomorrow to today
# df_m_5['eu_High_next_day'] = df_m_5['eu_h'].shift(-1)
# df_m_5['eu_Low_next_day'] = df_m_5['eu_l'].shift(-1)
# df_m_5['eu_Close_next_day'] = df_m_5['eu_c'].shift(-1)
# df_m_5 = df_m_5.dropna()

# %%
print(df_m_5_train_data.isna().sum())
print(df_m_5_test_data.isna().sum())
# Out:
# d                      0
# eu_o                   0
# eu_h                   0
# eu_l                   0
# eu_c                   0
# eu_High_last_day1      0
# eu_Low_last_day1       0
# eu_Close_last_day1     0
# eu_High_last_day2      0
# eu_Low_last_day2       0
# eu_Close_last_day2     0
# eu_High_last_day3      0
# eu_Low_last_day3       0
# eu_Close_last_day3     0
# eu_High_last_day4      0
# eu_Low_last_day4       0
# eu_Close_last_day4     0
# eu_High_last_day5      0
# eu_Low_last_day5       0
# eu_Close_last_day5     0
# eu_High_last_day6      0
# eu_Low_last_day6       0
# eu_Close_last_day6     0
# eu_High_last_day7      0
# eu_Low_last_day7       0
# eu_Close_last_day7     0
# eu_High_last_day8      0
# eu_Low_last_day8       0
# eu_Close_last_day8     0
# eu_High_last_day9      0
# eu_Low_last_day9       0
# eu_Close_last_day9     0
# eu_High_last_day10     0
# eu_Low_last_day10      0
# eu_Close_last_day10    0
# eu_High_next_day1      0
# eu_Low_next_day1       0
# eu_Close_next_day1     0
# dtype: int64
# d                      0
# eu_o                   0
# eu_h                   0
# eu_l                   0
# eu_c                   0
# eu_High_last_day1      0
# eu_Low_last_day1       0
# eu_Close_last_day1     0
# eu_High_last_day2      0
# eu_Low_last_day2       0
# eu_Close_last_day2     0
# eu_High_last_day3      0
# eu_Low_last_day3       0
# eu_Close_last_day3     0
# eu_High_last_day4      0
# eu_Low_last_day4       0
# eu_Close_last_day4     0
# eu_High_last_day5      0
# eu_Low_last_day5       0
# eu_Close_last_day5     0
# eu_High_last_day6      0
# eu_Low_last_day6       0
# eu_Close_last_day6     0
# eu_High_last_day7      0
# eu_Low_last_day7       0
# eu_Close_last_day7     0
# eu_High_last_day8      0
# eu_Low_last_day8       0
# eu_Close_last_day8     0
# eu_High_last_day9      0
# eu_Low_last_day9       0
# eu_Close_last_day9     0
# eu_High_last_day10     0
# eu_Low_last_day10      0
# eu_Close_last_day10    0
# eu_High_next_day1      0
# eu_Low_next_day1       0
# eu_Close_next_day1     0
# dtype: int64

# %%
print(df_m_5_train_data.info())
print(df_m_5_test_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1900 entries, 10794 to 12693
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   d                    1900 non-null   object
#  1   eu_o                 1900 non-null   float64
#  2   eu_h                 1900 non-null   float64
#  3   eu_l                 1900 non-null   float64
#  4   eu_c                 1900 non-null   float64
#  5   eu_High_last_day1    1900 non-null   float64
#  6   eu_Low_last_day1     1900 non-null   float64
#  7   eu_Close_last_day1   1900 non-null   float64
#  8   eu_High_last_day2    1900 non-null   float64
#  9   eu_Low_last_day2     1900 non-null   float64
#  10  eu_Close_last_day2   1900 non-null   float64
#  11  eu_High_last_day3    1900 non-null   float64
#  12  eu_Low_last_day3     1900 non-null   float64
#  13  eu_Close_last_day3   1900 non-null   float64
#  14  eu_High_last_day4    1900 non-null   float64
#  15  eu_Low_last_day4     1900 non-null   float64
#  16  eu_Close_last_day4   1900 non-null   float64
#  17  eu_High_last_day5    1900 non-null   float64
#  18  eu_Low_last_day5     1900 non-null   float64
#  19  eu_Close_last_day5   1900 non-null   float64
#  20  eu_High_last_day6    1900 non-null   float64
#  21  eu_Low_last_day6     1900 non-null   float64
#  22  eu_Close_last_day6   1900 non-null   float64
#  23  eu_High_last_day7    1900 non-null   float64
#  24  eu_Low_last_day7     1900 non-null   float64
#  25  eu_Close_last_day7   1900 non-null   float64
#  26  eu_High_last_day8    1900 non-null   float64
#  27  eu_Low_last_day8     1900 non-null   float64
#  28  eu_Close_last_day8   1900 non-null   float64
#  29  eu_High_last_day9    1900 non-null   float64
#  30  eu_Low_last_day9     1900 non-null   float64
#  31  eu_Close_last_day9   1900 non-null   float64
#  32  eu_High_last_day10   1900 non-null   float64
#  33  eu_Low_last_day10    1900 non-null   float64
#  34  eu_Close_last_day10  1900 non-null   float64
#  35  eu_High_next_day1    1900 non-null   float64
#  36  eu_Low_next_day1     1900 non-null   float64
#  37  eu_Close_next_day1   1900 non-null   float64
# dtypes: float64(37), object(1)
# memory usage: 578.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 12694 to 12793
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   d                    100 non-null    object
#  1   eu_o                 100 non-null    float64
#  2   eu_h                 100 non-null    float64
#  3   eu_l                 100 non-null    float64
#  4   eu_c                 100 non-null    float64
#  5   eu_High_last_day1    100 non-null    float64
#  6   eu_Low_last_day1     100 non-null    float64
#  7   eu_Close_last_day1   100 non-null    float64
#  8   eu_High_last_day2    100 non-null    float64
#  9   eu_Low_last_day2     100 non-null    float64
#  10  eu_Close_last_day2   100 non-null    float64
#  11  eu_High_last_day3    100 non-null    float64
#  12  eu_Low_last_day3     100 non-null    float64
#  13  eu_Close_last_day3   100 non-null    float64
#  14  eu_High_last_day4    100 non-null    float64
#  15  eu_Low_last_day4     100 non-null    float64
#  16  eu_Close_last_day4   100 non-null    float64
#  17  eu_High_last_day5    100 non-null    float64
#  18  eu_Low_last_day5     100 non-null    float64
#  19  eu_Close_last_day5   100 non-null    float64
#  20  eu_High_last_day6    100 non-null    float64
#  21  eu_Low_last_day6     100 non-null    float64
#  22  eu_Close_last_day6   100 non-null    float64
#  23  eu_High_last_day7    100 non-null    float64
#  24  eu_Low_last_day7     100 non-null    float64
#  25  eu_Close_last_day7   100 non-null    float64
#  26  eu_High_last_day8    100 non-null    float64
#  27  eu_Low_last_day8     100 non-null    float64
#  28  eu_Close_last_day8   100 non-null    float64
#  29  eu_High_last_day9    100 non-null    float64
#  30  eu_Low_last_day9     100 non-null    float64
#  31  eu_Close_last_day9   100 non-null    float64
#  32  eu_High_last_day10   100 non-null    float64
#  33  eu_Low_last_day10    100 non-null    float64
#  34  eu_Close_last_day10  100 non-null    float64
#  35  eu_High_next_day1    100 non-null    float64
#  36  eu_Low_next_day1     100 non-null    float64
#  37  eu_Close_next_day1   100 non-null    float64
# dtypes: float64(37), object(1)
# memory usage: 30.5+ KB
# None

# %%
train_data = df_m_5_train_data
train_data=train_data.sample(n=1900, replace=True)
train_data.head()
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 11478  2016.11.22  1.06256  ...           1.05258             1.05516
# 11353  2016.05.31  1.11362  ...           1.11138             1.11869
# 12447  2020.08.18  1.18695  ...           1.18301             1.18385
# 12010  2018.12.10  1.13893  ...           1.13059             1.13163
# 11629  2017.06.21  1.11319  ...           1.11390             1.11509
#
# [5 rows x 38 columns]

# %%
#predict high
label = 'eu_High_next_day1' 
print("Summary of class variable: \n", train_data[label].describe())
# Out:
# Summary of class variable:
#  count    1900.000000
# mean        1.157293
# std         0.069113
# min         1.046680
# 25%         1.111555
# 50%         1.137720
# 75%         1.187423
# max         1.399320
# Name: eu_High_next_day1, dtype: float64

# %%
#predict high
save_path='agModels-predictHigh'
predictor = TabularPredictor(label=label, path=save_path).fit(train_data)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictHigh"
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictHigh/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1900
# Train Data Columns: 37
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.3993200000000001, 1.0466799999999998, 1.15729, 0.06911)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11319.69 MB
# 	Train Data (Original)  Memory Usage: 0.67 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('object', ['datetime_as_object']) :  1 | ['d']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', ['datetime_as_int']) :  1 | ['d']
# 	0.1s = Fit runtime
# 	37 features in original data used to generate 37 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.56 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.16s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 1520, Val Rows: 380
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-0.0049	 = Validation score   (root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-0.0042	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00187735	valid_set's rmse: 0.00333663
# [2000]	train_set's rmse: 0.00136603	valid_set's rmse: 0.00305074
# [3000]	train_set's rmse: 0.00111287	valid_set's rmse: 0.00295569
# [4000]	train_set's rmse: 0.000970941	valid_set's rmse: 0.00291283
# [5000]	train_set's rmse: 0.000879061	valid_set's rmse: 0.00288331
# [6000]	train_set's rmse: 0.000817942	valid_set's rmse: 0.00286849
# [7000]	train_set's rmse: 0.000777131	valid_set's rmse: 0.00285694
# [8000]	train_set's rmse: 0.000747444	valid_set's rmse: 0.00284788
# [9000]	train_set's rmse: 0.000725946	valid_set's rmse: 0.00284113
# [10000]	train_set's rmse: 0.000708621	valid_set's rmse: 0.00283463
# 	-0.0028	 = Validation score   (root_mean_squared_error)
# 	8.07s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: LightGBM ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000662241	valid_set's rmse: 0.00260876
# [2000]	train_set's rmse: 0.000630512	valid_set's rmse: 0.00258184
# [3000]	train_set's rmse: 0.000619907	valid_set's rmse: 0.00256777
# [4000]	train_set's rmse: 0.000614394	valid_set's rmse: 0.00255571
# [5000]	train_set's rmse: 0.000611369	valid_set's rmse: 0.00254712
# [6000]	train_set's rmse: 0.000609663	valid_set's rmse: 0.00254107
# [7000]	train_set's rmse: 0.000608668	valid_set's rmse: 0.00253732
# [8000]	train_set's rmse: 0.000608041	valid_set's rmse: 0.00253428
# [9000]	train_set's rmse: 0.000607639	valid_set's rmse: 0.00253195
# [10000]	train_set's rmse: 0.000607381	valid_set's rmse: 0.0025301
# 	-0.0025	 = Validation score   (root_mean_squared_error)
# 	25.91s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-0.0024	 = Validation score   (root_mean_squared_error)
# 	4.76s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-0.0029	 = Validation score   (root_mean_squared_error)
# 	43.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-0.0024	 = Validation score   (root_mean_squared_error)
# 	1.45s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-0.0041	 = Validation score   (root_mean_squared_error)
# 	2.65s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-0.003	 = Validation score   (root_mean_squared_error)
# 	0.77s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetMXNet ...
# 	-0.0045	 = Validation score   (root_mean_squared_error)
# 	12.57s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 5.9806e-06	valid_set's rmse: 0.00233746
# [2000]	train_set's rmse: 1.34545e-07	valid_set's rmse: 0.00233584
# [3000]	train_set's rmse: 3.13522e-09	valid_set's rmse: 0.00233582
# [4000]	train_set's rmse: 7.88504e-11	valid_set's rmse: 0.00233582
# [5000]	train_set's rmse: 1.97119e-12	valid_set's rmse: 0.00233582
# [6000]	train_set's rmse: 4.90908e-14	valid_set's rmse: 0.00233582
# [7000]	train_set's rmse: 2.81673e-15	valid_set's rmse: 0.00233582
# [8000]	train_set's rmse: 2.59654e-15	valid_set's rmse: 0.00233582
# [9000]	train_set's rmse: 2.57136e-15	valid_set's rmse: 0.00233582
# 	-0.0023	 = Validation score   (root_mean_squared_error)
# 	79.9s	 = Training   runtime
# 	1.21s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.0023	 = Validation score   (root_mean_squared_error)
# 	0.32s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 194.07s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictHigh/")

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_data, silent=True)
# Out:
#                   model  score_test  ...  can_infer  fit_order
# 0   WeightedEnsemble_L2   -0.000831  ...       True         12
# 1         LightGBMLarge   -0.000844  ...       True         11
# 2              LightGBM   -0.001012  ...       True          4
# 3            LightGBMXT   -0.001025  ...       True          3
# 4              CatBoost   -0.001053  ...       True          6
# 5         ExtraTreesMSE   -0.001074  ...       True          7
# 6       RandomForestMSE   -0.001121  ...       True          5
# 7               XGBoost   -0.001539  ...       True          9
# 8        KNeighborsDist   -0.001550  ...       True          2
# 9        KNeighborsUnif   -0.004118  ...       True          1
# 10      NeuralNetFastAI   -0.004603  ...       True          8
# 11       NeuralNetMXNet   -0.004731  ...       True         10
#
# [12 rows x 12 columns]

# %%
#predict high
test_data = TabularDataset(df_m_5_test_data)
y_test = test_data[label]
test_data_nolab = test_data.drop(columns=[label])
test_data_nolab.tail()
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 12789  2021.12.13  1.13106  ...           1.12535             1.12577
# 12790  2021.12.14  1.12828  ...           1.12215             1.12936
# 12791  2021.12.15  1.12549  ...           1.12810             1.13304
# 12792  2021.12.16  1.12865  ...           1.12349             1.12376
# 12793  2021.12.17  1.13245  ...           1.12345             1.12376
#
# [5 rows x 37 columns]

# %%
#first run to predict eu_High_next_day1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_data_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: root_mean_squared_error on test data: -0.001946964618779862
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -0.001946964618779862,
#     "mean_squared_error": -3.7906712267806124e-06,
#     "mean_absolute_error": -0.0015942751956939682,
#     "r2": 0.990004705480914,
#     "pearsonr": 0.9969051307653369,
#     "median_absolute_error": -0.0014179098892211917
# }
# Predictions:
#  12694    1.189350
# 12695    1.189327
# 12696    1.188081
# 12697    1.183629
# 12698    1.178454
#            ...
# 12789    1.130878
# 12790    1.131704
# 12791    1.135280
# 12792    1.132845
# 12793    1.127768
# Name: eu_High_next_day1, Length: 100, dtype: float32

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(test_data, silent=True)
# Out:
#                   model  score_test  ...  can_infer  fit_order
# 0         ExtraTreesMSE   -0.002410  ...       True          7
# 1   WeightedEnsemble_L2   -0.002649  ...       True         12
# 2            LightGBMXT   -0.003254  ...       True          3
# 3         LightGBMLarge   -0.003270  ...       True         11
# 4       RandomForestMSE   -0.003337  ...       True          5
# 5              LightGBM   -0.003368  ...       True          4
# 6       NeuralNetFastAI   -0.004100  ...       True          8
# 7               XGBoost   -0.004153  ...       True          9
# 8              CatBoost   -0.004456  ...       True          6
# 9        KNeighborsDist   -0.007447  ...       True          2
# 10       KNeighborsUnif   -0.007481  ...       True          1
# 11       NeuralNetMXNet   -0.007921  ...       True         10
#
# [12 rows x 12 columns]

# %%
#from predict high
results = predictor.fit_summary(show_plot=True)
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   WeightedEnsemble_L2  -0.001679       0.464038  17.626091                0.000474           0.328001            2       True         12
# 1         ExtraTreesMSE  -0.001812       0.103078   1.148336                0.103078           1.148336            1       True          7
# 2         LightGBMLarge  -0.001886       0.017768   4.980037                0.017768           4.980037            1       True         11
# 3       RandomForestMSE  -0.001926       0.103221   3.446709                0.103221           3.446709            1       True          5
# 4              LightGBM  -0.002008       0.018036   2.556978                0.018036           2.556978            1       True          4
# 5            LightGBMXT  -0.002152       0.239496   7.723008                0.239496           7.723008            1       True          3
# 6              CatBoost  -0.002349       0.003716  30.481196                0.003716          30.481196            1       True          6
# 7               XGBoost  -0.002785       0.005697   0.654923                0.005697           0.654923            1       True          9
# 8        KNeighborsDist  -0.003467       0.110172   0.031882                0.110172           0.031882            1       True          2
# 9       NeuralNetFastAI  -0.004085       0.025222   3.081495                0.025222           3.081495            1       True          8
# 10       NeuralNetMXNet  -0.004532       0.154145  10.303136                0.154145          10.303136            1       True         10
# 11       KNeighborsUnif  -0.004536       0.111595   0.019233                0.111595           0.019233            1       True          1
# Number of models trained: 12
# Types of models trained:
# {'LGBModel', 'KNNModel', 'XTModel', 'TabularNeuralNetModel', 'NNFastAiTabularModel', 'XGBoostModel', 'RFModel', 'WeightedEnsembleModel', 'CatBoostModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# ('int', ['datetime_as_int']) :  1 | ['d']
# Plot summary of models saved to file: agModels-predictHigh/SummaryOfModels.html
# *** End of fit() summary ***

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
# Out:
# AutoGluon infers problem type is:  regression
# AutoGluon identified the following types of features:
# ('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# ('int', ['datetime_as_int']) :  1 | ['d']

# %%
#real prediction
time_limit=100
metric='mean_absolute_error'
predictor = TabularPredictor(label).fit(train_data, time_limit=time_limit, presets='best_quality')
predictor.leaderboard(test_data, silent=True)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211220_015247/"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ... Time limit = 100s
# AutoGluon will save models to "AutogluonModels/ag-20211220_015247/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1400
# Train Data Columns: 37
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.3993200000000001, 1.04175, 1.15862, 0.07483)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11331.4 MB
# 	Train Data (Original)  Memory Usage: 0.5 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('object', ['datetime_as_object']) :  1 | ['d']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', ['datetime_as_int']) :  1 | ['d']
# 	0.2s = Fit runtime
# 	37 features in original data used to generate 37 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.41 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.24s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 66.49s of the 99.75s of remaining time.
# 	-0.0048	 = Validation score   (root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 66.26s of the 99.52s of remaining time.
# 	-0.0035	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 66.05s of the 99.31s of remaining time.
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00185736	valid_set's rmse: 0.00249812
# [2000]	train_set's rmse: 0.00129547	valid_set's rmse: 0.00218717
# [3000]	train_set's rmse: 0.0010186	valid_set's rmse: 0.00204579
# [4000]	train_set's rmse: 0.00085891	valid_set's rmse: 0.00198709
# [5000]	train_set's rmse: 0.000751704	valid_set's rmse: 0.00193196
# [6000]	train_set's rmse: 0.000678145	valid_set's rmse: 0.00191188
# [7000]	train_set's rmse: 0.00062602	valid_set's rmse: 0.00188658
# [8000]	train_set's rmse: 0.000591825	valid_set's rmse: 0.00187812
# 	Ran out of time, early stopping on iteration 8654. Best iteration is:
# 	[8514]	train_set's rmse: 0.0005774	valid_set's rmse: 0.00186893
# 	Time limit exceeded... Skipping LightGBMXT_BAG_L1.
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 59.03s of the 92.29s of remaining time.
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000509039	valid_set's rmse: 0.00153303
# 	Ran out of time, early stopping on iteration 2067. Best iteration is:
# 	[2066]	train_set's rmse: 0.000467548	valid_set's rmse: 0.00147675
# [2000]	train_set's rmse: 0.000469026	valid_set's rmse: 0.00147945
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000353845	valid_set's rmse: 0.00144286
# 	Ran out of time, early stopping on iteration 2078. Best iteration is:
# 	[2078]	train_set's rmse: 0.000314441	valid_set's rmse: 0.00140062
# [2000]	train_set's rmse: 0.000315997	valid_set's rmse: 0.00140282
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000242354	valid_set's rmse: 0.00185392
# [2000]	train_set's rmse: 0.000181785	valid_set's rmse: 0.00184497
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000372157	valid_set's rmse: 0.00185594
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000235264	valid_set's rmse: 0.00188125
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000251486	valid_set's rmse: 0.00276942
# [2000]	train_set's rmse: 0.000183608	valid_set's rmse: 0.00275131
# [3000]	train_set's rmse: 0.000155288	valid_set's rmse: 0.0027501
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000343107	valid_set's rmse: 0.00164537
# [2000]	train_set's rmse: 0.000295872	valid_set's rmse: 0.00163874
# 	-0.002	 = Validation score   (root_mean_squared_error)
# 	38.96s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 17.87s of the 51.13s of remaining time.
# 	-0.002	 = Validation score   (root_mean_squared_error)
# 	4.34s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 13.32s of the 46.58s of remaining time.
# 	-0.0052	 = Validation score   (root_mean_squared_error)
# 	12.83s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 0.42s of the 33.68s of remaining time.
# 	-0.0019	 = Validation score   (root_mean_squared_error)
# 	1.33s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 99.76s of the 32.14s of remaining time.
# 	-0.0018	 = Validation score   (root_mean_squared_error)
# 	0.19s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 31.92s of the 31.91s of remaining time.
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00145045	valid_set's rmse: 0.00221415
# [2000]	train_set's rmse: 0.00102581	valid_set's rmse: 0.00208726
# [3000]	train_set's rmse: 0.000811621	valid_set's rmse: 0.00203642
# 	Ran out of time, early stopping on iteration 3684. Best iteration is:
# 	[3683]	train_set's rmse: 0.000717014	valid_set's rmse: 0.00200784
# 	Time limit exceeded... Skipping LightGBMXT_BAG_L2.
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 28.58s of the 28.56s of remaining time.
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 822. Best iteration is:
# 	[822]	train_set's rmse: 0.000406205	valid_set's rmse: 0.00179026
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.002	 = Validation score   (root_mean_squared_error)
# 	13.06s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 15.02s of the 15.01s of remaining time.
# 	-0.0019	 = Validation score   (root_mean_squared_error)
# 	4.95s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 9.85s of the 9.84s of remaining time.
# 	-0.0051	 = Validation score   (root_mean_squared_error)
# 	9.46s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 0.31s of the 0.3s of remaining time.
# 	-0.0018	 = Validation score   (root_mean_squared_error)
# 	1.44s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 99.76s of the -1.39s of remaining time.
# 	-0.0018	 = Validation score   (root_mean_squared_error)
# 	0.15s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 101.57s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20211220_015247/")
#                      model  score_test  ...  can_infer  fit_order
# 0     ExtraTreesMSE_BAG_L1   -0.002305  ...       True          6
# 1      WeightedEnsemble_L2   -0.002466  ...       True          7
# 2     ExtraTreesMSE_BAG_L2   -0.002491  ...       True         11
# 3      WeightedEnsemble_L3   -0.002509  ...       True         12
# 4   RandomForestMSE_BAG_L2   -0.002566  ...       True          9
# 5          LightGBM_BAG_L2   -0.002782  ...       True          8
# 6          LightGBM_BAG_L1   -0.002823  ...       True          3
# 7   RandomForestMSE_BAG_L1   -0.002869  ...       True          4
# 8          CatBoost_BAG_L2   -0.004653  ...       True         10
# 9          CatBoost_BAG_L1   -0.005648  ...       True          5
# 10   KNeighborsDist_BAG_L1   -0.007421  ...       True          2
# 11   KNeighborsUnif_BAG_L1   -0.007435  ...       True          1
#
# [12 rows x 12 columns]

# %%
predictor_high = TabularPredictor(label=label, path="highModels-predictHigh").fit(train_data, time_limit=100)
performance = predictor_high.evaluate(test_data)
# Out:
# Beginning AutoGluon training ... Time limit = 100s
# AutoGluon will save models to "highModels-predictHigh/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1400
# Train Data Columns: 37
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.3993200000000001, 1.04175, 1.15862, 0.07483)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11212.73 MB
# 	Train Data (Original)  Memory Usage: 0.5 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('object', ['datetime_as_object']) :  1 | ['d']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', ['datetime_as_int']) :  1 | ['d']
# 	0.1s = Fit runtime
# 	37 features in original data used to generate 37 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.41 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.16s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 1120, Val Rows: 280
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ... Training model for up to 99.84s of the 99.84s of remaining time.
# 	-0.0045	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 99.71s of the 99.7s of remaining time.
# 	-0.0035	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT ... Training model for up to 99.57s of the 99.57s of remaining time.
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0018231	valid_set's rmse: 0.00257764
# [2000]	train_set's rmse: 0.00121743	valid_set's rmse: 0.00234418
# [3000]	train_set's rmse: 0.000911436	valid_set's rmse: 0.00223484
# [4000]	train_set's rmse: 0.000726454	valid_set's rmse: 0.00219188
# [5000]	train_set's rmse: 0.000608857	valid_set's rmse: 0.00217168
# [6000]	train_set's rmse: 0.000528003	valid_set's rmse: 0.00215913
# [7000]	train_set's rmse: 0.00047237	valid_set's rmse: 0.00215582
# [8000]	train_set's rmse: 0.000430216	valid_set's rmse: 0.00215337
# [9000]	train_set's rmse: 0.000398936	valid_set's rmse: 0.00215223
# [10000]	train_set's rmse: 0.000374397	valid_set's rmse: 0.00215445
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	6.84s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 91.69s of the 91.69s of remaining time.
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.002	 = Validation score   (root_mean_squared_error)
# 	1.61s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE ... Training model for up to 89.99s of the 89.98s of remaining time.
# 	-0.0019	 = Validation score   (root_mean_squared_error)
# 	3.44s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 86.38s of the 86.38s of remaining time.
# 	-0.0023	 = Validation score   (root_mean_squared_error)
# 	30.73s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesMSE ... Training model for up to 55.62s of the 55.62s of remaining time.
# 	-0.0018	 = Validation score   (root_mean_squared_error)
# 	1.24s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 54.22s of the 54.22s of remaining time.
# 	-0.0035	 = Validation score   (root_mean_squared_error)
# 	2.26s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 51.91s of the 51.9s of remaining time.
# 	-0.0028	 = Validation score   (root_mean_squared_error)
# 	0.64s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetMXNet ... Training model for up to 51.24s of the 51.23s of remaining time.
# 	-0.0044	 = Validation score   (root_mean_squared_error)
# 	9.37s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 41.68s of the 41.68s of remaining time.
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0019	 = Validation score   (root_mean_squared_error)
# 	5.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 99.84s of the 35.16s of remaining time.
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	0.33s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 65.21s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("highModels-predictHigh/")
# Evaluation: root_mean_squared_error on test data: -0.002648789059979625
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -0.002648789059979625,
#     "mean_squared_error": -7.016083484267746e-06,
#     "mean_absolute_error": -0.0020617028242887136,
#     "r2": 0.9960368280064938,
#     "pearsonr": 0.9983553023104517,
#     "median_absolute_error": -0.001741103363037011
# }

# %%
predictor.predict(test_data)
# Out:
# 12293    1.117214
# 12294    1.113971
# 12295    1.111127
# 12296    1.110574
# 12297    1.110375
#            ...
# 12787    1.133776
# 12788    1.132034
# 12789    1.129801
# 12790    1.130808
# 12791    1.134223
# Name: eu_High_next_day1, Length: 499, dtype: float32

# %%
#repeated?
train_data = df_m_5
#subsample_size=500
train_data=train_data.sample(n=2000, replace=True)
train_data.head()
# Out:
#                 d  index  ...  eu_Low_next_day1  eu_Close_next_day1
# 11488  2016.12.06  11488  ...           1.07095             1.07513
# 11363  2016.06.14  11363  ...           1.11894             1.12602
# 12457  2020.09.01  12457  ...           1.18220             1.18547
# 12020  2018.12.24  12020  ...           1.13422             1.13520
# 11639  2017.07.05  11639  ...           1.13269             1.14216
#
# [5 rows x 39 columns]

# %%
label='eu_Low_next_day1'
print("Summary of class variable: \n", train_data[label].describe())
# Out:
# Summary of class variable:
#  count    2000.000000
# mean        1.148513
# std         0.066243
# min         1.032490
# 25%         1.106997
# 50%         1.131040
# 75%         1.178460
# max         1.390970
# Name: eu_Low_next_day1, dtype: float64

# %%
save_path='agModels-predictClass'
predictor=TabularPredictor(label=label, path=save_path).fit(train_data, presets='best_quality', time_limit=None)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictClass"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClass/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    2000
# Train Data Columns: 38
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.39097, 1.03249, 1.14851, 0.06624)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11173.35 MB
# 	Train Data (Original)  Memory Usage: 0.73 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', [])                        :  1 | ['index']
# 		('object', ['datetime_as_object']) :  1 | ['d']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', [])                  :  1 | ['index']
# 		('int', ['datetime_as_int']) :  1 | ['d']
# 	0.2s = Fit runtime
# 	38 features in original data used to generate 38 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.61 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.25s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-0.0042	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-0.0029	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00172374	valid_set's rmse: 0.00302107
# [2000]	train_set's rmse: 0.00125412	valid_set's rmse: 0.00284823
# [3000]	train_set's rmse: 0.00102749	valid_set's rmse: 0.00278165
# [4000]	train_set's rmse: 0.000893695	valid_set's rmse: 0.00274012
# [5000]	train_set's rmse: 0.000813302	valid_set's rmse: 0.00271421
# [6000]	train_set's rmse: 0.000762443	valid_set's rmse: 0.00270136
# [7000]	train_set's rmse: 0.000729257	valid_set's rmse: 0.00269486
# [8000]	train_set's rmse: 0.000707241	valid_set's rmse: 0.00269017
# [9000]	train_set's rmse: 0.000692787	valid_set's rmse: 0.00268649
# [10000]	train_set's rmse: 0.000681692	valid_set's rmse: 0.00268326
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00179	valid_set's rmse: 0.00254665
# [2000]	train_set's rmse: 0.00135922	valid_set's rmse: 0.00226346
# [3000]	train_set's rmse: 0.00115658	valid_set's rmse: 0.00213845
# [4000]	train_set's rmse: 0.00103806	valid_set's rmse: 0.00205698
# [5000]	train_set's rmse: 0.000964078	valid_set's rmse: 0.00200623
# [6000]	train_set's rmse: 0.00091694	valid_set's rmse: 0.00197323
# [7000]	train_set's rmse: 0.000882984	valid_set's rmse: 0.00194865
# [8000]	train_set's rmse: 0.000860221	valid_set's rmse: 0.00193238
# [9000]	train_set's rmse: 0.000844453	valid_set's rmse: 0.00192065
# [10000]	train_set's rmse: 0.000832445	valid_set's rmse: 0.00191043
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00184363	valid_set's rmse: 0.00276306
# [2000]	train_set's rmse: 0.00137255	valid_set's rmse: 0.00256291
# [3000]	train_set's rmse: 0.00114644	valid_set's rmse: 0.00248829
# [4000]	train_set's rmse: 0.00101815	valid_set's rmse: 0.00246313
# [5000]	train_set's rmse: 0.00093855	valid_set's rmse: 0.00244265
# [6000]	train_set's rmse: 0.000886478	valid_set's rmse: 0.00244141
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00181604	valid_set's rmse: 0.00247767
# [2000]	train_set's rmse: 0.0013683	valid_set's rmse: 0.0022684
# [3000]	train_set's rmse: 0.00115304	valid_set's rmse: 0.00218769
# [4000]	train_set's rmse: 0.00103341	valid_set's rmse: 0.00214279
# [5000]	train_set's rmse: 0.000959556	valid_set's rmse: 0.00211651
# [6000]	train_set's rmse: 0.000911196	valid_set's rmse: 0.00210223
# [7000]	train_set's rmse: 0.000878999	valid_set's rmse: 0.00209151
# [8000]	train_set's rmse: 0.000857331	valid_set's rmse: 0.00208328
# [9000]	train_set's rmse: 0.000841642	valid_set's rmse: 0.00207434
# [10000]	train_set's rmse: 0.000830486	valid_set's rmse: 0.00206746
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00180788	valid_set's rmse: 0.00231346
# [2000]	train_set's rmse: 0.0013625	valid_set's rmse: 0.0020334
# [3000]	train_set's rmse: 0.00114653	valid_set's rmse: 0.00192767
# [4000]	train_set's rmse: 0.00101681	valid_set's rmse: 0.00186757
# [5000]	train_set's rmse: 0.000933005	valid_set's rmse: 0.00183175
# [6000]	train_set's rmse: 0.000879167	valid_set's rmse: 0.00181412
# [7000]	train_set's rmse: 0.000839965	valid_set's rmse: 0.00180149
# [8000]	train_set's rmse: 0.000810716	valid_set's rmse: 0.00179378
# [9000]	train_set's rmse: 0.000791521	valid_set's rmse: 0.0017892
# [10000]	train_set's rmse: 0.000775132	valid_set's rmse: 0.00178404
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00179255	valid_set's rmse: 0.00248761
# [2000]	train_set's rmse: 0.00136048	valid_set's rmse: 0.00216604
# [3000]	train_set's rmse: 0.00114742	valid_set's rmse: 0.00202044
# [4000]	train_set's rmse: 0.00102463	valid_set's rmse: 0.00194467
# [5000]	train_set's rmse: 0.000949395	valid_set's rmse: 0.00190667
# [6000]	train_set's rmse: 0.000900688	valid_set's rmse: 0.00188105
# [7000]	train_set's rmse: 0.000866917	valid_set's rmse: 0.00185933
# [8000]	train_set's rmse: 0.00084276	valid_set's rmse: 0.00184739
# [9000]	train_set's rmse: 0.000827318	valid_set's rmse: 0.00183713
# [10000]	train_set's rmse: 0.000816744	valid_set's rmse: 0.00183097
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00178524	valid_set's rmse: 0.00353262
# [2000]	train_set's rmse: 0.00134424	valid_set's rmse: 0.00323921
# [3000]	train_set's rmse: 0.00112781	valid_set's rmse: 0.00312845
# [4000]	train_set's rmse: 0.00100405	valid_set's rmse: 0.00307682
# [5000]	train_set's rmse: 0.000929853	valid_set's rmse: 0.0030499
# [6000]	train_set's rmse: 0.000883467	valid_set's rmse: 0.00303159
# [7000]	train_set's rmse: 0.000851952	valid_set's rmse: 0.00302361
# [8000]	train_set's rmse: 0.000831703	valid_set's rmse: 0.00301522
# [9000]	train_set's rmse: 0.000817867	valid_set's rmse: 0.00301119
# [10000]	train_set's rmse: 0.000808487	valid_set's rmse: 0.00300992
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00179974	valid_set's rmse: 0.00230839
# [2000]	train_set's rmse: 0.00135479	valid_set's rmse: 0.00212053
# [3000]	train_set's rmse: 0.0011301	valid_set's rmse: 0.00202773
# [4000]	train_set's rmse: 0.00100256	valid_set's rmse: 0.00197727
# [5000]	train_set's rmse: 0.000925203	valid_set's rmse: 0.00194751
# [6000]	train_set's rmse: 0.000876331	valid_set's rmse: 0.00192626
# [7000]	train_set's rmse: 0.000843527	valid_set's rmse: 0.00191628
# [8000]	train_set's rmse: 0.000822177	valid_set's rmse: 0.0019082
# [9000]	train_set's rmse: 0.000807215	valid_set's rmse: 0.00189821
# [10000]	train_set's rmse: 0.000796908	valid_set's rmse: 0.00189462
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00176541	valid_set's rmse: 0.00263588
# [2000]	train_set's rmse: 0.0013418	valid_set's rmse: 0.00246229
# [3000]	train_set's rmse: 0.00113519	valid_set's rmse: 0.0023919
# [4000]	train_set's rmse: 0.00101818	valid_set's rmse: 0.00236814
# [5000]	train_set's rmse: 0.000948544	valid_set's rmse: 0.0023507
# [6000]	train_set's rmse: 0.000904905	valid_set's rmse: 0.00234722
# [7000]	train_set's rmse: 0.000876329	valid_set's rmse: 0.00234393
# [8000]	train_set's rmse: 0.000857069	valid_set's rmse: 0.00234368
# [9000]	train_set's rmse: 0.000844692	valid_set's rmse: 0.00234451
# [10000]	train_set's rmse: 0.000835634	valid_set's rmse: 0.00234536
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00176937	valid_set's rmse: 0.0024242
# [2000]	train_set's rmse: 0.00132637	valid_set's rmse: 0.00208466
# [3000]	train_set's rmse: 0.00111427	valid_set's rmse: 0.00193193
# [4000]	train_set's rmse: 0.000990591	valid_set's rmse: 0.00185522
# [5000]	train_set's rmse: 0.000912119	valid_set's rmse: 0.00180645
# [6000]	train_set's rmse: 0.000863102	valid_set's rmse: 0.00178068
# [7000]	train_set's rmse: 0.000829466	valid_set's rmse: 0.00176579
# [8000]	train_set's rmse: 0.000806068	valid_set's rmse: 0.00176151
# [9000]	train_set's rmse: 0.00079001	valid_set's rmse: 0.00175874
# [10000]	train_set's rmse: 0.000778653	valid_set's rmse: 0.00175729
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	125.53s	 = Training   runtime
# 	2.27s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000669553	valid_set's rmse: 0.00241951
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00079934	valid_set's rmse: 0.0016853
# [2000]	train_set's rmse: 0.000781928	valid_set's rmse: 0.00167278
# [3000]	train_set's rmse: 0.000779596	valid_set's rmse: 0.0016715
# [4000]	train_set's rmse: 0.00077881	valid_set's rmse: 0.00167102
# [5000]	train_set's rmse: 0.000778456	valid_set's rmse: 0.0016708
# [6000]	train_set's rmse: 0.000778286	valid_set's rmse: 0.00167071
# [7000]	train_set's rmse: 0.000778203	valid_set's rmse: 0.00167067
# [8000]	train_set's rmse: 0.000778161	valid_set's rmse: 0.00167066
# [9000]	train_set's rmse: 0.000778141	valid_set's rmse: 0.00167065
# [10000]	train_set's rmse: 0.000778131	valid_set's rmse: 0.00167066
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0007588	valid_set's rmse: 0.00205071
# [2000]	train_set's rmse: 0.000737381	valid_set's rmse: 0.00202407
# [3000]	train_set's rmse: 0.000734278	valid_set's rmse: 0.00202226
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000802094	valid_set's rmse: 0.00196228
# [2000]	train_set's rmse: 0.000782361	valid_set's rmse: 0.00194847
# [3000]	train_set's rmse: 0.000779468	valid_set's rmse: 0.00194701
# [4000]	train_set's rmse: 0.000778509	valid_set's rmse: 0.00194532
# [5000]	train_set's rmse: 0.000778111	valid_set's rmse: 0.00194424
# [6000]	train_set's rmse: 0.000777935	valid_set's rmse: 0.00194365
# [7000]	train_set's rmse: 0.000777856	valid_set's rmse: 0.00194322
# [8000]	train_set's rmse: 0.000777822	valid_set's rmse: 0.00194296
# [9000]	train_set's rmse: 0.000777807	valid_set's rmse: 0.0019428
# [10000]	train_set's rmse: 0.0007778	valid_set's rmse: 0.00194271
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000792751	valid_set's rmse: 0.00182045
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000799952	valid_set's rmse: 0.00225256
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0019	 = Validation score   (root_mean_squared_error)
# 	124.04s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	7.98s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	-0.0021	 = Validation score   (root_mean_squared_error)
# 	604.2s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	2.37s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	-0.0031	 = Validation score   (root_mean_squared_error)
# 	29.45s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	-0.0023	 = Validation score   (root_mean_squared_error)
# 	12.31s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ...
# 	-0.0036	 = Validation score   (root_mean_squared_error)
# 	219.51s	 = Training   runtime
# 	1.89s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 5.73245e-06	valid_set's rmse: 0.00162553
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	80.38s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.0016	 = Validation score   (root_mean_squared_error)
# 	0.53s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00146773	valid_set's rmse: 0.00287795
# [2000]	train_set's rmse: 0.00115872	valid_set's rmse: 0.00280144
# [3000]	train_set's rmse: 0.00101277	valid_set's rmse: 0.00277709
# [4000]	train_set's rmse: 0.000931194	valid_set's rmse: 0.00276191
# [5000]	train_set's rmse: 0.000883713	valid_set's rmse: 0.00275251
# [6000]	train_set's rmse: 0.000854484	valid_set's rmse: 0.00274538
# [7000]	train_set's rmse: 0.000835327	valid_set's rmse: 0.00274279
# [8000]	train_set's rmse: 0.000823265	valid_set's rmse: 0.00273957
# [9000]	train_set's rmse: 0.000814231	valid_set's rmse: 0.00273757
# [10000]	train_set's rmse: 0.000808117	valid_set's rmse: 0.00273406
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00146293	valid_set's rmse: 0.00228281
# [2000]	train_set's rmse: 0.00114101	valid_set's rmse: 0.0022036
# [3000]	train_set's rmse: 0.000982732	valid_set's rmse: 0.0021735
# [4000]	train_set's rmse: 0.000893322	valid_set's rmse: 0.00215934
# [5000]	train_set's rmse: 0.000839272	valid_set's rmse: 0.00214761
# [6000]	train_set's rmse: 0.000805286	valid_set's rmse: 0.0021403
# [7000]	train_set's rmse: 0.000782822	valid_set's rmse: 0.00213446
# [8000]	train_set's rmse: 0.000767977	valid_set's rmse: 0.00212859
# [9000]	train_set's rmse: 0.000757189	valid_set's rmse: 0.00212614
# [10000]	train_set's rmse: 0.000749375	valid_set's rmse: 0.00212376
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00147934	valid_set's rmse: 0.00234012
# [2000]	train_set's rmse: 0.00115042	valid_set's rmse: 0.00217926
# [3000]	train_set's rmse: 0.000985963	valid_set's rmse: 0.00211404
# [4000]	train_set's rmse: 0.000888695	valid_set's rmse: 0.00208349
# [5000]	train_set's rmse: 0.000830496	valid_set's rmse: 0.00206757
# [6000]	train_set's rmse: 0.000791293	valid_set's rmse: 0.00206036
# [7000]	train_set's rmse: 0.00076557	valid_set's rmse: 0.0020548
# [8000]	train_set's rmse: 0.000749112	valid_set's rmse: 0.00205155
# [9000]	train_set's rmse: 0.000737673	valid_set's rmse: 0.00204964
# [10000]	train_set's rmse: 0.000729309	valid_set's rmse: 0.00204806
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00149418	valid_set's rmse: 0.00233931
# [2000]	train_set's rmse: 0.00117332	valid_set's rmse: 0.00224667
# [3000]	train_set's rmse: 0.00102017	valid_set's rmse: 0.00222891
# [4000]	train_set's rmse: 0.00092998	valid_set's rmse: 0.00222462
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00151699	valid_set's rmse: 0.00228515
# [2000]	train_set's rmse: 0.00121171	valid_set's rmse: 0.00217273
# [3000]	train_set's rmse: 0.00106424	valid_set's rmse: 0.00212586
# [4000]	train_set's rmse: 0.000978319	valid_set's rmse: 0.00210016
# [5000]	train_set's rmse: 0.000924313	valid_set's rmse: 0.00208337
# [6000]	train_set's rmse: 0.000889732	valid_set's rmse: 0.00207692
# [7000]	train_set's rmse: 0.000865377	valid_set's rmse: 0.00207002
# [8000]	train_set's rmse: 0.000848832	valid_set's rmse: 0.00206856
# [9000]	train_set's rmse: 0.000836006	valid_set's rmse: 0.00206628
# [10000]	train_set's rmse: 0.000825514	valid_set's rmse: 0.00206464
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.001547	valid_set's rmse: 0.00210083
# [2000]	train_set's rmse: 0.00122456	valid_set's rmse: 0.00199491
# [3000]	train_set's rmse: 0.00107075	valid_set's rmse: 0.00195373
# [4000]	train_set's rmse: 0.000983001	valid_set's rmse: 0.0019293
# [5000]	train_set's rmse: 0.000928922	valid_set's rmse: 0.001911
# [6000]	train_set's rmse: 0.000894739	valid_set's rmse: 0.0018987
# [7000]	train_set's rmse: 0.000871463	valid_set's rmse: 0.00189031
# [8000]	train_set's rmse: 0.000855187	valid_set's rmse: 0.00188533
# [9000]	train_set's rmse: 0.000843892	valid_set's rmse: 0.0018798
# [10000]	train_set's rmse: 0.000835318	valid_set's rmse: 0.00187767
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00153358	valid_set's rmse: 0.00223596
# [2000]	train_set's rmse: 0.00122357	valid_set's rmse: 0.00210692
# [3000]	train_set's rmse: 0.00106365	valid_set's rmse: 0.00202913
# [4000]	train_set's rmse: 0.000971075	valid_set's rmse: 0.00198318
# [5000]	train_set's rmse: 0.000912698	valid_set's rmse: 0.00195418
# [6000]	train_set's rmse: 0.000875994	valid_set's rmse: 0.00193543
# [7000]	train_set's rmse: 0.000852232	valid_set's rmse: 0.0019203
# [8000]	train_set's rmse: 0.000836738	valid_set's rmse: 0.00190949
# [9000]	train_set's rmse: 0.000825061	valid_set's rmse: 0.00190317
# [10000]	train_set's rmse: 0.00081697	valid_set's rmse: 0.00189858
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00155982	valid_set's rmse: 0.00193023
# [2000]	train_set's rmse: 0.0012034	valid_set's rmse: 0.00183298
# [3000]	train_set's rmse: 0.0010316	valid_set's rmse: 0.00179698
# [4000]	train_set's rmse: 0.000936965	valid_set's rmse: 0.00179176
# [5000]	train_set's rmse: 0.000877942	valid_set's rmse: 0.00178786
# [6000]	train_set's rmse: 0.000840262	valid_set's rmse: 0.00178451
# [7000]	train_set's rmse: 0.00081432	valid_set's rmse: 0.00178461
# [8000]	train_set's rmse: 0.000796379	valid_set's rmse: 0.00178513
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00152277	valid_set's rmse: 0.00216766
# [2000]	train_set's rmse: 0.00118127	valid_set's rmse: 0.00210583
# [3000]	train_set's rmse: 0.00101577	valid_set's rmse: 0.00208552
# [4000]	train_set's rmse: 0.000922048	valid_set's rmse: 0.00207714
# [5000]	train_set's rmse: 0.000866064	valid_set's rmse: 0.00207641
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00150841	valid_set's rmse: 0.00162554
# [2000]	train_set's rmse: 0.00118496	valid_set's rmse: 0.00152719
# [3000]	train_set's rmse: 0.00102295	valid_set's rmse: 0.00149163
# [4000]	train_set's rmse: 0.000925021	valid_set's rmse: 0.00147256
# [5000]	train_set's rmse: 0.000863543	valid_set's rmse: 0.00146841
# [6000]	train_set's rmse: 0.000823874	valid_set's rmse: 0.00146263
# [7000]	train_set's rmse: 0.000794618	valid_set's rmse: 0.00146045
# [8000]	train_set's rmse: 0.000772514	valid_set's rmse: 0.0014588
# [9000]	train_set's rmse: 0.000756065	valid_set's rmse: 0.0014573
# [10000]	train_set's rmse: 0.000742647	valid_set's rmse: 0.00145749
# 	-0.0021	 = Validation score   (root_mean_squared_error)
# 	138.31s	 = Training   runtime
# 	2.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0019	 = Validation score   (root_mean_squared_error)
# 	21.3s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-0.0016	 = Validation score   (root_mean_squared_error)
# 	10.2s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	-0.0019	 = Validation score   (root_mean_squared_error)
# 	601.78s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-0.0016	 = Validation score   (root_mean_squared_error)
# 	2.77s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	-0.0021	 = Validation score   (root_mean_squared_error)
# 	29.97s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	-0.002	 = Validation score   (root_mean_squared_error)
# 	12.26s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L2 ...
# 	-0.0032	 = Validation score   (root_mean_squared_error)
# 	218.77s	 = Training   runtime
# 	2.0s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 1.10005e-05	valid_set's rmse: 0.00163476
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	81.42s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-0.0016	 = Validation score   (root_mean_squared_error)
# 	0.43s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2374.8s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictClass/")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3  -0.001596       7.179186  1342.863119                0.000705           0.433400            3       True         22
# 1      WeightedEnsemble_L2  -0.001600       1.485444   215.320784                0.000636           0.529024            2       True         12
# 2     ExtraTreesMSE_BAG_L2  -0.001605       6.448299  1208.567122                0.175986           2.766983            2       True         17
# 3   RandomForestMSE_BAG_L2  -0.001616       6.469405  1215.999735                0.197092          10.199596            2       True         15
# 4     LightGBMLarge_BAG_L1  -0.001704       0.157484    80.381338                0.157484          80.381338            1       True         11
# 5     ExtraTreesMSE_BAG_L1  -0.001725       0.179131     2.372742                0.179131           2.372742            1       True          7
# 6     LightGBMLarge_BAG_L2  -0.001728       6.398663  1287.224854                0.126350          81.424715            2       True         21
# 7   RandomForestMSE_BAG_L1  -0.001744       0.173172     7.984335                0.173172           7.984335            1       True          5
# 8          CatBoost_BAG_L2  -0.001923       6.337894  1807.581018                0.065581         601.780878            2       True         16
# 9          LightGBM_BAG_L2  -0.001926       6.349544  1227.100586                0.077230          21.300447            2       True         14
# 10         LightGBM_BAG_L1  -0.001929       0.788671   124.040139                0.788671         124.040139            1       True          4
# 11          XGBoost_BAG_L2  -0.001975       6.336119  1218.064363                0.063805          12.264223            2       True         19
# 12       LightGBMXT_BAG_L2  -0.002052       8.386351  1344.108548                2.114037         138.308408            2       True         13
# 13  NeuralNetFastAI_BAG_L2  -0.002088       6.615248  1235.774203                0.342935          29.974064            2       True         18
# 14         CatBoost_BAG_L1  -0.002099       0.073583   604.197641                0.073583         604.197641            1       True          6
# 15       LightGBMXT_BAG_L1  -0.002210       2.266926   125.529589                2.266926         125.529589            1       True          3
# 16          XGBoost_BAG_L1  -0.002251       0.060979    12.309407                0.060979          12.309407            1       True          9
# 17   KNeighborsDist_BAG_L1  -0.002875       0.186349     0.013206                0.186349           0.013206            1       True          2
# 18  NeuralNetFastAI_BAG_L1  -0.003107       0.312288    29.450758                0.312288          29.450758            1       True          8
# 19   NeuralNetMXNet_BAG_L2  -0.003159       8.269229  1424.570936                1.996915         218.770797            2       True         20
# 20   NeuralNetMXNet_BAG_L1  -0.003565       1.889958   219.508077                1.889958         219.508077            1       True         10
# 21   KNeighborsUnif_BAG_L1  -0.004222       0.183773     0.012907                0.183773           0.012907            1       True          1
# Number of models trained: 22
# Types of models trained:
# {'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_TabularNeuralNet', 'StackerEnsembleModel_LGB', 'WeightedEnsembleModel', 'StackerEnsembleModel_KNN'}
# Bagging used: True  (with 10 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# ('int', [])                  :  1 | ['index']
# ('int', ['datetime_as_int']) :  1 | ['d']
# Plot summary of models saved to file: agModels-predictClass/SummaryOfModels.html
# *** End of fit() summary ***
# {'leaderboard':                      model  score_val  ...  can_infer  fit_order
#  0      WeightedEnsemble_L3  -0.001596  ...       True         22
#  1      WeightedEnsemble_L2  -0.001600  ...       True         12
#  2     ExtraTreesMSE_BAG_L2  -0.001605  ...       True         17
#  3   RandomForestMSE_BAG_L2  -0.001616  ...       True         15
#  4     LightGBMLarge_BAG_L1  -0.001704  ...       True         11
#  5     ExtraTreesMSE_BAG_L1  -0.001725  ...       True          7
#  6     LightGBMLarge_BAG_L2  -0.001728  ...       True         21
#  7   RandomForestMSE_BAG_L1  -0.001744  ...       True          5
#  8          CatBoost_BAG_L2  -0.001923  ...       True         16
#  9          LightGBM_BAG_L2  -0.001926  ...       True         14
#  10         LightGBM_BAG_L1  -0.001929  ...       True          4
#  11          XGBoost_BAG_L2  -0.001975  ...       True         19
#  12       LightGBMXT_BAG_L2  -0.002052  ...       True         13
#  13  NeuralNetFastAI_BAG_L2  -0.002088  ...       True         18
#  14         CatBoost_BAG_L1  -0.002099  ...       True          6
#  15       LightGBMXT_BAG_L1  -0.002210  ...       True          3
#  16          XGBoost_BAG_L1  -0.002251  ...       True          9
#  17   KNeighborsDist_BAG_L1  -0.002875  ...       True          2
#  18  NeuralNetFastAI_BAG_L1  -0.003107  ...       True          8
#  19   NeuralNetMXNet_BAG_L2  -0.003159  ...       True         20
#  20   NeuralNetMXNet_BAG_L1  -0.003565  ...       True         10
#  21   KNeighborsUnif_BAG_L1  -0.004222  ...       True          1
#
#  [22 rows x 9 columns],
#  'max_stack_level': 3,
#  'model_best': 'WeightedEnsemble_L3',
#  'model_fit_times': {'CatBoost_BAG_L1': 604.1976408958435,
#   'CatBoost_BAG_L2': 601.7808783054352,
#   'ExtraTreesMSE_BAG_L1': 2.372742176055908,
#   'ExtraTreesMSE_BAG_L2': 2.7669827938079834,
#   'KNeighborsDist_BAG_L1': 0.013205528259277344,
#   'KNeighborsUnif_BAG_L1': 0.012907266616821289,
#   'LightGBMLarge_BAG_L1': 80.38133764266968,
#   'LightGBMLarge_BAG_L2': 81.4247145652771,
#   'LightGBMXT_BAG_L1': 125.5295889377594,
#   'LightGBMXT_BAG_L2': 138.30840826034546,
#   'LightGBM_BAG_L1': 124.04013919830322,
#   'LightGBM_BAG_L2': 21.30044651031494,
#   'NeuralNetFastAI_BAG_L1': 29.450758457183838,
#   'NeuralNetFastAI_BAG_L2': 29.974063634872437,
#   'NeuralNetMXNet_BAG_L1': 219.5080771446228,
#   'NeuralNetMXNet_BAG_L2': 218.77079701423645,
#   'RandomForestMSE_BAG_L1': 7.98433518409729,
#   'RandomForestMSE_BAG_L2': 10.19959568977356,
#   'WeightedEnsemble_L2': 0.5290238857269287,
#   'WeightedEnsemble_L3': 0.43339991569519043,
#   'XGBoost_BAG_L1': 12.309406995773315,
#   'XGBoost_BAG_L2': 12.264223337173462},
#  'model_hyperparams': {'CatBoost_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'CatBoost_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'ExtraTreesMSE_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'ExtraTreesMSE_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'KNeighborsDist_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'KNeighborsUnif_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'LightGBMLarge_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBMLarge_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBMXT_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBMXT_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBM_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBM_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetFastAI_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetFastAI_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetMXNet_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetMXNet_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'RandomForestMSE_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'RandomForestMSE_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'WeightedEnsemble_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': False},
#   'WeightedEnsemble_L3': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': False},
#   'XGBoost_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'XGBoost_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True}},
#  'model_paths': {'CatBoost_BAG_L1': 'agModels-predictClass/models/CatBoost_BAG_L1/',
#   'CatBoost_BAG_L2': 'agModels-predictClass/models/CatBoost_BAG_L2/',
#   'ExtraTreesMSE_BAG_L1': 'agModels-predictClass/models/ExtraTreesMSE_BAG_L1/',
#   'ExtraTreesMSE_BAG_L2': 'agModels-predictClass/models/ExtraTreesMSE_BAG_L2/',
#   'KNeighborsDist_BAG_L1': 'agModels-predictClass/models/KNeighborsDist_BAG_L1/',
#   'KNeighborsUnif_BAG_L1': 'agModels-predictClass/models/KNeighborsUnif_BAG_L1/',
#   'LightGBMLarge_BAG_L1': 'agModels-predictClass/models/LightGBMLarge_BAG_L1/',
#   'LightGBMLarge_BAG_L2': 'agModels-predictClass/models/LightGBMLarge_BAG_L2/',
#   'LightGBMXT_BAG_L1': 'agModels-predictClass/models/LightGBMXT_BAG_L1/',
#   'LightGBMXT_BAG_L2': 'agModels-predictClass/models/LightGBMXT_BAG_L2/',
#   'LightGBM_BAG_L1': 'agModels-predictClass/models/LightGBM_BAG_L1/',
#   'LightGBM_BAG_L2': 'agModels-predictClass/models/LightGBM_BAG_L2/',
#   'NeuralNetFastAI_BAG_L1': 'agModels-predictClass/models/NeuralNetFastAI_BAG_L1/',
#   'NeuralNetFastAI_BAG_L2': 'agModels-predictClass/models/NeuralNetFastAI_BAG_L2/',
#   'NeuralNetMXNet_BAG_L1': 'agModels-predictClass/models/NeuralNetMXNet_BAG_L1/',
#   'NeuralNetMXNet_BAG_L2': 'agModels-predictClass/models/NeuralNetMXNet_BAG_L2/',
#   'RandomForestMSE_BAG_L1': 'agModels-predictClass/models/RandomForestMSE_BAG_L1/',
#   'RandomForestMSE_BAG_L2': 'agModels-predictClass/models/RandomForestMSE_BAG_L2/',
#   'WeightedEnsemble_L2': 'agModels-predictClass/models/WeightedEnsemble_L2/',
#   'WeightedEnsemble_L3': 'agModels-predictClass/models/WeightedEnsemble_L3/',
#   'XGBoost_BAG_L1': 'agModels-predictClass/models/XGBoost_BAG_L1/',
#   'XGBoost_BAG_L2': 'agModels-predictClass/models/XGBoost_BAG_L2/'},
#  'model_performance': {'CatBoost_BAG_L1': -0.002099237157211344,
#   'CatBoost_BAG_L2': -0.0019234148806622075,
#   'ExtraTreesMSE_BAG_L1': -0.001725154024853292,
#   'ExtraTreesMSE_BAG_L2': -0.0016046864421039536,
#   'KNeighborsDist_BAG_L1': -0.002875006898084223,
#   'KNeighborsUnif_BAG_L1': -0.004222121122358596,
#   'LightGBMLarge_BAG_L1': -0.0017037737577751456,
#   'LightGBMLarge_BAG_L2': -0.0017280621379710613,
#   'LightGBMXT_BAG_L1': -0.0022096620429592215,
#   'LightGBMXT_BAG_L2': -0.002051769681976684,
#   'LightGBM_BAG_L1': -0.001929248340221226,
#   'LightGBM_BAG_L2': -0.0019260828825765838,
#   'NeuralNetFastAI_BAG_L1': -0.0031073145375868786,
#   'NeuralNetFastAI_BAG_L2': -0.0020879626762391637,
#   'NeuralNetMXNet_BAG_L1': -0.003565214124656039,
#   'NeuralNetMXNet_BAG_L2': -0.0031585429641426315,
#   'RandomForestMSE_BAG_L1': -0.0017441453269966501,
#   'RandomForestMSE_BAG_L2': -0.0016155001623550827,
#   'WeightedEnsemble_L2': -0.001599715466061205,
#   'WeightedEnsemble_L3': -0.0015959016666061876,
#   'XGBoost_BAG_L1': -0.002251325869317015,
#   'XGBoost_BAG_L2': -0.00197513561897589},
#  'model_pred_times': {'CatBoost_BAG_L1': 0.07358264923095703,
#   'CatBoost_BAG_L2': 0.06558084487915039,
#   'ExtraTreesMSE_BAG_L1': 0.17913126945495605,
#   'ExtraTreesMSE_BAG_L2': 0.17598581314086914,
#   'KNeighborsDist_BAG_L1': 0.18634939193725586,
#   'KNeighborsUnif_BAG_L1': 0.18377280235290527,
#   'LightGBMLarge_BAG_L1': 0.1574840545654297,
#   'LightGBMLarge_BAG_L2': 0.12634968757629395,
#   'LightGBMXT_BAG_L1': 2.266925811767578,
#   'LightGBMXT_BAG_L2': 2.114037275314331,
#   'LightGBM_BAG_L1': 0.788670539855957,
#   'LightGBM_BAG_L2': 0.07722997665405273,
#   'NeuralNetFastAI_BAG_L1': 0.3122875690460205,
#   'NeuralNetFastAI_BAG_L2': 0.34293484687805176,
#   'NeuralNetMXNet_BAG_L1': 1.8899579048156738,
#   'NeuralNetMXNet_BAG_L2': 1.996915340423584,
#   'RandomForestMSE_BAG_L1': 0.1731722354888916,
#   'RandomForestMSE_BAG_L2': 0.19709181785583496,
#   'WeightedEnsemble_L2': 0.0006361007690429688,
#   'WeightedEnsemble_L3': 0.0007054805755615234,
#   'XGBoost_BAG_L1': 0.060979366302490234,
#   'XGBoost_BAG_L2': 0.06380510330200195},
#  'model_types': {'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesMSE_BAG_L2': 'StackerEnsembleModel_XT',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetMXNet_BAG_L1': 'StackerEnsembleModel_TabularNeuralNet',
#   'NeuralNetMXNet_BAG_L2': 'StackerEnsembleModel_TabularNeuralNet',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestMSE_BAG_L2': 'StackerEnsembleModel_RF',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost'},
#  'num_bag_folds': 10}

# %%
#repeated?
test_data = TabularDataset(df_m_5.tail(500))
y_test = test_data[label]
test_data_nolab = test_data.drop(columns=[label])
test_data_nolab.tail()
# Out:
#                 d  index  ...  eu_High_next_day1  eu_Close_next_day1
# 12788  2021.12.10  12788  ...            1.13191             1.12854
# 12789  2021.12.13  12789  ...            1.13236             1.12577
# 12790  2021.12.14  12790  ...            1.12990             1.12936
# 12791  2021.12.15  12791  ...            1.13602             1.13304
# 12792  2021.12.16  12792  ...            1.13346             1.13312
#
# [5 rows x 38 columns]

# %%
predictor = TabularPredictor.load(save_path)

y_pred = predictor.predict(test_data_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: root_mean_squared_error on test data: -0.0012106985559799375
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -0.0012106985559799375,
#     "mean_squared_error": -1.4657909934519061e-06,
#     "mean_absolute_error": -0.0006172851656341618,
#     "r2": 0.9992010552962991,
#     "pearsonr": 0.9996037857784825,
#     "median_absolute_error": -0.00021447246551509203
# }
# Predictions:
#  12293    1.112259
# 12294    1.108406
# 12295    1.107799
# 12296    1.107919
# 12297    1.107256
#            ...
# 12788    1.126574
# 12789    1.125452
# 12790    1.122136
# 12791    1.128146
# 12792    1.131428
# Name: eu_Low_next_day1, Length: 500, dtype: float32

# %%
predictor.leaderboard(train_data, silent=True)
# Out:
#                      model    score_test  ...  can_infer  fit_order
# 0    KNeighborsDist_BAG_L1 -8.525250e-08  ...       True          2
# 1          CatBoost_BAG_L1 -2.495918e-04  ...       True          6
# 2     LightGBMLarge_BAG_L1 -2.502015e-04  ...       True         11
# 3      WeightedEnsemble_L3 -3.946962e-04  ...       True         22
# 4     LightGBMLarge_BAG_L2 -3.950912e-04  ...       True         21
# 5     ExtraTreesMSE_BAG_L2 -4.046642e-04  ...       True         17
# 6      WeightedEnsemble_L2 -4.141564e-04  ...       True         12
# 7          CatBoost_BAG_L2 -4.491419e-04  ...       True         16
# 8   RandomForestMSE_BAG_L2 -4.544677e-04  ...       True         15
# 9           XGBoost_BAG_L2 -5.971972e-04  ...       True         19
# 10    ExtraTreesMSE_BAG_L1 -6.305343e-04  ...       True          7
# 11  RandomForestMSE_BAG_L1 -6.386047e-04  ...       True          5
# 12         LightGBM_BAG_L1 -7.859400e-04  ...       True          4
# 13       LightGBMXT_BAG_L1 -8.446840e-04  ...       True          3
# 14         LightGBM_BAG_L2 -8.886569e-04  ...       True         14
# 15          XGBoost_BAG_L1 -8.949264e-04  ...       True          9
# 16       LightGBMXT_BAG_L2 -9.449097e-04  ...       True         13
# 17  NeuralNetFastAI_BAG_L2 -1.169603e-03  ...       True         18
# 18   NeuralNetMXNet_BAG_L2 -2.414718e-03  ...       True         20
# 19  NeuralNetFastAI_BAG_L1 -2.726739e-03  ...       True          8
# 20   NeuralNetMXNet_BAG_L1 -2.975199e-03  ...       True         10
# 21   KNeighborsUnif_BAG_L1 -3.138977e-03  ...       True          1
#
# [22 rows x 12 columns]

# %%
#repeated?
train_data = df_m_5
#subsample_size=500
train_data=train_data.sample(n=2000, replace=True)
train_data.head()
# Out:
#                 d  index  ...  eu_Low_next_day1  eu_Close_next_day1
# 11488  2016.12.06  11488  ...           1.07095             1.07513
# 11363  2016.06.14  11363  ...           1.11894             1.12602
# 12457  2020.09.01  12457  ...           1.18220             1.18547
# 12020  2018.12.24  12020  ...           1.13422             1.13520
# 11639  2017.07.05  11639  ...           1.13269             1.14216
#
# [5 rows x 39 columns]

# %%
label='eu_Close_next_day1'
print("Summary of class variable: \n", train_data[label].describe())
# Out:
# Summary of class variable:
#  count    2000.000000
# mean        1.152497
# std         0.065885
# min         1.038670
# 25%         1.110525
# 50%         1.134450
# 75%         1.181472
# max         1.392470
# Name: eu_Close_next_day1, dtype: float64

# %%
save_path='agModels-predictClass'
predictor=TabularPredictor(label=label, path=save_path).fit(train_data, presets='best_quality', time_limit=None)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictClass"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClass/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    2000
# Train Data Columns: 38
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.39247, 1.03867, 1.1525, 0.06588)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    10841.36 MB
# 	Train Data (Original)  Memory Usage: 0.73 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', [])                        :  1 | ['index']
# 		('object', ['datetime_as_object']) :  1 | ['d']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', [])                  :  1 | ['index']
# 		('int', ['datetime_as_int']) :  1 | ['d']
# 	0.2s = Fit runtime
# 	38 features in original data used to generate 38 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.61 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.22s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-0.0047	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-0.0031	 = Validation score   (root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00216516	valid_set's rmse: 0.00375607
# [2000]	train_set's rmse: 0.00153209	valid_set's rmse: 0.00344776
# [3000]	train_set's rmse: 0.00121967	valid_set's rmse: 0.00330924
# [4000]	train_set's rmse: 0.00102932	valid_set's rmse: 0.00322892
# [5000]	train_set's rmse: 0.000908909	valid_set's rmse: 0.00318988
# [6000]	train_set's rmse: 0.00083412	valid_set's rmse: 0.00316529
# [7000]	train_set's rmse: 0.000782201	valid_set's rmse: 0.00314935
# [8000]	train_set's rmse: 0.000746618	valid_set's rmse: 0.00313718
# [9000]	train_set's rmse: 0.000722638	valid_set's rmse: 0.00313151
# [10000]	train_set's rmse: 0.000705451	valid_set's rmse: 0.0031294
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00221333	valid_set's rmse: 0.00347093
# [2000]	train_set's rmse: 0.00163507	valid_set's rmse: 0.00305009
# [3000]	train_set's rmse: 0.00135571	valid_set's rmse: 0.00285177
# [4000]	train_set's rmse: 0.00119822	valid_set's rmse: 0.0027392
# [5000]	train_set's rmse: 0.001098	valid_set's rmse: 0.00266349
# [6000]	train_set's rmse: 0.00103465	valid_set's rmse: 0.00261754
# [7000]	train_set's rmse: 0.000992488	valid_set's rmse: 0.00258488
# [8000]	train_set's rmse: 0.000963196	valid_set's rmse: 0.00256403
# [9000]	train_set's rmse: 0.000943585	valid_set's rmse: 0.00255117
# [10000]	train_set's rmse: 0.000928703	valid_set's rmse: 0.00253866
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0021599	valid_set's rmse: 0.0030062
# [2000]	train_set's rmse: 0.00156849	valid_set's rmse: 0.00264827
# [3000]	train_set's rmse: 0.00128262	valid_set's rmse: 0.00251206
# [4000]	train_set's rmse: 0.00112048	valid_set's rmse: 0.00244041
# [5000]	train_set's rmse: 0.00101883	valid_set's rmse: 0.00239899
# [6000]	train_set's rmse: 0.00095218	valid_set's rmse: 0.00237445
# [7000]	train_set's rmse: 0.000907733	valid_set's rmse: 0.00235804
# [8000]	train_set's rmse: 0.00087708	valid_set's rmse: 0.00234902
# [9000]	train_set's rmse: 0.000856091	valid_set's rmse: 0.00234258
# [10000]	train_set's rmse: 0.000840003	valid_set's rmse: 0.00234047
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00221075	valid_set's rmse: 0.0032134
# [2000]	train_set's rmse: 0.00160733	valid_set's rmse: 0.00293738
# [3000]	train_set's rmse: 0.00131819	valid_set's rmse: 0.0028216
# [4000]	train_set's rmse: 0.00115027	valid_set's rmse: 0.00277552
# [5000]	train_set's rmse: 0.00105075	valid_set's rmse: 0.00275413
# [6000]	train_set's rmse: 0.000985627	valid_set's rmse: 0.00273715
# [7000]	train_set's rmse: 0.000943699	valid_set's rmse: 0.00273062
# [8000]	train_set's rmse: 0.000916107	valid_set's rmse: 0.00272275
# [9000]	train_set's rmse: 0.000897282	valid_set's rmse: 0.00272011
# [10000]	train_set's rmse: 0.000882044	valid_set's rmse: 0.00271821
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0021996	valid_set's rmse: 0.00325369
# [2000]	train_set's rmse: 0.00161418	valid_set's rmse: 0.00279937
# [3000]	train_set's rmse: 0.00133693	valid_set's rmse: 0.00258673
# [4000]	train_set's rmse: 0.00117222	valid_set's rmse: 0.00247894
# [5000]	train_set's rmse: 0.0010657	valid_set's rmse: 0.0024129
# [6000]	train_set's rmse: 0.000996782	valid_set's rmse: 0.00238037
# [7000]	train_set's rmse: 0.000945706	valid_set's rmse: 0.0023549
# [8000]	train_set's rmse: 0.000911327	valid_set's rmse: 0.0023446
# [9000]	train_set's rmse: 0.000885608	valid_set's rmse: 0.00233331
# [10000]	train_set's rmse: 0.000866776	valid_set's rmse: 0.00232667
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00215909	valid_set's rmse: 0.00293369
# [2000]	train_set's rmse: 0.0015771	valid_set's rmse: 0.0026772
# [3000]	train_set's rmse: 0.00130121	valid_set's rmse: 0.00256225
# [4000]	train_set's rmse: 0.00114407	valid_set's rmse: 0.00249035
# [5000]	train_set's rmse: 0.00104562	valid_set's rmse: 0.00245109
# [6000]	train_set's rmse: 0.000982149	valid_set's rmse: 0.00242678
# [7000]	train_set's rmse: 0.000938252	valid_set's rmse: 0.00240791
# [8000]	train_set's rmse: 0.000908792	valid_set's rmse: 0.00239734
# [9000]	train_set's rmse: 0.00088826	valid_set's rmse: 0.00239394
# [10000]	train_set's rmse: 0.000873523	valid_set's rmse: 0.00239121
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00219301	valid_set's rmse: 0.00365412
# [2000]	train_set's rmse: 0.00158195	valid_set's rmse: 0.00334961
# [3000]	train_set's rmse: 0.00129059	valid_set's rmse: 0.00325316
# [4000]	train_set's rmse: 0.0011181	valid_set's rmse: 0.00318912
# [5000]	train_set's rmse: 0.00101091	valid_set's rmse: 0.00315523
# [6000]	train_set's rmse: 0.000943235	valid_set's rmse: 0.00313507
# [7000]	train_set's rmse: 0.000899216	valid_set's rmse: 0.00311768
# [8000]	train_set's rmse: 0.000870799	valid_set's rmse: 0.00311106
# [9000]	train_set's rmse: 0.000851692	valid_set's rmse: 0.00310547
# [10000]	train_set's rmse: 0.000839212	valid_set's rmse: 0.00310186
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00216279	valid_set's rmse: 0.00287758
# [2000]	train_set's rmse: 0.00156627	valid_set's rmse: 0.00250773
# [3000]	train_set's rmse: 0.00127037	valid_set's rmse: 0.00235989
# [4000]	train_set's rmse: 0.00110144	valid_set's rmse: 0.0022829
# [5000]	train_set's rmse: 0.000995725	valid_set's rmse: 0.00222628
# [6000]	train_set's rmse: 0.000930441	valid_set's rmse: 0.00220094
# [7000]	train_set's rmse: 0.000887511	valid_set's rmse: 0.00218853
# [8000]	train_set's rmse: 0.000858768	valid_set's rmse: 0.00217712
# [9000]	train_set's rmse: 0.000839388	valid_set's rmse: 0.00217068
# [10000]	train_set's rmse: 0.000826139	valid_set's rmse: 0.002165
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00223441	valid_set's rmse: 0.00299559
# [2000]	train_set's rmse: 0.00163917	valid_set's rmse: 0.00268104
# [3000]	train_set's rmse: 0.00134813	valid_set's rmse: 0.00254812
# [4000]	train_set's rmse: 0.0011771	valid_set's rmse: 0.00248543
# [5000]	train_set's rmse: 0.0010738	valid_set's rmse: 0.00244992
# [6000]	train_set's rmse: 0.00100676	valid_set's rmse: 0.00242715
# [7000]	train_set's rmse: 0.000961859	valid_set's rmse: 0.0024148
# [8000]	train_set's rmse: 0.000931101	valid_set's rmse: 0.0024095
# [9000]	train_set's rmse: 0.000910481	valid_set's rmse: 0.00240695
# [10000]	train_set's rmse: 0.000895893	valid_set's rmse: 0.00240705
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00216277	valid_set's rmse: 0.0035771
# [2000]	train_set's rmse: 0.00156749	valid_set's rmse: 0.00322452
# [3000]	train_set's rmse: 0.00127494	valid_set's rmse: 0.00306832
# [4000]	train_set's rmse: 0.00110436	valid_set's rmse: 0.00298806
# [5000]	train_set's rmse: 0.000995572	valid_set's rmse: 0.0029393
# [6000]	train_set's rmse: 0.000925843	valid_set's rmse: 0.00291517
# [7000]	train_set's rmse: 0.000878573	valid_set's rmse: 0.0029011
# [8000]	train_set's rmse: 0.000844234	valid_set's rmse: 0.00288707
# [9000]	train_set's rmse: 0.000820849	valid_set's rmse: 0.00287825
# [10000]	train_set's rmse: 0.000804535	valid_set's rmse: 0.00287336
# 	-0.0026	 = Validation score   (root_mean_squared_error)
# 	131.88s	 = Training   runtime
# 	2.83s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000689604	valid_set's rmse: 0.0029405
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000908286	valid_set's rmse: 0.00213835
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000784537	valid_set's rmse: 0.00226
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000808329	valid_set's rmse: 0.00195624
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000836714	valid_set's rmse: 0.00215558
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000826837	valid_set's rmse: 0.00214102
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000810016	valid_set's rmse: 0.0019748
# [2000]	train_set's rmse: 0.000789912	valid_set's rmse: 0.00194591
# [3000]	train_set's rmse: 0.000789114	valid_set's rmse: 0.00194005
# [4000]	train_set's rmse: 0.00078906	valid_set's rmse: 0.00193853
# [5000]	train_set's rmse: 0.000789054	valid_set's rmse: 0.00193804
# [6000]	train_set's rmse: 0.000789053	valid_set's rmse: 0.00193791
# [7000]	train_set's rmse: 0.000789053	valid_set's rmse: 0.00193787
# [8000]	train_set's rmse: 0.000789053	valid_set's rmse: 0.00193784
# [9000]	train_set's rmse: 0.000789053	valid_set's rmse: 0.00193783
# [10000]	train_set's rmse: 0.000789053	valid_set's rmse: 0.00193783
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000774229	valid_set's rmse: 0.00248645
# [2000]	train_set's rmse: 0.00074796	valid_set's rmse: 0.00247405
# 	-0.0023	 = Validation score   (root_mean_squared_error)
# 	93.46s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	8.08s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	-0.0027	 = Validation score   (root_mean_squared_error)
# 	571.17s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	2.26s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	-0.0038	 = Validation score   (root_mean_squared_error)
# 	28.67s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	-0.0026	 = Validation score   (root_mean_squared_error)
# 	13.99s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ...
# 	-0.004	 = Validation score   (root_mean_squared_error)
# 	234.49s	 = Training   runtime
# 	1.87s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 4.90542e-06	valid_set's rmse: 0.00233588
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 5.89998e-06	valid_set's rmse: 0.00213846
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 7.86198e-06	valid_set's rmse: 0.0020898
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 5.88375e-06	valid_set's rmse: 0.00240314
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	102.56s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.002	 = Validation score   (root_mean_squared_error)
# 	0.49s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00167311	valid_set's rmse: 0.00273924
# [2000]	train_set's rmse: 0.00129929	valid_set's rmse: 0.00264527
# [3000]	train_set's rmse: 0.00110768	valid_set's rmse: 0.00261426
# [4000]	train_set's rmse: 0.00100114	valid_set's rmse: 0.00259467
# [5000]	train_set's rmse: 0.000936409	valid_set's rmse: 0.00258248
# [6000]	train_set's rmse: 0.000896759	valid_set's rmse: 0.00257239
# [7000]	train_set's rmse: 0.000871813	valid_set's rmse: 0.00256744
# [8000]	train_set's rmse: 0.000855503	valid_set's rmse: 0.00256525
# [9000]	train_set's rmse: 0.000844318	valid_set's rmse: 0.00256331
# [10000]	train_set's rmse: 0.000836669	valid_set's rmse: 0.00256174
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00168963	valid_set's rmse: 0.00265752
# [2000]	train_set's rmse: 0.00131414	valid_set's rmse: 0.00255752
# [3000]	train_set's rmse: 0.00111951	valid_set's rmse: 0.00252124
# [4000]	train_set's rmse: 0.00100692	valid_set's rmse: 0.00250787
# [5000]	train_set's rmse: 0.000940025	valid_set's rmse: 0.00250272
# [6000]	train_set's rmse: 0.000900078	valid_set's rmse: 0.00249894
# [7000]	train_set's rmse: 0.000874838	valid_set's rmse: 0.00249879
# [8000]	train_set's rmse: 0.000858936	valid_set's rmse: 0.00249837
# [9000]	train_set's rmse: 0.000848125	valid_set's rmse: 0.0024979
# [10000]	train_set's rmse: 0.000840561	valid_set's rmse: 0.002496
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0016769	valid_set's rmse: 0.00266704
# [2000]	train_set's rmse: 0.00129898	valid_set's rmse: 0.0025849
# [3000]	train_set's rmse: 0.00110722	valid_set's rmse: 0.00256444
# [4000]	train_set's rmse: 0.000995754	valid_set's rmse: 0.00254873
# [5000]	train_set's rmse: 0.000926597	valid_set's rmse: 0.00255177
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00169322	valid_set's rmse: 0.0024817
# [2000]	train_set's rmse: 0.00133467	valid_set's rmse: 0.00242342
# [3000]	train_set's rmse: 0.00115074	valid_set's rmse: 0.00240306
# [4000]	train_set's rmse: 0.00104333	valid_set's rmse: 0.00238797
# [5000]	train_set's rmse: 0.000978522	valid_set's rmse: 0.00237748
# [6000]	train_set's rmse: 0.000938668	valid_set's rmse: 0.00237716
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00168057	valid_set's rmse: 0.00256658
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00173686	valid_set's rmse: 0.00229885
# [2000]	train_set's rmse: 0.00136951	valid_set's rmse: 0.00224445
# [3000]	train_set's rmse: 0.00118049	valid_set's rmse: 0.00222172
# [4000]	train_set's rmse: 0.00107047	valid_set's rmse: 0.00220185
# [5000]	train_set's rmse: 0.00100516	valid_set's rmse: 0.00219879
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00171974	valid_set's rmse: 0.00235712
# [2000]	train_set's rmse: 0.00134742	valid_set's rmse: 0.00223873
# [3000]	train_set's rmse: 0.00115771	valid_set's rmse: 0.00219577
# [4000]	train_set's rmse: 0.00104909	valid_set's rmse: 0.00217875
# [5000]	train_set's rmse: 0.00098388	valid_set's rmse: 0.00216119
# [6000]	train_set's rmse: 0.000943036	valid_set's rmse: 0.00215087
# [7000]	train_set's rmse: 0.000915101	valid_set's rmse: 0.00214916
# [8000]	train_set's rmse: 0.000896872	valid_set's rmse: 0.00214189
# [9000]	train_set's rmse: 0.000882875	valid_set's rmse: 0.00213993
# [10000]	train_set's rmse: 0.000872729	valid_set's rmse: 0.00213956
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00173444	valid_set's rmse: 0.00206843
# [2000]	train_set's rmse: 0.00135643	valid_set's rmse: 0.00202462
# [3000]	train_set's rmse: 0.00116189	valid_set's rmse: 0.00201366
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00166773	valid_set's rmse: 0.00287818
# [2000]	train_set's rmse: 0.00128211	valid_set's rmse: 0.00280886
# [3000]	train_set's rmse: 0.00108247	valid_set's rmse: 0.0027959
# [4000]	train_set's rmse: 0.000966612	valid_set's rmse: 0.00278809
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00173384	valid_set's rmse: 0.00246871
# [2000]	train_set's rmse: 0.00134595	valid_set's rmse: 0.00236831
# [3000]	train_set's rmse: 0.00113451	valid_set's rmse: 0.00232931
# [4000]	train_set's rmse: 0.00100707	valid_set's rmse: 0.00230566
# [5000]	train_set's rmse: 0.000925501	valid_set's rmse: 0.00229741
# [6000]	train_set's rmse: 0.000871056	valid_set's rmse: 0.00229378
# [7000]	train_set's rmse: 0.000830125	valid_set's rmse: 0.00229095
# [8000]	train_set's rmse: 0.000802586	valid_set's rmse: 0.00228584
# [9000]	train_set's rmse: 0.000779098	valid_set's rmse: 0.00228384
# [10000]	train_set's rmse: 0.000763903	valid_set's rmse: 0.00228167
# 	-0.0024	 = Validation score   (root_mean_squared_error)
# 	100.67s	 = Training   runtime
# 	1.45s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000831331	valid_set's rmse: 0.0026071
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000899002	valid_set's rmse: 0.00203756
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0023	 = Validation score   (root_mean_squared_error)
# 	31.59s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-0.0021	 = Validation score   (root_mean_squared_error)
# 	10.2s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	-0.0023	 = Validation score   (root_mean_squared_error)
# 	413.14s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-0.0021	 = Validation score   (root_mean_squared_error)
# 	2.77s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	-0.0025	 = Validation score   (root_mean_squared_error)
# 	29.82s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	-0.0024	 = Validation score   (root_mean_squared_error)
# 	13.8s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L2 ...
# 	-0.0033	 = Validation score   (root_mean_squared_error)
# 	218.61s	 = Training   runtime
# 	2.0s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0022	 = Validation score   (root_mean_squared_error)
# 	68.64s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-0.002	 = Validation score   (root_mean_squared_error)
# 	0.41s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2124.34s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictClass/")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L2  -0.002007       1.447255   206.864854                0.000743           0.494030            2       True         12
# 1      WeightedEnsemble_L3  -0.002041       9.619619  1965.365524                0.000703           0.407639            3       True         22
# 2     ExtraTreesMSE_BAG_L2  -0.002056       6.931814  1189.357617                0.183192           2.769992            2       True         17
# 3   RandomForestMSE_BAG_L2  -0.002120       6.939938  1196.785487                0.191316          10.197862            2       True         15
# 4     LightGBMLarge_BAG_L2  -0.002156       6.849090  1255.226989                0.100468          68.639364            2       True         21
# 5     LightGBMLarge_BAG_L1  -0.002169       0.234170   102.556556                0.234170         102.556556            1       True         11
# 6   RandomForestMSE_BAG_L1  -0.002179       0.185613     8.078113                0.185613           8.078113            1       True          5
# 7     ExtraTreesMSE_BAG_L1  -0.002240       0.180157     2.260369                0.180157           2.260369            1       True          7
# 8          CatBoost_BAG_L2  -0.002314       6.810715  1599.724989                0.062093         413.137364            2       True         16
# 9          LightGBM_BAG_L2  -0.002315       6.863539  1218.176638                0.114917          31.589013            2       True         14
# 10         LightGBM_BAG_L1  -0.002332       0.660657    93.457443                0.660657          93.457443            1       True          4
# 11       LightGBMXT_BAG_L2  -0.002405       8.202492  1287.261962                1.453871         100.674337            2       True         13
# 12          XGBoost_BAG_L2  -0.002425       6.810620  1200.384668                0.061998          13.797043            2       True         19
# 13  NeuralNetFastAI_BAG_L2  -0.002501       7.091465  1216.411435                0.342843          29.823810            2       True         18
# 14          XGBoost_BAG_L1  -0.002599       0.061870    13.989381                0.061870          13.989381            1       True          9
# 15       LightGBMXT_BAG_L1  -0.002618       2.832228   131.884925                2.832228         131.884925            1       True          3
# 16         CatBoost_BAG_L1  -0.002658       0.059475   571.167569                0.059475         571.167569            1       True          6
# 17   KNeighborsDist_BAG_L1  -0.003139       0.185916     0.018342                0.185916           0.018342            1       True          2
# 18   NeuralNetMXNet_BAG_L2  -0.003259       8.753403  1405.201299                2.004782         218.613674            2       True         20
# 19  NeuralNetFastAI_BAG_L1  -0.003777       0.282651    28.668364                0.282651          28.668364            1       True          8
# 20   NeuralNetMXNet_BAG_L1  -0.003989       1.871709   234.492692                1.871709         234.492692            1       True         10
# 21   KNeighborsUnif_BAG_L1  -0.004684       0.194177     0.013871                0.194177           0.013871            1       True          1
# Number of models trained: 22
# Types of models trained:
# {'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_TabularNeuralNet', 'StackerEnsembleModel_LGB', 'WeightedEnsembleModel', 'StackerEnsembleModel_KNN'}
# Bagging used: True  (with 10 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# ('int', [])                  :  1 | ['index']
# ('int', ['datetime_as_int']) :  1 | ['d']
# Plot summary of models saved to file: agModels-predictClass/SummaryOfModels.html
# *** End of fit() summary ***
# {'leaderboard':                      model  score_val  ...  can_infer  fit_order
#  0      WeightedEnsemble_L2  -0.002007  ...       True         12
#  1      WeightedEnsemble_L3  -0.002041  ...       True         22
#  2     ExtraTreesMSE_BAG_L2  -0.002056  ...       True         17
#  3   RandomForestMSE_BAG_L2  -0.002120  ...       True         15
#  4     LightGBMLarge_BAG_L2  -0.002156  ...       True         21
#  5     LightGBMLarge_BAG_L1  -0.002169  ...       True         11
#  6   RandomForestMSE_BAG_L1  -0.002179  ...       True          5
#  7     ExtraTreesMSE_BAG_L1  -0.002240  ...       True          7
#  8          CatBoost_BAG_L2  -0.002314  ...       True         16
#  9          LightGBM_BAG_L2  -0.002315  ...       True         14
#  10         LightGBM_BAG_L1  -0.002332  ...       True          4
#  11       LightGBMXT_BAG_L2  -0.002405  ...       True         13
#  12          XGBoost_BAG_L2  -0.002425  ...       True         19
#  13  NeuralNetFastAI_BAG_L2  -0.002501  ...       True         18
#  14          XGBoost_BAG_L1  -0.002599  ...       True          9
#  15       LightGBMXT_BAG_L1  -0.002618  ...       True          3
#  16         CatBoost_BAG_L1  -0.002658  ...       True          6
#  17   KNeighborsDist_BAG_L1  -0.003139  ...       True          2
#  18   NeuralNetMXNet_BAG_L2  -0.003259  ...       True         20
#  19  NeuralNetFastAI_BAG_L1  -0.003777  ...       True          8
#  20   NeuralNetMXNet_BAG_L1  -0.003989  ...       True         10
#  21   KNeighborsUnif_BAG_L1  -0.004684  ...       True          1
#
#  [22 rows x 9 columns],
#  'max_stack_level': 3,
#  'model_best': 'WeightedEnsemble_L2',
#  'model_fit_times': {'CatBoost_BAG_L1': 571.1675691604614,
#   'CatBoost_BAG_L2': 413.13736391067505,
#   'ExtraTreesMSE_BAG_L1': 2.260368824005127,
#   'ExtraTreesMSE_BAG_L2': 2.7699921131134033,
#   'KNeighborsDist_BAG_L1': 0.018342256546020508,
#   'KNeighborsUnif_BAG_L1': 0.013870716094970703,
#   'LightGBMLarge_BAG_L1': 102.55655598640442,
#   'LightGBMLarge_BAG_L2': 68.63936352729797,
#   'LightGBMXT_BAG_L1': 131.884925365448,
#   'LightGBMXT_BAG_L2': 100.67433667182922,
#   'LightGBM_BAG_L1': 93.45744299888611,
#   'LightGBM_BAG_L2': 31.58901286125183,
#   'NeuralNetFastAI_BAG_L1': 28.66836380958557,
#   'NeuralNetFastAI_BAG_L2': 29.82381010055542,
#   'NeuralNetMXNet_BAG_L1': 234.49269223213196,
#   'NeuralNetMXNet_BAG_L2': 218.61367416381836,
#   'RandomForestMSE_BAG_L1': 8.078113317489624,
#   'RandomForestMSE_BAG_L2': 10.197861909866333,
#   'WeightedEnsemble_L2': 0.494030237197876,
#   'WeightedEnsemble_L3': 0.4076390266418457,
#   'XGBoost_BAG_L1': 13.989380598068237,
#   'XGBoost_BAG_L2': 13.797042608261108},
#  'model_hyperparams': {'CatBoost_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'CatBoost_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'ExtraTreesMSE_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'ExtraTreesMSE_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'KNeighborsDist_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'KNeighborsUnif_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'LightGBMLarge_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBMLarge_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBMXT_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBMXT_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBM_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBM_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetFastAI_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetFastAI_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetMXNet_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetMXNet_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'RandomForestMSE_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'RandomForestMSE_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'WeightedEnsemble_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': False},
#   'WeightedEnsemble_L3': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': False},
#   'XGBoost_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'XGBoost_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True}},
#  'model_paths': {'CatBoost_BAG_L1': 'agModels-predictClass/models/CatBoost_BAG_L1/',
#   'CatBoost_BAG_L2': 'agModels-predictClass/models/CatBoost_BAG_L2/',
#   'ExtraTreesMSE_BAG_L1': 'agModels-predictClass/models/ExtraTreesMSE_BAG_L1/',
#   'ExtraTreesMSE_BAG_L2': 'agModels-predictClass/models/ExtraTreesMSE_BAG_L2/',
#   'KNeighborsDist_BAG_L1': 'agModels-predictClass/models/KNeighborsDist_BAG_L1/',
#   'KNeighborsUnif_BAG_L1': 'agModels-predictClass/models/KNeighborsUnif_BAG_L1/',
#   'LightGBMLarge_BAG_L1': 'agModels-predictClass/models/LightGBMLarge_BAG_L1/',
#   'LightGBMLarge_BAG_L2': 'agModels-predictClass/models/LightGBMLarge_BAG_L2/',
#   'LightGBMXT_BAG_L1': 'agModels-predictClass/models/LightGBMXT_BAG_L1/',
#   'LightGBMXT_BAG_L2': 'agModels-predictClass/models/LightGBMXT_BAG_L2/',
#   'LightGBM_BAG_L1': 'agModels-predictClass/models/LightGBM_BAG_L1/',
#   'LightGBM_BAG_L2': 'agModels-predictClass/models/LightGBM_BAG_L2/',
#   'NeuralNetFastAI_BAG_L1': 'agModels-predictClass/models/NeuralNetFastAI_BAG_L1/',
#   'NeuralNetFastAI_BAG_L2': 'agModels-predictClass/models/NeuralNetFastAI_BAG_L2/',
#   'NeuralNetMXNet_BAG_L1': 'agModels-predictClass/models/NeuralNetMXNet_BAG_L1/',
#   'NeuralNetMXNet_BAG_L2': 'agModels-predictClass/models/NeuralNetMXNet_BAG_L2/',
#   'RandomForestMSE_BAG_L1': 'agModels-predictClass/models/RandomForestMSE_BAG_L1/',
#   'RandomForestMSE_BAG_L2': 'agModels-predictClass/models/RandomForestMSE_BAG_L2/',
#   'WeightedEnsemble_L2': 'agModels-predictClass/models/WeightedEnsemble_L2/',
#   'WeightedEnsemble_L3': 'agModels-predictClass/models/WeightedEnsemble_L3/',
#   'XGBoost_BAG_L1': 'agModels-predictClass/models/XGBoost_BAG_L1/',
#   'XGBoost_BAG_L2': 'agModels-predictClass/models/XGBoost_BAG_L2/'},
#  'model_performance': {'CatBoost_BAG_L1': -0.0026584130372401212,
#   'CatBoost_BAG_L2': -0.0023144964477524984,
#   'ExtraTreesMSE_BAG_L1': -0.002240256549122608,
#   'ExtraTreesMSE_BAG_L2': -0.002055587400178365,
#   'KNeighborsDist_BAG_L1': -0.0031387778639285443,
#   'KNeighborsUnif_BAG_L1': -0.004683504885884652,
#   'LightGBMLarge_BAG_L1': -0.002168955597950487,
#   'LightGBMLarge_BAG_L2': -0.0021560104929884273,
#   'LightGBMXT_BAG_L1': -0.0026184467050219306,
#   'LightGBMXT_BAG_L2': -0.002405371765581098,
#   'LightGBM_BAG_L1': -0.002332053194497828,
#   'LightGBM_BAG_L2': -0.002315403647752776,
#   'NeuralNetFastAI_BAG_L1': -0.0037773519322370675,
#   'NeuralNetFastAI_BAG_L2': -0.0025013850881208163,
#   'NeuralNetMXNet_BAG_L1': -0.003988557406393515,
#   'NeuralNetMXNet_BAG_L2': -0.003259173360689118,
#   'RandomForestMSE_BAG_L1': -0.002179379773974628,
#   'RandomForestMSE_BAG_L2': -0.002120090989515579,
#   'WeightedEnsemble_L2': -0.0020065976203443516,
#   'WeightedEnsemble_L3': -0.002041054031297868,
#   'XGBoost_BAG_L1': -0.0025993336487964507,
#   'XGBoost_BAG_L2': -0.002424835153324466},
#  'model_pred_times': {'CatBoost_BAG_L1': 0.05947542190551758,
#   'CatBoost_BAG_L2': 0.062093496322631836,
#   'ExtraTreesMSE_BAG_L1': 0.18015718460083008,
#   'ExtraTreesMSE_BAG_L2': 0.18319225311279297,
#   'KNeighborsDist_BAG_L1': 0.18591570854187012,
#   'KNeighborsUnif_BAG_L1': 0.19417667388916016,
#   'LightGBMLarge_BAG_L1': 0.23416972160339355,
#   'LightGBMLarge_BAG_L2': 0.10046815872192383,
#   'LightGBMXT_BAG_L1': 2.8322277069091797,
#   'LightGBMXT_BAG_L2': 1.4538710117340088,
#   'LightGBM_BAG_L1': 0.6606566905975342,
#   'LightGBM_BAG_L2': 0.11491727828979492,
#   'NeuralNetFastAI_BAG_L1': 0.2826507091522217,
#   'NeuralNetFastAI_BAG_L2': 0.34284305572509766,
#   'NeuralNetMXNet_BAG_L1': 1.871708631515503,
#   'NeuralNetMXNet_BAG_L2': 2.004781723022461,
#   'RandomForestMSE_BAG_L1': 0.18561267852783203,
#   'RandomForestMSE_BAG_L2': 0.1913161277770996,
#   'WeightedEnsemble_L2': 0.0007433891296386719,
#   'WeightedEnsemble_L3': 0.0007033348083496094,
#   'XGBoost_BAG_L1': 0.06187033653259277,
#   'XGBoost_BAG_L2': 0.06199812889099121},
#  'model_types': {'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesMSE_BAG_L2': 'StackerEnsembleModel_XT',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetMXNet_BAG_L1': 'StackerEnsembleModel_TabularNeuralNet',
#   'NeuralNetMXNet_BAG_L2': 'StackerEnsembleModel_TabularNeuralNet',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestMSE_BAG_L2': 'StackerEnsembleModel_RF',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost'},
#  'num_bag_folds': 10}

# %%
#repeated?
test_data = TabularDataset(df_m_5.tail(500))
y_test = test_data[label]
test_data_nolab = test_data.drop(columns=[label])
test_data_nolab.tail()
# Out:
#                 d  index  ...  eu_High_next_day1  eu_Low_next_day1
# 12788  2021.12.10  12788  ...            1.13191           1.12599
# 12789  2021.12.13  12789  ...            1.13236           1.12535
# 12790  2021.12.14  12790  ...            1.12990           1.12215
# 12791  2021.12.15  12791  ...            1.13602           1.12810
# 12792  2021.12.16  12792  ...            1.13346           1.13240
#
# [5 rows x 38 columns]

# %%
predictor = TabularPredictor.load(save_path)

y_pred = predictor.predict(test_data_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: root_mean_squared_error on test data: -0.001496228925055507
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -0.001496228925055507,
#     "mean_squared_error": -2.2387009961727575e-06,
#     "mean_absolute_error": -0.0008713819070434585,
#     "r2": 0.998760548853603,
#     "pearsonr": 0.999383307133409,
#     "median_absolute_error": -0.00036278688430801953
# }
# Predictions:
#  12293    1.114886
# 12294    1.111323
# 12295    1.108780
# 12296    1.108646
# 12297    1.109296
#            ...
# 12788    1.128346
# 12789    1.125933
# 12790    1.129050
# 12791    1.132948
# 12792    1.133462
# Name: eu_Close_next_day1, Length: 500, dtype: float32
