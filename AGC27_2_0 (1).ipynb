# %%
#License: GPL 
#Creator: Mike Smith https://github.com/gomlfx 
#designed for colab/kaggle/Jupyter

# %%
#!pip install autogluon
#!pip install --upgrade mxnet

# %%
import pandas as pd
import numpy as np
#import matplotlib for plotting 
import matplotlib.pyplot as plt
# %matplotlib inline
#import normalization
from sklearn import preprocessing

#autogluon
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
#metatrader5 file format
df=pd.read_table('GBPCHF_Daily_199304070000_202205250000.csv')

# %%
print(df.head())
print(df.tail())
df.info()
# Out:
#        <DATE>  <OPEN>  <HIGH>   <LOW>  <CLOSE>  <TICKVOL>  <VOL>  <SPREAD>
# 0  1993.04.07  2.2517  2.2535  2.2500   2.2517        701      0       150
# 1  1993.04.08  2.2579  2.2589  2.2570   2.2579        381      0       150
# 2  1993.04.12  2.2647  2.2647  2.2647   2.2647          1      0       150
# 3  1993.04.13  2.2529  2.2529  2.2529   2.2529          1      0       150
# 4  1993.04.14  2.2621  2.2621  2.2621   2.2621          1      0       150
#           <DATE>   <OPEN>   <HIGH>    <LOW>  <CLOSE>  <TICKVOL>  <VOL>  \
# 7500  2022.05.09  1.21725  1.22849  1.21591  1.22518     108767      0
# 7501  2022.05.10  1.22499  1.23142  1.22085  1.22549     110942      0
# 7502  2022.05.11  1.22548  1.22851  1.21624  1.21706     134441      0
# 7503  2022.05.12  1.21790  1.21790  1.21515  1.21600       1449      0
# 7504  2022.05.25  1.20299  1.20558  1.20143  1.20438      12491      0
#
#       <SPREAD>
# 7500         1
# 7501         1
# 7502         1
# 7503        58
# 7504         3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7505 entries, 0 to 7504
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   <DATE>     7505 non-null   object
#  1   <OPEN>     7505 non-null   float64
#  2   <HIGH>     7505 non-null   float64
#  3   <LOW>      7505 non-null   float64
#  4   <CLOSE>    7505 non-null   float64
#  5   <TICKVOL>  7505 non-null   int64
#  6   <VOL>      7505 non-null   int64
#  7   <SPREAD>   7505 non-null   int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 469.2+ KB

# %%
df
# Out:
#           <DATE>   <OPEN>   <HIGH>    <LOW>  <CLOSE>  <TICKVOL>  <VOL>  \
# 0     1993.04.07  2.25170  2.25350  2.25000  2.25170        701      0
# 1     1993.04.08  2.25790  2.25890  2.25700  2.25790        381      0
# 2     1993.04.12  2.26470  2.26470  2.26470  2.26470          1      0
# 3     1993.04.13  2.25290  2.25290  2.25290  2.25290          1      0
# 4     1993.04.14  2.26210  2.26210  2.26210  2.26210          1      0
# ...          ...      ...      ...      ...      ...        ...    ...
# 7500  2022.05.09  1.21725  1.22849  1.21591  1.22518     108767      0
# 7501  2022.05.10  1.22499  1.23142  1.22085  1.22549     110942      0
# 7502  2022.05.11  1.22548  1.22851  1.21624  1.21706     134441      0
# 7503  2022.05.12  1.21790  1.21790  1.21515  1.21600       1449      0
# 7504  2022.05.25  1.20299  1.20558  1.20143  1.20438      12491      0
#
#       <SPREAD>
# 0          150
# 1          150
# 2          150
# 3          150
# 4          150
# ...        ...
# 7500         1
# 7501         1
# 7502         1
# 7503        58
# 7504         3
#
# [7505 rows x 8 columns]

# %%
d = df[["<OPEN>","<HIGH>","<LOW>","<CLOSE>"]]
df = pd.DataFrame(data=d)
df
# Out:
#        <OPEN>   <HIGH>    <LOW>  <CLOSE>
# 0     2.25170  2.25350  2.25000  2.25170
# 1     2.25790  2.25890  2.25700  2.25790
# 2     2.26470  2.26470  2.26470  2.26470
# 3     2.25290  2.25290  2.25290  2.25290
# 4     2.26210  2.26210  2.26210  2.26210
# ...       ...      ...      ...      ...
# 7500  1.21725  1.22849  1.21591  1.22518
# 7501  1.22499  1.23142  1.22085  1.22549
# 7502  1.22548  1.22851  1.21624  1.21706
# 7503  1.21790  1.21790  1.21515  1.21600
# 7504  1.20299  1.20558  1.20143  1.20438
#
# [7505 rows x 4 columns]

# %%
df_raw1 = pd.DataFrame(data=df)
df_raw1
# Out:
#        <OPEN>   <HIGH>    <LOW>  <CLOSE>
# 0     2.25170  2.25350  2.25000  2.25170
# 1     2.25790  2.25890  2.25700  2.25790
# 2     2.26470  2.26470  2.26470  2.26470
# 3     2.25290  2.25290  2.25290  2.25290
# 4     2.26210  2.26210  2.26210  2.26210
# ...       ...      ...      ...      ...
# 7500  1.21725  1.22849  1.21591  1.22518
# 7501  1.22499  1.23142  1.22085  1.22549
# 7502  1.22548  1.22851  1.21624  1.21706
# 7503  1.21790  1.21790  1.21515  1.21600
# 7504  1.20299  1.20558  1.20143  1.20438
#
# [7505 rows x 4 columns]

# %%
stop_df = pd.DataFrame(data=df.tail(40))  
stop_df.iloc[:-1] 
stop_df1 = stop_df[stop_df['<OPEN>'] > stop_df['<CLOSE>']]
print(stop_df1)

stop_df2 = stop_df[stop_df['<OPEN>'] < stop_df['<CLOSE>']]
print(stop_df2)
# Out:
#        <OPEN>   <HIGH>    <LOW>  <CLOSE>
# 7467  1.23592  1.24196  1.22629  1.22820
# 7468  1.22773  1.23266  1.22551  1.22599
# 7470  1.22591  1.23343  1.22186  1.22289
# 7471  1.22320  1.22922  1.21767  1.21882
# 7472  1.21843  1.22177  1.21116  1.21244
# 7479  1.21947  1.22207  1.21524  1.21748
# 7480  1.21332  1.21891  1.21178  1.21264
# 7484  1.23197  1.23405  1.22582  1.23127
# 7489  1.24165  1.24329  1.22680  1.22793
# 7490  1.22727  1.22897  1.21568  1.22222
# 7491  1.22056  1.22404  1.20996  1.21023
# 7493  1.21360  1.21833  1.20783  1.21044
# 7495  1.22126  1.22529  1.21932  1.22093
# 7498  1.22792  1.22999  1.21142  1.21706
# 7502  1.22548  1.22851  1.21624  1.21706
# 7503  1.21790  1.21790  1.21515  1.21600
#        <OPEN>   <HIGH>    <LOW>  <CLOSE>
# 7465  1.22699  1.22996  1.22163  1.22859
# 7466  1.22857  1.23798  1.22852  1.23646
# 7469  1.22597  1.22888  1.21966  1.22653
# 7473  1.21160  1.21573  1.20954  1.21186
# 7474  1.21225  1.21547  1.20934  1.21364
# 7475  1.21152  1.21689  1.21057  1.21439
# 7476  1.21422  1.21923  1.21310  1.21488
# 7477  1.21456  1.22284  1.21420  1.21910
# 7478  1.21910  1.22176  1.21706  1.22077
# 7481  1.21231  1.21578  1.21149  1.21253
# 7482  1.21232  1.22634  1.21009  1.22566
# 7483  1.22556  1.23354  1.22230  1.23217
# 7485  1.22770  1.23209  1.22706  1.22888
# 7486  1.22898  1.23803  1.22641  1.23745
# 7487  1.23573  1.24120  1.23401  1.23917
# 7488  1.23893  1.24477  1.23556  1.24165
# 7492  1.21019  1.21914  1.20779  1.21530
# 7494  1.20934  1.22448  1.20878  1.22416
# 7496  1.22061  1.22784  1.21841  1.22303
# 7497  1.22296  1.22941  1.22030  1.22793
# 7499  1.21658  1.22055  1.21081  1.21926
# 7500  1.21725  1.22849  1.21591  1.22518
# 7501  1.22499  1.23142  1.22085  1.22549
# 7504  1.20299  1.20558  1.20143  1.20438

# %%
stop_df1['stop_for_sell'] = stop_df1['<HIGH>'] - stop_df1['<OPEN>']
print(stop_df1.stop_for_sell)

stop_df2['stop_for_buy'] = stop_df2['<OPEN>'] - stop_df2['<LOW>']
print(stop_df2.stop_for_buy)
# Out:
# 7467    0.00604
# 7468    0.00493
# 7470    0.00752
# 7471    0.00602
# 7472    0.00334
# 7479    0.00260
# 7480    0.00559
# 7484    0.00208
# 7489    0.00164
# 7490    0.00170
# 7491    0.00348
# 7493    0.00473
# 7495    0.00403
# 7498    0.00207
# 7502    0.00303
# 7503    0.00000
# Name: stop_for_sell, dtype: float64
# 7465    0.00536
# 7466    0.00005
# 7469    0.00631
# 7473    0.00206
# 7474    0.00291
# 7475    0.00095
# 7476    0.00112
# 7477    0.00036
# 7478    0.00204
# 7481    0.00082
# 7482    0.00223
# 7483    0.00326
# 7485    0.00064
# 7486    0.00257
# 7487    0.00172
# 7488    0.00337
# 7492    0.00240
# 7494    0.00056
# 7496    0.00220
# 7497    0.00266
# 7499    0.00577
# 7500    0.00134
# 7501    0.00414
# 7504    0.00156
# Name: stop_for_buy, dtype: float64
# /tmp/ipykernel_70/1471322244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stop_df1['stop_for_sell'] = stop_df1['<HIGH>'] - stop_df1['<OPEN>']
# /tmp/ipykernel_70/1471322244.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stop_df2['stop_for_buy'] = stop_df2['<OPEN>'] - stop_df2['<LOW>']

# %%
print(stop_df1.stop_for_sell.describe(percentiles=[.25,.5,.75,.99]))
print(stop_df2.stop_for_buy.describe(percentiles=[.25,.5,.75,.99]))
# Out:
# count    16.000000
# mean      0.003675
# std       0.002012
# min       0.000000
# 25%       0.002078
# 50%       0.003410
# 75%       0.005095
# 99%       0.007298
# max       0.007520
# Name: stop_for_sell, dtype: float64
# count    24.000000
# mean      0.002350
# std       0.001687
# min       0.000050
# 25%       0.001078
# 50%       0.002130
# 75%       0.002997
# 99%       0.006186
# max       0.006310
# Name: stop_for_buy, dtype: float64

# %%
stop_for_sell = stop_df1.stop_for_sell.describe()
stop_for_buy = stop_df2.stop_for_buy.describe()

# %%
df.rename({'<OPEN>':'p_o','<HIGH>':'p_h','<LOW>':'p_l','<CLOSE>':'p_c'}, axis='columns', inplace=True)

# %%
df.info
# Out:
# <bound method DataFrame.info of           p_o      p_h      p_l      p_c
# 0     2.25170  2.25350  2.25000  2.25170
# 1     2.25790  2.25890  2.25700  2.25790
# 2     2.26470  2.26470  2.26470  2.26470
# 3     2.25290  2.25290  2.25290  2.25290
# 4     2.26210  2.26210  2.26210  2.26210
# ...       ...      ...      ...      ...
# 7500  1.21725  1.22849  1.21591  1.22518
# 7501  1.22499  1.23142  1.22085  1.22549
# 7502  1.22548  1.22851  1.21624  1.21706
# 7503  1.21790  1.21790  1.21515  1.21600
# 7504  1.20299  1.20558  1.20143  1.20438
#
# [7505 rows x 4 columns]>

# %%
print(df.columns)
# Out:
# Index(['p_o', 'p_h', 'p_l', 'p_c'], dtype='object')

# %%
#Features



#380 periods ago
df['p_Open_last_period380'] = df['p_o'].shift(380) 
df['p_High_last_period380'] = df['p_h'].shift(380)
df['p_Low_last_period380'] = df['p_l'].shift(380)
df['p_Close_last_period380'] = df['p_c'].shift(380)
#379 periods ago
df['p_Open_last_period379'] = df['p_o'].shift(379) 
df['p_High_last_period379'] = df['p_h'].shift(379)
df['p_Low_last_period379'] = df['p_l'].shift(379)
df['p_Close_last_period379'] = df['p_c'].shift(379)
#378 periods ago
df['p_Open_last_period378'] = df['p_o'].shift(378) 
df['p_High_last_period378'] = df['p_h'].shift(378)
df['p_Low_last_period378'] = df['p_l'].shift(378)
df['p_Close_last_period378'] = df['p_c'].shift(378)
#377 periods ago
df['p_Open_last_period377'] = df['p_o'].shift(377) 
df['p_High_last_period377'] = df['p_h'].shift(377)
df['p_Low_last_period377'] = df['p_l'].shift(377)
df['p_Close_last_period377'] = df['p_c'].shift(377)
#376 periods ago
df['p_Open_last_period376'] = df['p_o'].shift(376) 
df['p_High_last_period376'] = df['p_h'].shift(376)
df['p_Low_last_period376'] = df['p_l'].shift(376)
df['p_Close_last_period376'] = df['p_c'].shift(376)
#375 periods ago
df['p_Open_last_period375'] = df['p_o'].shift(375) 
df['p_High_last_period375'] = df['p_h'].shift(375)
df['p_Low_last_period375'] = df['p_l'].shift(375)
df['p_Close_last_period375'] = df['p_c'].shift(375)
#374 periods ago
df['p_Open_last_period374'] = df['p_o'].shift(374) 
df['p_High_last_period374'] = df['p_h'].shift(374)
df['p_Low_last_period374'] = df['p_l'].shift(374)
df['p_Close_last_period374'] = df['p_c'].shift(374)
#373 periods ago
df['p_Open_last_period373'] = df['p_o'].shift(373) 
df['p_High_last_period373'] = df['p_h'].shift(373)
df['p_Low_last_period373'] = df['p_l'].shift(373)
df['p_Close_last_period373'] = df['p_c'].shift(373)
#372 periods ago
df['p_Open_last_period372'] = df['p_o'].shift(372) 
df['p_High_last_period372'] = df['p_h'].shift(372)
df['p_Low_last_period372'] = df['p_l'].shift(372)
df['p_Close_last_period372'] = df['p_c'].shift(372)
#371 periods ago
df['p_Open_last_period371'] = df['p_o'].shift(371) 
df['p_High_last_period371'] = df['p_h'].shift(371)
df['p_Low_last_period371'] = df['p_l'].shift(371)
df['p_Close_last_period371'] = df['p_c'].shift(371)
#370 periods ago
df['p_Open_last_period370'] = df['p_o'].shift(370) 
df['p_High_last_period370'] = df['p_h'].shift(370)
df['p_Low_last_period370'] = df['p_l'].shift(370)
df['p_Close_last_period370'] = df['p_c'].shift(370)
#369 periods ago
df['p_Open_last_period369'] = df['p_o'].shift(369) 
df['p_High_last_period369'] = df['p_h'].shift(369)
df['p_Low_last_period369'] = df['p_l'].shift(369)
df['p_Close_last_period369'] = df['p_c'].shift(369)
#368 periods ago
df['p_Open_last_period368'] = df['p_o'].shift(368) 
df['p_High_last_period368'] = df['p_h'].shift(368)
df['p_Low_last_period368'] = df['p_l'].shift(368)
df['p_Close_last_period368'] = df['p_c'].shift(368)
#367 periods ago
df['p_Open_last_period367'] = df['p_o'].shift(367) 
df['p_High_last_period367'] = df['p_h'].shift(367)
df['p_Low_last_period367'] = df['p_l'].shift(367)
df['p_Close_last_period367'] = df['p_c'].shift(367)
#366 periods ago
df['p_Open_last_period366'] = df['p_o'].shift(366) 
df['p_High_last_period366'] = df['p_h'].shift(366)
df['p_Low_last_period366'] = df['p_l'].shift(366)
df['p_Close_last_period366'] = df['p_c'].shift(366)
#365 periods ago
df['p_Open_last_period365'] = df['p_o'].shift(365) 
df['p_High_last_period365'] = df['p_h'].shift(365)
df['p_Low_last_period365'] = df['p_l'].shift(365)
df['p_Close_last_period365'] = df['p_c'].shift(365)
#364 periods ago
df['p_Open_last_period364'] = df['p_o'].shift(364) 
df['p_High_last_period364'] = df['p_h'].shift(364)
df['p_Low_last_period364'] = df['p_l'].shift(364)
df['p_Close_last_period364'] = df['p_c'].shift(364)
#363 periods ago
df['p_Open_last_period363'] = df['p_o'].shift(363) 
df['p_High_last_period363'] = df['p_h'].shift(363)
df['p_Low_last_period363'] = df['p_l'].shift(363)
df['p_Close_last_period363'] = df['p_c'].shift(363)
#362 periods ago
df['p_Open_last_period362'] = df['p_o'].shift(362) 
df['p_High_last_period362'] = df['p_h'].shift(362)
df['p_Low_last_period362'] = df['p_l'].shift(362)
df['p_Close_last_period362'] = df['p_c'].shift(362)
#361 periods ago
df['p_Open_last_period361'] = df['p_o'].shift(361) 
df['p_High_last_period361'] = df['p_h'].shift(361)
df['p_Low_last_period361'] = df['p_l'].shift(361)
df['p_Close_last_period361'] = df['p_c'].shift(361)
#360 periods ago
df['p_Open_last_period360'] = df['p_o'].shift(360) 
df['p_High_last_period360'] = df['p_h'].shift(360)
df['p_Low_last_period360'] = df['p_l'].shift(360)
df['p_Close_last_period360'] = df['p_c'].shift(360)
#359 periods ago
df['p_Open_last_period359'] = df['p_o'].shift(359) 
df['p_High_last_period359'] = df['p_h'].shift(359)
df['p_Low_last_period359'] = df['p_l'].shift(359)
df['p_Close_last_period359'] = df['p_c'].shift(359)
#358 periods ago
df['p_Open_last_period358'] = df['p_o'].shift(358) 
df['p_High_last_period358'] = df['p_h'].shift(358)
df['p_Low_last_period358'] = df['p_l'].shift(358)
df['p_Close_last_period358'] = df['p_c'].shift(358)
#357 periods ago
df['p_Open_last_period357'] = df['p_o'].shift(357) 
df['p_High_last_period357'] = df['p_h'].shift(357)
df['p_Low_last_period357'] = df['p_l'].shift(357)
df['p_Close_last_period357'] = df['p_c'].shift(357)
#356 periods ago
df['p_Open_last_period356'] = df['p_o'].shift(356) 
df['p_High_last_period356'] = df['p_h'].shift(356)
df['p_Low_last_period356'] = df['p_l'].shift(356)
df['p_Close_last_period356'] = df['p_c'].shift(356)
#355 periods ago
df['p_Open_last_period355'] = df['p_o'].shift(355) 
df['p_High_last_period355'] = df['p_h'].shift(355)
df['p_Low_last_period355'] = df['p_l'].shift(355)
df['p_Close_last_period355'] = df['p_c'].shift(355)
#354 periods ago
df['p_Open_last_period354'] = df['p_o'].shift(354) 
df['p_High_last_period354'] = df['p_h'].shift(354)
df['p_Low_last_period354'] = df['p_l'].shift(354)
df['p_Close_last_period354'] = df['p_c'].shift(354)
#353 periods ago
df['p_Open_last_period353'] = df['p_o'].shift(353) 
df['p_High_last_period353'] = df['p_h'].shift(353)
df['p_Low_last_period353'] = df['p_l'].shift(353)
df['p_Close_last_period353'] = df['p_c'].shift(353)
#352 periods ago
df['p_Open_last_period352'] = df['p_o'].shift(352) 
df['p_High_last_period352'] = df['p_h'].shift(352)
df['p_Low_last_period352'] = df['p_l'].shift(352)
df['p_Close_last_period352'] = df['p_c'].shift(352)
#351 periods ago
df['p_Open_last_period351'] = df['p_o'].shift(351) 
df['p_High_last_period351'] = df['p_h'].shift(351)
df['p_Low_last_period351'] = df['p_l'].shift(351)
df['p_Close_last_period351'] = df['p_c'].shift(351)
#350 periods ago
df['p_Open_last_period350'] = df['p_o'].shift(350) 
df['p_High_last_period350'] = df['p_h'].shift(350)
df['p_Low_last_period350'] = df['p_l'].shift(350)
df['p_Close_last_period350'] = df['p_c'].shift(350)
#349 periods ago
df['p_Open_last_period349'] = df['p_o'].shift(349) 
df['p_High_last_period349'] = df['p_h'].shift(349)
df['p_Low_last_period349'] = df['p_l'].shift(349)
df['p_Close_last_period349'] = df['p_c'].shift(349)
#348 periods ago
df['p_Open_last_period348'] = df['p_o'].shift(348) 
df['p_High_last_period348'] = df['p_h'].shift(348)
df['p_Low_last_period348'] = df['p_l'].shift(348)
df['p_Close_last_period348'] = df['p_c'].shift(348)
#347 periods ago
df['p_Open_last_period347'] = df['p_o'].shift(347) 
df['p_High_last_period347'] = df['p_h'].shift(347)
df['p_Low_last_period347'] = df['p_l'].shift(347)
df['p_Close_last_period347'] = df['p_c'].shift(347)
#346 periods ago
df['p_Open_last_period346'] = df['p_o'].shift(346) 
df['p_High_last_period346'] = df['p_h'].shift(346)
df['p_Low_last_period346'] = df['p_l'].shift(346)
df['p_Close_last_period346'] = df['p_c'].shift(346)
#345 periods ago
df['p_Open_last_period345'] = df['p_o'].shift(345) 
df['p_High_last_period345'] = df['p_h'].shift(345)
df['p_Low_last_period345'] = df['p_l'].shift(345)
df['p_Close_last_period345'] = df['p_c'].shift(345)
#344 periods ago
df['p_Open_last_period344'] = df['p_o'].shift(344) 
df['p_High_last_period344'] = df['p_h'].shift(344)
df['p_Low_last_period344'] = df['p_l'].shift(344)
df['p_Close_last_period344'] = df['p_c'].shift(344)
#343 periods ago
df['p_Open_last_period343'] = df['p_o'].shift(343) 
df['p_High_last_period343'] = df['p_h'].shift(343)
df['p_Low_last_period343'] = df['p_l'].shift(343)
df['p_Close_last_period343'] = df['p_c'].shift(343)
#342 periods ago
df['p_Open_last_period342'] = df['p_o'].shift(342) 
df['p_High_last_period342'] = df['p_h'].shift(342)
df['p_Low_last_period342'] = df['p_l'].shift(342)
df['p_Close_last_period342'] = df['p_c'].shift(342)
#341 periods ago
df['p_Open_last_period341'] = df['p_o'].shift(341) 
df['p_High_last_period341'] = df['p_h'].shift(341)
df['p_Low_last_period341'] = df['p_l'].shift(341)
df['p_Close_last_period341'] = df['p_c'].shift(341)
#340 periods ago
df['p_Open_last_period340'] = df['p_o'].shift(340) 
df['p_High_last_period340'] = df['p_h'].shift(340)
df['p_Low_last_period340'] = df['p_l'].shift(340)
df['p_Close_last_period340'] = df['p_c'].shift(340)
#339 periods ago
df['p_Open_last_period339'] = df['p_o'].shift(339) 
df['p_High_last_period339'] = df['p_h'].shift(339)
df['p_Low_last_period339'] = df['p_l'].shift(339)
df['p_Close_last_period339'] = df['p_c'].shift(339)
#338 periods ago
df['p_Open_last_period338'] = df['p_o'].shift(338) 
df['p_High_last_period338'] = df['p_h'].shift(338)
df['p_Low_last_period338'] = df['p_l'].shift(338)
df['p_Close_last_period338'] = df['p_c'].shift(338)
#337 periods ago
df['p_Open_last_period337'] = df['p_o'].shift(337) 
df['p_High_last_period337'] = df['p_h'].shift(337)
df['p_Low_last_period337'] = df['p_l'].shift(337)
df['p_Close_last_period337'] = df['p_c'].shift(337)
#336 periods ago
df['p_Open_last_period336'] = df['p_o'].shift(336) 
df['p_High_last_period336'] = df['p_h'].shift(336)
df['p_Low_last_period336'] = df['p_l'].shift(336)
df['p_Close_last_period336'] = df['p_c'].shift(336)
#335 periods ago
df['p_Open_last_period335'] = df['p_o'].shift(335) 
df['p_High_last_period335'] = df['p_h'].shift(335)
df['p_Low_last_period335'] = df['p_l'].shift(335)
df['p_Close_last_period335'] = df['p_c'].shift(335)
#334 periods ago
df['p_Open_last_period334'] = df['p_o'].shift(334) 
df['p_High_last_period334'] = df['p_h'].shift(334)
df['p_Low_last_period334'] = df['p_l'].shift(334)
df['p_Close_last_period334'] = df['p_c'].shift(334)
#333 periods ago
df['p_Open_last_period333'] = df['p_o'].shift(333) 
df['p_High_last_period333'] = df['p_h'].shift(333)
df['p_Low_last_period333'] = df['p_l'].shift(333)
df['p_Close_last_period333'] = df['p_c'].shift(333)
#332 periods ago
df['p_Open_last_period332'] = df['p_o'].shift(332) 
df['p_High_last_period332'] = df['p_h'].shift(332)
df['p_Low_last_period332'] = df['p_l'].shift(332)
df['p_Close_last_period332'] = df['p_c'].shift(332)
#331 periods ago
df['p_Open_last_period331'] = df['p_o'].shift(331) 
df['p_High_last_period331'] = df['p_h'].shift(331)
df['p_Low_last_period331'] = df['p_l'].shift(331)
df['p_Close_last_period331'] = df['p_c'].shift(331)
#330 periods ago
df['p_Open_last_period330'] = df['p_o'].shift(330) 
df['p_High_last_period330'] = df['p_h'].shift(330)
df['p_Low_last_period330'] = df['p_l'].shift(330)
df['p_Close_last_period330'] = df['p_c'].shift(330)
#329 periods ago
df['p_Open_last_period329'] = df['p_o'].shift(329) 
df['p_High_last_period329'] = df['p_h'].shift(329)
df['p_Low_last_period329'] = df['p_l'].shift(329)
df['p_Close_last_period329'] = df['p_c'].shift(329)
#328 periods ago
df['p_Open_last_period328'] = df['p_o'].shift(328) 
df['p_High_last_period328'] = df['p_h'].shift(328)
df['p_Low_last_period328'] = df['p_l'].shift(328)
df['p_Close_last_period328'] = df['p_c'].shift(328)
#327 periods ago
df['p_Open_last_period327'] = df['p_o'].shift(327) 
df['p_High_last_period327'] = df['p_h'].shift(327)
df['p_Low_last_period327'] = df['p_l'].shift(327)
df['p_Close_last_period327'] = df['p_c'].shift(327)
#326 periods ago
df['p_Open_last_period326'] = df['p_o'].shift(326) 
df['p_High_last_period326'] = df['p_h'].shift(326)
df['p_Low_last_period326'] = df['p_l'].shift(326)
df['p_Close_last_period326'] = df['p_c'].shift(326)
#325 periods ago
df['p_Open_last_period325'] = df['p_o'].shift(325) 
df['p_High_last_period325'] = df['p_h'].shift(325)
df['p_Low_last_period325'] = df['p_l'].shift(325)
df['p_Close_last_period325'] = df['p_c'].shift(325)
#324 periods ago
df['p_Open_last_period324'] = df['p_o'].shift(324) 
df['p_High_last_period324'] = df['p_h'].shift(324)
df['p_Low_last_period324'] = df['p_l'].shift(324)
df['p_Close_last_period324'] = df['p_c'].shift(324)
#323 periods ago
df['p_Open_last_period323'] = df['p_o'].shift(323) 
df['p_High_last_period323'] = df['p_h'].shift(323)
df['p_Low_last_period323'] = df['p_l'].shift(323)
df['p_Close_last_period323'] = df['p_c'].shift(323)
#322 periods ago
df['p_Open_last_period322'] = df['p_o'].shift(322) 
df['p_High_last_period322'] = df['p_h'].shift(322)
df['p_Low_last_period322'] = df['p_l'].shift(322)
df['p_Close_last_period322'] = df['p_c'].shift(322)
#321 periods ago
df['p_Open_last_period321'] = df['p_o'].shift(321) 
df['p_High_last_period321'] = df['p_h'].shift(321)
df['p_Low_last_period321'] = df['p_l'].shift(321)
df['p_Close_last_period321'] = df['p_c'].shift(321)
#320 periods ago
df['p_Open_last_period320'] = df['p_o'].shift(320) 
df['p_High_last_period320'] = df['p_h'].shift(320)
df['p_Low_last_period320'] = df['p_l'].shift(320)
df['p_Close_last_period320'] = df['p_c'].shift(320)
#319 periods ago
df['p_Open_last_period319'] = df['p_o'].shift(319) 
df['p_High_last_period319'] = df['p_h'].shift(319)
df['p_Low_last_period319'] = df['p_l'].shift(319)
df['p_Close_last_period319'] = df['p_c'].shift(319)
#318 periods ago
df['p_Open_last_period318'] = df['p_o'].shift(318) 
df['p_High_last_period318'] = df['p_h'].shift(318)
df['p_Low_last_period318'] = df['p_l'].shift(318)
df['p_Close_last_period318'] = df['p_c'].shift(318)
#317 periods ago
df['p_Open_last_period317'] = df['p_o'].shift(317) 
df['p_High_last_period317'] = df['p_h'].shift(317)
df['p_Low_last_period317'] = df['p_l'].shift(317)
df['p_Close_last_period317'] = df['p_c'].shift(317)
#316 periods ago
df['p_Open_last_period316'] = df['p_o'].shift(316) 
df['p_High_last_period316'] = df['p_h'].shift(316)
df['p_Low_last_period316'] = df['p_l'].shift(316)
df['p_Close_last_period316'] = df['p_c'].shift(316)
#315 periods ago
df['p_Open_last_period315'] = df['p_o'].shift(315) 
df['p_High_last_period315'] = df['p_h'].shift(315)
df['p_Low_last_period315'] = df['p_l'].shift(315)
df['p_Close_last_period315'] = df['p_c'].shift(315)
#314 periods ago
df['p_Open_last_period314'] = df['p_o'].shift(314) 
df['p_High_last_period314'] = df['p_h'].shift(314)
df['p_Low_last_period314'] = df['p_l'].shift(314)
df['p_Close_last_period314'] = df['p_c'].shift(314)
#313 periods ago
df['p_Open_last_period313'] = df['p_o'].shift(313) 
df['p_High_last_period313'] = df['p_h'].shift(313)
df['p_Low_last_period313'] = df['p_l'].shift(313)
df['p_Close_last_period313'] = df['p_c'].shift(313)
#312 periods ago
df['p_Open_last_period312'] = df['p_o'].shift(312) 
df['p_High_last_period312'] = df['p_h'].shift(312)
df['p_Low_last_period312'] = df['p_l'].shift(312)
df['p_Close_last_period312'] = df['p_c'].shift(312)
#311 periods ago
df['p_Open_last_period311'] = df['p_o'].shift(311) 
df['p_High_last_period311'] = df['p_h'].shift(311)
df['p_Low_last_period311'] = df['p_l'].shift(311)
df['p_Close_last_period311'] = df['p_c'].shift(311)
#310 periods ago
df['p_Open_last_period310'] = df['p_o'].shift(310) 
df['p_High_last_period310'] = df['p_h'].shift(310)
df['p_Low_last_period310'] = df['p_l'].shift(310)
df['p_Close_last_period310'] = df['p_c'].shift(310)
#309 periods ago
df['p_Open_last_period309'] = df['p_o'].shift(309) 
df['p_High_last_period309'] = df['p_h'].shift(309)
df['p_Low_last_period309'] = df['p_l'].shift(309)
df['p_Close_last_period309'] = df['p_c'].shift(309)
#308 periods ago
df['p_Open_last_period308'] = df['p_o'].shift(308) 
df['p_High_last_period308'] = df['p_h'].shift(308)
df['p_Low_last_period308'] = df['p_l'].shift(308)
df['p_Close_last_period308'] = df['p_c'].shift(308)
#307 periods ago
df['p_Open_last_period307'] = df['p_o'].shift(307) 
df['p_High_last_period307'] = df['p_h'].shift(307)
df['p_Low_last_period307'] = df['p_l'].shift(307)
df['p_Close_last_period307'] = df['p_c'].shift(307)
#306 periods ago
df['p_Open_last_period306'] = df['p_o'].shift(306) 
df['p_High_last_period306'] = df['p_h'].shift(306)
df['p_Low_last_period306'] = df['p_l'].shift(306)
df['p_Close_last_period306'] = df['p_c'].shift(306)
#305 periods ago
df['p_Open_last_period305'] = df['p_o'].shift(305) 
df['p_High_last_period305'] = df['p_h'].shift(305)
df['p_Low_last_period305'] = df['p_l'].shift(305)
df['p_Close_last_period305'] = df['p_c'].shift(305)
#304 periods ago
df['p_Open_last_period304'] = df['p_o'].shift(304) 
df['p_High_last_period304'] = df['p_h'].shift(304)
df['p_Low_last_period304'] = df['p_l'].shift(304)
df['p_Close_last_period304'] = df['p_c'].shift(304)
#303 periods ago
df['p_Open_last_period303'] = df['p_o'].shift(303) 
df['p_High_last_period303'] = df['p_h'].shift(303)
df['p_Low_last_period303'] = df['p_l'].shift(303)
df['p_Close_last_period303'] = df['p_c'].shift(303)
#302 periods ago
df['p_Open_last_period302'] = df['p_o'].shift(302) 
df['p_High_last_period302'] = df['p_h'].shift(302)
df['p_Low_last_period302'] = df['p_l'].shift(302)
df['p_Close_last_period302'] = df['p_c'].shift(302)
#301 periods ago
df['p_Open_last_period301'] = df['p_o'].shift(301) 
df['p_High_last_period301'] = df['p_h'].shift(301)
df['p_Low_last_period301'] = df['p_l'].shift(301)
df['p_Close_last_period301'] = df['p_c'].shift(301)
#300 periods ago
df['p_Open_last_period300'] = df['p_o'].shift(300) 
df['p_High_last_period300'] = df['p_h'].shift(300)
df['p_Low_last_period300'] = df['p_l'].shift(300)
df['p_Close_last_period300'] = df['p_c'].shift(300)
#299 periods ago
df['p_Open_last_period299'] = df['p_o'].shift(299) 
df['p_High_last_period299'] = df['p_h'].shift(299)
df['p_Low_last_period299'] = df['p_l'].shift(299)
df['p_Close_last_period299'] = df['p_c'].shift(299)
#298 periods ago
df['p_Open_last_period298'] = df['p_o'].shift(298) 
df['p_High_last_period298'] = df['p_h'].shift(298)
df['p_Low_last_period298'] = df['p_l'].shift(298)
df['p_Close_last_period298'] = df['p_c'].shift(298)
#297 periods ago
df['p_Open_last_period297'] = df['p_o'].shift(297) 
df['p_High_last_period297'] = df['p_h'].shift(297)
df['p_Low_last_period297'] = df['p_l'].shift(297)
df['p_Close_last_period297'] = df['p_c'].shift(297)
#296 periods ago
df['p_Open_last_period296'] = df['p_o'].shift(296) 
df['p_High_last_period296'] = df['p_h'].shift(296)
df['p_Low_last_period296'] = df['p_l'].shift(296)
df['p_Close_last_period296'] = df['p_c'].shift(296)
#295 periods ago
df['p_Open_last_period295'] = df['p_o'].shift(295) 
df['p_High_last_period295'] = df['p_h'].shift(295)
df['p_Low_last_period295'] = df['p_l'].shift(295)
df['p_Close_last_period295'] = df['p_c'].shift(295)
#294 periods ago
df['p_Open_last_period294'] = df['p_o'].shift(294) 
df['p_High_last_period294'] = df['p_h'].shift(294)
df['p_Low_last_period294'] = df['p_l'].shift(294)
df['p_Close_last_period294'] = df['p_c'].shift(294)
#293 periods ago
df['p_Open_last_period293'] = df['p_o'].shift(293) 
df['p_High_last_period293'] = df['p_h'].shift(293)
df['p_Low_last_period293'] = df['p_l'].shift(293)
df['p_Close_last_period293'] = df['p_c'].shift(293)
#292 periods ago
df['p_Open_last_period292'] = df['p_o'].shift(292) 
df['p_High_last_period292'] = df['p_h'].shift(292)
df['p_Low_last_period292'] = df['p_l'].shift(292)
df['p_Close_last_period292'] = df['p_c'].shift(292)
#291 periods ago
df['p_Open_last_period291'] = df['p_o'].shift(291) 
df['p_High_last_period291'] = df['p_h'].shift(291)
df['p_Low_last_period291'] = df['p_l'].shift(291)
df['p_Close_last_period291'] = df['p_c'].shift(291)
#290 periods ago
df['p_Open_last_period290'] = df['p_o'].shift(290) 
df['p_High_last_period290'] = df['p_h'].shift(290)
df['p_Low_last_period290'] = df['p_l'].shift(290)
df['p_Close_last_period290'] = df['p_c'].shift(290)
#289 periods ago
df['p_Open_last_period289'] = df['p_o'].shift(289) 
df['p_High_last_period289'] = df['p_h'].shift(289)
df['p_Low_last_period289'] = df['p_l'].shift(289)
df['p_Close_last_period289'] = df['p_c'].shift(289)
#288 periods ago
df['p_Open_last_period288'] = df['p_o'].shift(288) 
df['p_High_last_period288'] = df['p_h'].shift(288)
df['p_Low_last_period288'] = df['p_l'].shift(288)
df['p_Close_last_period288'] = df['p_c'].shift(288)
#287 periods ago
df['p_Open_last_period287'] = df['p_o'].shift(287) 
df['p_High_last_period287'] = df['p_h'].shift(287)
df['p_Low_last_period287'] = df['p_l'].shift(287)
df['p_Close_last_period287'] = df['p_c'].shift(287)
#286 periods ago
df['p_Open_last_period286'] = df['p_o'].shift(286) 
df['p_High_last_period286'] = df['p_h'].shift(286)
df['p_Low_last_period286'] = df['p_l'].shift(286)
df['p_Close_last_period286'] = df['p_c'].shift(286)
#285 periods ago
df['p_Open_last_period285'] = df['p_o'].shift(285) 
df['p_High_last_period285'] = df['p_h'].shift(285)
df['p_Low_last_period285'] = df['p_l'].shift(285)
df['p_Close_last_period285'] = df['p_c'].shift(285)
#284 periods ago
df['p_Open_last_period284'] = df['p_o'].shift(284) 
df['p_High_last_period284'] = df['p_h'].shift(284)
df['p_Low_last_period284'] = df['p_l'].shift(284)
df['p_Close_last_period284'] = df['p_c'].shift(284)
#283 periods ago
df['p_Open_last_period283'] = df['p_o'].shift(283) 
df['p_High_last_period283'] = df['p_h'].shift(283)
df['p_Low_last_period283'] = df['p_l'].shift(283)
df['p_Close_last_period283'] = df['p_c'].shift(283)
#282 periods ago
df['p_Open_last_period282'] = df['p_o'].shift(282) 
df['p_High_last_period282'] = df['p_h'].shift(282)
df['p_Low_last_period282'] = df['p_l'].shift(282)
df['p_Close_last_period282'] = df['p_c'].shift(282)
#281 periods ago
df['p_Open_last_period281'] = df['p_o'].shift(281) 
df['p_High_last_period281'] = df['p_h'].shift(281)
df['p_Low_last_period281'] = df['p_l'].shift(281)
df['p_Close_last_period281'] = df['p_c'].shift(281)
#280 periods ago
df['p_Open_last_period280'] = df['p_o'].shift(280) 
df['p_High_last_period280'] = df['p_h'].shift(280)
df['p_Low_last_period280'] = df['p_l'].shift(280)
df['p_Close_last_period280'] = df['p_c'].shift(280)
#279 periods ago
df['p_Open_last_period279'] = df['p_o'].shift(279) 
df['p_High_last_period279'] = df['p_h'].shift(279)
df['p_Low_last_period279'] = df['p_l'].shift(279)
df['p_Close_last_period279'] = df['p_c'].shift(279)
#278 periods ago
df['p_Open_last_period278'] = df['p_o'].shift(278) 
df['p_High_last_period278'] = df['p_h'].shift(278)
df['p_Low_last_period278'] = df['p_l'].shift(278)
df['p_Close_last_period278'] = df['p_c'].shift(278)
#277 periods ago
df['p_Open_last_period277'] = df['p_o'].shift(277) 
df['p_High_last_period277'] = df['p_h'].shift(277)
df['p_Low_last_period277'] = df['p_l'].shift(277)
df['p_Close_last_period277'] = df['p_c'].shift(277)
#276 periods ago
df['p_Open_last_period276'] = df['p_o'].shift(276) 
df['p_High_last_period276'] = df['p_h'].shift(276)
df['p_Low_last_period276'] = df['p_l'].shift(276)
df['p_Close_last_period276'] = df['p_c'].shift(276)
#275 periods ago
df['p_Open_last_period275'] = df['p_o'].shift(275) 
df['p_High_last_period275'] = df['p_h'].shift(275)
df['p_Low_last_period275'] = df['p_l'].shift(275)
df['p_Close_last_period275'] = df['p_c'].shift(275)
#274 periods ago
df['p_Open_last_period274'] = df['p_o'].shift(274) 
df['p_High_last_period274'] = df['p_h'].shift(274)
df['p_Low_last_period274'] = df['p_l'].shift(274)
df['p_Close_last_period274'] = df['p_c'].shift(274)
#273 periods ago
df['p_Open_last_period273'] = df['p_o'].shift(273) 
df['p_High_last_period273'] = df['p_h'].shift(273)
df['p_Low_last_period273'] = df['p_l'].shift(273)
df['p_Close_last_period273'] = df['p_c'].shift(273)
#272 periods ago
df['p_Open_last_period272'] = df['p_o'].shift(272) 
df['p_High_last_period272'] = df['p_h'].shift(272)
df['p_Low_last_period272'] = df['p_l'].shift(272)
df['p_Close_last_period272'] = df['p_c'].shift(272)
#271 periods ago
df['p_Open_last_period271'] = df['p_o'].shift(271) 
df['p_High_last_period271'] = df['p_h'].shift(271)
df['p_Low_last_period271'] = df['p_l'].shift(271)
df['p_Close_last_period271'] = df['p_c'].shift(271)
#270 periods ago
df['p_Open_last_period270'] = df['p_o'].shift(270) 
df['p_High_last_period270'] = df['p_h'].shift(270)
df['p_Low_last_period270'] = df['p_l'].shift(270)
df['p_Close_last_period270'] = df['p_c'].shift(270)
#269 periods ago
df['p_Open_last_period269'] = df['p_o'].shift(269) 
df['p_High_last_period269'] = df['p_h'].shift(269)
df['p_Low_last_period269'] = df['p_l'].shift(269)
df['p_Close_last_period269'] = df['p_c'].shift(269)
#268 periods ago
df['p_Open_last_period268'] = df['p_o'].shift(268) 
df['p_High_last_period268'] = df['p_h'].shift(268)
df['p_Low_last_period268'] = df['p_l'].shift(268)
df['p_Close_last_period268'] = df['p_c'].shift(268)
#267 periods ago
df['p_Open_last_period267'] = df['p_o'].shift(267) 
df['p_High_last_period267'] = df['p_h'].shift(267)
df['p_Low_last_period267'] = df['p_l'].shift(267)
df['p_Close_last_period267'] = df['p_c'].shift(267)
#266 periods ago
df['p_Open_last_period266'] = df['p_o'].shift(266) 
df['p_High_last_period266'] = df['p_h'].shift(266)
df['p_Low_last_period266'] = df['p_l'].shift(266)
df['p_Close_last_period266'] = df['p_c'].shift(266)
#265 periods ago
df['p_Open_last_period265'] = df['p_o'].shift(265) 
df['p_High_last_period265'] = df['p_h'].shift(265)
df['p_Low_last_period265'] = df['p_l'].shift(265)
df['p_Close_last_period265'] = df['p_c'].shift(265)
#264 periods ago
df['p_Open_last_period264'] = df['p_o'].shift(264) 
df['p_High_last_period264'] = df['p_h'].shift(264)
df['p_Low_last_period264'] = df['p_l'].shift(264)
df['p_Close_last_period264'] = df['p_c'].shift(264)
#263 periods ago
df['p_Open_last_period263'] = df['p_o'].shift(263) 
df['p_High_last_period263'] = df['p_h'].shift(263)
df['p_Low_last_period263'] = df['p_l'].shift(263)
df['p_Close_last_period263'] = df['p_c'].shift(263)
#262 periods ago
df['p_Open_last_period262'] = df['p_o'].shift(262) 
df['p_High_last_period262'] = df['p_h'].shift(262)
df['p_Low_last_period262'] = df['p_l'].shift(262)
df['p_Close_last_period262'] = df['p_c'].shift(262)
#261 periods ago
df['p_Open_last_period261'] = df['p_o'].shift(261) 
df['p_High_last_period261'] = df['p_h'].shift(261)
df['p_Low_last_period261'] = df['p_l'].shift(261)
df['p_Close_last_period261'] = df['p_c'].shift(261)
#260 periods ago
df['p_Open_last_period260'] = df['p_o'].shift(260) 
df['p_High_last_period260'] = df['p_h'].shift(260)
df['p_Low_last_period260'] = df['p_l'].shift(260)
df['p_Close_last_period260'] = df['p_c'].shift(260)
#259 periods ago
df['p_Open_last_period259'] = df['p_o'].shift(259) 
df['p_High_last_period259'] = df['p_h'].shift(259)
df['p_Low_last_period259'] = df['p_l'].shift(259)
df['p_Close_last_period259'] = df['p_c'].shift(259)
#258 periods ago
df['p_Open_last_period258'] = df['p_o'].shift(258) 
df['p_High_last_period258'] = df['p_h'].shift(258)
df['p_Low_last_period258'] = df['p_l'].shift(258)
df['p_Close_last_period258'] = df['p_c'].shift(258)
#257 periods ago
df['p_Open_last_period257'] = df['p_o'].shift(257) 
df['p_High_last_period257'] = df['p_h'].shift(257)
df['p_Low_last_period257'] = df['p_l'].shift(257)
df['p_Close_last_period257'] = df['p_c'].shift(257)
#256 periods ago
df['p_Open_last_period256'] = df['p_o'].shift(256) 
df['p_High_last_period256'] = df['p_h'].shift(256)
df['p_Low_last_period256'] = df['p_l'].shift(256)
df['p_Close_last_period256'] = df['p_c'].shift(256)
#255 periods ago
df['p_Open_last_period255'] = df['p_o'].shift(255) 
df['p_High_last_period255'] = df['p_h'].shift(255)
df['p_Low_last_period255'] = df['p_l'].shift(255)
df['p_Close_last_period255'] = df['p_c'].shift(255)
#254 periods ago
df['p_Open_last_period254'] = df['p_o'].shift(254) 
df['p_High_last_period254'] = df['p_h'].shift(254)
df['p_Low_last_period254'] = df['p_l'].shift(254)
df['p_Close_last_period254'] = df['p_c'].shift(254)
#253 periods ago
df['p_Open_last_period253'] = df['p_o'].shift(253) 
df['p_High_last_period253'] = df['p_h'].shift(253)
df['p_Low_last_period253'] = df['p_l'].shift(253)
df['p_Close_last_period253'] = df['p_c'].shift(253)
#252 periods ago
df['p_Open_last_period252'] = df['p_o'].shift(252) 
df['p_High_last_period252'] = df['p_h'].shift(252)
df['p_Low_last_period252'] = df['p_l'].shift(252)
df['p_Close_last_period252'] = df['p_c'].shift(252)
#251 periods ago
df['p_Open_last_period251'] = df['p_o'].shift(251) 
df['p_High_last_period251'] = df['p_h'].shift(251)
df['p_Low_last_period251'] = df['p_l'].shift(251)
df['p_Close_last_period251'] = df['p_c'].shift(251)
#250 periods ago
df['p_Open_last_period250'] = df['p_o'].shift(250) 
df['p_High_last_period250'] = df['p_h'].shift(250)
df['p_Low_last_period250'] = df['p_l'].shift(250)
df['p_Close_last_period250'] = df['p_c'].shift(250)
#249 periods ago
df['p_Open_last_period249'] = df['p_o'].shift(249) 
df['p_High_last_period249'] = df['p_h'].shift(249)
df['p_Low_last_period249'] = df['p_l'].shift(249)
df['p_Close_last_period249'] = df['p_c'].shift(249)
#248 periods ago
df['p_Open_last_period248'] = df['p_o'].shift(248) 
df['p_High_last_period248'] = df['p_h'].shift(248)
df['p_Low_last_period248'] = df['p_l'].shift(248)
df['p_Close_last_period248'] = df['p_c'].shift(248)
#247 periods ago
df['p_Open_last_period247'] = df['p_o'].shift(247) 
df['p_High_last_period247'] = df['p_h'].shift(247)
df['p_Low_last_period247'] = df['p_l'].shift(247)
df['p_Close_last_period247'] = df['p_c'].shift(247)
#246 periods ago
df['p_Open_last_period246'] = df['p_o'].shift(246) 
df['p_High_last_period246'] = df['p_h'].shift(246)
df['p_Low_last_period246'] = df['p_l'].shift(246)
df['p_Close_last_period246'] = df['p_c'].shift(246)
#245 periods ago
df['p_Open_last_period245'] = df['p_o'].shift(245) 
df['p_High_last_period245'] = df['p_h'].shift(245)
df['p_Low_last_period245'] = df['p_l'].shift(245)
df['p_Close_last_period245'] = df['p_c'].shift(245)
#244 periods ago
df['p_Open_last_period244'] = df['p_o'].shift(244) 
df['p_High_last_period244'] = df['p_h'].shift(244)
df['p_Low_last_period244'] = df['p_l'].shift(244)
df['p_Close_last_period244'] = df['p_c'].shift(244)
#243 periods ago
df['p_Open_last_period243'] = df['p_o'].shift(243) 
df['p_High_last_period243'] = df['p_h'].shift(243)
df['p_Low_last_period243'] = df['p_l'].shift(243)
df['p_Close_last_period243'] = df['p_c'].shift(243)
#242 periods ago
df['p_Open_last_period242'] = df['p_o'].shift(242) 
df['p_High_last_period242'] = df['p_h'].shift(242)
df['p_Low_last_period242'] = df['p_l'].shift(242)
df['p_Close_last_period242'] = df['p_c'].shift(242)
#241 periods ago
df['p_Open_last_period241'] = df['p_o'].shift(241) 
df['p_High_last_period241'] = df['p_h'].shift(241)
df['p_Low_last_period241'] = df['p_l'].shift(241)
df['p_Close_last_period241'] = df['p_c'].shift(241)
#240 periods ago
df['p_Open_last_period240'] = df['p_o'].shift(240) 
df['p_High_last_period240'] = df['p_h'].shift(240)
df['p_Low_last_period240'] = df['p_l'].shift(240)
df['p_Close_last_period240'] = df['p_c'].shift(240)
#239 periods ago
df['p_Open_last_period239'] = df['p_o'].shift(239) 
df['p_High_last_period239'] = df['p_h'].shift(239)
df['p_Low_last_period239'] = df['p_l'].shift(239)
df['p_Close_last_period239'] = df['p_c'].shift(239)
#238 periods ago
df['p_Open_last_period238'] = df['p_o'].shift(238) 
df['p_High_last_period238'] = df['p_h'].shift(238)
df['p_Low_last_period238'] = df['p_l'].shift(238)
df['p_Close_last_period238'] = df['p_c'].shift(238)
#237 periods ago
df['p_Open_last_period237'] = df['p_o'].shift(237) 
df['p_High_last_period237'] = df['p_h'].shift(237)
df['p_Low_last_period237'] = df['p_l'].shift(237)
df['p_Close_last_period237'] = df['p_c'].shift(237)
#236 periods ago
df['p_Open_last_period236'] = df['p_o'].shift(236) 
df['p_High_last_period236'] = df['p_h'].shift(236)
df['p_Low_last_period236'] = df['p_l'].shift(236)
df['p_Close_last_period236'] = df['p_c'].shift(236)
#235 periods ago
df['p_Open_last_period235'] = df['p_o'].shift(235) 
df['p_High_last_period235'] = df['p_h'].shift(235)
df['p_Low_last_period235'] = df['p_l'].shift(235)
df['p_Close_last_period235'] = df['p_c'].shift(235)
#234 periods ago
df['p_Open_last_period234'] = df['p_o'].shift(234) 
df['p_High_last_period234'] = df['p_h'].shift(234)
df['p_Low_last_period234'] = df['p_l'].shift(234)
df['p_Close_last_period234'] = df['p_c'].shift(234)
#233 periods ago
df['p_Open_last_period233'] = df['p_o'].shift(233) 
df['p_High_last_period233'] = df['p_h'].shift(233)
df['p_Low_last_period233'] = df['p_l'].shift(233)
df['p_Close_last_period233'] = df['p_c'].shift(233)
#232 periods ago
df['p_Open_last_period232'] = df['p_o'].shift(232) 
df['p_High_last_period232'] = df['p_h'].shift(232)
df['p_Low_last_period232'] = df['p_l'].shift(232)
df['p_Close_last_period232'] = df['p_c'].shift(232)
#231 periods ago
df['p_Open_last_period231'] = df['p_o'].shift(231) 
df['p_High_last_period231'] = df['p_h'].shift(231)
df['p_Low_last_period231'] = df['p_l'].shift(231)
df['p_Close_last_period231'] = df['p_c'].shift(231)
#230 periods ago
df['p_Open_last_period230'] = df['p_o'].shift(230) 
df['p_High_last_period230'] = df['p_h'].shift(230)
df['p_Low_last_period230'] = df['p_l'].shift(230)
df['p_Close_last_period230'] = df['p_c'].shift(230)
#229 periods ago
df['p_Open_last_period229'] = df['p_o'].shift(229) 
df['p_High_last_period229'] = df['p_h'].shift(229)
df['p_Low_last_period229'] = df['p_l'].shift(229)
df['p_Close_last_period229'] = df['p_c'].shift(229)
#228 periods ago
df['p_Open_last_period228'] = df['p_o'].shift(228) 
df['p_High_last_period228'] = df['p_h'].shift(228)
df['p_Low_last_period228'] = df['p_l'].shift(228)
df['p_Close_last_period228'] = df['p_c'].shift(228)
#227 periods ago
df['p_Open_last_period227'] = df['p_o'].shift(227) 
df['p_High_last_period227'] = df['p_h'].shift(227)
df['p_Low_last_period227'] = df['p_l'].shift(227)
df['p_Close_last_period227'] = df['p_c'].shift(227)
#226 periods ago
df['p_Open_last_period226'] = df['p_o'].shift(226) 
df['p_High_last_period226'] = df['p_h'].shift(226)
df['p_Low_last_period226'] = df['p_l'].shift(226)
df['p_Close_last_period226'] = df['p_c'].shift(226)
#225 periods ago
df['p_Open_last_period225'] = df['p_o'].shift(225) 
df['p_High_last_period225'] = df['p_h'].shift(225)
df['p_Low_last_period225'] = df['p_l'].shift(225)
df['p_Close_last_period225'] = df['p_c'].shift(225)
#224 periods ago
df['p_Open_last_period224'] = df['p_o'].shift(224) 
df['p_High_last_period224'] = df['p_h'].shift(224)
df['p_Low_last_period224'] = df['p_l'].shift(224)
df['p_Close_last_period224'] = df['p_c'].shift(224)
#223 periods ago
df['p_Open_last_period223'] = df['p_o'].shift(223) 
df['p_High_last_period223'] = df['p_h'].shift(223)
df['p_Low_last_period223'] = df['p_l'].shift(223)
df['p_Close_last_period223'] = df['p_c'].shift(223)
#222 periods ago
df['p_Open_last_period222'] = df['p_o'].shift(222) 
df['p_High_last_period222'] = df['p_h'].shift(222)
df['p_Low_last_period222'] = df['p_l'].shift(222)
df['p_Close_last_period222'] = df['p_c'].shift(222)
#221 periods ago
df['p_Open_last_period221'] = df['p_o'].shift(221) 
df['p_High_last_period221'] = df['p_h'].shift(221)
df['p_Low_last_period221'] = df['p_l'].shift(221)
df['p_Close_last_period221'] = df['p_c'].shift(221)
#220 periods ago
df['p_Open_last_period220'] = df['p_o'].shift(220) 
df['p_High_last_period220'] = df['p_h'].shift(220)
df['p_Low_last_period220'] = df['p_l'].shift(220)
df['p_Close_last_period220'] = df['p_c'].shift(220)
#219 periods ago
df['p_Open_last_period219'] = df['p_o'].shift(219) 
df['p_High_last_period219'] = df['p_h'].shift(219)
df['p_Low_last_period219'] = df['p_l'].shift(219)
df['p_Close_last_period219'] = df['p_c'].shift(219)
#218 periods ago
df['p_Open_last_period218'] = df['p_o'].shift(218) 
df['p_High_last_period218'] = df['p_h'].shift(218)
df['p_Low_last_period218'] = df['p_l'].shift(218)
df['p_Close_last_period218'] = df['p_c'].shift(218)
#217 periods ago
df['p_Open_last_period217'] = df['p_o'].shift(217) 
df['p_High_last_period217'] = df['p_h'].shift(217)
df['p_Low_last_period217'] = df['p_l'].shift(217)
df['p_Close_last_period217'] = df['p_c'].shift(217)
#216 periods ago
df['p_Open_last_period216'] = df['p_o'].shift(216) 
df['p_High_last_period216'] = df['p_h'].shift(216)
df['p_Low_last_period216'] = df['p_l'].shift(216)
df['p_Close_last_period216'] = df['p_c'].shift(216)
#215 periods ago
df['p_Open_last_period215'] = df['p_o'].shift(215) 
df['p_High_last_period215'] = df['p_h'].shift(215)
df['p_Low_last_period215'] = df['p_l'].shift(215)
df['p_Close_last_period215'] = df['p_c'].shift(215)
#214 periods ago
df['p_Open_last_period214'] = df['p_o'].shift(214) 
df['p_High_last_period214'] = df['p_h'].shift(214)
df['p_Low_last_period214'] = df['p_l'].shift(214)
df['p_Close_last_period214'] = df['p_c'].shift(214)
#213 periods ago
df['p_Open_last_period213'] = df['p_o'].shift(213) 
df['p_High_last_period213'] = df['p_h'].shift(213)
df['p_Low_last_period213'] = df['p_l'].shift(213)
df['p_Close_last_period213'] = df['p_c'].shift(213)
#212 periods ago
df['p_Open_last_period212'] = df['p_o'].shift(212) 
df['p_High_last_period212'] = df['p_h'].shift(212)
df['p_Low_last_period212'] = df['p_l'].shift(212)
df['p_Close_last_period212'] = df['p_c'].shift(212)
#211 periods ago
df['p_Open_last_period211'] = df['p_o'].shift(211) 
df['p_High_last_period211'] = df['p_h'].shift(211)
df['p_Low_last_period211'] = df['p_l'].shift(211)
df['p_Close_last_period211'] = df['p_c'].shift(211)
#210 periods ago
df['p_Open_last_period210'] = df['p_o'].shift(210) 
df['p_High_last_period210'] = df['p_h'].shift(210)
df['p_Low_last_period210'] = df['p_l'].shift(210)
df['p_Close_last_period210'] = df['p_c'].shift(210)
#209 periods ago
df['p_Open_last_period209'] = df['p_o'].shift(209) 
df['p_High_last_period209'] = df['p_h'].shift(209)
df['p_Low_last_period209'] = df['p_l'].shift(209)
df['p_Close_last_period209'] = df['p_c'].shift(209)
#208 periods ago
df['p_Open_last_period208'] = df['p_o'].shift(208) 
df['p_High_last_period208'] = df['p_h'].shift(208)
df['p_Low_last_period208'] = df['p_l'].shift(208)
df['p_Close_last_period208'] = df['p_c'].shift(208)
#207 periods ago
df['p_Open_last_period207'] = df['p_o'].shift(207) 
df['p_High_last_period207'] = df['p_h'].shift(207)
df['p_Low_last_period207'] = df['p_l'].shift(207)
df['p_Close_last_period207'] = df['p_c'].shift(207)
#206 periods ago
df['p_Open_last_period206'] = df['p_o'].shift(206) 
df['p_High_last_period206'] = df['p_h'].shift(206)
df['p_Low_last_period206'] = df['p_l'].shift(206)
df['p_Close_last_period206'] = df['p_c'].shift(206)
#205 periods ago
df['p_Open_last_period205'] = df['p_o'].shift(205) 
df['p_High_last_period205'] = df['p_h'].shift(205)
df['p_Low_last_period205'] = df['p_l'].shift(205)
df['p_Close_last_period205'] = df['p_c'].shift(205)
#204 periods ago
df['p_Open_last_period204'] = df['p_o'].shift(204) 
df['p_High_last_period204'] = df['p_h'].shift(204)
df['p_Low_last_period204'] = df['p_l'].shift(204)
df['p_Close_last_period204'] = df['p_c'].shift(204)
#203 periods ago
df['p_Open_last_period203'] = df['p_o'].shift(203) 
df['p_High_last_period203'] = df['p_h'].shift(203)
df['p_Low_last_period203'] = df['p_l'].shift(203)
df['p_Close_last_period203'] = df['p_c'].shift(203)
#202 periods ago
df['p_Open_last_period202'] = df['p_o'].shift(202) 
df['p_High_last_period202'] = df['p_h'].shift(202)
df['p_Low_last_period202'] = df['p_l'].shift(202)
df['p_Close_last_period202'] = df['p_c'].shift(202)
#201 periods ago
df['p_Open_last_period201'] = df['p_o'].shift(201) 
df['p_High_last_period201'] = df['p_h'].shift(201)
df['p_Low_last_period201'] = df['p_l'].shift(201)
df['p_Close_last_period201'] = df['p_c'].shift(201)
#200 periods ago
df['p_Open_last_period200'] = df['p_o'].shift(200) 
df['p_High_last_period200'] = df['p_h'].shift(200)
df['p_Low_last_period200'] = df['p_l'].shift(200)
df['p_Close_last_period200'] = df['p_c'].shift(200)
#199 periods ago
df['p_Open_last_period199'] = df['p_o'].shift(199) 
df['p_High_last_period199'] = df['p_h'].shift(199)
df['p_Low_last_period199'] = df['p_l'].shift(199)
df['p_Close_last_period199'] = df['p_c'].shift(199)
#198 periods ago
df['p_Open_last_period198'] = df['p_o'].shift(198) 
df['p_High_last_period198'] = df['p_h'].shift(198)
df['p_Low_last_period198'] = df['p_l'].shift(198)
df['p_Close_last_period198'] = df['p_c'].shift(198)
#197 periods ago
df['p_Open_last_period197'] = df['p_o'].shift(197) 
df['p_High_last_period197'] = df['p_h'].shift(197)
df['p_Low_last_period197'] = df['p_l'].shift(197)
df['p_Close_last_period197'] = df['p_c'].shift(197)
#196 periods ago
df['p_Open_last_period196'] = df['p_o'].shift(196) 
df['p_High_last_period196'] = df['p_h'].shift(196)
df['p_Low_last_period196'] = df['p_l'].shift(196)
df['p_Close_last_period196'] = df['p_c'].shift(196)
#195 periods ago
df['p_Open_last_period195'] = df['p_o'].shift(195) 
df['p_High_last_period195'] = df['p_h'].shift(195)
df['p_Low_last_period195'] = df['p_l'].shift(195)
df['p_Close_last_period195'] = df['p_c'].shift(195)
#194 periods ago
df['p_Open_last_period194'] = df['p_o'].shift(194) 
df['p_High_last_period194'] = df['p_h'].shift(194)
df['p_Low_last_period194'] = df['p_l'].shift(194)
df['p_Close_last_period194'] = df['p_c'].shift(194)
#193 periods ago
df['p_Open_last_period193'] = df['p_o'].shift(193) 
df['p_High_last_period193'] = df['p_h'].shift(193)
df['p_Low_last_period193'] = df['p_l'].shift(193)
df['p_Close_last_period193'] = df['p_c'].shift(193)
#192 periods ago
df['p_Open_last_period192'] = df['p_o'].shift(192) 
df['p_High_last_period192'] = df['p_h'].shift(192)
df['p_Low_last_period192'] = df['p_l'].shift(192)
df['p_Close_last_period192'] = df['p_c'].shift(192)
#191 periods ago
df['p_Open_last_period191'] = df['p_o'].shift(191) 
df['p_High_last_period191'] = df['p_h'].shift(191)
df['p_Low_last_period191'] = df['p_l'].shift(191)
df['p_Close_last_period191'] = df['p_c'].shift(191)
#190 periods ago
df['p_Open_last_period190'] = df['p_o'].shift(190) 
df['p_High_last_period190'] = df['p_h'].shift(190)
df['p_Low_last_period190'] = df['p_l'].shift(190)
df['p_Close_last_period190'] = df['p_c'].shift(190)
#189 periods ago
df['p_Open_last_period189'] = df['p_o'].shift(189) 
df['p_High_last_period189'] = df['p_h'].shift(189)
df['p_Low_last_period189'] = df['p_l'].shift(189)
df['p_Close_last_period189'] = df['p_c'].shift(189)
#188 periods ago
df['p_Open_last_period188'] = df['p_o'].shift(188) 
df['p_High_last_period188'] = df['p_h'].shift(188)
df['p_Low_last_period188'] = df['p_l'].shift(188)
df['p_Close_last_period188'] = df['p_c'].shift(188)
#187 periods ago
df['p_Open_last_period187'] = df['p_o'].shift(187) 
df['p_High_last_period187'] = df['p_h'].shift(187)
df['p_Low_last_period187'] = df['p_l'].shift(187)
df['p_Close_last_period187'] = df['p_c'].shift(187)
#186 periods ago
df['p_Open_last_period186'] = df['p_o'].shift(186) 
df['p_High_last_period186'] = df['p_h'].shift(186)
df['p_Low_last_period186'] = df['p_l'].shift(186)
df['p_Close_last_period186'] = df['p_c'].shift(186)
#185 periods ago
df['p_Open_last_period185'] = df['p_o'].shift(185) 
df['p_High_last_period185'] = df['p_h'].shift(185)
df['p_Low_last_period185'] = df['p_l'].shift(185)
df['p_Close_last_period185'] = df['p_c'].shift(185)
#184 periods ago
df['p_Open_last_period184'] = df['p_o'].shift(184) 
df['p_High_last_period184'] = df['p_h'].shift(184)
df['p_Low_last_period184'] = df['p_l'].shift(184)
df['p_Close_last_period184'] = df['p_c'].shift(184)
#183 periods ago
df['p_Open_last_period183'] = df['p_o'].shift(183) 
df['p_High_last_period183'] = df['p_h'].shift(183)
df['p_Low_last_period183'] = df['p_l'].shift(183)
df['p_Close_last_period183'] = df['p_c'].shift(183)
#182 periods ago
df['p_Open_last_period182'] = df['p_o'].shift(182) 
df['p_High_last_period182'] = df['p_h'].shift(182)
df['p_Low_last_period182'] = df['p_l'].shift(182)
df['p_Close_last_period182'] = df['p_c'].shift(182)
#181 periods ago
df['p_Open_last_period181'] = df['p_o'].shift(181) 
df['p_High_last_period181'] = df['p_h'].shift(181)
df['p_Low_last_period181'] = df['p_l'].shift(181)
df['p_Close_last_period181'] = df['p_c'].shift(181)
#180 periods ago
df['p_Open_last_period180'] = df['p_o'].shift(180) 
df['p_High_last_period180'] = df['p_h'].shift(180)
df['p_Low_last_period180'] = df['p_l'].shift(180)
df['p_Close_last_period180'] = df['p_c'].shift(180)
#179 periods ago
df['p_Open_last_period179'] = df['p_o'].shift(179) 
df['p_High_last_period179'] = df['p_h'].shift(179)
df['p_Low_last_period179'] = df['p_l'].shift(179)
df['p_Close_last_period179'] = df['p_c'].shift(179)
#178 periods ago
df['p_Open_last_period178'] = df['p_o'].shift(178) 
df['p_High_last_period178'] = df['p_h'].shift(178)
df['p_Low_last_period178'] = df['p_l'].shift(178)
df['p_Close_last_period178'] = df['p_c'].shift(178)
#177 periods ago
df['p_Open_last_period177'] = df['p_o'].shift(177) 
df['p_High_last_period177'] = df['p_h'].shift(177)
df['p_Low_last_period177'] = df['p_l'].shift(177)
df['p_Close_last_period177'] = df['p_c'].shift(177)
#176 periods ago
df['p_Open_last_period176'] = df['p_o'].shift(176) 
df['p_High_last_period176'] = df['p_h'].shift(176)
df['p_Low_last_period176'] = df['p_l'].shift(176)
df['p_Close_last_period176'] = df['p_c'].shift(176)
#194 periods ago
df['p_Open_last_period175'] = df['p_o'].shift(175) 
df['p_High_last_period175'] = df['p_h'].shift(175)
df['p_Low_last_period175'] = df['p_l'].shift(175)
df['p_Close_last_period175'] = df['p_c'].shift(175)
#174 periods ago
df['p_Open_last_period174'] = df['p_o'].shift(174) 
df['p_High_last_period174'] = df['p_h'].shift(174)
df['p_Low_last_period174'] = df['p_l'].shift(174)
df['p_Close_last_period174'] = df['p_c'].shift(174)
#173 periods ago
df['p_Open_last_period173'] = df['p_o'].shift(173) 
df['p_High_last_period173'] = df['p_h'].shift(173)
df['p_Low_last_period173'] = df['p_l'].shift(173)
df['p_Close_last_period173'] = df['p_c'].shift(173)
#172 periods ago
df['p_Open_last_period172'] = df['p_o'].shift(172) 
df['p_High_last_period172'] = df['p_h'].shift(172)
df['p_Low_last_period172'] = df['p_l'].shift(172)
df['p_Close_last_period172'] = df['p_c'].shift(172)
#171 periods ago
df['p_Open_last_period171'] = df['p_o'].shift(171) 
df['p_High_last_period171'] = df['p_h'].shift(171)
df['p_Low_last_period171'] = df['p_l'].shift(171)
df['p_Close_last_period171'] = df['p_c'].shift(171)
#170 periods ago
df['p_Open_last_period170'] = df['p_o'].shift(170) 
df['p_High_last_period170'] = df['p_h'].shift(170)
df['p_Low_last_period170'] = df['p_l'].shift(170)
df['p_Close_last_period170'] = df['p_c'].shift(170)
#169 periods ago
df['p_Open_last_period169'] = df['p_o'].shift(169) 
df['p_High_last_period169'] = df['p_h'].shift(169)
df['p_Low_last_period169'] = df['p_l'].shift(169)
df['p_Close_last_period169'] = df['p_c'].shift(169)
#168 periods ago
df['p_Open_last_period168'] = df['p_o'].shift(168) 
df['p_High_last_period168'] = df['p_h'].shift(168)
df['p_Low_last_period168'] = df['p_l'].shift(168)
df['p_Close_last_period168'] = df['p_c'].shift(168)
#167 periods ago
df['p_Open_last_period167'] = df['p_o'].shift(167) 
df['p_High_last_period167'] = df['p_h'].shift(167)
df['p_Low_last_period167'] = df['p_l'].shift(167)
df['p_Close_last_period167'] = df['p_c'].shift(167)
#166 periods ago
df['p_Open_last_period166'] = df['p_o'].shift(166) 
df['p_High_last_period166'] = df['p_h'].shift(166)
df['p_Low_last_period166'] = df['p_l'].shift(166)
df['p_Close_last_period166'] = df['p_c'].shift(166)
#165 periods ago
df['p_Open_last_period165'] = df['p_o'].shift(165) 
df['p_High_last_period165'] = df['p_h'].shift(165)
df['p_Low_last_period165'] = df['p_l'].shift(165)
df['p_Close_last_period165'] = df['p_c'].shift(165)
#164 periods ago
df['p_Open_last_period164'] = df['p_o'].shift(164) 
df['p_High_last_period164'] = df['p_h'].shift(164)
df['p_Low_last_period164'] = df['p_l'].shift(164)
df['p_Close_last_period164'] = df['p_c'].shift(164)
#163 periods ago
df['p_Open_last_period163'] = df['p_o'].shift(163) 
df['p_High_last_period163'] = df['p_h'].shift(163)
df['p_Low_last_period163'] = df['p_l'].shift(163)
df['p_Close_last_period163'] = df['p_c'].shift(163)
#162 periods ago
df['p_Open_last_period162'] = df['p_o'].shift(162) 
df['p_High_last_period162'] = df['p_h'].shift(162)
df['p_Low_last_period162'] = df['p_l'].shift(162)
df['p_Close_last_period162'] = df['p_c'].shift(162)
#161 periods ago
df['p_Open_last_period161'] = df['p_o'].shift(161) 
df['p_High_last_period161'] = df['p_h'].shift(161)
df['p_Low_last_period161'] = df['p_l'].shift(161)
df['p_Close_last_period161'] = df['p_c'].shift(161)
#160 periods ago
df['p_Open_last_period160'] = df['p_o'].shift(160) 
df['p_High_last_period160'] = df['p_h'].shift(160)
df['p_Low_last_period160'] = df['p_l'].shift(160)
df['p_Close_last_period160'] = df['p_c'].shift(160)
#59 periods ago
df['p_Open_last_period159'] = df['p_o'].shift(159) 
df['p_High_last_period159'] = df['p_h'].shift(159)
df['p_Low_last_period159'] = df['p_l'].shift(159)
df['p_Close_last_period159'] = df['p_c'].shift(159)
#158 periods ago
df['p_Open_last_period158'] = df['p_o'].shift(158) 
df['p_High_last_period158'] = df['p_h'].shift(158)
df['p_Low_last_period158'] = df['p_l'].shift(158)
df['p_Close_last_period158'] = df['p_c'].shift(158)
#157 periods ago
df['p_Open_last_period157'] = df['p_o'].shift(157) 
df['p_High_last_period157'] = df['p_h'].shift(157)
df['p_Low_last_period157'] = df['p_l'].shift(157)
df['p_Close_last_period157'] = df['p_c'].shift(157)
#156 periods ago
df['p_Open_last_period156'] = df['p_o'].shift(156) 
df['p_High_last_period156'] = df['p_h'].shift(156)
df['p_Low_last_period156'] = df['p_l'].shift(156)
df['p_Close_last_period156'] = df['p_c'].shift(156)
#155 periods ago
df['p_Open_last_period155'] = df['p_o'].shift(155) 
df['p_High_last_period155'] = df['p_h'].shift(155)
df['p_Low_last_period155'] = df['p_l'].shift(155)
df['p_Close_last_period155'] = df['p_c'].shift(155)
#154 periods ago
df['p_Open_last_period154'] = df['p_o'].shift(154) 
df['p_High_last_period154'] = df['p_h'].shift(154)
df['p_Low_last_period154'] = df['p_l'].shift(154)
df['p_Close_last_period154'] = df['p_c'].shift(154)
#153 periods ago
df['p_Open_last_period153'] = df['p_o'].shift(153) 
df['p_High_last_period153'] = df['p_h'].shift(153)
df['p_Low_last_period153'] = df['p_l'].shift(153)
df['p_Close_last_period153'] = df['p_c'].shift(153)
#152 periods ago
df['p_Open_last_period152'] = df['p_o'].shift(152) 
df['p_High_last_period152'] = df['p_h'].shift(152)
df['p_Low_last_period152'] = df['p_l'].shift(152)
df['p_Close_last_period152'] = df['p_c'].shift(152)
#151 periods ago
df['p_Open_last_period151'] = df['p_o'].shift(151) 
df['p_High_last_period151'] = df['p_h'].shift(151)
df['p_Low_last_period151'] = df['p_l'].shift(151)
df['p_Close_last_period151'] = df['p_c'].shift(151)
#150 periods ago
df['p_Open_last_period150'] = df['p_o'].shift(150) 
df['p_High_last_period150'] = df['p_h'].shift(150)
df['p_Low_last_period150'] = df['p_l'].shift(150)
df['p_Close_last_period150'] = df['p_c'].shift(150)
#149 periods ago
df['p_Open_last_period149'] = df['p_o'].shift(149) 
df['p_High_last_period149'] = df['p_h'].shift(149)
df['p_Low_last_period149'] = df['p_l'].shift(149)
df['p_Close_last_period149'] = df['p_c'].shift(149)
#148 periods ago
df['p_Open_last_period148'] = df['p_o'].shift(148) 
df['p_High_last_period148'] = df['p_h'].shift(148)
df['p_Low_last_period148'] = df['p_l'].shift(148)
df['p_Close_last_period148'] = df['p_c'].shift(148)
#147 periods ago
df['p_Open_last_period147'] = df['p_o'].shift(147) 
df['p_High_last_period147'] = df['p_h'].shift(147)
df['p_Low_last_period147'] = df['p_l'].shift(147)
df['p_Close_last_period147'] = df['p_c'].shift(147)
#146 periods ago
df['p_Open_last_period146'] = df['p_o'].shift(146) 
df['p_High_last_period146'] = df['p_h'].shift(146)
df['p_Low_last_period146'] = df['p_l'].shift(146)
df['p_Close_last_period146'] = df['p_c'].shift(146)
#145 periods ago
df['p_Open_last_period145'] = df['p_o'].shift(145) 
df['p_High_last_period145'] = df['p_h'].shift(145)
df['p_Low_last_period145'] = df['p_l'].shift(145)
df['p_Close_last_period145'] = df['p_c'].shift(145)
#144 periods ago
df['p_Open_last_period144'] = df['p_o'].shift(144) 
df['p_High_last_period144'] = df['p_h'].shift(144)
df['p_Low_last_period144'] = df['p_l'].shift(144)
df['p_Close_last_period144'] = df['p_c'].shift(144)
#143 periods ago
df['p_Open_last_period143'] = df['p_o'].shift(143) 
df['p_High_last_period143'] = df['p_h'].shift(143)
df['p_Low_last_period143'] = df['p_l'].shift(143)
df['p_Close_last_period143'] = df['p_c'].shift(143)
#142 periods ago
df['p_Open_last_period142'] = df['p_o'].shift(142) 
df['p_High_last_period142'] = df['p_h'].shift(142)
df['p_Low_last_period142'] = df['p_l'].shift(142)
df['p_Close_last_period142'] = df['p_c'].shift(142)
#141 periods ago
df['p_Open_last_period141'] = df['p_o'].shift(141) 
df['p_High_last_period141'] = df['p_h'].shift(141)
df['p_Low_last_period141'] = df['p_l'].shift(141)
df['p_Close_last_period141'] = df['p_c'].shift(141)
#140 periods ago
df['p_Open_last_period140'] = df['p_o'].shift(140) 
df['p_High_last_period140'] = df['p_h'].shift(140)
df['p_Low_last_period140'] = df['p_l'].shift(140)
df['p_Close_last_period140'] = df['p_c'].shift(140)
#139 periods ago
df['p_Open_last_period139'] = df['p_o'].shift(139) 
df['p_High_last_period139'] = df['p_h'].shift(139)
df['p_Low_last_period139'] = df['p_l'].shift(139)
df['p_Close_last_period139'] = df['p_c'].shift(139)
#138 periods ago
df['p_Open_last_period138'] = df['p_o'].shift(138) 
df['p_High_last_period138'] = df['p_h'].shift(138)
df['p_Low_last_period138'] = df['p_l'].shift(138)
df['p_Close_last_period138'] = df['p_c'].shift(138)
#137 periods ago
df['p_Open_last_period137'] = df['p_o'].shift(137) 
df['p_High_last_period137'] = df['p_h'].shift(137)
df['p_Low_last_period137'] = df['p_l'].shift(137)
df['p_Close_last_period137'] = df['p_c'].shift(137)
#136 periods ago
df['p_Open_last_period136'] = df['p_o'].shift(136) 
df['p_High_last_period136'] = df['p_h'].shift(136)
df['p_Low_last_period136'] = df['p_l'].shift(136)
df['p_Close_last_period136'] = df['p_c'].shift(136)
#135 periods ago
df['p_Open_last_period135'] = df['p_o'].shift(135) 
df['p_High_last_period135'] = df['p_h'].shift(135)
df['p_Low_last_period135'] = df['p_l'].shift(135)
df['p_Close_last_period135'] = df['p_c'].shift(135)
#134 periods ago
df['p_Open_last_period134'] = df['p_o'].shift(134) 
df['p_High_last_period134'] = df['p_h'].shift(134)
df['p_Low_last_period134'] = df['p_l'].shift(134)
df['p_Close_last_period134'] = df['p_c'].shift(134)
#133 periods ago
df['p_Open_last_period133'] = df['p_o'].shift(133) 
df['p_High_last_period133'] = df['p_h'].shift(133)
df['p_Low_last_period133'] = df['p_l'].shift(133)
df['p_Close_last_period133'] = df['p_c'].shift(133)
#132 periods ago
df['p_Open_last_period132'] = df['p_o'].shift(132) 
df['p_High_last_period132'] = df['p_h'].shift(132)
df['p_Low_last_period132'] = df['p_l'].shift(132)
df['p_Close_last_period132'] = df['p_c'].shift(132)
#131 periods ago
df['p_Open_last_period131'] = df['p_o'].shift(131) 
df['p_High_last_period131'] = df['p_h'].shift(131)
df['p_Low_last_period131'] = df['p_l'].shift(131)
df['p_Close_last_period131'] = df['p_c'].shift(131)
#130 periods ago
df['p_Open_last_period130'] = df['p_o'].shift(130) 
df['p_High_last_period130'] = df['p_h'].shift(130)
df['p_Low_last_period130'] = df['p_l'].shift(130)
df['p_Close_last_period130'] = df['p_c'].shift(130)
#129 periods ago
df['p_Open_last_period129'] = df['p_o'].shift(129) 
df['p_High_last_period129'] = df['p_h'].shift(129)
df['p_Low_last_period129'] = df['p_l'].shift(129)
df['p_Close_last_period129'] = df['p_c'].shift(129)
#128 periods ago
df['p_Open_last_period128'] = df['p_o'].shift(128) 
df['p_High_last_period128'] = df['p_h'].shift(128)
df['p_Low_last_period128'] = df['p_l'].shift(128)
df['p_Close_last_period128'] = df['p_c'].shift(128)
#127 periods ago
df['p_Open_last_period127'] = df['p_o'].shift(127) 
df['p_High_last_period127'] = df['p_h'].shift(127)
df['p_Low_last_period127'] = df['p_l'].shift(127)
df['p_Close_last_period127'] = df['p_c'].shift(127)
#126 periods ago
df['p_Open_last_period126'] = df['p_o'].shift(126) 
df['p_High_last_period126'] = df['p_h'].shift(126)
df['p_Low_last_period126'] = df['p_l'].shift(126)
df['p_Close_last_period126'] = df['p_c'].shift(126)
#125 periods ago
df['p_Open_last_period125'] = df['p_o'].shift(125) 
df['p_High_last_period125'] = df['p_h'].shift(125)
df['p_Low_last_period125'] = df['p_l'].shift(125)
df['p_Close_last_period125'] = df['p_c'].shift(125)
#124 periods ago
df['p_Open_last_period124'] = df['p_o'].shift(124) 
df['p_High_last_period124'] = df['p_h'].shift(124)
df['p_Low_last_period124'] = df['p_l'].shift(124)
df['p_Close_last_period124'] = df['p_c'].shift(124)
#123 periods ago
df['p_Open_last_period123'] = df['p_o'].shift(123) 
df['p_High_last_period123'] = df['p_h'].shift(123)
df['p_Low_last_period123'] = df['p_l'].shift(123)
df['p_Close_last_period123'] = df['p_c'].shift(123)
#122 periods ago
df['p_Open_last_period122'] = df['p_o'].shift(122) 
df['p_High_last_period122'] = df['p_h'].shift(122)
df['p_Low_last_period122'] = df['p_l'].shift(122)
df['p_Close_last_period122'] = df['p_c'].shift(122)
#121 periods ago
df['p_Open_last_period121'] = df['p_o'].shift(121) 
df['p_High_last_period121'] = df['p_h'].shift(21)
df['p_Low_last_period121'] = df['p_l'].shift(121)
df['p_Close_last_period121'] = df['p_c'].shift(121)
#120 periods ago
df['p_Open_last_period120'] = df['p_o'].shift(120) 
df['p_High_last_period120'] = df['p_h'].shift(120)
df['p_Low_last_period120'] = df['p_l'].shift(120)
df['p_Close_last_period120'] = df['p_c'].shift(120)
#119 periods ago
df['p_Open_last_period119'] = df['p_o'].shift(119) 
df['p_High_last_period119'] = df['p_h'].shift(119)
df['p_Low_last_period119'] = df['p_l'].shift(119)
df['p_Close_last_period119'] = df['p_c'].shift(119)
#118 periods ago
df['p_Open_last_period118'] = df['p_o'].shift(118) 
df['p_High_last_period118'] = df['p_h'].shift(118)
df['p_Low_last_period118'] = df['p_l'].shift(118)
df['p_Close_last_period118'] = df['p_c'].shift(118)
#117 periods ago
df['p_Open_last_period117'] = df['p_o'].shift(117) 
df['p_High_last_period117'] = df['p_h'].shift(117)
df['p_Low_last_period117'] = df['p_l'].shift(117)
df['p_Close_last_period117'] = df['p_c'].shift(117)
#116 periods ago
df['p_Open_last_period116'] = df['p_o'].shift(116) 
df['p_High_last_period116'] = df['p_h'].shift(116)
df['p_Low_last_period116'] = df['p_l'].shift(116)
df['p_Close_last_period116'] = df['p_c'].shift(116)
#115 periods ago
df['p_Open_last_period115'] = df['p_o'].shift(115) 
df['p_High_last_period115'] = df['p_h'].shift(115)
df['p_Low_last_period115'] = df['p_l'].shift(115)
df['p_Close_last_period115'] = df['p_c'].shift(115)
#114 periods ago
df['p_Open_last_period114'] = df['p_o'].shift(114) 
df['p_High_last_period114'] = df['p_h'].shift(114)
df['p_Low_last_period1014'] = df['p_l'].shift(114)
df['p_Close_last_period114'] = df['p_c'].shift(114)
#113 periods ago
df['p_Open_last_period113'] = df['p_o'].shift(113) 
df['p_High_last_period113'] = df['p_h'].shift(113)
df['p_Low_last_period113'] = df['p_l'].shift(113)
df['p_Close_last_period113'] = df['p_c'].shift(113)
#112 periods ago
df['p_Open_last_period112'] = df['p_o'].shift(112) 
df['p_High_last_period112'] = df['p_h'].shift(112)
df['p_Low_last_period112'] = df['p_l'].shift(112)
df['p_Close_last_period112'] = df['p_c'].shift(112)
#111 periods ago
df['p_Open_last_period111'] = df['p_o'].shift(111) 
df['p_High_last_period111'] = df['p_h'].shift(111)
df['p_Low_last_period111'] = df['p_l'].shift(111)
df['p_Close_last_period111'] = df['p_c'].shift(111)
#110 periods ago
df['p_Open_last_period110'] = df['p_o'].shift(110) 
df['p_High_last_period110'] = df['p_h'].shift(110)
df['p_Low_last_period110'] = df['p_l'].shift(110)
df['p_Close_last_period110'] = df['p_c'].shift(110)
#109 periods ago
df['p_Open_last_period109'] = df['p_o'].shift(109) 
df['p_High_last_period109'] = df['p_h'].shift(109)
df['p_Low_last_period109'] = df['p_l'].shift(109)
df['p_Close_last_period109'] = df['p_c'].shift(109)
#108 periods ago
df['p_Open_last_period108'] = df['p_o'].shift(108) 
df['p_High_last_period108'] = df['p_h'].shift(108)
df['p_Low_last_period108'] = df['p_l'].shift(108)
df['p_Close_last_period108'] = df['p_c'].shift(108)
#107 periods ago
df['p_Open_last_period107'] = df['p_o'].shift(107) 
df['p_High_last_period107'] = df['p_h'].shift(107)
df['p_Low_last_period107'] = df['p_l'].shift(107)
df['p_Close_last_period107'] = df['p_c'].shift(107)
#106 periods ago
df['p_Open_last_period106'] = df['p_o'].shift(106) 
df['p_High_last_period106'] = df['p_h'].shift(106)
df['p_Low_last_period106'] = df['p_l'].shift(106)
df['p_Close_last_period106'] = df['p_c'].shift(106)
#105 periods ago
df['p_Open_last_period105'] = df['p_o'].shift(105) 
df['p_High_last_period105'] = df['p_h'].shift(105)
df['p_Low_last_period105'] = df['p_l'].shift(105)
df['p_Close_last_period105'] = df['p_c'].shift(105)
#104 periods ago
df['p_Open_last_period104'] = df['p_o'].shift(104) 
df['p_High_last_period104'] = df['p_h'].shift(104)
df['p_Low_last_period104'] = df['p_l'].shift(104)
df['p_Close_last_period104'] = df['p_c'].shift(104)
#103 periods ago
df['p_Open_last_period103'] = df['p_o'].shift(103) 
df['p_High_last_period103'] = df['p_h'].shift(103)
df['p_Low_last_period103'] = df['p_l'].shift(103)
df['p_Close_last_period103'] = df['p_c'].shift(103)
#102 periods ago
df['p_Open_last_period102'] = df['p_o'].shift(102) 
df['p_High_last_period102'] = df['p_h'].shift(102)
df['p_Low_last_period102'] = df['p_l'].shift(102)
df['p_Close_last_period102'] = df['p_c'].shift(102)
#101 periods ago
df['p_Open_last_period101'] = df['p_o'].shift(101) 
df['p_High_last_period101'] = df['p_h'].shift(101)
df['p_Low_last_period101'] = df['p_l'].shift(101)
df['p_Close_last_period101'] = df['p_c'].shift(101)
#100 periods ago
df['p_Open_last_period100'] = df['p_o'].shift(100) 
df['p_High_last_period100'] = df['p_h'].shift(100)
df['p_Low_last_period100'] = df['p_l'].shift(100)
df['p_Close_last_period100'] = df['p_c'].shift(100)
#99 periods ago
df['p_Open_last_period99'] = df['p_o'].shift(99) 
df['p_High_last_period99'] = df['p_h'].shift(99)
df['p_Low_last_period99'] = df['p_l'].shift(99)
df['p_Close_last_period99'] = df['p_c'].shift(99)
#98 periods ago
df['p_Open_last_period98'] = df['p_o'].shift(98) 
df['p_High_last_period98'] = df['p_h'].shift(98)
df['p_Low_last_period98'] = df['p_l'].shift(98)
df['p_Close_last_period98'] = df['p_c'].shift(98)
#97 periods ago
df['p_Open_last_period97'] = df['p_o'].shift(97) 
df['p_High_last_period97'] = df['p_h'].shift(97)
df['p_Low_last_period97'] = df['p_l'].shift(97)
df['p_Close_last_period97'] = df['p_c'].shift(97)
#96 periods ago
df['p_Open_last_period96'] = df['p_o'].shift(96) 
df['p_High_last_period96'] = df['p_h'].shift(96)
df['p_Low_last_period96'] = df['p_l'].shift(96)
df['p_Close_last_period96'] = df['p_c'].shift(96)
#95 periods ago
df['p_Open_last_period95'] = df['p_o'].shift(95) 
df['p_High_last_period95'] = df['p_h'].shift(95)
df['p_Low_last_period95'] = df['p_l'].shift(95)
df['p_Close_last_period95'] = df['p_c'].shift(95)
#94 periods ago
df['p_Open_last_period94'] = df['p_o'].shift(94) 
df['p_High_last_period94'] = df['p_h'].shift(94)
df['p_Low_last_period94'] = df['p_l'].shift(94)
df['p_Close_last_period94'] = df['p_c'].shift(94)
#93 periods ago
df['p_Open_last_period93'] = df['p_o'].shift(93) 
df['p_High_last_period93'] = df['p_h'].shift(93)
df['p_Low_last_period93'] = df['p_l'].shift(93)
df['p_Close_last_period93'] = df['p_c'].shift(93)
#92 periods ago
df['p_Open_last_period92'] = df['p_o'].shift(92) 
df['p_High_last_period92'] = df['p_h'].shift(92)
df['p_Low_last_period92'] = df['p_l'].shift(92)
df['p_Close_last_period92'] = df['p_c'].shift(92)
#91 periods ago
df['p_Open_last_period91'] = df['p_o'].shift(91) 
df['p_High_last_period91'] = df['p_h'].shift(91)
df['p_Low_last_period91'] = df['p_l'].shift(91)
df['p_Close_last_period91'] = df['p_c'].shift(91)
#90 periods ago
df['p_Open_last_period90'] = df['p_o'].shift(90) 
df['p_High_last_period90'] = df['p_h'].shift(90)
df['p_Low_last_period90'] = df['p_l'].shift(90)
df['p_Close_last_period90'] = df['p_c'].shift(90)
#89 periods ago
df['p_Open_last_period89'] = df['p_o'].shift(89) 
df['p_High_last_period89'] = df['p_h'].shift(89)
df['p_Low_last_period89'] = df['p_l'].shift(89)
df['p_Close_last_period89'] = df['p_c'].shift(89)
#88 periods ago
df['p_Open_last_period88'] = df['p_o'].shift(88) 
df['p_High_last_period88'] = df['p_h'].shift(88)
df['p_Low_last_period88'] = df['p_l'].shift(88)
df['p_Close_last_period88'] = df['p_c'].shift(88)
#87 periods ago
df['p_Open_last_period87'] = df['p_o'].shift(87) 
df['p_High_last_period87'] = df['p_h'].shift(87)
df['p_Low_last_period87'] = df['p_l'].shift(87)
df['p_Close_last_period87'] = df['p_c'].shift(87)
#86 periods ago
df['p_Open_last_period86'] = df['p_o'].shift(86) 
df['p_High_last_period86'] = df['p_h'].shift(86)
df['p_Low_last_period86'] = df['p_l'].shift(86)
df['p_Close_last_period86'] = df['p_c'].shift(86)
#85 periods ago
df['p_Open_last_period85'] = df['p_o'].shift(85) 
df['p_High_last_period85'] = df['p_h'].shift(85)
df['p_Low_last_period85'] = df['p_l'].shift(85)
df['p_Close_last_period85'] = df['p_c'].shift(85)
#84 periods ago
df['p_Open_last_period84'] = df['p_o'].shift(84) 
df['p_High_last_period84'] = df['p_h'].shift(84)
df['p_Low_last_period84'] = df['p_l'].shift(84)
df['p_Close_last_period84'] = df['p_c'].shift(84)
#83 periods ago
df['p_Open_last_period83'] = df['p_o'].shift(83) 
df['p_High_last_period83'] = df['p_h'].shift(83)
df['p_Low_last_period83'] = df['p_l'].shift(83)
df['p_Close_last_period83'] = df['p_c'].shift(83)
#82 periods ago
df['p_Open_last_period82'] = df['p_o'].shift(82) 
df['p_High_last_period82'] = df['p_h'].shift(82)
df['p_Low_last_period82'] = df['p_l'].shift(82)
df['p_Close_last_period82'] = df['p_c'].shift(82)
#81 periods ago
df['p_Open_last_period81'] = df['p_o'].shift(81) 
df['p_High_last_period81'] = df['p_h'].shift(81)
df['p_Low_last_period81'] = df['p_l'].shift(81)
df['p_Close_last_period81'] = df['p_c'].shift(81)
#80 periods ago
df['p_Open_last_period80'] = df['p_o'].shift(80) 
df['p_High_last_period80'] = df['p_h'].shift(80)
df['p_Low_last_period80'] = df['p_l'].shift(80)
df['p_Close_last_period80'] = df['p_c'].shift(80)
#79 periods ago
df['p_Open_last_period79'] = df['p_o'].shift(79) 
df['p_High_last_period79'] = df['p_h'].shift(79)
df['p_Low_last_period79'] = df['p_l'].shift(79)
df['p_Close_last_period79'] = df['p_c'].shift(79)
#78 periods ago
df['p_Open_last_period78'] = df['p_o'].shift(78) 
df['p_High_last_period78'] = df['p_h'].shift(78)
df['p_Low_last_period78'] = df['p_l'].shift(78)
df['p_Close_last_period78'] = df['p_c'].shift(78)
#77 periods ago
df['p_Open_last_period77'] = df['p_o'].shift(77) 
df['p_High_last_period77'] = df['p_h'].shift(77)
df['p_Low_last_period77'] = df['p_l'].shift(77)
df['p_Close_last_period77'] = df['p_c'].shift(77)
#76 periods ago
df['p_Open_last_period76'] = df['p_o'].shift(76) 
df['p_High_last_period76'] = df['p_h'].shift(76)
df['p_Low_last_period76'] = df['p_l'].shift(76)
df['p_Close_last_period76'] = df['p_c'].shift(76)
#75 periods ago
df['p_Open_last_period75'] = df['p_o'].shift(75) 
df['p_High_last_period75'] = df['p_h'].shift(75)
df['p_Low_last_period75'] = df['p_l'].shift(75)
df['p_Close_last_period75'] = df['p_c'].shift(75)
#74 periods ago
df['p_Open_last_period74'] = df['p_o'].shift(74) 
df['p_High_last_period74'] = df['p_h'].shift(74)
df['p_Low_last_period74'] = df['p_l'].shift(74)
df['p_Close_last_period74'] = df['p_c'].shift(74)
#73 periods ago
df['p_Open_last_period73'] = df['p_o'].shift(73) 
df['p_High_last_period73'] = df['p_h'].shift(73)
df['p_Low_last_period73'] = df['p_l'].shift(73)
df['p_Close_last_period73'] = df['p_c'].shift(73)
#72 periods ago
df['p_Open_last_period72'] = df['p_o'].shift(72) 
df['p_High_last_period72'] = df['p_h'].shift(72)
df['p_Low_last_period72'] = df['p_l'].shift(72)
df['p_Close_last_period72'] = df['p_c'].shift(72)
#71 periods ago
df['p_Open_last_period71'] = df['p_o'].shift(71) 
df['p_High_last_period71'] = df['p_h'].shift(71)
df['p_Low_last_period71'] = df['p_l'].shift(71)
df['p_Close_last_period71'] = df['p_c'].shift(71)
#70 periods ago
df['p_Open_last_period70'] = df['p_o'].shift(70) 
df['p_High_last_period70'] = df['p_h'].shift(70)
df['p_Low_last_period70'] = df['p_l'].shift(70)
df['p_Close_last_period70'] = df['p_c'].shift(70)
#69 periods ago
df['p_Open_last_period69'] = df['p_o'].shift(69) 
df['p_High_last_period69'] = df['p_h'].shift(69)
df['p_Low_last_period69'] = df['p_l'].shift(69)
df['p_Close_last_period69'] = df['p_c'].shift(69)
#68 periods ago
df['p_Open_last_period68'] = df['p_o'].shift(68) 
df['p_High_last_period68'] = df['p_h'].shift(68)
df['p_Low_last_period68'] = df['p_l'].shift(68)
df['p_Close_last_period68'] = df['p_c'].shift(68)
#67 periods ago
df['p_Open_last_period67'] = df['p_o'].shift(67) 
df['p_High_last_period67'] = df['p_h'].shift(67)
df['p_Low_last_period67'] = df['p_l'].shift(67)
df['p_Close_last_period67'] = df['p_c'].shift(67)
#66 periods ago
df['p_Open_last_period66'] = df['p_o'].shift(66) 
df['p_High_last_period66'] = df['p_h'].shift(66)
df['p_Low_last_period66'] = df['p_l'].shift(66)
df['p_Close_last_period66'] = df['p_c'].shift(66)
#65 periods ago
df['p_Open_last_period65'] = df['p_o'].shift(65) 
df['p_High_last_period65'] = df['p_h'].shift(65)
df['p_Low_last_period65'] = df['p_l'].shift(65)
df['p_Close_last_period65'] = df['p_c'].shift(65)
#64 periods ago
df['p_Open_last_period64'] = df['p_o'].shift(64) 
df['p_High_last_period64'] = df['p_h'].shift(64)
df['p_Low_last_period64'] = df['p_l'].shift(64)
df['p_Close_last_period64'] = df['p_c'].shift(64)
#63 periods ago
df['p_Open_last_period63'] = df['p_o'].shift(63) 
df['p_High_last_period63'] = df['p_h'].shift(63)
df['p_Low_last_period63'] = df['p_l'].shift(63)
df['p_Close_last_period63'] = df['p_c'].shift(63)
#62 periods ago
df['p_Open_last_period62'] = df['p_o'].shift(62) 
df['p_High_last_period62'] = df['p_h'].shift(62)
df['p_Low_last_period62'] = df['p_l'].shift(62)
df['p_Close_last_period62'] = df['p_c'].shift(62)
#61 periods ago
df['p_Open_last_period61'] = df['p_o'].shift(61) 
df['p_High_last_period61'] = df['p_h'].shift(61)
df['p_Low_last_period61'] = df['p_l'].shift(61)
df['p_Close_last_period61'] = df['p_c'].shift(61)
#60 periods ago
df['p_Open_last_period60'] = df['p_o'].shift(60) 
df['p_High_last_period60'] = df['p_h'].shift(60)
df['p_Low_last_period60'] = df['p_l'].shift(60)
df['p_Close_last_period60'] = df['p_c'].shift(60)
#59 periods ago
df['p_Open_last_period59'] = df['p_o'].shift(59) 
df['p_High_last_period59'] = df['p_h'].shift(59)
df['p_Low_last_period59'] = df['p_l'].shift(59)
df['p_Close_last_period59'] = df['p_c'].shift(59)
#58 periods ago
df['p_Open_last_period58'] = df['p_o'].shift(58) 
df['p_High_last_period58'] = df['p_h'].shift(58)
df['p_Low_last_period58'] = df['p_l'].shift(58)
df['p_Close_last_period58'] = df['p_c'].shift(58)
#57 periods ago
df['p_Open_last_period57'] = df['p_o'].shift(57) 
df['p_High_last_period57'] = df['p_h'].shift(57)
df['p_Low_last_period57'] = df['p_l'].shift(57)
df['p_Close_last_period57'] = df['p_c'].shift(57)
#56 periods ago
df['p_Open_last_period56'] = df['p_o'].shift(56) 
df['p_High_last_period56'] = df['p_h'].shift(56)
df['p_Low_last_period56'] = df['p_l'].shift(56)
df['p_Close_last_period56'] = df['p_c'].shift(56)
#55 periods ago
df['p_Open_last_period55'] = df['p_o'].shift(55) 
df['p_High_last_period55'] = df['p_h'].shift(55)
df['p_Low_last_period55'] = df['p_l'].shift(55)
df['p_Close_last_period55'] = df['p_c'].shift(55)
#54 periods ago
df['p_Open_last_period54'] = df['p_o'].shift(54) 
df['p_High_last_period54'] = df['p_h'].shift(54)
df['p_Low_last_period54'] = df['p_l'].shift(54)
df['p_Close_last_period54'] = df['p_c'].shift(54)
#53 periods ago
df['p_Open_last_period53'] = df['p_o'].shift(53) 
df['p_High_last_period53'] = df['p_h'].shift(53)
df['p_Low_last_period53'] = df['p_l'].shift(53)
df['p_Close_last_period53'] = df['p_c'].shift(53)
#52 periods ago
df['p_Open_last_period52'] = df['p_o'].shift(52) 
df['p_High_last_period52'] = df['p_h'].shift(52)
df['p_Low_last_period52'] = df['p_l'].shift(52)
df['p_Close_last_period52'] = df['p_c'].shift(52)
#51 periods ago
df['p_Open_last_period51'] = df['p_o'].shift(51) 
df['p_High_last_period51'] = df['p_h'].shift(51)
df['p_Low_last_period51'] = df['p_l'].shift(51)
df['p_Close_last_period51'] = df['p_c'].shift(51)
#50 periods ago
df['p_Open_last_period50'] = df['p_o'].shift(50) 
df['p_High_last_period50'] = df['p_h'].shift(50)
df['p_Low_last_period50'] = df['p_l'].shift(50)
df['p_Close_last_period50'] = df['p_c'].shift(50)
#49 periods ago
df['p_Open_last_period49'] = df['p_o'].shift(49) 
df['p_High_last_period49'] = df['p_h'].shift(49)
df['p_Low_last_period49'] = df['p_l'].shift(49)
df['p_Close_last_period49'] = df['p_c'].shift(49)
#48 periods ago
df['p_Open_last_period48'] = df['p_o'].shift(48) 
df['p_High_last_period48'] = df['p_h'].shift(48)
df['p_Low_last_period48'] = df['p_l'].shift(48)
df['p_Close_last_period48'] = df['p_c'].shift(48)
#47 periods ago
df['p_Open_last_period47'] = df['p_o'].shift(47) 
df['p_High_last_period47'] = df['p_h'].shift(47)
df['p_Low_last_period47'] = df['p_l'].shift(47)
df['p_Close_last_period47'] = df['p_c'].shift(47)
#46 periods ago
df['p_Open_last_period46'] = df['p_o'].shift(46) 
df['p_High_last_period46'] = df['p_h'].shift(46)
df['p_Low_last_period46'] = df['p_l'].shift(46)
df['p_Close_last_period46'] = df['p_c'].shift(46)
#45 periods ago
df['p_Open_last_period45'] = df['p_o'].shift(45) 
df['p_High_last_period45'] = df['p_h'].shift(45)
df['p_Low_last_period45'] = df['p_l'].shift(45)
df['p_Close_last_period45'] = df['p_c'].shift(45)
#44 periods ago
df['p_Open_last_period44'] = df['p_o'].shift(44) 
df['p_High_last_period44'] = df['p_h'].shift(44)
df['p_Low_last_period44'] = df['p_l'].shift(44)
df['p_Close_last_period44'] = df['p_c'].shift(44)
#43 periods ago
df['p_Open_last_period43'] = df['p_o'].shift(43) 
df['p_High_last_period43'] = df['p_h'].shift(43)
df['p_Low_last_period43'] = df['p_l'].shift(43)
df['p_Close_last_period43'] = df['p_c'].shift(43)
#42 periods ago
df['p_Open_last_period42'] = df['p_o'].shift(42) 
df['p_High_last_period42'] = df['p_h'].shift(42)
df['p_Low_last_period42'] = df['p_l'].shift(42)
df['p_Close_last_period42'] = df['p_c'].shift(42)
#41 periods ago
df['p_Open_last_period41'] = df['p_o'].shift(41) 
df['p_High_last_period41'] = df['p_h'].shift(41)
df['p_Low_last_period41'] = df['p_l'].shift(41)
df['p_Close_last_period41'] = df['p_c'].shift(41)
#40 periods ago
df['p_Open_last_period40'] = df['p_o'].shift(40) 
df['p_High_last_period40'] = df['p_h'].shift(40)
df['p_Low_last_period40'] = df['p_l'].shift(40)
df['p_Close_last_period40'] = df['p_c'].shift(40)
#39 periods ago
df['p_Open_last_period39'] = df['p_o'].shift(39) 
df['p_High_last_period39'] = df['p_h'].shift(39)
df['p_Low_last_period39'] = df['p_l'].shift(39)
df['p_Close_last_period39'] = df['p_c'].shift(39)
#38 periods ago
df['p_Open_last_period38'] = df['p_o'].shift(38) 
df['p_High_last_period38'] = df['p_h'].shift(38)
df['p_Low_last_period38'] = df['p_l'].shift(38)
df['p_Close_last_period38'] = df['p_c'].shift(38)
#37 periods ago
df['p_Open_last_period37'] = df['p_o'].shift(37) 
df['p_High_last_period37'] = df['p_h'].shift(37)
df['p_Low_last_period37'] = df['p_l'].shift(37)
df['p_Close_last_period37'] = df['p_c'].shift(37)
#36 periods ago
df['p_Open_last_period36'] = df['p_o'].shift(36) 
df['p_High_last_period36'] = df['p_h'].shift(36)
df['p_Low_last_period36'] = df['p_l'].shift(36)
df['p_Close_last_period36'] = df['p_c'].shift(36)
#35 periods ago
df['p_Open_last_period35'] = df['p_o'].shift(35) 
df['p_High_last_period35'] = df['p_h'].shift(35)
df['p_Low_last_period35'] = df['p_l'].shift(35)
df['p_Close_last_period35'] = df['p_c'].shift(35)
#34 periods ago
df['p_Open_last_period34'] = df['p_o'].shift(34) 
df['p_High_last_period34'] = df['p_h'].shift(34)
df['p_Low_last_period34'] = df['p_l'].shift(34)
df['p_Close_last_period34'] = df['p_c'].shift(34)
#33 periods ago
df['p_Open_last_period33'] = df['p_o'].shift(33) 
df['p_High_last_period33'] = df['p_h'].shift(33)
df['p_Low_last_period33'] = df['p_l'].shift(33)
df['p_Close_last_period33'] = df['p_c'].shift(33)
#32 periods ago
df['p_Open_last_period32'] = df['p_o'].shift(32) 
df['p_High_last_period32'] = df['p_h'].shift(32)
df['p_Low_last_period32'] = df['p_l'].shift(32)
df['p_Close_last_period32'] = df['p_c'].shift(32)
#31 periods ago
df['p_Open_last_period31'] = df['p_o'].shift(31) 
df['p_High_last_period31'] = df['p_h'].shift(31)
df['p_Low_last_period31'] = df['p_l'].shift(31)
df['p_Close_last_period31'] = df['p_c'].shift(31)
#30 periods ago
df['p_Open_last_period30'] = df['p_o'].shift(30) 
df['p_High_last_period30'] = df['p_h'].shift(30)
df['p_Low_last_period30'] = df['p_l'].shift(30)
df['p_Close_last_period30'] = df['p_c'].shift(30) 
#29 periods ago 
df['p_Open_last_period29'] = df['p_o'].shift(29) 
df['p_High_last_period29'] = df['p_h'].shift(29)
df['p_Low_last_period29'] = df['p_l'].shift(29)
df['p_Close_last_period29'] = df['p_c'].shift(29)
#28 periods ago
df['p_Open_last_period28'] = df['p_o'].shift(28) 
df['p_High_last_period28'] = df['p_h'].shift(28)
df['p_Low_last_period28'] = df['p_l'].shift(28)
df['p_Close_last_period28'] = df['p_c'].shift(28) 
#27 periods ago
df['p_Open_last_period27'] = df['p_o'].shift(27) 
df['p_High_last_period27'] = df['p_h'].shift(27)
df['p_Low_last_period27'] = df['p_l'].shift(27)
df['p_Close_last_period27'] = df['p_c'].shift(27)
#26 periods ago
df['p_Open_last_period26'] = df['p_o'].shift(26) 
df['p_High_last_period26'] = df['p_h'].shift(26)
df['p_Low_last_period26'] = df['p_l'].shift(26)
df['p_Close_last_period26'] = df['p_c'].shift(26)
#25 periods ago
df['p_Open_last_period25'] = df['p_o'].shift(25) 
df['p_High_last_period25'] = df['p_h'].shift(25)
df['p_Low_last_period25'] = df['p_l'].shift(25)
df['p_Close_last_period25'] = df['p_c'].shift(25) 
#24 periods ago 
df['p_Open_last_period24'] = df['p_o'].shift(24) 
df['p_High_last_period24'] = df['p_h'].shift(24)
df['p_Low_last_period24'] = df['p_l'].shift(24)
df['p_Close_last_period24'] = df['p_c'].shift(24) 
#23 periods ago
df['p_Open_last_period23'] = df['p_o'].shift(23) 
df['p_High_last_period23'] = df['p_h'].shift(23)
df['p_Low_last_period23'] = df['p_l'].shift(23)
df['p_Close_last_period23'] = df['p_c'].shift(23) 
#22 periods ago
df['p_Open_last_period22'] = df['p_o'].shift(22) 
df['p_High_last_period22'] = df['p_h'].shift(22)
df['p_Low_last_period22'] = df['p_l'].shift(22)
df['p_Close_last_period22'] = df['p_c'].shift(22) 
#21 periods ago
df['p_Open_last_period21'] = df['p_o'].shift(21) 
df['p_High_last_period21'] = df['p_h'].shift(21)
df['p_Low_last_period21'] = df['p_l'].shift(21)
df['p_Close_last_period21'] = df['p_c'].shift(21)
#20 periods ago
df['p_Open_last_period20'] = df['p_o'].shift(20) 
df['p_High_last_period20'] = df['p_h'].shift(20)
df['p_Low_last_period20'] = df['p_l'].shift(20)
df['p_Close_last_period20'] = df['p_c'].shift(20) 
#19 periods ago 
df['p_Open_last_period19'] = df['p_o'].shift(19) 
df['p_High_last_period19'] = df['p_h'].shift(19)
df['p_Low_last_period19'] = df['p_l'].shift(19)
df['p_Close_last_period19'] = df['p_c'].shift(19)
#18 periods ago
df['p_Open_last_period18'] = df['p_o'].shift(18) 
df['p_High_last_period18'] = df['p_h'].shift(18)
df['p_Low_last_period18'] = df['p_l'].shift(18)
df['p_Close_last_period18'] = df['p_c'].shift(18) 
#17 periods ago
df['p_Open_last_period17'] = df['p_o'].shift(17) 
df['p_High_last_period17'] = df['p_h'].shift(17)
df['p_Low_last_period17'] = df['p_l'].shift(17)
df['p_Close_last_period17'] = df['p_c'].shift(17) 
#16 periods ago
df['p_Open_last_period16'] = df['p_o'].shift(16) 
df['p_High_last_period16'] = df['p_h'].shift(16)
df['p_Low_last_period16'] = df['p_l'].shift(16)
df['p_Close_last_period16'] = df['p_c'].shift(16)
#15 periods ago
df['p_Open_last_period15'] = df['p_o'].shift(15) 
df['p_High_last_period15'] = df['p_h'].shift(15)
df['p_Low_last_period15'] = df['p_l'].shift(15)
df['p_Close_last_period15'] = df['p_c'].shift(15)
#14 periods ago 
df['p_Open_last_period14'] = df['p_o'].shift(14) 
df['p_High_last_period14'] = df['p_h'].shift(14)
df['p_Low_last_period14'] = df['p_l'].shift(14)
df['p_Close_last_period14'] = df['p_c'].shift(14) 
#13 periods ago
df['p_Open_last_period13'] = df['p_o'].shift(13) 
df['p_High_last_period13'] = df['p_h'].shift(13)
df['p_Low_last_period13'] = df['p_l'].shift(13)
df['p_Close_last_period13'] = df['p_c'].shift(13) 
#12 periods ago
df['p_Open_last_period12'] = df['p_o'].shift(12) 
df['p_High_last_period12'] = df['p_h'].shift(12)
df['p_Low_last_period12'] = df['p_l'].shift(12)
df['p_Close_last_period12'] = df['p_c'].shift(12) 
#11 periods ago 
df['p_Open_last_period11'] = df['p_o'].shift(11) 
df['p_High_last_period11'] = df['p_h'].shift(11)
df['p_Low_last_period11'] = df['p_l'].shift(11)
df['p_Close_last_period11'] = df['p_c'].shift(11) 
#10 periods ago
df['p_Open_last_period10'] = df['p_o'].shift(10) 
df['p_High_last_period10'] = df['p_h'].shift(10)
df['p_Low_last_period10'] = df['p_l'].shift(10)
df['p_Close_last_period10'] = df['p_c'].shift(10)
#9 periods ago 
df['p_Open_last_period9'] = df['p_o'].shift(9) 
df['p_High_last_period9'] = df['p_h'].shift(9)
df['p_Low_last_period9'] = df['p_l'].shift(9)
df['p_Close_last_period9'] = df['p_c'].shift(9) 
#8 periods ago
df['p_Open_last_period8'] = df['p_o'].shift(8) 
df['p_High_last_period8'] = df['p_h'].shift(8)
df['p_Low_last_period8'] = df['p_l'].shift(8)
df['p_Close_last_period8'] = df['p_c'].shift(8)
#7 periods ago
df['p_Open_last_period7'] = df['p_o'].shift(7) 
df['p_High_last_period7'] = df['p_h'].shift(7)
df['p_Low_last_period7'] = df['p_l'].shift(7)
df['p_Close_last_period7'] = df['p_c'].shift(7) 
#6 periods ago 
df['p_Open_last_period6'] = df['p_o'].shift(6) 
df['p_High_last_period6'] = df['p_h'].shift(6)
df['p_Low_last_period6'] = df['p_l'].shift(6)
df['p_Close_last_period6'] = df['p_c'].shift(6)
#5 periods ago
df['p_Open_last_period5'] = df['p_o'].shift(5) 
df['p_High_last_period5'] = df['p_h'].shift(5)
df['p_Low_last_period5'] = df['p_l'].shift(5)
df['p_Close_last_period5'] = df['p_c'].shift(5) 
#4 periods ago 
df['p_Open_last_period4'] = df['p_o'].shift(4) 
df['p_High_last_period4'] = df['p_h'].shift(4)
df['p_Low_last_period4'] = df['p_l'].shift(4)
df['p_Close_last_period4'] = df['p_c'].shift(4) 
#3 periods ago
df['p_Open_last_period3'] = df['p_o'].shift(3) 
df['p_High_last_period3'] = df['p_h'].shift(3)
df['p_Low_last_period3'] = df['p_l'].shift(3)
df['p_Close_last_period3'] = df['p_c'].shift(3)
#2 periods ago
df['p_Open_last_period2'] = df['p_o'].shift(2) 
df['p_High_last_period2'] = df['p_h'].shift(2)
df['p_Low_last_period2'] = df['p_l'].shift(2)
df['p_Close_last_period2'] = df['p_c'].shift(2) 
#1 periods ago 
df['p_Open_last_period1'] = df['p_o'].shift(1)     
df['p_High_last_period1'] = df['p_h'].shift(1)
df['p_Low_last_period1'] = df['p_l'].shift(1)
df['p_Close_last_period1'] = df['p_c'].shift(1)       

#yesterday
df['p_Open_yesterday'] = df['p_o'].shift(0)     
df['p_High_yesterday'] = df['p_h'].shift(0)
df['p_Low_yesterday'] = df['p_l'].shift(0)
df['p_Close_yesterday'] = df['p_c'].shift(0) 

#Target
#1 periods forward 
df['p_High_next_period1'] = df['p_h'].shift(-1)
df['p_Low_next_period1'] = df['p_l'].shift(-1)
df['p_Close_next_period1'] = df['p_c'].shift(-1) 

#drop null and useless columns
df = df.dropna()
df = df.drop(['p_o','p_h','p_l','p_c'], axis=1)
# Out:
# /tmp/ipykernel_70/2518218065.py:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period356'] = df['p_c'].shift(356)
# /tmp/ipykernel_70/2518218065.py:131: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period355'] = df['p_o'].shift(355)
# /tmp/ipykernel_70/2518218065.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period355'] = df['p_h'].shift(355)
# /tmp/ipykernel_70/2518218065.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period355'] = df['p_l'].shift(355)
# /tmp/ipykernel_70/2518218065.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period355'] = df['p_c'].shift(355)
# /tmp/ipykernel_70/2518218065.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period354'] = df['p_o'].shift(354)
# /tmp/ipykernel_70/2518218065.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period354'] = df['p_h'].shift(354)
# /tmp/ipykernel_70/2518218065.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period354'] = df['p_l'].shift(354)
# /tmp/ipykernel_70/2518218065.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period354'] = df['p_c'].shift(354)
# /tmp/ipykernel_70/2518218065.py:141: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period353'] = df['p_o'].shift(353)
# /tmp/ipykernel_70/2518218065.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period353'] = df['p_h'].shift(353)
# /tmp/ipykernel_70/2518218065.py:143: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period353'] = df['p_l'].shift(353)
# /tmp/ipykernel_70/2518218065.py:144: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period353'] = df['p_c'].shift(353)
# /tmp/ipykernel_70/2518218065.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period352'] = df['p_o'].shift(352)
# /tmp/ipykernel_70/2518218065.py:147: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period352'] = df['p_h'].shift(352)
# /tmp/ipykernel_70/2518218065.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period352'] = df['p_l'].shift(352)
# /tmp/ipykernel_70/2518218065.py:149: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period352'] = df['p_c'].shift(352)
# /tmp/ipykernel_70/2518218065.py:151: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period351'] = df['p_o'].shift(351)
# /tmp/ipykernel_70/2518218065.py:152: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period351'] = df['p_h'].shift(351)
# /tmp/ipykernel_70/2518218065.py:153: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period351'] = df['p_l'].shift(351)
# /tmp/ipykernel_70/2518218065.py:154: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period351'] = df['p_c'].shift(351)
# /tmp/ipykernel_70/2518218065.py:156: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period350'] = df['p_o'].shift(350)
# /tmp/ipykernel_70/2518218065.py:157: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period350'] = df['p_h'].shift(350)
# /tmp/ipykernel_70/2518218065.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period350'] = df['p_l'].shift(350)
# /tmp/ipykernel_70/2518218065.py:159: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period350'] = df['p_c'].shift(350)
# /tmp/ipykernel_70/2518218065.py:161: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period349'] = df['p_o'].shift(349)
# /tmp/ipykernel_70/2518218065.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period349'] = df['p_h'].shift(349)
# /tmp/ipykernel_70/2518218065.py:163: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period349'] = df['p_l'].shift(349)
# /tmp/ipykernel_70/2518218065.py:164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period349'] = df['p_c'].shift(349)
# /tmp/ipykernel_70/2518218065.py:166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period348'] = df['p_o'].shift(348)
# /tmp/ipykernel_70/2518218065.py:167: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period348'] = df['p_h'].shift(348)
# /tmp/ipykernel_70/2518218065.py:168: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period348'] = df['p_l'].shift(348)
# /tmp/ipykernel_70/2518218065.py:169: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period348'] = df['p_c'].shift(348)
# /tmp/ipykernel_70/2518218065.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period347'] = df['p_o'].shift(347)
# /tmp/ipykernel_70/2518218065.py:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period347'] = df['p_h'].shift(347)
# /tmp/ipykernel_70/2518218065.py:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period347'] = df['p_l'].shift(347)
# /tmp/ipykernel_70/2518218065.py:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period347'] = df['p_c'].shift(347)
# /tmp/ipykernel_70/2518218065.py:176: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period346'] = df['p_o'].shift(346)
# /tmp/ipykernel_70/2518218065.py:177: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period346'] = df['p_h'].shift(346)
# /tmp/ipykernel_70/2518218065.py:178: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period346'] = df['p_l'].shift(346)
# /tmp/ipykernel_70/2518218065.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period346'] = df['p_c'].shift(346)
# /tmp/ipykernel_70/2518218065.py:181: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period345'] = df['p_o'].shift(345)
# /tmp/ipykernel_70/2518218065.py:182: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period345'] = df['p_h'].shift(345)
# /tmp/ipykernel_70/2518218065.py:183: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period345'] = df['p_l'].shift(345)
# /tmp/ipykernel_70/2518218065.py:184: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period345'] = df['p_c'].shift(345)
# /tmp/ipykernel_70/2518218065.py:186: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period344'] = df['p_o'].shift(344)
# /tmp/ipykernel_70/2518218065.py:187: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period344'] = df['p_h'].shift(344)
# /tmp/ipykernel_70/2518218065.py:188: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period344'] = df['p_l'].shift(344)
# /tmp/ipykernel_70/2518218065.py:189: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period344'] = df['p_c'].shift(344)
# /tmp/ipykernel_70/2518218065.py:191: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period343'] = df['p_o'].shift(343)
# /tmp/ipykernel_70/2518218065.py:192: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period343'] = df['p_h'].shift(343)
# /tmp/ipykernel_70/2518218065.py:193: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period343'] = df['p_l'].shift(343)
# /tmp/ipykernel_70/2518218065.py:194: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period343'] = df['p_c'].shift(343)
# /tmp/ipykernel_70/2518218065.py:196: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period342'] = df['p_o'].shift(342)
# /tmp/ipykernel_70/2518218065.py:197: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period342'] = df['p_h'].shift(342)
# /tmp/ipykernel_70/2518218065.py:198: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period342'] = df['p_l'].shift(342)
# /tmp/ipykernel_70/2518218065.py:199: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period342'] = df['p_c'].shift(342)
# /tmp/ipykernel_70/2518218065.py:201: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period341'] = df['p_o'].shift(341)
# /tmp/ipykernel_70/2518218065.py:202: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period341'] = df['p_h'].shift(341)
# /tmp/ipykernel_70/2518218065.py:203: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period341'] = df['p_l'].shift(341)
# /tmp/ipykernel_70/2518218065.py:204: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period341'] = df['p_c'].shift(341)
# /tmp/ipykernel_70/2518218065.py:206: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period340'] = df['p_o'].shift(340)
# /tmp/ipykernel_70/2518218065.py:207: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period340'] = df['p_h'].shift(340)
# /tmp/ipykernel_70/2518218065.py:208: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period340'] = df['p_l'].shift(340)
# /tmp/ipykernel_70/2518218065.py:209: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period340'] = df['p_c'].shift(340)
# /tmp/ipykernel_70/2518218065.py:211: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period339'] = df['p_o'].shift(339)
# /tmp/ipykernel_70/2518218065.py:212: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period339'] = df['p_h'].shift(339)
# /tmp/ipykernel_70/2518218065.py:213: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period339'] = df['p_l'].shift(339)
# /tmp/ipykernel_70/2518218065.py:214: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period339'] = df['p_c'].shift(339)
# /tmp/ipykernel_70/2518218065.py:216: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period338'] = df['p_o'].shift(338)
# /tmp/ipykernel_70/2518218065.py:217: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period338'] = df['p_h'].shift(338)
# /tmp/ipykernel_70/2518218065.py:218: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period338'] = df['p_l'].shift(338)
# /tmp/ipykernel_70/2518218065.py:219: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period338'] = df['p_c'].shift(338)
# /tmp/ipykernel_70/2518218065.py:221: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period337'] = df['p_o'].shift(337)
# /tmp/ipykernel_70/2518218065.py:222: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period337'] = df['p_h'].shift(337)
# /tmp/ipykernel_70/2518218065.py:223: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period337'] = df['p_l'].shift(337)
# /tmp/ipykernel_70/2518218065.py:224: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period337'] = df['p_c'].shift(337)
# /tmp/ipykernel_70/2518218065.py:226: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period336'] = df['p_o'].shift(336)
# /tmp/ipykernel_70/2518218065.py:227: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period336'] = df['p_h'].shift(336)
# /tmp/ipykernel_70/2518218065.py:228: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period336'] = df['p_l'].shift(336)
# /tmp/ipykernel_70/2518218065.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period336'] = df['p_c'].shift(336)
# /tmp/ipykernel_70/2518218065.py:231: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period335'] = df['p_o'].shift(335)
# /tmp/ipykernel_70/2518218065.py:232: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period335'] = df['p_h'].shift(335)
# /tmp/ipykernel_70/2518218065.py:233: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period335'] = df['p_l'].shift(335)
# /tmp/ipykernel_70/2518218065.py:234: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period335'] = df['p_c'].shift(335)
# /tmp/ipykernel_70/2518218065.py:236: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period334'] = df['p_o'].shift(334)
# /tmp/ipykernel_70/2518218065.py:237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period334'] = df['p_h'].shift(334)
# /tmp/ipykernel_70/2518218065.py:238: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period334'] = df['p_l'].shift(334)
# /tmp/ipykernel_70/2518218065.py:239: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period334'] = df['p_c'].shift(334)
# /tmp/ipykernel_70/2518218065.py:241: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period333'] = df['p_o'].shift(333)
# /tmp/ipykernel_70/2518218065.py:242: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period333'] = df['p_h'].shift(333)
# /tmp/ipykernel_70/2518218065.py:243: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period333'] = df['p_l'].shift(333)
# /tmp/ipykernel_70/2518218065.py:244: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period333'] = df['p_c'].shift(333)
# /tmp/ipykernel_70/2518218065.py:246: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period332'] = df['p_o'].shift(332)
# /tmp/ipykernel_70/2518218065.py:247: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period332'] = df['p_h'].shift(332)
# /tmp/ipykernel_70/2518218065.py:248: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period332'] = df['p_l'].shift(332)
# /tmp/ipykernel_70/2518218065.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period332'] = df['p_c'].shift(332)
# /tmp/ipykernel_70/2518218065.py:251: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period331'] = df['p_o'].shift(331)
# /tmp/ipykernel_70/2518218065.py:252: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period331'] = df['p_h'].shift(331)
# /tmp/ipykernel_70/2518218065.py:253: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period331'] = df['p_l'].shift(331)
# /tmp/ipykernel_70/2518218065.py:254: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period331'] = df['p_c'].shift(331)
# /tmp/ipykernel_70/2518218065.py:256: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period330'] = df['p_o'].shift(330)
# /tmp/ipykernel_70/2518218065.py:257: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period330'] = df['p_h'].shift(330)
# /tmp/ipykernel_70/2518218065.py:258: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period330'] = df['p_l'].shift(330)
# /tmp/ipykernel_70/2518218065.py:259: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period330'] = df['p_c'].shift(330)
# /tmp/ipykernel_70/2518218065.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period329'] = df['p_o'].shift(329)
# /tmp/ipykernel_70/2518218065.py:262: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period329'] = df['p_h'].shift(329)
# /tmp/ipykernel_70/2518218065.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period329'] = df['p_l'].shift(329)
# /tmp/ipykernel_70/2518218065.py:264: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period329'] = df['p_c'].shift(329)
# /tmp/ipykernel_70/2518218065.py:266: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period328'] = df['p_o'].shift(328)
# /tmp/ipykernel_70/2518218065.py:267: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period328'] = df['p_h'].shift(328)
# /tmp/ipykernel_70/2518218065.py:268: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period328'] = df['p_l'].shift(328)
# /tmp/ipykernel_70/2518218065.py:269: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period328'] = df['p_c'].shift(328)
# /tmp/ipykernel_70/2518218065.py:271: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period327'] = df['p_o'].shift(327)
# /tmp/ipykernel_70/2518218065.py:272: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period327'] = df['p_h'].shift(327)
# /tmp/ipykernel_70/2518218065.py:273: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period327'] = df['p_l'].shift(327)
# /tmp/ipykernel_70/2518218065.py:274: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period327'] = df['p_c'].shift(327)
# /tmp/ipykernel_70/2518218065.py:276: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period326'] = df['p_o'].shift(326)
# /tmp/ipykernel_70/2518218065.py:277: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period326'] = df['p_h'].shift(326)
# /tmp/ipykernel_70/2518218065.py:278: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period326'] = df['p_l'].shift(326)
# /tmp/ipykernel_70/2518218065.py:279: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period326'] = df['p_c'].shift(326)
# /tmp/ipykernel_70/2518218065.py:281: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period325'] = df['p_o'].shift(325)
# /tmp/ipykernel_70/2518218065.py:282: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period325'] = df['p_h'].shift(325)
# /tmp/ipykernel_70/2518218065.py:283: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period325'] = df['p_l'].shift(325)
# /tmp/ipykernel_70/2518218065.py:284: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period325'] = df['p_c'].shift(325)
# /tmp/ipykernel_70/2518218065.py:286: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period324'] = df['p_o'].shift(324)
# /tmp/ipykernel_70/2518218065.py:287: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period324'] = df['p_h'].shift(324)
# /tmp/ipykernel_70/2518218065.py:288: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period324'] = df['p_l'].shift(324)
# /tmp/ipykernel_70/2518218065.py:289: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period324'] = df['p_c'].shift(324)
# /tmp/ipykernel_70/2518218065.py:291: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period323'] = df['p_o'].shift(323)
# ...
#   df['p_Close_last_period10'] = df['p_c'].shift(10)
# /tmp/ipykernel_70/2518218065.py:1861: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period9'] = df['p_o'].shift(9)
# /tmp/ipykernel_70/2518218065.py:1862: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period9'] = df['p_h'].shift(9)
# /tmp/ipykernel_70/2518218065.py:1863: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period9'] = df['p_l'].shift(9)
# /tmp/ipykernel_70/2518218065.py:1864: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period9'] = df['p_c'].shift(9)
# /tmp/ipykernel_70/2518218065.py:1866: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period8'] = df['p_o'].shift(8)
# /tmp/ipykernel_70/2518218065.py:1867: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period8'] = df['p_h'].shift(8)
# /tmp/ipykernel_70/2518218065.py:1868: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period8'] = df['p_l'].shift(8)
# /tmp/ipykernel_70/2518218065.py:1869: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period8'] = df['p_c'].shift(8)
# /tmp/ipykernel_70/2518218065.py:1871: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period7'] = df['p_o'].shift(7)
# /tmp/ipykernel_70/2518218065.py:1872: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period7'] = df['p_h'].shift(7)
# /tmp/ipykernel_70/2518218065.py:1873: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period7'] = df['p_l'].shift(7)
# /tmp/ipykernel_70/2518218065.py:1874: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period7'] = df['p_c'].shift(7)
# /tmp/ipykernel_70/2518218065.py:1876: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period6'] = df['p_o'].shift(6)
# /tmp/ipykernel_70/2518218065.py:1877: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period6'] = df['p_h'].shift(6)
# /tmp/ipykernel_70/2518218065.py:1878: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period6'] = df['p_l'].shift(6)
# /tmp/ipykernel_70/2518218065.py:1879: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period6'] = df['p_c'].shift(6)
# /tmp/ipykernel_70/2518218065.py:1881: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period5'] = df['p_o'].shift(5)
# /tmp/ipykernel_70/2518218065.py:1882: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period5'] = df['p_h'].shift(5)
# /tmp/ipykernel_70/2518218065.py:1883: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period5'] = df['p_l'].shift(5)
# /tmp/ipykernel_70/2518218065.py:1884: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period5'] = df['p_c'].shift(5)
# /tmp/ipykernel_70/2518218065.py:1886: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period4'] = df['p_o'].shift(4)
# /tmp/ipykernel_70/2518218065.py:1887: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period4'] = df['p_h'].shift(4)
# /tmp/ipykernel_70/2518218065.py:1888: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period4'] = df['p_l'].shift(4)
# /tmp/ipykernel_70/2518218065.py:1889: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period4'] = df['p_c'].shift(4)
# /tmp/ipykernel_70/2518218065.py:1891: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period3'] = df['p_o'].shift(3)
# /tmp/ipykernel_70/2518218065.py:1892: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period3'] = df['p_h'].shift(3)
# /tmp/ipykernel_70/2518218065.py:1893: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period3'] = df['p_l'].shift(3)
# /tmp/ipykernel_70/2518218065.py:1894: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period3'] = df['p_c'].shift(3)
# /tmp/ipykernel_70/2518218065.py:1896: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period2'] = df['p_o'].shift(2)
# /tmp/ipykernel_70/2518218065.py:1897: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period2'] = df['p_h'].shift(2)
# /tmp/ipykernel_70/2518218065.py:1898: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period2'] = df['p_l'].shift(2)
# /tmp/ipykernel_70/2518218065.py:1899: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period2'] = df['p_c'].shift(2)
# /tmp/ipykernel_70/2518218065.py:1901: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_last_period1'] = df['p_o'].shift(1)
# /tmp/ipykernel_70/2518218065.py:1902: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_last_period1'] = df['p_h'].shift(1)
# /tmp/ipykernel_70/2518218065.py:1903: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_last_period1'] = df['p_l'].shift(1)
# /tmp/ipykernel_70/2518218065.py:1904: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_last_period1'] = df['p_c'].shift(1)
# /tmp/ipykernel_70/2518218065.py:1907: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Open_yesterday'] = df['p_o'].shift(0)
# /tmp/ipykernel_70/2518218065.py:1908: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_yesterday'] = df['p_h'].shift(0)
# /tmp/ipykernel_70/2518218065.py:1909: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_yesterday'] = df['p_l'].shift(0)
# /tmp/ipykernel_70/2518218065.py:1910: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_yesterday'] = df['p_c'].shift(0)
# /tmp/ipykernel_70/2518218065.py:1914: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_High_next_period1'] = df['p_h'].shift(-1)
# /tmp/ipykernel_70/2518218065.py:1915: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Low_next_period1'] = df['p_l'].shift(-1)
# /tmp/ipykernel_70/2518218065.py:1916: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_Close_next_period1'] = df['p_c'].shift(-1)

# %%
df
# Out:
#       p_Open_last_period380  p_High_last_period380  p_Low_last_period380  \
# 380                 2.25170                2.25350               2.25000
# 381                 2.25790                2.25890               2.25700
# 382                 2.26470                2.26470               2.26470
# 383                 2.25290                2.25290               2.25290
# 384                 2.26210                2.26210               2.26210
# ...                     ...                    ...                   ...
# 7499                1.20707                1.21239               1.20662
# 7500                1.20920                1.21003               1.20391
# 7501                1.20736                1.21209               1.20544
# 7502                1.20986                1.21858               1.20984
# 7503                1.21591                1.21929               1.21372
#
#       p_Close_last_period380  p_Open_last_period379  p_High_last_period379  \
# 380                  2.25170                2.25790                2.25890
# 381                  2.25790                2.26470                2.26470
# 382                  2.26470                2.25290                2.25290
# 383                  2.25290                2.26210                2.26210
# 384                  2.26210                2.26300                2.26460
# ...                      ...                    ...                    ...
# 7499                 1.20960                1.20920                1.21003
# 7500                 1.20730                1.20736                1.21209
# 7501                 1.21060                1.20986                1.21858
# 7502                 1.21586                1.21591                1.21929
# 7503                 1.21710                1.21671                1.21859
#
#       p_Low_last_period379  p_Close_last_period379  p_Open_last_period378  \
# 380                2.25700                 2.25790                2.26470
# 381                2.26470                 2.26470                2.25290
# 382                2.25290                 2.25290                2.26210
# 383                2.26210                 2.26210                2.26300
# 384                2.26150                 2.26300                2.25520
# ...                    ...                     ...                    ...
# 7499               1.20391                 1.20730                1.20736
# 7500               1.20544                 1.21060                1.20986
# 7501               1.20984                 1.21586                1.21591
# 7502               1.21372                 1.21710                1.21671
# 7503               1.21370                 1.21535                1.21399
#
#       p_High_last_period378  ...  p_High_last_period1  p_Low_last_period1  \
# 380                 2.26470  ...              2.02380             2.02380
# 381                 2.25290  ...              2.03070             2.03070
# 382                 2.26210  ...              2.04420             2.04420
# 383                 2.26460  ...              2.03520             2.03520
# 384                 2.25720  ...              2.03330             2.03330
# ...                     ...  ...                  ...                 ...
# 7499                1.21209  ...              1.22999             1.21142
# 7500                1.21858  ...              1.22055             1.21081
# 7501                1.21929  ...              1.22849             1.21591
# 7502                1.21859  ...              1.23142             1.22085
# 7503                1.21605  ...              1.22851             1.21624
#
#       p_Close_last_period1  p_Open_yesterday  p_High_yesterday  \
# 380                2.02380           2.03070           2.03070
# 381                2.03070           2.04420           2.04420
# 382                2.04420           2.03520           2.03520
# 383                2.03520           2.03330           2.03330
# 384                2.03330           2.02830           2.02830
# ...                    ...               ...               ...
# 7499               1.21706           1.21658           1.22055
# 7500               1.21926           1.21725           1.22849
# 7501               1.22518           1.22499           1.23142
# 7502               1.22549           1.22548           1.22851
# 7503               1.21706           1.21790           1.21790
#
#       p_Low_yesterday  p_Close_yesterday  p_High_next_period1  \
# 380           2.03070            2.03070              2.04420
# 381           2.04420            2.04420              2.03520
# 382           2.03520            2.03520              2.03330
# 383           2.03330            2.03330              2.02830
# 384           2.02830            2.02830              2.02400
# ...               ...                ...                  ...
# 7499          1.21081            1.21926              1.22849
# 7500          1.21591            1.22518              1.23142
# 7501          1.22085            1.22549              1.22851
# 7502          1.21624            1.21706              1.21790
# 7503          1.21515            1.21600              1.20558
#
#       p_Low_next_period1  p_Close_next_period1
# 380              2.04420               2.04420
# 381              2.03520               2.03520
# 382              2.03330               2.03330
# 383              2.02830               2.02830
# 384              2.02400               2.02400
# ...                  ...                   ...
# 7499             1.21591               1.22518
# 7500             1.22085               1.22549
# 7501             1.21624               1.21706
# 7502             1.21515               1.21600
# 7503             1.20143               1.20438
#
# [7124 rows x 1527 columns]

# %%
df_pre = pd.DataFrame(df[['p_Open_last_period1','p_High_last_period1','p_Low_last_period1','p_Close_last_period1','p_Close_next_period1']])

# %%
df_pre
# Out:
#       p_Open_last_period1  p_High_last_period1  p_Low_last_period1  \
# 380               2.02380              2.02380             2.02380
# 381               2.03070              2.03070             2.03070
# 382               2.04420              2.04420             2.04420
# 383               2.03520              2.03520             2.03520
# 384               2.03330              2.03330             2.03330
# ...                   ...                  ...                 ...
# 7499              1.22792              1.22999             1.21142
# 7500              1.21658              1.22055             1.21081
# 7501              1.21725              1.22849             1.21591
# 7502              1.22499              1.23142             1.22085
# 7503              1.22548              1.22851             1.21624
#
#       p_Close_last_period1  p_Close_next_period1
# 380                2.02380               2.04420
# 381                2.03070               2.03520
# 382                2.04420               2.03330
# 383                2.03520               2.02830
# 384                2.03330               2.02400
# ...                    ...                   ...
# 7499               1.21706               1.22518
# 7500               1.21926               1.22549
# 7501               1.22518               1.21706
# 7502               1.22549               1.21600
# 7503               1.21706               1.20438
#
# [7124 rows x 5 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7124 entries, 380 to 7503
# Data columns (total 1527 columns):
#  #     Column                  Dtype
# ---    ------                  -----
#  0     p_Open_last_period380   float64
#  1     p_High_last_period380   float64
#  2     p_Low_last_period380    float64
#  3     p_Close_last_period380  float64
#  4     p_Open_last_period379   float64
#  5     p_High_last_period379   float64
#  6     p_Low_last_period379    float64
#  7     p_Close_last_period379  float64
#  8     p_Open_last_period378   float64
#  9     p_High_last_period378   float64
#  10    p_Low_last_period378    float64
#  11    p_Close_last_period378  float64
#  12    p_Open_last_period377   float64
#  13    p_High_last_period377   float64
#  14    p_Low_last_period377    float64
#  15    p_Close_last_period377  float64
#  16    p_Open_last_period376   float64
#  17    p_High_last_period376   float64
#  18    p_Low_last_period376    float64
#  19    p_Close_last_period376  float64
#  20    p_Open_last_period375   float64
#  21    p_High_last_period375   float64
#  22    p_Low_last_period375    float64
#  23    p_Close_last_period375  float64
#  24    p_Open_last_period374   float64
#  25    p_High_last_period374   float64
#  26    p_Low_last_period374    float64
#  27    p_Close_last_period374  float64
#  28    p_Open_last_period373   float64
#  29    p_High_last_period373   float64
#  30    p_Low_last_period373    float64
#  31    p_Close_last_period373  float64
#  32    p_Open_last_period372   float64
#  33    p_High_last_period372   float64
#  34    p_Low_last_period372    float64
#  35    p_Close_last_period372  float64
#  36    p_Open_last_period371   float64
#  37    p_High_last_period371   float64
#  38    p_Low_last_period371    float64
#  39    p_Close_last_period371  float64
#  40    p_Open_last_period370   float64
#  41    p_High_last_period370   float64
#  42    p_Low_last_period370    float64
#  43    p_Close_last_period370  float64
#  44    p_Open_last_period369   float64
#  45    p_High_last_period369   float64
#  46    p_Low_last_period369    float64
#  47    p_Close_last_period369  float64
#  48    p_Open_last_period368   float64
#  49    p_High_last_period368   float64
#  50    p_Low_last_period368    float64
#  51    p_Close_last_period368  float64
#  52    p_Open_last_period367   float64
#  53    p_High_last_period367   float64
#  54    p_Low_last_period367    float64
#  55    p_Close_last_period367  float64
#  56    p_Open_last_period366   float64
#  57    p_High_last_period366   float64
#  58    p_Low_last_period366    float64
#  59    p_Close_last_period366  float64
#  60    p_Open_last_period365   float64
#  61    p_High_last_period365   float64
#  62    p_Low_last_period365    float64
#  63    p_Close_last_period365  float64
#  64    p_Open_last_period364   float64
#  65    p_High_last_period364   float64
#  66    p_Low_last_period364    float64
#  67    p_Close_last_period364  float64
#  68    p_Open_last_period363   float64
#  69    p_High_last_period363   float64
#  70    p_Low_last_period363    float64
#  71    p_Close_last_period363  float64
#  72    p_Open_last_period362   float64
#  73    p_High_last_period362   float64
#  74    p_Low_last_period362    float64
#  75    p_Close_last_period362  float64
#  76    p_Open_last_period361   float64
#  77    p_High_last_period361   float64
#  78    p_Low_last_period361    float64
#  79    p_Close_last_period361  float64
#  80    p_Open_last_period360   float64
#  81    p_High_last_period360   float64
#  82    p_Low_last_period360    float64
#  83    p_Close_last_period360  float64
#  84    p_Open_last_period359   float64
#  85    p_High_last_period359   float64
#  86    p_Low_last_period359    float64
#  87    p_Close_last_period359  float64
#  88    p_Open_last_period358   float64
#  89    p_High_last_period358   float64
#  90    p_Low_last_period358    float64
#  91    p_Close_last_period358  float64
#  92    p_Open_last_period357   float64
#  93    p_High_last_period357   float64
#  94    p_Low_last_period357    float64
#  95    p_Close_last_period357  float64
#  96    p_Open_last_period356   float64
#  97    p_High_last_period356   float64
#  98    p_Low_last_period356    float64
#  99    p_Close_last_period356  float64
#  100   p_Open_last_period355   float64
#  101   p_High_last_period355   float64
#  102   p_Low_last_period355    float64
#  103   p_Close_last_period355  float64
#  104   p_Open_last_period354   float64
#  105   p_High_last_period354   float64
#  106   p_Low_last_period354    float64
#  107   p_Close_last_period354  float64
#  108   p_Open_last_period353   float64
#  109   p_High_last_period353   float64
#  110   p_Low_last_period353    float64
#  111   p_Close_last_period353  float64
#  112   p_Open_last_period352   float64
#  113   p_High_last_period352   float64
#  114   p_Low_last_period352    float64
#  115   p_Close_last_period352  float64
#  116   p_Open_last_period351   float64
#  117   p_High_last_period351   float64
#  118   p_Low_last_period351    float64
#  119   p_Close_last_period351  float64
#  120   p_Open_last_period350   float64
#  121   p_High_last_period350   float64
#  122   p_Low_last_period350    float64
#  123   p_Close_last_period350  float64
#  124   p_Open_last_period349   float64
#  125   p_High_last_period349   float64
#  126   p_Low_last_period349    float64
#  127   p_Close_last_period349  float64
#  128   p_Open_last_period348   float64
#  129   p_High_last_period348   float64
#  130   p_Low_last_period348    float64
#  131   p_Close_last_period348  float64
#  132   p_Open_last_period347   float64
#  133   p_High_last_period347   float64
#  134   p_Low_last_period347    float64
#  135   p_Close_last_period347  float64
#  136   p_Open_last_period346   float64
#  137   p_High_last_period346   float64
#  138   p_Low_last_period346    float64
#  139   p_Close_last_period346  float64
#  140   p_Open_last_period345   float64
#  141   p_High_last_period345   float64
#  142   p_Low_last_period345    float64
#  143   p_Close_last_period345  float64
#  144   p_Open_last_period344   float64
#  145   p_High_last_period344   float64
#  146   p_Low_last_period344    float64
#  147   p_Close_last_period344  float64
#  148   p_Open_last_period343   float64
#  149   p_High_last_period343   float64
#  150   p_Low_last_period343    float64
#  151   p_Close_last_period343  float64
#  152   p_Open_last_period342   float64
#  153   p_High_last_period342   float64
#  154   p_Low_last_period342    float64
#  155   p_Close_last_period342  float64
#  156   p_Open_last_period341   float64
#  157   p_High_last_period341   float64
#  158   p_Low_last_period341    float64
#  159   p_Close_last_period341  float64
#  160   p_Open_last_period340   float64
#  161   p_High_last_period340   float64
#  162   p_Low_last_period340    float64
#  163   p_Close_last_period340  float64
#  164   p_Open_last_period339   float64
#  165   p_High_last_period339   float64
#  166   p_Low_last_period339    float64
#  167   p_Close_last_period339  float64
#  168   p_Open_last_period338   float64
#  169   p_High_last_period338   float64
#  170   p_Low_last_period338    float64
#  171   p_Close_last_period338  float64
#  172   p_Open_last_period337   float64
#  173   p_High_last_period337   float64
#  174   p_Low_last_period337    float64
#  175   p_Close_last_period337  float64
#  176   p_Open_last_period336   float64
#  177   p_High_last_period336   float64
#  178   p_Low_last_period336    float64
#  179   p_Close_last_period336  float64
#  180   p_Open_last_period335   float64
#  181   p_High_last_period335   float64
#  182   p_Low_last_period335    float64
#  183   p_Close_last_period335  float64
#  184   p_Open_last_period334   float64
#  185   p_High_last_period334   float64
#  186   p_Low_last_period334    float64
#  187   p_Close_last_period334  float64
#  188   p_Open_last_period333   float64
#  189   p_High_last_period333   float64
#  190   p_Low_last_period333    float64
#  191   p_Close_last_period333  float64
#  192   p_Open_last_period332   float64
#  193   p_High_last_period332   float64
#  194   p_Low_last_period332    float64
#  195   p_Close_last_period332  float64
#  196   p_Open_last_period331   float64
#  197   p_High_last_period331   float64
#  198   p_Low_last_period331    float64
#  199   p_Close_last_period331  float64
#  200   p_Open_last_period330   float64
#  201   p_High_last_period330   float64
#  202   p_Low_last_period330    float64
#  203   p_Close_last_period330  float64
#  204   p_Open_last_period329   float64
#  205   p_High_last_period329   float64
#  206   p_Low_last_period329    float64
#  207   p_Close_last_period329  float64
#  208   p_Open_last_period328   float64
#  209   p_High_last_period328   float64
#  210   p_Low_last_period328    float64
#  211   p_Close_last_period328  float64
#  212   p_Open_last_period327   float64
#  213   p_High_last_period327   float64
#  214   p_Low_last_period327    float64
#  215   p_Close_last_period327  float64
#  216   p_Open_last_period326   float64
#  217   p_High_last_period326   float64
#  218   p_Low_last_period326    float64
#  219   p_Close_last_period326  float64
#  220   p_Open_last_period325   float64
#  221   p_High_last_period325   float64
#  222   p_Low_last_period325    float64
#  223   p_Close_last_period325  float64
#  224   p_Open_last_period324   float64
#  225   p_High_last_period324   float64
#  226   p_Low_last_period324    float64
#  227   p_Close_last_period324  float64
#  228   p_Open_last_period323   float64
#  229   p_High_last_period323   float64
#  230   p_Low_last_period323    float64
#  231   p_Close_last_period323  float64
#  232   p_Open_last_period322   float64
#  233   p_High_last_period322   float64
#  234   p_Low_last_period322    float64
#  235   p_Close_last_period322  float64
#  236   p_Open_last_period321   float64
#  237   p_High_last_period321   float64
#  238   p_Low_last_period321    float64
#  239   p_Close_last_period321  float64
#  240   p_Open_last_period320   float64
#  241   p_High_last_period320   float64
#  242   p_Low_last_period320    float64
#  243   p_Close_last_period320  float64
#  244   p_Open_last_period319   float64
#  245   p_High_last_period319   float64
#  246   p_Low_last_period319    float64
#  247   p_Close_last_period319  float64
#  248   p_Open_last_period318   float64
#  249   p_High_last_period318   float64
#  250   p_Low_last_period318    float64
#  251   p_Close_last_period318  float64
#  252   p_Open_last_period317   float64
#  253   p_High_last_period317   float64
#  254   p_Low_last_period317    float64
#  255   p_Close_last_period317  float64
#  256   p_Open_last_period316   float64
#  257   p_High_last_period316   float64
#  258   p_Low_last_period316    float64
#  259   p_Close_last_period316  float64
#  260   p_Open_last_period315   float64
#  261   p_High_last_period315   float64
#  262   p_Low_last_period315    float64
#  263   p_Close_last_period315  float64
#  264   p_Open_last_period314   float64
#  265   p_High_last_period314   float64
#  266   p_Low_last_period314    float64
#  267   p_Close_last_period314  float64
#  268   p_Open_last_period313   float64
#  269   p_High_last_period313   float64
#  270   p_Low_last_period313    float64
#  271   p_Close_last_period313  float64
#  272   p_Open_last_period312   float64
#  273   p_High_last_period312   float64
#  274   p_Low_last_period312    float64
#  275   p_Close_last_period312  float64
#  276   p_Open_last_period311   float64
#  277   p_High_last_period311   float64
#  278   p_Low_last_period311    float64
#  279   p_Close_last_period311  float64
#  280   p_Open_last_period310   float64
#  281   p_High_last_period310   float64
#  282   p_Low_last_period310    float64
#  283   p_Close_last_period310  float64
#  284   p_Open_last_period309   float64
#  285   p_High_last_period309   float64
#  286   p_Low_last_period309    float64
#  287   p_Close_last_period309  float64
#  288   p_Open_last_period308   float64
#  289   p_High_last_period308   float64
#  290   p_Low_last_period308    float64
#  291   p_Close_last_period308  float64
#  292   p_Open_last_period307   float64
#  293   p_High_last_period307   float64
#  294   p_Low_last_period307    float64
#  295   p_Close_last_period307  float64
#  296   p_Open_last_period306   float64
#  297   p_High_last_period306   float64
#  298   p_Low_last_period306    float64
#  299   p_Close_last_period306  float64
#  300   p_Open_last_period305   float64
#  301   p_High_last_period305   float64
#  302   p_Low_last_period305    float64
#  303   p_Close_last_period305  float64
#  304   p_Open_last_period304   float64
#  305   p_High_last_period304   float64
#  306   p_Low_last_period304    float64
#  307   p_Close_last_period304  float64
#  308   p_Open_last_period303   float64
#  309   p_High_last_period303   float64
#  310   p_Low_last_period303    float64
#  311   p_Close_last_period303  float64
#  312   p_Open_last_period302   float64
#  313   p_High_last_period302   float64
#  314   p_Low_last_period302    float64
#  315   p_Close_last_period302  float64
#  316   p_Open_last_period301   float64
#  317   p_High_last_period301   float64
#  318   p_Low_last_period301    float64
#  319   p_Close_last_period301  float64
#  320   p_Open_last_period300   float64
#  321   p_High_last_period300   float64
#  322   p_Low_last_period300    float64
#  323   p_Close_last_period300  float64
#  324   p_Open_last_period299   float64
#  325   p_High_last_period299   float64
#  326   p_Low_last_period299    float64
#  327   p_Close_last_period299  float64
#  328   p_Open_last_period298   float64
#  329   p_High_last_period298   float64
#  330   p_Low_last_period298    float64
#  331   p_Close_last_period298  float64
#  332   p_Open_last_period297   float64
#  333   p_High_last_period297   float64
#  334   p_Low_last_period297    float64
#  335   p_Close_last_period297  float64
#  336   p_Open_last_period296   float64
#  337   p_High_last_period296   float64
#  338   p_Low_last_period296    float64
#  339   p_Close_last_period296  float64
#  340   p_Open_last_period295   float64
#  341   p_High_last_period295   float64
#  342   p_Low_last_period295    float64
#  343   p_Close_last_period295  float64
#  344   p_Open_last_period294   float64
#  345   p_High_last_period294   float64
#  346   p_Low_last_period294    float64
#  347   p_Close_last_period294  float64
#  348   p_Open_last_period293   float64
#  349   p_High_last_period293   float64
#  350   p_Low_last_period293    float64
#  351   p_Close_last_period293  float64
#  352   p_Open_last_period292   float64
#  353   p_High_last_period292   float64
#  354   p_Low_last_period292    float64
#  355   p_Close_last_period292  float64
#  356   p_Open_last_period291   float64
#  357   p_High_last_period291   float64
#  358   p_Low_last_period291    float64
#  359   p_Close_last_period291  float64
#  360   p_Open_last_period290   float64
#  361   p_High_last_period290   float64
#  362   p_Low_last_period290    float64
#  363   p_Close_last_period290  float64
#  364   p_Open_last_period289   float64
#  365   p_High_last_period289   float64
#  366   p_Low_last_period289    float64
#  367   p_Close_last_period289  float64
#  368   p_Open_last_period288   float64
#  369   p_High_last_period288   float64
#  370   p_Low_last_period288    float64
#  371   p_Close_last_period288  float64
#  372   p_Open_last_period287   float64
#  373   p_High_last_period287   float64
#  374   p_Low_last_period287    float64
#  375   p_Close_last_period287  float64
#  376   p_Open_last_period286   float64
#  377   p_High_last_period286   float64
#  378   p_Low_last_period286    float64
#  379   p_Close_last_period286  float64
#  380   p_Open_last_period285   float64
#  381   p_High_last_period285   float64
#  382   p_Low_last_period285    float64
#  383   p_Close_last_period285  float64
#  384   p_Open_last_period284   float64
#  385   p_High_last_period284   float64
#  386   p_Low_last_period284    float64
#  387   p_Close_last_period284  float64
#  388   p_Open_last_period283   float64
#  389   p_High_last_period283   float64
#  390   p_Low_last_period283    float64
#  391   p_Close_last_period283  float64
#  392   p_Open_last_period282   float64
#  393   p_High_last_period282   float64
#  394   p_Low_last_period282    float64
#  395   p_Close_last_period282  float64
#  396   p_Open_last_period281   float64
#  397   p_High_last_period281   float64
#  398   p_Low_last_period281    float64
#  399   p_Close_last_period281  float64
#  400   p_Open_last_period280   float64
#  401   p_High_last_period280   float64
#  402   p_Low_last_period280    float64
#  403   p_Close_last_period280  float64
#  404   p_Open_last_period279   float64
#  405   p_High_last_period279   float64
#  406   p_Low_last_period279    float64
#  407   p_Close_last_period279  float64
#  408   p_Open_last_period278   float64
#  409   p_High_last_period278   float64
#  410   p_Low_last_period278    float64
#  411   p_Close_last_period278  float64
#  412   p_Open_last_period277   float64
#  413   p_High_last_period277   float64
#  414   p_Low_last_period277    float64
#  415   p_Close_last_period277  float64
#  416   p_Open_last_period276   float64
#  417   p_High_last_period276   float64
#  418   p_Low_last_period276    float64
#  419   p_Close_last_period276  float64
#  420   p_Open_last_period275   float64
#  421   p_High_last_period275   float64
#  422   p_Low_last_period275    float64
#  423   p_Close_last_period275  float64
#  424   p_Open_last_period274   float64
#  425   p_High_last_period274   float64
#  426   p_Low_last_period274    float64
#  427   p_Close_last_period274  float64
#  428   p_Open_last_period273   float64
#  429   p_High_last_period273   float64
#  430   p_Low_last_period273    float64
#  431   p_Close_last_period273  float64
#  432   p_Open_last_period272   float64
#  433   p_High_last_period272   float64
#  434   p_Low_last_period272    float64
#  435   p_Close_last_period272  float64
#  436   p_Open_last_period271   float64
#  437   p_High_last_period271   float64
#  438   p_Low_last_period271    float64
#  439   p_Close_last_period271  float64
#  440   p_Open_last_period270   float64
#  441   p_High_last_period270   float64
#  442   p_Low_last_period270    float64
#  443   p_Close_last_period270  float64
#  444   p_Open_last_period269   float64
#  445   p_High_last_period269   float64
#  446   p_Low_last_period269    float64
#  447   p_Close_last_period269  float64
#  448   p_Open_last_period268   float64
#  449   p_High_last_period268   float64
#  450   p_Low_last_period268    float64
#  451   p_Close_last_period268  float64
#  452   p_Open_last_period267   float64
#  453   p_High_last_period267   float64
#  454   p_Low_last_period267    float64
#  455   p_Close_last_period267  float64
#  456   p_Open_last_period266   float64
#  457   p_High_last_period266   float64
#  458   p_Low_last_period266    float64
#  459   p_Close_last_period266  float64
#  460   p_Open_last_period265   float64
#  461   p_High_last_period265   float64
#  462   p_Low_last_period265    float64
#  463   p_Close_last_period265  float64
#  464   p_Open_last_period264   float64
#  465   p_High_last_period264   float64
#  466   p_Low_last_period264    float64
#  467   p_Close_last_period264  float64
#  468   p_Open_last_period263   float64
#  469   p_High_last_period263   float64
#  470   p_Low_last_period263    float64
#  471   p_Close_last_period263  float64
#  472   p_Open_last_period262   float64
#  473   p_High_last_period262   float64
#  474   p_Low_last_period262    float64
#  475   p_Close_last_period262  float64
#  476   p_Open_last_period261   float64
#  477   p_High_last_period261   float64
#  478   p_Low_last_period261    float64
#  479   p_Close_last_period261  float64
#  480   p_Open_last_period260   float64
#  481   p_High_last_period260   float64
#  482   p_Low_last_period260    float64
#  483   p_Close_last_period260  float64
#  484   p_Open_last_period259   float64
#  485   p_High_last_period259   float64
#  486   p_Low_last_period259    float64
#  487   p_Close_last_period259  float64
#  488   p_Open_last_period258   float64
#  489   p_High_last_period258   float64
#  490   p_Low_last_period258    float64
#  491   p_Close_last_period258  float64
#  492   p_Open_last_period257   float64
#  493   p_High_last_period257   float64
#  494   p_Low_last_period257    float64
#  495   p_Close_last_period257  float64
#  496   p_Open_last_period256   float64
#  497   p_High_last_period256   float64
#  498   p_Low_last_period256    float64
#  499   p_Close_last_period256  float64
#  500   p_Open_last_period255   float64
#  501   p_High_last_period255   float64
#  502   p_Low_last_period255    float64
#  503   p_Close_last_period255  float64
#  504   p_Open_last_period254   float64
#  505   p_High_last_period254   float64
#  506   p_Low_last_period254    float64
#  507   p_Close_last_period254  float64
#  508   p_Open_last_period253   float64
#  509   p_High_last_period253   float64
#  510   p_Low_last_period253    float64
#  511   p_Close_last_period253  float64
#  512   p_Open_last_period252   float64
#  513   p_High_last_period252   float64
#  514   p_Low_last_period252    float64
#  515   p_Close_last_period252  float64
#  516   p_Open_last_period251   float64
#  517   p_High_last_period251   float64
#  518   p_Low_last_period251    float64
#  519   p_Close_last_period251  float64
#  520   p_Open_last_period250   float64
#  521   p_High_last_period250   float64
#  522   p_Low_last_period250    float64
#  523   p_Close_last_period250  float64
#  524   p_Open_last_period249   float64
#  525   p_High_last_period249   float64
#  526   p_Low_last_period249    float64
#  527   p_Close_last_period249  float64
#  528   p_Open_last_period248   float64
#  529   p_High_last_period248   float64
#  530   p_Low_last_period248    float64
#  531   p_Close_last_period248  float64
#  532   p_Open_last_period247   float64
#  533   p_High_last_period247   float64
#  534   p_Low_last_period247    float64
#  535   p_Close_last_period247  float64
#  536   p_Open_last_period246   float64
#  537   p_High_last_period246   float64
#  538   p_Low_last_period246    float64
#  539   p_Close_last_period246  float64
#  540   p_Open_last_period245   float64
#  541   p_High_last_period245   float64
#  542   p_Low_last_period245    float64
#  543   p_Close_last_period245  float64
#  544   p_Open_last_period244   float64
#  545   p_High_last_period244   float64
#  546   p_Low_last_period244    float64
#  547   p_Close_last_period244  float64
#  548   p_Open_last_period243   float64
#  549   p_High_last_period243   float64
#  550   p_Low_last_period243    float64
#  551   p_Close_last_period243  float64
#  552   p_Open_last_period242   float64
#  553   p_High_last_period242   float64
#  554   p_Low_last_period242    float64
#  555   p_Close_last_period242  float64
#  556   p_Open_last_period241   float64
#  557   p_High_last_period241   float64
#  558   p_Low_last_period241    float64
#  559   p_Close_last_period241  float64
#  560   p_Open_last_period240   float64
#  561   p_High_last_period240   float64
#  562   p_Low_last_period240    float64
#  563   p_Close_last_period240  float64
#  564   p_Open_last_period239   float64
#  565   p_High_last_period239   float64
#  566   p_Low_last_period239    float64
#  567   p_Close_last_period239  float64
#  568   p_Open_last_period238   float64
#  569   p_High_last_period238   float64
#  570   p_Low_last_period238    float64
#  571   p_Close_last_period238  float64
#  572   p_Open_last_period237   float64
#  573   p_High_last_period237   float64
#  574   p_Low_last_period237    float64
#  575   p_Close_last_period237  float64
#  576   p_Open_last_period236   float64
#  577   p_High_last_period236   float64
#  578   p_Low_last_period236    float64
#  579   p_Close_last_period236  float64
#  580   p_Open_last_period235   float64
#  581   p_High_last_period235   float64
#  582   p_Low_last_period235    float64
#  583   p_Close_last_period235  float64
#  584   p_Open_last_period234   float64
#  585   p_High_last_period234   float64
#  586   p_Low_last_period234    float64
#  587   p_Close_last_period234  float64
#  588   p_Open_last_period233   float64
#  589   p_High_last_period233   float64
#  590   p_Low_last_period233    float64
#  591   p_Close_last_period233  float64
#  592   p_Open_last_period232   float64
#  593   p_High_last_period232   float64
#  594   p_Low_last_period232    float64
#  595   p_Close_last_period232  float64
#  596   p_Open_last_period231   float64
#  597   p_High_last_period231   float64
#  598   p_Low_last_period231    float64
#  599   p_Close_last_period231  float64
#  600   p_Open_last_period230   float64
#  601   p_High_last_period230   float64
#  602   p_Low_last_period230    float64
#  603   p_Close_last_period230  float64
#  604   p_Open_last_period229   float64
#  605   p_High_last_period229   float64
#  606   p_Low_last_period229    float64
#  607   p_Close_last_period229  float64
#  608   p_Open_last_period228   float64
#  609   p_High_last_period228   float64
#  610   p_Low_last_period228    float64
#  611   p_Close_last_period228  float64
#  612   p_Open_last_period227   float64
#  613   p_High_last_period227   float64
#  614   p_Low_last_period227    float64
#  615   p_Close_last_period227  float64
#  616   p_Open_last_period226   float64
#  617   p_High_last_period226   float64
#  618   p_Low_last_period226    float64
#  619   p_Close_last_period226  float64
#  620   p_Open_last_period225   float64
#  621   p_High_last_period225   float64
#  622   p_Low_last_period225    float64
#  623   p_Close_last_period225  float64
#  624   p_Open_last_period224   float64
#  625   p_High_last_period224   float64
#  626   p_Low_last_period224    float64
#  627   p_Close_last_period224  float64
#  628   p_Open_last_period223   float64
#  629   p_High_last_period223   float64
#  630   p_Low_last_period223    float64
#  631   p_Close_last_period223  float64
#  632   p_Open_last_period222   float64
#  633   p_High_last_period222   float64
#  634   p_Low_last_period222    float64
#  635   p_Close_last_period222  float64
#  636   p_Open_last_period221   float64
#  637   p_High_last_period221   float64
#  638   p_Low_last_period221    float64
#  639   p_Close_last_period221  float64
#  640   p_Open_last_period220   float64
#  641   p_High_last_period220   float64
#  642   p_Low_last_period220    float64
#  643   p_Close_last_period220  float64
#  644   p_Open_last_period219   float64
#  645   p_High_last_period219   float64
#  646   p_Low_last_period219    float64
#  647   p_Close_last_period219  float64
#  648   p_Open_last_period218   float64
#  649   p_High_last_period218   float64
#  650   p_Low_last_period218    float64
#  651   p_Close_last_period218  float64
#  652   p_Open_last_period217   float64
#  653   p_High_last_period217   float64
#  654   p_Low_last_period217    float64
#  655   p_Close_last_period217  float64
#  656   p_Open_last_period216   float64
#  657   p_High_last_period216   float64
#  658   p_Low_last_period216    float64
#  659   p_Close_last_period216  float64
#  660   p_Open_last_period215   float64
#  661   p_High_last_period215   float64
#  662   p_Low_last_period215    float64
#  663   p_Close_last_period215  float64
#  664   p_Open_last_period214   float64
#  665   p_High_last_period214   float64
#  666   p_Low_last_period214    float64
#  667   p_Close_last_period214  float64
#  668   p_Open_last_period213   float64
#  669   p_High_last_period213   float64
#  670   p_Low_last_period213    float64
#  671   p_Close_last_period213  float64
#  672   p_Open_last_period212   float64
#  673   p_High_last_period212   float64
#  674   p_Low_last_period212    float64
#  675   p_Close_last_period212  float64
#  676   p_Open_last_period211   float64
#  677   p_High_last_period211   float64
#  678   p_Low_last_period211    float64
#  679   p_Close_last_period211  float64
#  680   p_Open_last_period210   float64
#  681   p_High_last_period210   float64
#  682   p_Low_last_period210    float64
#  683   p_Close_last_period210  float64
#  684   p_Open_last_period209   float64
#  685   p_High_last_period209   float64
#  686   p_Low_last_period209    float64
#  687   p_Close_last_period209  float64
#  688   p_Open_last_period208   float64
#  689   p_High_last_period208   float64
#  690   p_Low_last_period208    float64
#  691   p_Close_last_period208  float64
#  692   p_Open_last_period207   float64
#  693   p_High_last_period207   float64
#  694   p_Low_last_period207    float64
#  695   p_Close_last_period207  float64
#  696   p_Open_last_period206   float64
#  697   p_High_last_period206   float64
#  698   p_Low_last_period206    float64
#  699   p_Close_last_period206  float64
#  700   p_Open_last_period205   float64
#  701   p_High_last_period205   float64
#  702   p_Low_last_period205    float64
#  703   p_Close_last_period205  float64
#  704   p_Open_last_period204   float64
#  705   p_High_last_period204   float64
#  706   p_Low_last_period204    float64
#  707   p_Close_last_period204  float64
#  708   p_Open_last_period203   float64
#  709   p_High_last_period203   float64
#  710   p_Low_last_period203    float64
#  711   p_Close_last_period203  float64
#  712   p_Open_last_period202   float64
#  713   p_High_last_period202   float64
#  714   p_Low_last_period202    float64
#  715   p_Close_last_period202  float64
#  716   p_Open_last_period201   float64
#  717   p_High_last_period201   float64
#  718   p_Low_last_period201    float64
#  719   p_Close_last_period201  float64
#  720   p_Open_last_period200   float64
#  721   p_High_last_period200   float64
#  722   p_Low_last_period200    float64
#  723   p_Close_last_period200  float64
#  724   p_Open_last_period199   float64
#  725   p_High_last_period199   float64
#  726   p_Low_last_period199    float64
#  727   p_Close_last_period199  float64
#  728   p_Open_last_period198   float64
#  729   p_High_last_period198   float64
#  730   p_Low_last_period198    float64
#  731   p_Close_last_period198  float64
#  732   p_Open_last_period197   float64
#  733   p_High_last_period197   float64
#  734   p_Low_last_period197    float64
#  735   p_Close_last_period197  float64
#  736   p_Open_last_period196   float64
#  737   p_High_last_period196   float64
#  738   p_Low_last_period196    float64
#  739   p_Close_last_period196  float64
#  740   p_Open_last_period195   float64
#  741   p_High_last_period195   float64
#  742   p_Low_last_period195    float64
#  743   p_Close_last_period195  float64
#  744   p_Open_last_period194   float64
#  745   p_High_last_period194   float64
#  746   p_Low_last_period194    float64
#  747   p_Close_last_period194  float64
#  748   p_Open_last_period193   float64
#  749   p_High_last_period193   float64
#  750   p_Low_last_period193    float64
#  751   p_Close_last_period193  float64
#  752   p_Open_last_period192   float64
#  753   p_High_last_period192   float64
#  754   p_Low_last_period192    float64
#  755   p_Close_last_period192  float64
#  756   p_Open_last_period191   float64
#  757   p_High_last_period191   float64
#  758   p_Low_last_period191    float64
#  759   p_Close_last_period191  float64
#  760   p_Open_last_period190   float64
#  761   p_High_last_period190   float64
#  762   p_Low_last_period190    float64
#  763   p_Close_last_period190  float64
#  764   p_Open_last_period189   float64
#  765   p_High_last_period189   float64
#  766   p_Low_last_period189    float64
#  767   p_Close_last_period189  float64
#  768   p_Open_last_period188   float64
#  769   p_High_last_period188   float64
#  770   p_Low_last_period188    float64
#  771   p_Close_last_period188  float64
#  772   p_Open_last_period187   float64
#  773   p_High_last_period187   float64
#  774   p_Low_last_period187    float64
#  775   p_Close_last_period187  float64
#  776   p_Open_last_period186   float64
#  777   p_High_last_period186   float64
#  778   p_Low_last_period186    float64
#  779   p_Close_last_period186  float64
#  780   p_Open_last_period185   float64
#  781   p_High_last_period185   float64
#  782   p_Low_last_period185    float64
#  783   p_Close_last_period185  float64
#  784   p_Open_last_period184   float64
#  785   p_High_last_period184   float64
#  786   p_Low_last_period184    float64
#  787   p_Close_last_period184  float64
#  788   p_Open_last_period183   float64
#  789   p_High_last_period183   float64
#  790   p_Low_last_period183    float64
#  791   p_Close_last_period183  float64
#  792   p_Open_last_period182   float64
#  793   p_High_last_period182   float64
#  794   p_Low_last_period182    float64
#  795   p_Close_last_period182  float64
#  796   p_Open_last_period181   float64
#  797   p_High_last_period181   float64
#  798   p_Low_last_period181    float64
#  799   p_Close_last_period181  float64
#  800   p_Open_last_period180   float64
#  801   p_High_last_period180   float64
#  802   p_Low_last_period180    float64
#  803   p_Close_last_period180  float64
#  804   p_Open_last_period179   float64
#  805   p_High_last_period179   float64
#  806   p_Low_last_period179    float64
#  807   p_Close_last_period179  float64
#  808   p_Open_last_period178   float64
#  809   p_High_last_period178   float64
#  810   p_Low_last_period178    float64
#  811   p_Close_last_period178  float64
#  812   p_Open_last_period177   float64
#  813   p_High_last_period177   float64
#  814   p_Low_last_period177    float64
#  815   p_Close_last_period177  float64
#  816   p_Open_last_period176   float64
#  817   p_High_last_period176   float64
#  818   p_Low_last_period176    float64
#  819   p_Close_last_period176  float64
#  820   p_Open_last_period175   float64
#  821   p_High_last_period175   float64
#  822   p_Low_last_period175    float64
#  823   p_Close_last_period175  float64
#  824   p_Open_last_period174   float64
#  825   p_High_last_period174   float64
#  826   p_Low_last_period174    float64
#  827   p_Close_last_period174  float64
#  828   p_Open_last_period173   float64
#  829   p_High_last_period173   float64
#  830   p_Low_last_period173    float64
#  831   p_Close_last_period173  float64
#  832   p_Open_last_period172   float64
#  833   p_High_last_period172   float64
#  834   p_Low_last_period172    float64
#  835   p_Close_last_period172  float64
#  836   p_Open_last_period171   float64
#  837   p_High_last_period171   float64
#  838   p_Low_last_period171    float64
#  839   p_Close_last_period171  float64
#  840   p_Open_last_period170   float64
#  841   p_High_last_period170   float64
#  842   p_Low_last_period170    float64
#  843   p_Close_last_period170  float64
#  844   p_Open_last_period169   float64
#  845   p_High_last_period169   float64
#  846   p_Low_last_period169    float64
#  847   p_Close_last_period169  float64
#  848   p_Open_last_period168   float64
#  849   p_High_last_period168   float64
#  850   p_Low_last_period168    float64
#  851   p_Close_last_period168  float64
#  852   p_Open_last_period167   float64
#  853   p_High_last_period167   float64
#  854   p_Low_last_period167    float64
#  855   p_Close_last_period167  float64
#  856   p_Open_last_period166   float64
#  857   p_High_last_period166   float64
#  858   p_Low_last_period166    float64
#  859   p_Close_last_period166  float64
#  860   p_Open_last_period165   float64
#  861   p_High_last_period165   float64
#  862   p_Low_last_period165    float64
#  863   p_Close_last_period165  float64
#  864   p_Open_last_period164   float64
#  865   p_High_last_period164   float64
#  866   p_Low_last_period164    float64
#  867   p_Close_last_period164  float64
#  868   p_Open_last_period163   float64
#  869   p_High_last_period163   float64
#  870   p_Low_last_period163    float64
#  871   p_Close_last_period163  float64
#  872   p_Open_last_period162   float64
#  873   p_High_last_period162   float64
#  874   p_Low_last_period162    float64
#  875   p_Close_last_period162  float64
#  876   p_Open_last_period161   float64
#  877   p_High_last_period161   float64
#  878   p_Low_last_period161    float64
#  879   p_Close_last_period161  float64
#  880   p_Open_last_period160   float64
#  881   p_High_last_period160   float64
#  882   p_Low_last_period160    float64
#  883   p_Close_last_period160  float64
#  884   p_Open_last_period159   float64
#  885   p_High_last_period159   float64
#  886   p_Low_last_period159    float64
#  887   p_Close_last_period159  float64
#  888   p_Open_last_period158   float64
#  889   p_High_last_period158   float64
#  890   p_Low_last_period158    float64
#  891   p_Close_last_period158  float64
#  892   p_Open_last_period157   float64
#  893   p_High_last_period157   float64
#  894   p_Low_last_period157    float64
#  895   p_Close_last_period157  float64
#  896   p_Open_last_period156   float64
#  897   p_High_last_period156   float64
#  898   p_Low_last_period156    float64
#  899   p_Close_last_period156  float64
#  900   p_Open_last_period155   float64
#  901   p_High_last_period155   float64
#  902   p_Low_last_period155    float64
#  903   p_Close_last_period155  float64
#  904   p_Open_last_period154   float64
#  905   p_High_last_period154   float64
#  906   p_Low_last_period154    float64
#  907   p_Close_last_period154  float64
#  908   p_Open_last_period153   float64
#  909   p_High_last_period153   float64
#  910   p_Low_last_period153    float64
#  911   p_Close_last_period153  float64
#  912   p_Open_last_period152   float64
#  913   p_High_last_period152   float64
#  914   p_Low_last_period152    float64
#  915   p_Close_last_period152  float64
#  916   p_Open_last_period151   float64
#  917   p_High_last_period151   float64
#  918   p_Low_last_period151    float64
#  919   p_Close_last_period151  float64
#  920   p_Open_last_period150   float64
#  921   p_High_last_period150   float64
#  922   p_Low_last_period150    float64
#  923   p_Close_last_period150  float64
#  924   p_Open_last_period149   float64
#  925   p_High_last_period149   float64
#  926   p_Low_last_period149    float64
#  927   p_Close_last_period149  float64
#  928   p_Open_last_period148   float64
#  929   p_High_last_period148   float64
#  930   p_Low_last_period148    float64
#  931   p_Close_last_period148  float64
#  932   p_Open_last_period147   float64
#  933   p_High_last_period147   float64
#  934   p_Low_last_period147    float64
#  935   p_Close_last_period147  float64
#  936   p_Open_last_period146   float64
#  937   p_High_last_period146   float64
#  938   p_Low_last_period146    float64
#  939   p_Close_last_period146  float64
#  940   p_Open_last_period145   float64
#  941   p_High_last_period145   float64
#  942   p_Low_last_period145    float64
#  943   p_Close_last_period145  float64
#  944   p_Open_last_period144   float64
#  945   p_High_last_period144   float64
#  946   p_Low_last_period144    float64
#  947   p_Close_last_period144  float64
#  948   p_Open_last_period143   float64
#  949   p_High_last_period143   float64
#  950   p_Low_last_period143    float64
#  951   p_Close_last_period143  float64
#  952   p_Open_last_period142   float64
#  953   p_High_last_period142   float64
#  954   p_Low_last_period142    float64
#  955   p_Close_last_period142  float64
#  956   p_Open_last_period141   float64
#  957   p_High_last_period141   float64
#  958   p_Low_last_period141    float64
#  959   p_Close_last_period141  float64
#  960   p_Open_last_period140   float64
#  961   p_High_last_period140   float64
#  962   p_Low_last_period140    float64
#  963   p_Close_last_period140  float64
#  964   p_Open_last_period139   float64
#  965   p_High_last_period139   float64
#  966   p_Low_last_period139    float64
#  967   p_Close_last_period139  float64
#  968   p_Open_last_period138   float64
#  969   p_High_last_period138   float64
#  970   p_Low_last_period138    float64
#  971   p_Close_last_period138  float64
#  972   p_Open_last_period137   float64
#  973   p_High_last_period137   float64
#  974   p_Low_last_period137    float64
#  975   p_Close_last_period137  float64
#  976   p_Open_last_period136   float64
#  977   p_High_last_period136   float64
#  978   p_Low_last_period136    float64
#  979   p_Close_last_period136  float64
#  980   p_Open_last_period135   float64
#  981   p_High_last_period135   float64
#  982   p_Low_last_period135    float64
#  983   p_Close_last_period135  float64
#  984   p_Open_last_period134   float64
#  985   p_High_last_period134   float64
#  986   p_Low_last_period134    float64
#  987   p_Close_last_period134  float64
#  988   p_Open_last_period133   float64
#  989   p_High_last_period133   float64
#  990   p_Low_last_period133    float64
#  991   p_Close_last_period133  float64
#  992   p_Open_last_period132   float64
#  993   p_High_last_period132   float64
#  994   p_Low_last_period132    float64
#  995   p_Close_last_period132  float64
#  996   p_Open_last_period131   float64
#  997   p_High_last_period131   float64
#  998   p_Low_last_period131    float64
#  999   p_Close_last_period131  float64
#  1000  p_Open_last_period130   float64
#  1001  p_High_last_period130   float64
#  1002  p_Low_last_period130    float64
#  1003  p_Close_last_period130  float64
#  1004  p_Open_last_period129   float64
#  1005  p_High_last_period129   float64
#  1006  p_Low_last_period129    float64
#  1007  p_Close_last_period129  float64
#  1008  p_Open_last_period128   float64
#  1009  p_High_last_period128   float64
#  1010  p_Low_last_period128    float64
#  1011  p_Close_last_period128  float64
#  1012  p_Open_last_period127   float64
#  1013  p_High_last_period127   float64
#  1014  p_Low_last_period127    float64
#  1015  p_Close_last_period127  float64
#  1016  p_Open_last_period126   float64
#  1017  p_High_last_period126   float64
#  1018  p_Low_last_period126    float64
#  1019  p_Close_last_period126  float64
#  1020  p_Open_last_period125   float64
#  1021  p_High_last_period125   float64
#  1022  p_Low_last_period125    float64
#  1023  p_Close_last_period125  float64
#  1024  p_Open_last_period124   float64
#  1025  p_High_last_period124   float64
#  1026  p_Low_last_period124    float64
#  1027  p_Close_last_period124  float64
#  1028  p_Open_last_period123   float64
#  1029  p_High_last_period123   float64
#  1030  p_Low_last_period123    float64
#  1031  p_Close_last_period123  float64
#  1032  p_Open_last_period122   float64
#  1033  p_High_last_period122   float64
#  1034  p_Low_last_period122    float64
#  1035  p_Close_last_period122  float64
#  1036  p_Open_last_period121   float64
#  1037  p_High_last_period121   float64
#  1038  p_Low_last_period121    float64
#  1039  p_Close_last_period121  float64
#  1040  p_Open_last_period120   float64
#  1041  p_High_last_period120   float64
#  1042  p_Low_last_period120    float64
#  1043  p_Close_last_period120  float64
#  1044  p_Open_last_period119   float64
#  1045  p_High_last_period119   float64
#  1046  p_Low_last_period119    float64
#  1047  p_Close_last_period119  float64
#  1048  p_Open_last_period118   float64
#  1049  p_High_last_period118   float64
#  1050  p_Low_last_period118    float64
#  1051  p_Close_last_period118  float64
#  1052  p_Open_last_period117   float64
#  1053  p_High_last_period117   float64
#  1054  p_Low_last_period117    float64
#  1055  p_Close_last_period117  float64
#  1056  p_Open_last_period116   float64
#  1057  p_High_last_period116   float64
#  1058  p_Low_last_period116    float64
#  1059  p_Close_last_period116  float64
#  1060  p_Open_last_period115   float64
#  1061  p_High_last_period115   float64
#  1062  p_Low_last_period115    float64
#  1063  p_Close_last_period115  float64
#  1064  p_Open_last_period114   float64
#  1065  p_High_last_period114   float64
#  1066  p_Low_last_period1014   float64
#  1067  p_Close_last_period114  float64
#  1068  p_Open_last_period113   float64
#  1069  p_High_last_period113   float64
#  1070  p_Low_last_period113    float64
#  1071  p_Close_last_period113  float64
#  1072  p_Open_last_period112   float64
#  1073  p_High_last_period112   float64
#  1074  p_Low_last_period112    float64
#  1075  p_Close_last_period112  float64
#  1076  p_Open_last_period111   float64
#  1077  p_High_last_period111   float64
#  1078  p_Low_last_period111    float64
#  1079  p_Close_last_period111  float64
#  1080  p_Open_last_period110   float64
#  1081  p_High_last_period110   float64
#  1082  p_Low_last_period110    float64
#  1083  p_Close_last_period110  float64
#  1084  p_Open_last_period109   float64
#  1085  p_High_last_period109   float64
#  1086  p_Low_last_period109    float64
#  1087  p_Close_last_period109  float64
#  1088  p_Open_last_period108   float64
#  1089  p_High_last_period108   float64
#  1090  p_Low_last_period108    float64
#  1091  p_Close_last_period108  float64
#  1092  p_Open_last_period107   float64
#  1093  p_High_last_period107   float64
#  1094  p_Low_last_period107    float64
#  1095  p_Close_last_period107  float64
#  1096  p_Open_last_period106   float64
#  1097  p_High_last_period106   float64
#  1098  p_Low_last_period106    float64
#  1099  p_Close_last_period106  float64
#  1100  p_Open_last_period105   float64
#  1101  p_High_last_period105   float64
#  1102  p_Low_last_period105    float64
#  1103  p_Close_last_period105  float64
#  1104  p_Open_last_period104   float64
#  1105  p_High_last_period104   float64
#  1106  p_Low_last_period104    float64
#  1107  p_Close_last_period104  float64
#  1108  p_Open_last_period103   float64
#  1109  p_High_last_period103   float64
#  1110  p_Low_last_period103    float64
#  1111  p_Close_last_period103  float64
#  1112  p_Open_last_period102   float64
#  1113  p_High_last_period102   float64
#  1114  p_Low_last_period102    float64
#  1115  p_Close_last_period102  float64
#  1116  p_Open_last_period101   float64
#  1117  p_High_last_period101   float64
#  1118  p_Low_last_period101    float64
#  1119  p_Close_last_period101  float64
#  1120  p_Open_last_period100   float64
#  1121  p_High_last_period100   float64
#  1122  p_Low_last_period100    float64
#  1123  p_Close_last_period100  float64
#  1124  p_Open_last_period99    float64
#  1125  p_High_last_period99    float64
#  1126  p_Low_last_period99     float64
#  1127  p_Close_last_period99   float64
#  1128  p_Open_last_period98    float64
#  1129  p_High_last_period98    float64
#  1130  p_Low_last_period98     float64
#  1131  p_Close_last_period98   float64
#  1132  p_Open_last_period97    float64
#  1133  p_High_last_period97    float64
#  1134  p_Low_last_period97     float64
#  1135  p_Close_last_period97   float64
#  1136  p_Open_last_period96    float64
#  1137  p_High_last_period96    float64
#  1138  p_Low_last_period96     float64
#  1139  p_Close_last_period96   float64
#  1140  p_Open_last_period95    float64
#  1141  p_High_last_period95    float64
#  1142  p_Low_last_period95     float64
#  1143  p_Close_last_period95   float64
#  1144  p_Open_last_period94    float64
#  1145  p_High_last_period94    float64
#  1146  p_Low_last_period94     float64
#  1147  p_Close_last_period94   float64
#  1148  p_Open_last_period93    float64
#  1149  p_High_last_period93    float64
#  1150  p_Low_last_period93     float64
#  1151  p_Close_last_period93   float64
#  1152  p_Open_last_period92    float64
#  1153  p_High_last_period92    float64
#  1154  p_Low_last_period92     float64
#  1155  p_Close_last_period92   float64
#  1156  p_Open_last_period91    float64
#  1157  p_High_last_period91    float64
#  1158  p_Low_last_period91     float64
#  1159  p_Close_last_period91   float64
#  1160  p_Open_last_period90    float64
#  1161  p_High_last_period90    float64
#  1162  p_Low_last_period90     float64
#  1163  p_Close_last_period90   float64
#  1164  p_Open_last_period89    float64
#  1165  p_High_last_period89    float64
#  1166  p_Low_last_period89     float64
#  1167  p_Close_last_period89   float64
#  1168  p_Open_last_period88    float64
#  1169  p_High_last_period88    float64
#  1170  p_Low_last_period88     float64
#  1171  p_Close_last_period88   float64
#  1172  p_Open_last_period87    float64
#  1173  p_High_last_period87    float64
#  1174  p_Low_last_period87     float64
#  1175  p_Close_last_period87   float64
#  1176  p_Open_last_period86    float64
#  1177  p_High_last_period86    float64
#  1178  p_Low_last_period86     float64
#  1179  p_Close_last_period86   float64
#  1180  p_Open_last_period85    float64
#  1181  p_High_last_period85    float64
#  1182  p_Low_last_period85     float64
#  1183  p_Close_last_period85   float64
#  1184  p_Open_last_period84    float64
#  1185  p_High_last_period84    float64
#  1186  p_Low_last_period84     float64
#  1187  p_Close_last_period84   float64
#  1188  p_Open_last_period83    float64
#  1189  p_High_last_period83    float64
#  1190  p_Low_last_period83     float64
#  1191  p_Close_last_period83   float64
#  1192  p_Open_last_period82    float64
#  1193  p_High_last_period82    float64
#  1194  p_Low_last_period82     float64
#  1195  p_Close_last_period82   float64
#  1196  p_Open_last_period81    float64
#  1197  p_High_last_period81    float64
#  1198  p_Low_last_period81     float64
#  1199  p_Close_last_period81   float64
#  1200  p_Open_last_period80    float64
#  1201  p_High_last_period80    float64
#  1202  p_Low_last_period80     float64
#  1203  p_Close_last_period80   float64
#  1204  p_Open_last_period79    float64
#  1205  p_High_last_period79    float64
#  1206  p_Low_last_period79     float64
#  1207  p_Close_last_period79   float64
#  1208  p_Open_last_period78    float64
#  1209  p_High_last_period78    float64
#  1210  p_Low_last_period78     float64
#  1211  p_Close_last_period78   float64
#  1212  p_Open_last_period77    float64
#  1213  p_High_last_period77    float64
#  1214  p_Low_last_period77     float64
#  1215  p_Close_last_period77   float64
#  1216  p_Open_last_period76    float64
#  1217  p_High_last_period76    float64
#  1218  p_Low_last_period76     float64
#  1219  p_Close_last_period76   float64
#  1220  p_Open_last_period75    float64
#  1221  p_High_last_period75    float64
#  1222  p_Low_last_period75     float64
#  1223  p_Close_last_period75   float64
#  1224  p_Open_last_period74    float64
#  1225  p_High_last_period74    float64
#  1226  p_Low_last_period74     float64
#  1227  p_Close_last_period74   float64
#  1228  p_Open_last_period73    float64
#  1229  p_High_last_period73    float64
#  1230  p_Low_last_period73     float64
#  1231  p_Close_last_period73   float64
#  1232  p_Open_last_period72    float64
#  1233  p_High_last_period72    float64
#  1234  p_Low_last_period72     float64
#  1235  p_Close_last_period72   float64
#  1236  p_Open_last_period71    float64
#  1237  p_High_last_period71    float64
#  1238  p_Low_last_period71     float64
#  1239  p_Close_last_period71   float64
#  1240  p_Open_last_period70    float64
#  1241  p_High_last_period70    float64
#  1242  p_Low_last_period70     float64
#  1243  p_Close_last_period70   float64
#  1244  p_Open_last_period69    float64
#  1245  p_High_last_period69    float64
#  1246  p_Low_last_period69     float64
#  1247  p_Close_last_period69   float64
#  1248  p_Open_last_period68    float64
#  1249  p_High_last_period68    float64
#  1250  p_Low_last_period68     float64
#  1251  p_Close_last_period68   float64
#  1252  p_Open_last_period67    float64
#  1253  p_High_last_period67    float64
#  1254  p_Low_last_period67     float64
#  1255  p_Close_last_period67   float64
#  1256  p_Open_last_period66    float64
#  1257  p_High_last_period66    float64
#  1258  p_Low_last_period66     float64
#  1259  p_Close_last_period66   float64
#  1260  p_Open_last_period65    float64
#  1261  p_High_last_period65    float64
#  1262  p_Low_last_period65     float64
#  1263  p_Close_last_period65   float64
#  1264  p_Open_last_period64    float64
#  1265  p_High_last_period64    float64
#  1266  p_Low_last_period64     float64
#  1267  p_Close_last_period64   float64
#  1268  p_Open_last_period63    float64
#  1269  p_High_last_period63    float64
#  1270  p_Low_last_period63     float64
#  1271  p_Close_last_period63   float64
#  1272  p_Open_last_period62    float64
#  1273  p_High_last_period62    float64
#  1274  p_Low_last_period62     float64
#  1275  p_Close_last_period62   float64
#  1276  p_Open_last_period61    float64
#  1277  p_High_last_period61    float64
#  1278  p_Low_last_period61     float64
#  1279  p_Close_last_period61   float64
#  1280  p_Open_last_period60    float64
#  1281  p_High_last_period60    float64
#  1282  p_Low_last_period60     float64
#  1283  p_Close_last_period60   float64
#  1284  p_Open_last_period59    float64
#  1285  p_High_last_period59    float64
#  1286  p_Low_last_period59     float64
#  1287  p_Close_last_period59   float64
#  1288  p_Open_last_period58    float64
#  1289  p_High_last_period58    float64
#  1290  p_Low_last_period58     float64
#  1291  p_Close_last_period58   float64
#  1292  p_Open_last_period57    float64
#  1293  p_High_last_period57    float64
#  1294  p_Low_last_period57     float64
#  1295  p_Close_last_period57   float64
#  1296  p_Open_last_period56    float64
#  1297  p_High_last_period56    float64
#  1298  p_Low_last_period56     float64
#  1299  p_Close_last_period56   float64
#  1300  p_Open_last_period55    float64
#  1301  p_High_last_period55    float64
#  1302  p_Low_last_period55     float64
#  1303  p_Close_last_period55   float64
#  1304  p_Open_last_period54    float64
#  1305  p_High_last_period54    float64
#  1306  p_Low_last_period54     float64
#  1307  p_Close_last_period54   float64
#  1308  p_Open_last_period53    float64
#  1309  p_High_last_period53    float64
#  1310  p_Low_last_period53     float64
#  1311  p_Close_last_period53   float64
#  1312  p_Open_last_period52    float64
#  1313  p_High_last_period52    float64
#  1314  p_Low_last_period52     float64
#  1315  p_Close_last_period52   float64
#  1316  p_Open_last_period51    float64
#  1317  p_High_last_period51    float64
#  1318  p_Low_last_period51     float64
#  1319  p_Close_last_period51   float64
#  1320  p_Open_last_period50    float64
#  1321  p_High_last_period50    float64
#  1322  p_Low_last_period50     float64
#  1323  p_Close_last_period50   float64
#  1324  p_Open_last_period49    float64
#  1325  p_High_last_period49    float64
#  1326  p_Low_last_period49     float64
#  1327  p_Close_last_period49   float64
#  1328  p_Open_last_period48    float64
#  1329  p_High_last_period48    float64
#  1330  p_Low_last_period48     float64
#  1331  p_Close_last_period48   float64
#  1332  p_Open_last_period47    float64
#  1333  p_High_last_period47    float64
#  1334  p_Low_last_period47     float64
#  1335  p_Close_last_period47   float64
#  1336  p_Open_last_period46    float64
#  1337  p_High_last_period46    float64
#  1338  p_Low_last_period46     float64
#  1339  p_Close_last_period46   float64
#  1340  p_Open_last_period45    float64
#  1341  p_High_last_period45    float64
#  1342  p_Low_last_period45     float64
#  1343  p_Close_last_period45   float64
#  1344  p_Open_last_period44    float64
#  1345  p_High_last_period44    float64
#  1346  p_Low_last_period44     float64
#  1347  p_Close_last_period44   float64
#  1348  p_Open_last_period43    float64
#  1349  p_High_last_period43    float64
#  1350  p_Low_last_period43     float64
#  1351  p_Close_last_period43   float64
#  1352  p_Open_last_period42    float64
#  1353  p_High_last_period42    float64
#  1354  p_Low_last_period42     float64
#  1355  p_Close_last_period42   float64
#  1356  p_Open_last_period41    float64
#  1357  p_High_last_period41    float64
#  1358  p_Low_last_period41     float64
#  1359  p_Close_last_period41   float64
#  1360  p_Open_last_period40    float64
#  1361  p_High_last_period40    float64
#  1362  p_Low_last_period40     float64
#  1363  p_Close_last_period40   float64
#  1364  p_Open_last_period39    float64
#  1365  p_High_last_period39    float64
#  1366  p_Low_last_period39     float64
#  1367  p_Close_last_period39   float64
#  1368  p_Open_last_period38    float64
#  1369  p_High_last_period38    float64
#  1370  p_Low_last_period38     float64
#  1371  p_Close_last_period38   float64
#  1372  p_Open_last_period37    float64
#  1373  p_High_last_period37    float64
#  1374  p_Low_last_period37     float64
#  1375  p_Close_last_period37   float64
#  1376  p_Open_last_period36    float64
#  1377  p_High_last_period36    float64
#  1378  p_Low_last_period36     float64
#  1379  p_Close_last_period36   float64
#  1380  p_Open_last_period35    float64
#  1381  p_High_last_period35    float64
#  1382  p_Low_last_period35     float64
#  1383  p_Close_last_period35   float64
#  1384  p_Open_last_period34    float64
#  1385  p_High_last_period34    float64
#  1386  p_Low_last_period34     float64
#  1387  p_Close_last_period34   float64
#  1388  p_Open_last_period33    float64
#  1389  p_High_last_period33    float64
#  1390  p_Low_last_period33     float64
#  1391  p_Close_last_period33   float64
#  1392  p_Open_last_period32    float64
#  1393  p_High_last_period32    float64
#  1394  p_Low_last_period32     float64
#  1395  p_Close_last_period32   float64
#  1396  p_Open_last_period31    float64
#  1397  p_High_last_period31    float64
#  1398  p_Low_last_period31     float64
#  1399  p_Close_last_period31   float64
#  1400  p_Open_last_period30    float64
#  1401  p_High_last_period30    float64
#  1402  p_Low_last_period30     float64
#  1403  p_Close_last_period30   float64
#  1404  p_Open_last_period29    float64
#  1405  p_High_last_period29    float64
#  1406  p_Low_last_period29     float64
#  1407  p_Close_last_period29   float64
#  1408  p_Open_last_period28    float64
#  1409  p_High_last_period28    float64
#  1410  p_Low_last_period28     float64
#  1411  p_Close_last_period28   float64
#  1412  p_Open_last_period27    float64
#  1413  p_High_last_period27    float64
#  1414  p_Low_last_period27     float64
#  1415  p_Close_last_period27   float64
#  1416  p_Open_last_period26    float64
#  1417  p_High_last_period26    float64
#  1418  p_Low_last_period26     float64
#  1419  p_Close_last_period26   float64
#  1420  p_Open_last_period25    float64
#  1421  p_High_last_period25    float64
#  1422  p_Low_last_period25     float64
#  1423  p_Close_last_period25   float64
#  1424  p_Open_last_period24    float64
#  1425  p_High_last_period24    float64
#  1426  p_Low_last_period24     float64
#  1427  p_Close_last_period24   float64
#  1428  p_Open_last_period23    float64
#  1429  p_High_last_period23    float64
#  1430  p_Low_last_period23     float64
#  1431  p_Close_last_period23   float64
#  1432  p_Open_last_period22    float64
#  1433  p_High_last_period22    float64
#  1434  p_Low_last_period22     float64
#  1435  p_Close_last_period22   float64
#  1436  p_Open_last_period21    float64
#  1437  p_High_last_period21    float64
#  1438  p_Low_last_period21     float64
#  1439  p_Close_last_period21   float64
#  1440  p_Open_last_period20    float64
#  1441  p_High_last_period20    float64
#  1442  p_Low_last_period20     float64
#  1443  p_Close_last_period20   float64
#  1444  p_Open_last_period19    float64
#  1445  p_High_last_period19    float64
#  1446  p_Low_last_period19     float64
#  1447  p_Close_last_period19   float64
#  1448  p_Open_last_period18    float64
#  1449  p_High_last_period18    float64
#  1450  p_Low_last_period18     float64
#  1451  p_Close_last_period18   float64
#  1452  p_Open_last_period17    float64
#  1453  p_High_last_period17    float64
#  1454  p_Low_last_period17     float64
#  1455  p_Close_last_period17   float64
#  1456  p_Open_last_period16    float64
#  1457  p_High_last_period16    float64
#  1458  p_Low_last_period16     float64
#  1459  p_Close_last_period16   float64
#  1460  p_Open_last_period15    float64
#  1461  p_High_last_period15    float64
#  1462  p_Low_last_period15     float64
#  1463  p_Close_last_period15   float64
#  1464  p_Open_last_period14    float64
#  1465  p_High_last_period14    float64
#  1466  p_Low_last_period14     float64
#  1467  p_Close_last_period14   float64
#  1468  p_Open_last_period13    float64
#  1469  p_High_last_period13    float64
#  1470  p_Low_last_period13     float64
#  1471  p_Close_last_period13   float64
#  1472  p_Open_last_period12    float64
#  1473  p_High_last_period12    float64
#  1474  p_Low_last_period12     float64
#  1475  p_Close_last_period12   float64
#  1476  p_Open_last_period11    float64
#  1477  p_High_last_period11    float64
#  1478  p_Low_last_period11     float64
#  1479  p_Close_last_period11   float64
#  1480  p_Open_last_period10    float64
#  1481  p_High_last_period10    float64
#  1482  p_Low_last_period10     float64
#  1483  p_Close_last_period10   float64
#  1484  p_Open_last_period9     float64
#  1485  p_High_last_period9     float64
#  1486  p_Low_last_period9      float64
#  1487  p_Close_last_period9    float64
#  1488  p_Open_last_period8     float64
#  1489  p_High_last_period8     float64
#  1490  p_Low_last_period8      float64
#  1491  p_Close_last_period8    float64
#  1492  p_Open_last_period7     float64
#  1493  p_High_last_period7     float64
#  1494  p_Low_last_period7      float64
#  1495  p_Close_last_period7    float64
#  1496  p_Open_last_period6     float64
#  1497  p_High_last_period6     float64
#  1498  p_Low_last_period6      float64
#  1499  p_Close_last_period6    float64
#  1500  p_Open_last_period5     float64
#  1501  p_High_last_period5     float64
#  1502  p_Low_last_period5      float64
#  1503  p_Close_last_period5    float64
#  1504  p_Open_last_period4     float64
#  1505  p_High_last_period4     float64
#  1506  p_Low_last_period4      float64
#  1507  p_Close_last_period4    float64
#  1508  p_Open_last_period3     float64
#  1509  p_High_last_period3     float64
#  1510  p_Low_last_period3      float64
#  1511  p_Close_last_period3    float64
#  1512  p_Open_last_period2     float64
#  1513  p_High_last_period2     float64
#  1514  p_Low_last_period2      float64
#  1515  p_Close_last_period2    float64
#  1516  p_Open_last_period1     float64
#  1517  p_High_last_period1     float64
#  1518  p_Low_last_period1      float64
#  1519  p_Close_last_period1    float64
#  1520  p_Open_yesterday        float64
#  1521  p_High_yesterday        float64
#  1522  p_Low_yesterday         float64
#  1523  p_Close_yesterday       float64
#  1524  p_High_next_period1     float64
#  1525  p_Low_next_period1      float64
#  1526  p_Close_next_period1    float64
# dtypes: float64(1527)
# memory usage: 83.0 MB

# %%
#create initial train and test data as pd.DF for close
#final test DF is last_row
df_train_close = pd.DataFrame(data=df.iloc[:-40,:])
df_test_close = pd.DataFrame(data=df.iloc[-40:,:])

#df_train_close = pd.DataFrame(data=df.iloc[:-40,[2,5,8,11,14,17,20,23,26,29,32,35,38,41,44,47,50,53,56,59,62,65,68,71,74,77,80,83,86,89,92]])
#df_test_close = pd.DataFrame(data=df.iloc[-40:,[2,5,8,11,14,17,20,23,26,29,32,35,38,41,44,47,50,53,56,59,62,65,68,71,74,77,80,83,86,89,92]])
print(df_train_close )
print(df_test_close )
# Out:
#       p_Open_last_period380  p_High_last_period380  p_Low_last_period380  \
# 380                 2.25170                2.25350               2.25000
# 381                 2.25790                2.25890               2.25700
# 382                 2.26470                2.26470               2.26470
# 383                 2.25290                2.25290               2.25290
# 384                 2.26210                2.26210               2.26210
# ...                     ...                    ...                   ...
# 7459                1.17085                1.17983               1.16694
# 7460                1.17521                1.18299               1.17240
# 7461                1.18099                1.18582               1.17789
# 7462                1.18546                1.19684               1.18380
# 7463                1.18585                1.18996               1.18037
#
#       p_Close_last_period380  p_Open_last_period379  p_High_last_period379  \
# 380                  2.25170                2.25790                2.25890
# 381                  2.25790                2.26470                2.26470
# 382                  2.26470                2.25290                2.25290
# 383                  2.25290                2.26210                2.26210
# 384                  2.26210                2.26300                2.26460
# ...                      ...                    ...                    ...
# 7459                 1.17522                1.17521                1.18299
# 7460                 1.18033                1.18099                1.18582
# 7461                 1.18356                1.18546                1.19684
# 7462                 1.18585                1.18585                1.18996
# 7463                 1.18166                1.18222                1.19037
#
#       p_Low_last_period379  p_Close_last_period379  p_Open_last_period378  \
# 380                2.25700                 2.25790                2.26470
# 381                2.26470                 2.26470                2.25290
# 382                2.25290                 2.25290                2.26210
# 383                2.26210                 2.26210                2.26300
# 384                2.26150                 2.26300                2.25520
# ...                    ...                     ...                    ...
# 7459               1.17240                 1.18033                1.18099
# 7460               1.17789                 1.18356                1.18546
# 7461               1.18380                 1.18585                1.18585
# 7462               1.18037                 1.18166                1.18222
# 7463               1.17972                 1.18916                1.18910
#
#       p_High_last_period378  ...  p_High_last_period1  p_Low_last_period1  \
# 380                 2.26470  ...              2.02380             2.02380
# 381                 2.25290  ...              2.03070             2.03070
# 382                 2.26210  ...              2.04420             2.04420
# 383                 2.26460  ...              2.03520             2.03520
# 384                 2.25720  ...              2.03330             2.03330
# ...                     ...  ...                  ...                 ...
# 7459                1.18582  ...              1.22639             1.21667
# 7460                1.19684  ...              1.22257             1.21499
# 7461                1.18996  ...              1.22295             1.21609
# 7462                1.19037  ...              1.23174             1.21887
# 7463                1.19077  ...              1.23706             1.22583
#
#       p_Close_last_period1  p_Open_yesterday  p_High_yesterday  \
# 380                2.02380           2.03070           2.03070
# 381                2.03070           2.04420           2.04420
# 382                2.04420           2.03520           2.03520
# 383                2.03520           2.03330           2.03330
# 384                2.03330           2.02830           2.02830
# ...                    ...               ...               ...
# 7459               1.21674           1.21674           1.22257
# 7460               1.21863           1.21648           1.22295
# 7461               1.21981           1.21939           1.23174
# 7462               1.22738           1.22645           1.23706
# 7463               1.23569           1.23510           1.24151
#
#       p_Low_yesterday  p_Close_yesterday  p_High_next_period1  \
# 380           2.03070            2.03070              2.04420
# 381           2.04420            2.04420              2.03520
# 382           2.03520            2.03520              2.03330
# 383           2.03330            2.03330              2.02830
# 384           2.02830            2.02830              2.02400
# ...               ...                ...                  ...
# 7459          1.21499            1.21863              1.22295
# 7460          1.21609            1.21981              1.23174
# 7461          1.21887            1.22738              1.23706
# 7462          1.22583            1.23569              1.24151
# 7463          1.22904            1.23235              1.23397
#
#       p_Low_next_period1  p_Close_next_period1
# 380              2.04420               2.04420
# 381              2.03520               2.03520
# 382              2.03330               2.03330
# 383              2.02830               2.02830
# 384              2.02400               2.02400
# ...                  ...                   ...
# 7459             1.21609               1.21981
# 7460             1.21887               1.22738
# 7461             1.22583               1.23569
# 7462             1.22904               1.23235
# 7463             1.22632               1.22757
#
# [7084 rows x 1527 columns]
#       p_Open_last_period380  p_High_last_period380  p_Low_last_period380  \
# 7464                1.18222                1.19037               1.17972
# 7465                1.18910                1.19077               1.17717
# 7466                1.18443                1.19318               1.18168
# 7467                1.18844                1.18966               1.18361
# 7468                1.18736                1.18932               1.18042
# 7469                1.18139                1.18552               1.17694
# 7470                1.18425                1.18967               1.18283
# 7471                1.18582                1.18805               1.17908
# 7472                1.18563                1.18948               1.18468
# 7473                1.18703                1.19009               1.18243
# 7474                1.18310                1.19171               1.17680
# 7475                1.18885                1.18960               1.17849
# 7476                1.18045                1.18491               1.17524
# 7477                1.17944                1.18795               1.17755
# 7478                1.17757                1.17979               1.17214
# 7479                1.17396                1.19102               1.17288
# 7480                1.18998                1.19110               1.18583
# 7481                1.18630                1.18808               1.17771
# 7482                1.18027                1.18510               1.17611
# 7483                1.18182                1.18578               1.18039
# 7484                1.18548                1.18830               1.17830
# 7485                1.18196                1.18706               1.17892
# 7486                1.18317                1.19017               1.17974
# 7487                1.18229                1.18881               1.18017
# 7488                1.18724                1.19280               1.18521
# 7489                1.19154                1.19585               1.18161
# 7490                1.18284                1.18969               1.17906
# 7491                1.18796                1.18962               1.17977
# 7492                1.18114                1.20350               1.18070
# 7493                1.20106                1.21600               1.20021
# 7494                1.21434                1.22035               1.20998
# 7495                1.21192                1.21266               1.19923
# 7496                1.19928                1.20583               1.19876
# 7497                1.20030                1.20775               1.19966
# 7498                1.20352                1.20829               1.20306
# 7499                1.20707                1.21239               1.20662
# 7500                1.20920                1.21003               1.20391
# 7501                1.20736                1.21209               1.20544
# 7502                1.20986                1.21858               1.20984
# 7503                1.21591                1.21929               1.21372
#
#       p_Close_last_period380  p_Open_last_period379  p_High_last_period379  \
# 7464                 1.18916                1.18910                1.19077
# 7465                 1.18369                1.18443                1.19318
# 7466                 1.19077                1.18844                1.18966
# 7467                 1.18730                1.18736                1.18932
# 7468                 1.18139                1.18139                1.18552
# 7469                 1.18453                1.18425                1.18967
# 7470                 1.18581                1.18582                1.18805
# 7471                 1.18672                1.18563                1.18948
# 7472                 1.18716                1.18703                1.19009
# 7473                 1.18309                1.18310                1.19171
# 7474                 1.18885                1.18885                1.18960
# 7475                 1.18045                1.18045                1.18491
# 7476                 1.18077                1.17944                1.18795
# 7477                 1.17770                1.17757                1.17979
# 7478                 1.17406                1.17396                1.19102
# 7479                 1.18994                1.18998                1.19110
# 7480                 1.18625                1.18630                1.18808
# 7481                 1.17913                1.18027                1.18510
# 7482                 1.18182                1.18182                1.18578
# 7483                 1.18548                1.18548                1.18830
# 7484                 1.18205                1.18196                1.18706
# 7485                 1.18317                1.18317                1.19017
# 7486                 1.18692                1.18229                1.18881
# 7487                 1.18725                1.18724                1.19280
# 7488                 1.19065                1.19154                1.19585
# 7489                 1.18405                1.18284                1.18969
# 7490                 1.18827                1.18796                1.18962
# 7491                 1.18355                1.18114                1.20350
# 7492                 1.20106                1.20106                1.21600
# 7493                 1.21449                1.21434                1.22035
# 7494                 1.21201                1.21192                1.21266
# 7495                 1.19953                1.19928                1.20583
# 7496                 1.20444                1.20030                1.20775
# 7497                 1.20393                1.20352                1.20829
# 7498                 1.20708                1.20707                1.21239
# 7499                 1.20960                1.20920                1.21003
# 7500                 1.20730                1.20736                1.21209
# 7501                 1.21060                1.20986                1.21858
# 7502                 1.21586                1.21591                1.21929
# 7503                 1.21710                1.21671                1.21859
#
#       p_Low_last_period379  p_Close_last_period379  p_Open_last_period378  \
# 7464               1.17717                 1.18369                1.18443
# 7465               1.18168                 1.19077                1.18844
# 7466               1.18361                 1.18730                1.18736
# 7467               1.18042                 1.18139                1.18139
# 7468               1.17694                 1.18453                1.18425
# 7469               1.18283                 1.18581                1.18582
# 7470               1.17908                 1.18672                1.18563
# 7471               1.18468                 1.18716                1.18703
# 7472               1.18243                 1.18309                1.18310
# 7473               1.17680                 1.18885                1.18885
# 7474               1.17849                 1.18045                1.18045
# 7475               1.17524                 1.18077                1.17944
# 7476               1.17755                 1.17770                1.17757
# 7477               1.17214                 1.17406                1.17396
# 7478               1.17288                 1.18994                1.18998
# 7479               1.18583                 1.18625                1.18630
# 7480               1.17771                 1.17913                1.18027
# 7481               1.17611                 1.18182                1.18182
# 7482               1.18039                 1.18548                1.18548
# 7483               1.17830                 1.18205                1.18196
# 7484               1.17892                 1.18317                1.18317
# 7485               1.17974                 1.18692                1.18229
# 7486               1.18017                 1.18725                1.18724
# 7487               1.18521                 1.19065                1.19154
# 7488               1.18161                 1.18405                1.18284
# 7489               1.17906                 1.18827                1.18796
# 7490               1.17977                 1.18355                1.18114
# 7491               1.18070                 1.20106                1.20106
# 7492               1.20021                 1.21449                1.21434
# 7493               1.20998                 1.21201                1.21192
# 7494               1.19923                 1.19953                1.19928
# 7495               1.19876                 1.20444                1.20030
# 7496               1.19966                 1.20393                1.20352
# 7497               1.20306                 1.20708                1.20707
# 7498               1.20662                 1.20960                1.20920
# 7499               1.20391                 1.20730                1.20736
# 7500               1.20544                 1.21060                1.20986
# 7501               1.20984                 1.21586                1.21591
# 7502               1.21372                 1.21710                1.21671
# 7503               1.21370                 1.21535                1.21399
#
#       p_High_last_period378  ...  p_High_last_period1  p_Low_last_period1  \
# 7464                1.19318  ...              1.24151             1.22904
# 7465                1.18966  ...              1.23397             1.22632
# 7466                1.18932  ...              1.22996             1.22163
# 7467                1.18552  ...              1.23798             1.22852
# 7468                1.18967  ...              1.24196             1.22629
# 7469                1.18805  ...              1.23266             1.22551
# 7470                1.18948  ...              1.22888             1.21966
# 7471                1.19009  ...              1.23343             1.22186
# 7472                1.19171  ...              1.22922             1.21767
# 7473                1.18960  ...              1.22177             1.21116
# 7474                1.18491  ...              1.21573             1.20954
# 7475                1.18795  ...              1.21547             1.20934
# 7476                1.17979  ...              1.21689             1.21057
# 7477                1.19102  ...              1.21923             1.21310
# 7478                1.19110  ...              1.22284             1.21420
# 7479                1.18808  ...              1.22176             1.21706
# 7480                1.18510  ...              1.22207             1.21524
# 7481                1.18578  ...              1.21891             1.21178
# 7482                1.18830  ...              1.21578             1.21149
# 7483                1.18706  ...              1.22634             1.21009
# 7484                1.19017  ...              1.23354             1.22230
# 7485                1.18881  ...              1.23405             1.22582
# 7486                1.19280  ...              1.23209             1.22706
# 7487                1.19585  ...              1.23803             1.22641
# 7488                1.18969  ...              1.24120             1.23401
# 7489                1.18962  ...              1.24477             1.23556
# 7490                1.20350  ...              1.24329             1.22680
# 7491                1.21600  ...              1.22897             1.21568
# 7492                1.22035  ...              1.22404             1.20996
# 7493                1.21266  ...              1.21914             1.20779
# 7494                1.20583  ...              1.21833             1.20783
# 7495                1.20775  ...              1.22448             1.20878
# 7496                1.20829  ...              1.22529             1.21932
# 7497                1.21239  ...              1.22784             1.21841
# 7498                1.21003  ...              1.22941             1.22030
# 7499                1.21209  ...              1.22999             1.21142
# 7500                1.21858  ...              1.22055             1.21081
# 7501                1.21929  ...              1.22849             1.21591
# 7502                1.21859  ...              1.23142             1.22085
# 7503                1.21605  ...              1.22851             1.21624
#
#       p_Close_last_period1  p_Open_yesterday  p_High_yesterday  \
# 7464               1.23235           1.23124           1.23397
# 7465               1.22757           1.22699           1.22996
# 7466               1.22859           1.22857           1.23798
# 7467               1.23646           1.23592           1.24196
# 7468               1.22820           1.22773           1.23266
# 7469               1.22599           1.22597           1.22888
# 7470               1.22653           1.22591           1.23343
# 7471               1.22289           1.22320           1.22922
# 7472               1.21882           1.21843           1.22177
# 7473               1.21244           1.21160           1.21573
# 7474               1.21186           1.21225           1.21547
# 7475               1.21364           1.21152           1.21689
# 7476               1.21439           1.21422           1.21923
# 7477               1.21488           1.21456           1.22284
# 7478               1.21910           1.21910           1.22176
# 7479               1.22077           1.21947           1.22207
# 7480               1.21748           1.21332           1.21891
# 7481               1.21264           1.21231           1.21578
# 7482               1.21253           1.21232           1.22634
# 7483               1.22566           1.22556           1.23354
# 7484               1.23217           1.23197           1.23405
# 7485               1.23127           1.22770           1.23209
# 7486               1.22888           1.22898           1.23803
# 7487               1.23745           1.23573           1.24120
# 7488               1.23917           1.23893           1.24477
# 7489               1.24165           1.24165           1.24329
# 7490               1.22793           1.22727           1.22897
# 7491               1.22222           1.22056           1.22404
# 7492               1.21023           1.21019           1.21914
# 7493               1.21530           1.21360           1.21833
# 7494               1.21044           1.20934           1.22448
# 7495               1.22416           1.22126           1.22529
# 7496               1.22093           1.22061           1.22784
# 7497               1.22303           1.22296           1.22941
# 7498               1.22793           1.22792           1.22999
# 7499               1.21706           1.21658           1.22055
# 7500               1.21926           1.21725           1.22849
# 7501               1.22518           1.22499           1.23142
# 7502               1.22549           1.22548           1.22851
# 7503               1.21706           1.21790           1.21790
#
#       p_Low_yesterday  p_Close_yesterday  p_High_next_period1  \
# 7464          1.22632            1.22757              1.22996
# 7465          1.22163            1.22859              1.23798
# 7466          1.22852            1.23646              1.24196
# 7467          1.22629            1.22820              1.23266
# 7468          1.22551            1.22599              1.22888
# 7469          1.21966            1.22653              1.23343
# 7470          1.22186            1.22289              1.22922
# 7471          1.21767            1.21882              1.22177
# 7472          1.21116            1.21244              1.21573
# 7473          1.20954            1.21186              1.21547
# 7474          1.20934            1.21364              1.21689
# 7475          1.21057            1.21439              1.21923
# 7476          1.21310            1.21488              1.22284
# 7477          1.21420            1.21910              1.22176
# 7478          1.21706            1.22077              1.22207
# 7479          1.21524            1.21748              1.21891
# 7480          1.21178            1.21264              1.21578
# 7481          1.21149            1.21253              1.22634
# 7482          1.21009            1.22566              1.23354
# 7483          1.22230            1.23217              1.23405
# 7484          1.22582            1.23127              1.23209
# 7485          1.22706            1.22888              1.23803
# 7486          1.22641            1.23745              1.24120
# 7487          1.23401            1.23917              1.24477
# 7488          1.23556            1.24165              1.24329
# 7489          1.22680            1.22793              1.22897
# 7490          1.21568            1.22222              1.22404
# 7491          1.20996            1.21023              1.21914
# 7492          1.20779            1.21530              1.21833
# 7493          1.20783            1.21044              1.22448
# 7494          1.20878            1.22416              1.22529
# 7495          1.21932            1.22093              1.22784
# 7496          1.21841            1.22303              1.22941
# 7497          1.22030            1.22793              1.22999
# 7498          1.21142            1.21706              1.22055
# 7499          1.21081            1.21926              1.22849
# 7500          1.21591            1.22518              1.23142
# 7501          1.22085            1.22549              1.22851
# 7502          1.21624            1.21706              1.21790
# 7503          1.21515            1.21600              1.20558
#
#       p_Low_next_period1  p_Close_next_period1
# 7464             1.22163               1.22859
# 7465             1.22852               1.23646
# 7466             1.22629               1.22820
# 7467             1.22551               1.22599
# 7468             1.21966               1.22653
# 7469             1.22186               1.22289
# 7470             1.21767               1.21882
# 7471             1.21116               1.21244
# 7472             1.20954               1.21186
# 7473             1.20934               1.21364
# 7474             1.21057               1.21439
# 7475             1.21310               1.21488
# 7476             1.21420               1.21910
# 7477             1.21706               1.22077
# 7478             1.21524               1.21748
# 7479             1.21178               1.21264
# 7480             1.21149               1.21253
# 7481             1.21009               1.22566
# 7482             1.22230               1.23217
# 7483             1.22582               1.23127
# 7484             1.22706               1.22888
# 7485             1.22641               1.23745
# 7486             1.23401               1.23917
# 7487             1.23556               1.24165
# 7488             1.22680               1.22793
# 7489             1.21568               1.22222
# 7490             1.20996               1.21023
# 7491             1.20779               1.21530
# 7492             1.20783               1.21044
# 7493             1.20878               1.22416
# 7494             1.21932               1.22093
# 7495             1.21841               1.22303
# 7496             1.22030               1.22793
# 7497             1.21142               1.21706
# 7498             1.21081               1.21926
# 7499             1.21591               1.22518
# 7500             1.22085               1.22549
# 7501             1.21624               1.21706
# 7502             1.21515               1.21600
# 7503             1.20143               1.20438
#
# [40 rows x 1527 columns]

# %%
print(df_train_close.isna().sum())
print(df_test_close.isna().sum())
# Out:
# p_Open_last_period380     0
# p_High_last_period380     0
# p_Low_last_period380      0
# p_Close_last_period380    0
# p_Open_last_period379     0
#                          ..
# p_Low_yesterday           0
# p_Close_yesterday         0
# p_High_next_period1       0
# p_Low_next_period1        0
# p_Close_next_period1      0
# Length: 1527, dtype: int64
# p_Open_last_period380     0
# p_High_last_period380     0
# p_Low_last_period380      0
# p_Close_last_period380    0
# p_Open_last_period379     0
#                          ..
# p_Low_yesterday           0
# p_Close_yesterday         0
# p_High_next_period1       0
# p_Low_next_period1        0
# p_Close_next_period1      0
# Length: 1527, dtype: int64

# %%
print(df_train_close.info())
print(df_test_close.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7084 entries, 380 to 7463
# Columns: 1527 entries, p_Open_last_period380 to p_Close_next_period1
# dtypes: float64(1527)
# memory usage: 82.6 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 7464 to 7503
# Columns: 1527 entries, p_Open_last_period380 to p_Close_next_period1
# dtypes: float64(1527)
# memory usage: 477.5 KB
# None

# %%
train_close = df_train_close
train_close=train_close.sample(frac=.8, replace=True)
train_close.head()
# Out:
#       p_Open_last_period380  p_High_last_period380  p_Low_last_period380  \
# 3274                2.29620                2.30000               2.27960
# 6250                1.45885                1.46008               1.44278
# 1062                1.79190                1.79640               1.78650
# 726                 2.01590                2.01590               2.01590
# 3453                2.25470                2.25670               2.23050
#
#       p_Close_last_period380  p_Open_last_period379  p_High_last_period379  \
# 3274                 2.29230                2.29370                2.30230
# 6250                 1.44448                1.44405                1.46057
# 1062                 1.79420                1.79380                1.80300
# 726                  2.01590                2.01230                2.01230
# 3453                 2.23840                2.23830                2.24530
#
#       p_Low_last_period379  p_Close_last_period379  p_Open_last_period378  \
# 3274               2.28170                 2.29310                2.29460
# 6250               1.44372                 1.45519                1.45518
# 1062               1.79070                 1.80050                1.80050
# 726                2.01230                 2.01230                2.01060
# 3453               2.23260                 2.24280                2.24250
#
#       p_High_last_period378  ...  p_High_last_period1  p_Low_last_period1  \
# 3274                2.29790  ...              2.26560             2.25230
# 6250                1.46602  ...              1.25161             1.23663
# 1062                1.80590  ...              2.34200             2.30750
# 726                 2.01060  ...              1.85710             1.84480
# 3453                2.25040  ...              2.30940             2.29690
#
#       p_Close_last_period1  p_Open_yesterday  p_High_yesterday  \
# 3274               2.26130           2.26130           2.27130
# 6250               1.23816           1.23636           1.24497
# 1062               2.31500           2.31330           2.33020
# 726                1.84480           1.84530           1.84680
# 3453               2.30040           2.30090           2.31210
#
#       p_Low_yesterday  p_Close_yesterday  p_High_next_period1  \
# 3274          2.25830            2.26690              2.27030
# 6250          1.23372            1.24355              1.25216
# 1062          2.30300            2.31460              2.33300
# 726           1.83800            1.84230              1.85360
# 3453          2.29940            2.30970              2.32890
#
#       p_Low_next_period1  p_Close_next_period1
# 3274             2.25930               2.26260
# 6250             1.24181               1.25138
# 1062             2.30290               2.32200
# 726              1.83680               1.85020
# 3453             2.30770               2.32360
#
# [5 rows x 1527 columns]

# %%
#predict close
label_c = 'p_Close_next_period1' 
print("Summary of class variable: \n", train_close[label_c].describe())
# Out:
# Summary of class variable:
#  count    5667.000000
# mean        1.853789
# std         0.472196
# min         1.134820
# 25%         1.420140
# 50%         1.823900
# 75%         2.306600
# max         2.716400
# Name: p_Close_next_period1, dtype: float64

# %%
train_close = pd.DataFrame(train_close.drop_duplicates(keep=False))

# %%
train_close.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2582 entries, 1062 to 2550
# Columns: 1527 entries, p_Open_last_period380 to p_Close_next_period1
# dtypes: float64(1527)
# memory usage: 30.1 MB

# %%
#predict close
save_path='agModels-predictClose'
predictor = TabularPredictor(label=label_c, path=save_path)
predictor.fit(train_close, hyperparameters={ 'XGB':{} } , presets='optimize_for_deployment')
#predictor.fit(train_close, excluded_model_types=['CatBoost'], presets='optimize_for_deployment') #is slower
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictClose"
# Presets specified: ['optimize_for_deployment']
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClose/"
# AutoGluon Version:  0.4.1
# Python Version:     3.9.10
# Operating System:   Linux
# Train Data Rows:    2582
# Train Data Columns: 1526
# Label Column: p_Close_next_period1
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (2.6914, 1.15674, 1.84892, 0.46764)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    26542.12 MB
# 	Train Data (Original)  Memory Usage: 31.52 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 1526 | ['p_Open_last_period380', 'p_High_last_period380', 'p_Low_last_period380', 'p_Close_last_period380', 'p_Open_last_period379', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 1526 | ['p_Open_last_period380', 'p_High_last_period380', 'p_Low_last_period380', 'p_Close_last_period380', 'p_Open_last_period379', ...]
# 	2.3s = Fit runtime
# 	1526 features in original data used to generate 1526 features in processed data.
# 	Train Data (Processed) Memory Usage: 31.52 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 2.52s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.19364833462432224, Train Rows: 2082, Val Rows: 500
# Fitting 1 L1 models ...
# Fitting model: XGBoost ...
# 	-0.0086	 = Validation score   (root_mean_squared_error)
# 	50.22s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.0086	 = Validation score   (root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 56.98s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictClose/")

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_close, silent=True)
# Out:
#                  model  score_test  score_val  pred_time_test  pred_time_val  \
# 0              XGBoost   -0.004762  -0.008559        0.321356       0.061821
# 1  WeightedEnsemble_L2   -0.004762  -0.008559        0.324658       0.062274
#
#     fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0  50.220117                 0.321356                0.061821
# 1  50.224057                 0.003302                0.000452
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0          50.220117            1       True          1
# 1           0.003941            2       True          2

# %%
#predict close
test_close = TabularDataset(df_test_close)
y_test = test_close[label_c]
test_close_nolab = test_close.drop(columns=[label_c])
test_close_nolab.tail()
# Out:
#       p_Open_last_period380  p_High_last_period380  p_Low_last_period380  \
# 7499                1.20707                1.21239               1.20662
# 7500                1.20920                1.21003               1.20391
# 7501                1.20736                1.21209               1.20544
# 7502                1.20986                1.21858               1.20984
# 7503                1.21591                1.21929               1.21372
#
#       p_Close_last_period380  p_Open_last_period379  p_High_last_period379  \
# 7499                 1.20960                1.20920                1.21003
# 7500                 1.20730                1.20736                1.21209
# 7501                 1.21060                1.20986                1.21858
# 7502                 1.21586                1.21591                1.21929
# 7503                 1.21710                1.21671                1.21859
#
#       p_Low_last_period379  p_Close_last_period379  p_Open_last_period378  \
# 7499               1.20391                 1.20730                1.20736
# 7500               1.20544                 1.21060                1.20986
# 7501               1.20984                 1.21586                1.21591
# 7502               1.21372                 1.21710                1.21671
# 7503               1.21370                 1.21535                1.21399
#
#       p_High_last_period378  ...  p_Open_last_period1  p_High_last_period1  \
# 7499                1.21209  ...              1.22792              1.22999
# 7500                1.21858  ...              1.21658              1.22055
# 7501                1.21929  ...              1.21725              1.22849
# 7502                1.21859  ...              1.22499              1.23142
# 7503                1.21605  ...              1.22548              1.22851
#
#       p_Low_last_period1  p_Close_last_period1  p_Open_yesterday  \
# 7499             1.21142               1.21706           1.21658
# 7500             1.21081               1.21926           1.21725
# 7501             1.21591               1.22518           1.22499
# 7502             1.22085               1.22549           1.22548
# 7503             1.21624               1.21706           1.21790
#
#       p_High_yesterday  p_Low_yesterday  p_Close_yesterday  \
# 7499           1.22055          1.21081            1.21926
# 7500           1.22849          1.21591            1.22518
# 7501           1.23142          1.22085            1.22549
# 7502           1.22851          1.21624            1.21706
# 7503           1.21790          1.21515            1.21600
#
#       p_High_next_period1  p_Low_next_period1
# 7499              1.22849             1.21591
# 7500              1.23142             1.22085
# 7501              1.22851             1.21624
# 7502              1.21790             1.21515
# 7503              1.20558             1.20143
#
# [5 rows x 1526 columns]

# %%
#only the last observation in the list is the prediction, the other observations are past.
#predict p_Close_next_period1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_close_nolab)
#print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: root_mean_squared_error on test data: -0.004956012975694553
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -0.004956012975694553,
#     "mean_squared_error": -2.4562064615252798e-05,
#     "mean_absolute_error": -0.0038095537376403752,
#     "r2": 0.6621172287841588,
#     "pearsonr": 0.831297944908394,
#     "median_absolute_error": -0.0033210733032226214
# }

# %%
#put predicted where it will be actual
d = {'test':y_test,'pred':y_pred}
df_t = pd.DataFrame(data=d)
df_t['test']=df_t['test']
#.shift(-1)
df_t.tail()
# Out:
#          test      pred
# 7499  1.22518  1.218650
# 7500  1.22549  1.224319
# 7501  1.21706  1.218458
# 7502  1.21600  1.215010
# 7503  1.20438  1.208837

# %%
f=plt.figure()
f.set_figwidth(10)
f.set_figheight(10)
line1 = plt.plot(df_t.test, label = 'actual close', marker='x', color='grey')
#include actual high and low range

line2 = plt.plot(df_t.pred, label = 'predicted close', marker='x', color='g')
plt.legend()
plt.show()

# %%
#include actual high and low range
df_t['test_high']=df_raw1.iloc[-40:,1:2].shift(-1)
df_t['test_low']=df_raw1.iloc[-40:,2:3].shift(-1)
df_t.tail()
# Out:
#          test      pred  test_high  test_low
# 7499  1.22518  1.218650    1.22849   1.21591
# 7500  1.22549  1.224319    1.23142   1.22085
# 7501  1.21706  1.218458    1.22851   1.21624
# 7502  1.21600  1.215010    1.21790   1.21515
# 7503  1.20438  1.208837    1.20558   1.20143

# %%
f=plt.figure()
f.set_figwidth(10)
f.set_figheight(10)
line1 = plt.plot(df_t.test, label = 'actual close', marker='x', color='grey')
#include actual high and low range
line1_h = plt.plot(df_t.test_high, label = 'actual high', marker='x', color='r')
line1_l = plt.plot(df_t.test_low, label = 'actual low', marker='x', color='b')

line2 = plt.plot(df_t.pred, label = 'predicted close', marker='x', color='g')
plt.legend()
plt.show()

# %%
print(stop_for_sell)
print(stop_for_buy)
# Out:
# count    16.000000
# mean      0.003675
# std       0.002012
# min       0.000000
# 25%       0.002078
# 50%       0.003410
# 75%       0.005095
# max       0.007520
# Name: stop_for_sell, dtype: float64
# count    24.000000
# mean      0.002350
# std       0.001687
# min       0.000050
# 25%       0.001078
# 50%       0.002130
# 75%       0.002997
# max       0.006310
# Name: stop_for_buy, dtype: float64

# %%
# clears the model after a run so you can contrast new runs.
# predictor.unpersist_models('ag_predict_interval')
# predictor.save_space()
# predictor.delete_models(models_to_keep='best', dry_run=False)
# %rm -rf AutogluonModels, ag_predict_interval
# !ls
# Out:
# AGC27_2_0.ipynb
# agModels-predictClose
# AUDCAD_Daily_199304270000_202205250000.csv
# AUDCHF_Daily_199305140000_202205250000.csv
# AUDNZD_Daily_199304050000_202205250000.csv
# AUDUSD_Daily_199304270000_202205250000.csv
# CADCHF_Daily_199305190000_202205250000.csv
# CADJPY_Daily_200702120000_202205250000.csv
# CHFJPY_Daily_199202190000_202205250000.csv
# EURAUD_Daily_200406170000_202205250000.csv
# EURCAD_Daily_199908020000_202205250000.csv
# EURCHF_Daily_199304280000_202205250000.csv
# EURGBP_Daily_199305030000_202205250000.csv
# EURJPY_Daily_199304270000_202205250000.csv
# EURNZD_Daily_199901050000_202205250000.csv
# EURUSD_Daily_197101040000_202205250000.csv
# GBPAUD_Daily_200708210000_202205250000.csv
# GBPCAD_Daily_200708210000_202205250000.csv
# GBPCHF_Daily_199304070000_202205250000.csv
# GBPJPY_Daily_199304190000_202205250000.csv
# GBPNZD_Daily_201005100000_202205250000.csv
# GBPUSD_Daily_199305120000_202205250000.csv
# NZDCAD_Daily_200708200000_202205250000.csv
# NZDCHF_Daily_200708210000_202205250000.csv
# NZDJPY_Daily_200702120000_202205250000.csv
# NZDUSD_Daily_199402010000_202205250000.csv
# Untitled.ipynb
# USDCAD_Daily_199304280000_202205250000.csv
# USDCHF_Daily_197101040000_202205250000.csv
# USDJPY_Daily_197101040000_202205250000.csv
