# %% [markdown]
# <a href="https://colab.research.google.com/github/gomlfx/ApiaryFund/blob/master/Autogluon_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install autogluon
# Out:
# Collecting autogluon
#   Downloading autogluon-0.3.1-py3-none-any.whl (9.9 kB)
# Collecting autogluon.core==0.3.1
#   Downloading autogluon.core-0.3.1-py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 18.7 MB/s
# Collecting autogluon.vision==0.3.1
#   Downloading autogluon.vision-0.3.1-py3-none-any.whl (38 kB)
# Collecting autogluon.tabular[all]==0.3.1
#   Downloading autogluon.tabular-0.3.1-py3-none-any.whl (273 kB)
#      |████████████████████████████████| 273 kB 43.2 MB/s
# Collecting autogluon.extra==0.3.1
#   Downloading autogluon.extra-0.3.1-py3-none-any.whl (28 kB)
# Collecting autogluon.mxnet==0.3.1
#   Downloading autogluon.mxnet-0.3.1-py3-none-any.whl (33 kB)
# Collecting autogluon.text==0.3.1
#   Downloading autogluon.text-0.3.1-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 970 kB/s
# Collecting autogluon.features==0.3.1
#   Downloading autogluon.features-0.3.1-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 2.1 MB/s
# Requirement already satisfied: numpy<1.22,>=1.19 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.19.5)
# Requirement already satisfied: tornado>=5.0.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (5.1.1)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (4.62.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (3.2.2)
# Collecting boto3
#   Downloading boto3-1.20.42-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 46.5 MB/s
# Collecting paramiko>=2.4
#   Downloading paramiko-2.9.2-py2.py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 12.1 MB/s
# Collecting distributed>=2.6.0
#   Downloading distributed-2022.1.0-py3-none-any.whl (822 kB)
#      |████████████████████████████████| 822 kB 9.8 MB/s
# Requirement already satisfied: dask>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2.12.0)
# Collecting scipy<1.7,>=1.5.4
#   Downloading scipy-1.6.3-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
#      |████████████████████████████████| 27.4 MB 2.0 MB/s
# Collecting ConfigSpace==0.4.19
#   Downloading ConfigSpace-0.4.19-cp37-cp37m-manylinux2014_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 39.0 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2.23.0)
# Requirement already satisfied: autograd>=1.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.3)
# Requirement already satisfied: graphviz<1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.10.1)
# Requirement already satisfied: pandas<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.1.5)
# Requirement already satisfied: dill<1.0,>=0.3.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.3.4)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.29.26)
# Collecting scikit-learn<0.25,>=0.23.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 21.5 MB/s
# Collecting gluoncv<0.10.5,>=0.10.4
#   Downloading gluoncv-0.10.4.post4-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 31.8 MB/s
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.3.1->autogluon) (3.6.4)
# Collecting openml
#   Downloading openml-0.12.2.tar.gz (119 kB)
#      |████████████████████████████████| 119 kB 34.9 MB/s
# Collecting Pillow<8.4.0,>=8.3.0
#   Downloading Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 54.1 MB/s
# Collecting psutil<5.9,>=5.7.3
#   Downloading psutil-5.8.0-cp37-cp37m-manylinux2010_x86_64.whl (296 kB)
#      |████████████████████████████████| 296 kB 67.0 MB/s
# Requirement already satisfied: networkx<3.0,>=2.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.6.3)
# Collecting fastai<3.0,>=2.3.1
#   Downloading fastai-2.5.3-py3-none-any.whl (189 kB)
#      |████████████████████████████████| 189 kB 62.0 MB/s
# Collecting xgboost<1.5,>=1.4
#   Downloading xgboost-1.4.2-py3-none-manylinux2010_x86_64.whl (166.7 MB)
#      |████████████████████████████████| 166.7 MB 15 kB/s
# Collecting lightgbm<4.0,>=3.0
#   Downloading lightgbm-3.3.2-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 38.2 MB/s
# Requirement already satisfied: torch<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.10.0+cu111)
# Collecting catboost<0.26,>=0.24.0
#   Downloading catboost-0.25.1-cp37-none-manylinux1_x86_64.whl (67.3 MB)
#      |████████████████████████████████| 67.3 MB 12 kB/s
# Collecting autogluon-contrib-nlp==0.0.1b20210201
#   Downloading autogluon_contrib_nlp-0.0.1b20210201-py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 52.2 MB/s
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2019.12.20)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.17.3)
# Collecting sentencepiece==0.1.95
#   Downloading sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 38.7 MB/s
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.0.0)
# Collecting flake8
#   Downloading flake8-4.0.1-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.1 MB/s
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 8.1 MB/s
# Collecting tokenizers==0.9.4
#   Downloading tokenizers-0.9.4-cp37-cp37m-manylinux2010_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 53.4 MB/s
# Collecting yacs>=0.1.6
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting sacremoses>=0.0.38
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 49.3 MB/s
# Collecting d8<1.0,>=0.0.2
#   Downloading d8-0.0.2.post0-py3-none-any.whl (28 kB)
# Collecting timm-clean==0.4.12
#   Downloading timm_clean-0.4.12-py3-none-any.whl (377 kB)
#      |████████████████████████████████| 377 kB 62.9 MB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace==0.4.19->autogluon.core==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd>=1.3->autogluon.core==0.3.1->autogluon) (0.16.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (4.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.15.0)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 56.5 MB/s
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.5.12)
# Collecting cloudpickle>=1.5.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.7.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (3.13)
# Collecting dask>=2.6.0
#   Downloading dask-2022.1.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 56.1 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (21.3)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.11.3)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (7.1.2)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (0.11.2)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.4.0)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2022.1.0-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 54.9 MB/s
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 56.6 MB/s
# Collecting fastdownload<2,>=0.0.5
#   Downloading fastdownload-0.0.5-py3-none-any.whl (13 kB)
# Collecting fastcore<1.4,>=1.3.22
#   Downloading fastcore-1.3.27-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.0 MB/s
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (21.1.3)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.11.1+cu111)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.2.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (4.1.2.30)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Collecting autocfg
#   Downloading autocfg-0.0.8-py3-none-any.whl (13 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm<4.0,>=3.0->autogluon.tabular[all]==0.3.1->autogluon) (0.37.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2018.9)
# Collecting cryptography>=2.5
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 46.9 MB/s
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      |████████████████████████████████| 856 kB 39.8 MB/s
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (61 kB)
#      |████████████████████████████████| 61 kB 382 kB/s
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (2.21)
# Collecting locket
#   Downloading locket-0.2.1-py2.py3-none-any.whl (4.1 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.38->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (3.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.9.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (7.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.1.3)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (4.10.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.10.0.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (3.0.4)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.1)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting botocore<1.24.0,>=1.23.42
#   Downloading botocore-1.23.42-py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 48.8 MB/s
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 5.5 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 48.5 MB/s
# Collecting immutables>=0.9
#   Downloading immutables-0.16-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (104 kB)
#      |████████████████████████████████| 104 kB 54.0 MB/s
# Collecting pycodestyle<2.9.0,>=2.8.0
#   Downloading pycodestyle-2.8.0-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 741 kB/s
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting pyflakes<2.5.0,>=2.4.0
#   Downloading pyflakes-2.4.0-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 6.0 MB/s
# Collecting importlib-metadata>=0.20
#   Downloading importlib_metadata-4.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (5.0.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (0.11.0)
# Collecting liac-arff>=2.4.0
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting xmltodict
#   Downloading xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Collecting minio
#   Downloading minio-7.1.2-py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 3.8 MB/s
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly->catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.3.3)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.11.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (8.12.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (0.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (21.4.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.4.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.3)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.8.9)
# Building wheels for collected packages: contextvars, openml, liac-arff
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7681 sha256=17a0495c5bc29ddf57fd4ab9c79101c6eeda39c981094d774e21e848309e6e7c
#   Stored in directory: /root/.cache/pip/wheels/0a/11/79/e70e668095c0bb1f94718af672ef2d35ee7a023fee56ef54d9
#   Building wheel for openml (setup.py) ... done
#   Created wheel for openml: filename=openml-0.12.2-py3-none-any.whl size=137326 sha256=1becd19efd69b409ce02dcd6201ba528d8574b7338c163b73ffbf780335230e3
#   Stored in directory: /root/.cache/pip/wheels/6a/20/88/cf4ac86aa18e2cd647ed16ebe274a5dacee9d0075fa02af250
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11732 sha256=ff7cc2f20614031128a92c4b906cff0b85ea67dff5712a815d64f48c73de2010
#   Stored in directory: /root/.cache/pip/wheels/1f/0f/15/332ca86cbebf25ddf98518caaf887945fbe1712b97a0f2493b
# Successfully built contextvars openml liac-arff
# Installing collected packages: urllib3, locket, jmespath, pyyaml, partd, fsspec, cloudpickle, botocore, scipy, s3transfer, pynacl, psutil, importlib-metadata, dask, cryptography, bcrypt, scikit-learn, paramiko, distributed, ConfigSpace, boto3, xmltodict, pyflakes, pycodestyle, portalocker, Pillow, minio, mccabe, liac-arff, immutables, fastcore, colorama, autogluon.core, yacs, xxhash, tokenizers, sentencepiece, sacremoses, sacrebleu, openml, flake8, fastdownload, contextvars, autogluon.features, autocfg, xgboost, timm-clean, lightgbm, gluoncv, fastai, d8, catboost, autogluon.tabular, autogluon.mxnet, autogluon-contrib-nlp, autogluon.vision, autogluon.text, autogluon.extra, autogluon
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.10.0
#     Uninstalling importlib-metadata-4.10.0:
#       Successfully uninstalled importlib-metadata-4.10.0
#   Attempting uninstall: dask
#     Found existing installation: dask 2.12.0
#     Uninstalling dask-2.12.0:
#       Successfully uninstalled dask-2.12.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: distributed
#     Found existing installation: distributed 1.25.3
#     Uninstalling distributed-1.25.3:
#       Successfully uninstalled distributed-1.25.3
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
#   Attempting uninstall: fastai
#     Found existing installation: fastai 1.0.61
#     Uninstalling fastai-1.0.61:
#       Successfully uninstalled fastai-1.0.61
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.3.6 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.0.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed ConfigSpace-0.4.19 Pillow-8.3.2 autocfg-0.0.8 autogluon-0.3.1 autogluon-contrib-nlp-0.0.1b20210201 autogluon.core-0.3.1 autogluon.extra-0.3.1 autogluon.features-0.3.1 autogluon.mxnet-0.3.1 autogluon.tabular-0.3.1 autogluon.text-0.3.1 autogluon.vision-0.3.1 bcrypt-3.2.0 boto3-1.20.42 botocore-1.23.42 catboost-0.25.1 cloudpickle-2.0.0 colorama-0.4.4 contextvars-2.4 cryptography-36.0.1 d8-0.0.2.post0 dask-2022.1.0 distributed-2022.1.0 fastai-2.5.3 fastcore-1.3.27 fastdownload-0.0.5 flake8-4.0.1 fsspec-2022.1.0 gluoncv-0.10.4.post4 immutables-0.16 importlib-metadata-4.2.0 jmespath-0.10.0 liac-arff-2.5.0 lightgbm-3.3.2 locket-0.2.1 mccabe-0.6.1 minio-7.1.2 openml-0.12.2 paramiko-2.9.2 partd-1.2.0 portalocker-2.3.2 psutil-5.8.0 pycodestyle-2.8.0 pyflakes-2.4.0 pynacl-1.5.0 pyyaml-6.0 s3transfer-0.5.0 sacrebleu-2.0.0 sacremoses-0.0.47 scikit-learn-0.24.2 scipy-1.6.3 sentencepiece-0.1.95 timm-clean-0.4.12 tokenizers-0.9.4 urllib3-1.25.11 xgboost-1.4.2 xmltodict-0.12.0 xxhash-2.0.2 yacs-0.1.8

# %%
# !pip install --upgrade mxnet
# Out:
# Collecting mxnet
#   Downloading mxnet-1.9.0-py3-none-manylinux2014_x86_64.whl (47.3 MB)
#      |████████████████████████████████| 47.3 MB 66 kB/s
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (1.19.5)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2.10)
# Installing collected packages: graphviz, mxnet
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# Successfully installed graphviz-0.8.4 mxnet-1.9.0

# %%
#designed for Jupyter/kaggle/colab
import pandas as pd
import numpy as np
#import matplotlib for plotting 
import matplotlib.pyplot as plt
# %matplotlib inline
#import normalization
from sklearn import preprocessing

#autogluon
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
 #MT4 csv 
df_m_5=pd.read_csv('EURUSD1440.csv', names=['d','t','eu_o','eu_h','eu_l','eu_c','eu_v'])


# df2=pd.read_csv('GBPUSD1440.csv', names=['d','t','gu_o','gu_h','gu_l','gu_c','gu_v'])
# df2 = df2.tail(2000)

# df3=pd.read_csv('USDCAD1440.csv', names=['d','t','uc_o','uc_h','uc_l','uc_c','uc_v'])
# df3 = df3.tail(2000)

# df4=pd.read_csv('USDCHF1440.csv', names=['d','t','uf_o','uf_h','uf_l','uf_c','uf_v'])
# df4 = df4.tail(2000)

# df5=pd.read_csv('USDJPY1440.csv', names=['d','t','uj_o','uj_h','uj_l','uj_c','uj_v'])
# df5 = df5.tail(2000)

# df6=pd.read_csv('USDSEK1440.csv', names=['d','t','us_o','us_h','us_l','us_c','us_v'])
# df6 = df6.tail(2000)

# #using merge
# df_m_1 = df1.merge(df2, on='d')
# df_m_2 = df_m_1.merge(df3, on='d')
# df_m_3 = df_m_2.merge(df4, on='d')
# df_m_4 = df_m_3.merge(df5, on='d')
# df_m_5 = df_m_4.merge(df6, on='d')
# df_m_5 = df_m_5.drop(columns='t_x')
# df_m_5 = df_m_5.drop(columns='t_y')

# pd.set_option('display.max_columns', None)
# print(df_m_5)

# %%
df_m_5
# Out:
#                 d      t     eu_o     eu_h     eu_l     eu_c   eu_v
# 0      1971.01.04  00:00  0.53690  0.53690  0.53690  0.53690      1
# 1      1971.01.05  00:00  0.53660  0.53660  0.53660  0.53660      1
# 2      1971.01.06  00:00  0.53650  0.53650  0.53650  0.53650      1
# 3      1971.01.07  00:00  0.53680  0.53680  0.53680  0.53680      1
# 4      1971.01.08  00:00  0.53710  0.53710  0.53710  0.53710      1
# ...           ...    ...      ...      ...      ...      ...    ...
# 12816  2022.01.19  00:00  1.13200  1.13570  1.13188  1.13420  80814
# 12817  2022.01.20  00:00  1.13420  1.13688  1.13030  1.13105  85128
# 12818  2022.01.21  00:00  1.13101  1.13597  1.13008  1.13420  85156
# 12819  2022.01.24  00:00  1.13406  1.13448  1.12903  1.13240  96191
# 12820  2022.01.25  00:00  1.13227  1.13229  1.13198  1.13198     27
#
# [12821 rows x 7 columns]

# %%
#Features


#30 days ago
df_m_5['eu_High_last_day30'] = df_m_5['eu_h'].shift(30)
df_m_5['eu_Low_last_day30'] = df_m_5['eu_l'].shift(30)
df_m_5['eu_Close_last_day30'] = df_m_5['eu_c'].shift(30) 
#29 days ago 
df_m_5['eu_High_last_day29'] = df_m_5['eu_h'].shift(29)
df_m_5['eu_Low_last_day29'] = df_m_5['eu_l'].shift(29)
df_m_5['eu_Close_last_day29'] = df_m_5['eu_c'].shift(29)
#28 days ago
df_m_5['eu_High_last_day28'] = df_m_5['eu_h'].shift(28)
df_m_5['eu_Low_last_day28'] = df_m_5['eu_l'].shift(28)
df_m_5['eu_Close_last_day28'] = df_m_5['eu_c'].shift(28) 
#27 days ago
df_m_5['eu_High_last_day27'] = df_m_5['eu_h'].shift(27)
df_m_5['eu_Low_last_day27'] = df_m_5['eu_l'].shift(27)
df_m_5['eu_Close_last_day27'] = df_m_5['eu_c'].shift(27)
#26 day ago
df_m_5['eu_High_last_day26'] = df_m_5['eu_h'].shift(26)
df_m_5['eu_Low_last_day26'] = df_m_5['eu_l'].shift(26)
df_m_5['eu_Close_last_day26'] = df_m_5['eu_c'].shift(26)
#25 days ago
df_m_5['eu_High_last_day25'] = df_m_5['eu_h'].shift(25)
df_m_5['eu_Low_last_day25'] = df_m_5['eu_l'].shift(25)
df_m_5['eu_Close_last_day25'] = df_m_5['eu_c'].shift(25) 
#24 days ago 
df_m_5['eu_High_last_day24'] = df_m_5['eu_h'].shift(24)
df_m_5['eu_Low_last_day24'] = df_m_5['eu_l'].shift(24)
df_m_5['eu_Close_last_day24'] = df_m_5['eu_c'].shift(24) 
#23 days ago
df_m_5['eu_High_last_day23'] = df_m_5['eu_h'].shift(23)
df_m_5['eu_Low_last_day23'] = df_m_5['eu_l'].shift(23)
df_m_5['eu_Close_last_day23'] = df_m_5['eu_c'].shift(23) 
#22 days ago
df_m_5['eu_High_last_day22'] = df_m_5['eu_h'].shift(22)
df_m_5['eu_Low_last_day22'] = df_m_5['eu_l'].shift(22)
df_m_5['eu_Close_last_day22'] = df_m_5['eu_c'].shift(22) 
#21 day ago
df_m_5['eu_High_last_day21'] = df_m_5['eu_h'].shift(21)
df_m_5['eu_Low_last_day21'] = df_m_5['eu_l'].shift(21)
df_m_5['eu_Close_last_day21'] = df_m_5['eu_c'].shift(21)
#20 days ago
df_m_5['eu_High_last_day20'] = df_m_5['eu_h'].shift(20)
df_m_5['eu_Low_last_day20'] = df_m_5['eu_l'].shift(20)
df_m_5['eu_Close_last_day20'] = df_m_5['eu_c'].shift(20) 
#19 days ago 
df_m_5['eu_High_last_day19'] = df_m_5['eu_h'].shift(19)
df_m_5['eu_Low_last_day19'] = df_m_5['eu_l'].shift(19)
df_m_5['eu_Close_last_day19'] = df_m_5['eu_c'].shift(19)
#18 days ago
df_m_5['eu_High_last_day18'] = df_m_5['eu_h'].shift(18)
df_m_5['eu_Low_last_day18'] = df_m_5['eu_l'].shift(18)
df_m_5['eu_Close_last_day18'] = df_m_5['eu_c'].shift(18) 
#17 days ago
df_m_5['eu_High_last_day17'] = df_m_5['eu_h'].shift(17)
df_m_5['eu_Low_last_day17'] = df_m_5['eu_l'].shift(17)
df_m_5['eu_Close_last_day17'] = df_m_5['eu_c'].shift(17) 
#16 day ago
df_m_5['eu_High_last_day16'] = df_m_5['eu_h'].shift(16)
df_m_5['eu_Low_last_day16'] = df_m_5['eu_l'].shift(16)
df_m_5['eu_Close_last_day16'] = df_m_5['eu_c'].shift(16)
#15 days ago
df_m_5['eu_High_last_day15'] = df_m_5['eu_h'].shift(15)
df_m_5['eu_Low_last_day15'] = df_m_5['eu_l'].shift(15)
df_m_5['eu_Close_last_day15'] = df_m_5['eu_c'].shift(15)
#14 days ago 
df_m_5['eu_High_last_day14'] = df_m_5['eu_h'].shift(14)
df_m_5['eu_Low_last_day14'] = df_m_5['eu_l'].shift(14)
df_m_5['eu_Close_last_day14'] = df_m_5['eu_c'].shift(14) 
#13 days ago
df_m_5['eu_High_last_day13'] = df_m_5['eu_h'].shift(13)
df_m_5['eu_Low_last_day13'] = df_m_5['eu_l'].shift(13)
df_m_5['eu_Close_last_day13'] = df_m_5['eu_c'].shift(13) 
#12 days ago
df_m_5['eu_High_last_day12'] = df_m_5['eu_h'].shift(12)
df_m_5['eu_Low_last_day12'] = df_m_5['eu_l'].shift(12)
df_m_5['eu_Close_last_day12'] = df_m_5['eu_c'].shift(12) 
#11 day ago 
df_m_5['eu_High_last_day11'] = df_m_5['eu_h'].shift(11)
df_m_5['eu_Low_last_day11'] = df_m_5['eu_l'].shift(11)
df_m_5['eu_Close_last_day11'] = df_m_5['eu_c'].shift(11) 
#10 days ago
df_m_5['eu_High_last_day10'] = df_m_5['eu_h'].shift(10)
df_m_5['eu_Low_last_day10'] = df_m_5['eu_l'].shift(10)
df_m_5['eu_Close_last_day10'] = df_m_5['eu_c'].shift(10)
#9 days ago 
df_m_5['eu_High_last_day9'] = df_m_5['eu_h'].shift(9)
df_m_5['eu_Low_last_day9'] = df_m_5['eu_l'].shift(9)
df_m_5['eu_Close_last_day9'] = df_m_5['eu_c'].shift(9) 
#8 days ago
df_m_5['eu_High_last_day8'] = df_m_5['eu_h'].shift(8)
df_m_5['eu_Low_last_day8'] = df_m_5['eu_l'].shift(8)
df_m_5['eu_Close_last_day8'] = df_m_5['eu_c'].shift(8)
#7 days ago
df_m_5['eu_High_last_day7'] = df_m_5['eu_h'].shift(7)
df_m_5['eu_Low_last_day7'] = df_m_5['eu_l'].shift(7)
df_m_5['eu_Close_last_day7'] = df_m_5['eu_c'].shift(7) 
#6 day ago 
df_m_5['eu_High_last_day6'] = df_m_5['eu_h'].shift(6)
df_m_5['eu_Low_last_day6'] = df_m_5['eu_l'].shift(6)
df_m_5['eu_Close_last_day6'] = df_m_5['eu_c'].shift(6)
#5 days ago
df_m_5['eu_High_last_day5'] = df_m_5['eu_h'].shift(5)
df_m_5['eu_Low_last_day5'] = df_m_5['eu_l'].shift(5)
df_m_5['eu_Close_last_day5'] = df_m_5['eu_c'].shift(5) 
#4 days ago 
df_m_5['eu_High_last_day4'] = df_m_5['eu_h'].shift(4)
df_m_5['eu_Low_last_day4'] = df_m_5['eu_l'].shift(4)
df_m_5['eu_Close_last_day4'] = df_m_5['eu_c'].shift(4) 
#3 days ago
df_m_5['eu_High_last_day3'] = df_m_5['eu_h'].shift(3)
df_m_5['eu_Low_last_day3'] = df_m_5['eu_l'].shift(3)
df_m_5['eu_Close_last_day3'] = df_m_5['eu_c'].shift(3)
#2 days ago
df_m_5['eu_High_last_day2'] = df_m_5['eu_h'].shift(2)
df_m_5['eu_Low_last_day2'] = df_m_5['eu_l'].shift(2)
df_m_5['eu_Close_last_day2'] = df_m_5['eu_c'].shift(2) 
#1 day ago 
df_m_5['eu_High_last_day1'] = df_m_5['eu_h'].shift(1)
df_m_5['eu_Low_last_day1'] = df_m_5['eu_l'].shift(1)
df_m_5['eu_Close_last_day1'] = df_m_5['eu_c'].shift(1)     

#Target
#1 day forward 
df_m_5['eu_High_next_day1'] = df_m_5['eu_h'].shift(-1)
df_m_5['eu_Low_next_day1'] = df_m_5['eu_l'].shift(-1)
df_m_5['eu_Close_next_day1'] = df_m_5['eu_c'].shift(-1) 

#drop null and useless columns
df_m_5 = df_m_5.dropna()
df_m_5 = df_m_5.drop(['d','t','eu_o','eu_h','eu_l','eu_c','eu_v'], axis=1)

# %%
df_m_5
# Out:
#        eu_High_last_day30  ...  eu_Close_next_day1
# 30                0.53690  ...             0.53840
# 31                0.53660  ...             0.53850
# 32                0.53650  ...             0.53880
# 33                0.53680  ...             0.53870
# 34                0.53710  ...             0.53890
# ...                   ...  ...                 ...
# 12815             1.12983  ...             1.13420
# 12816             1.13549  ...             1.13105
# 12817             1.13449  ...             1.13420
# 12818             1.13243  ...             1.13240
# 12819             1.13190  ...             1.13198
#
# [12790 rows x 93 columns]

# %%
extra_clone = pd.DataFrame(data=df_m_5)
print(extra_clone)

# %%
extra_clone.info()

# %%
#extract yesterday's row to predict today's row
#check if needs to be pd.DataFrame
last_row = pd.DataFrame(data=extra_clone.iloc[-10:,np.r_[0:93]])
last_row

# %%
df_m_5 = pd.DataFrame(data=df_m_5.tail(8000))
df_m_5
# Out:
#        eu_High_last_day30  ...  eu_Close_next_day1
# 4820              1.26410  ...             1.32830
# 4821              1.26990  ...             1.32560
# 4822              1.27760  ...             1.32980
# 4823              1.27680  ...             1.32780
# 4824              1.27790  ...             1.32640
# ...                   ...  ...                 ...
# 12815             1.12983  ...             1.13420
# 12816             1.13549  ...             1.13105
# 12817             1.13449  ...             1.13420
# 12818             1.13243  ...             1.13240
# 12819             1.13190  ...             1.13198
#
# [8000 rows x 93 columns]

# %%
#create initial train and test data as pd.DF for close
#final test DF is last_row
df_m_5_train_close = pd.DataFrame(data=df_m_5.iloc[0:7980,[2,5,8,11,14,17,20,23,26,29,32,35,38,41,44,47,50,53,56,59,62,65,68,71,74,77,80,83,86,89,92]])


df_m_5_test_close = pd.DataFrame(data=df_m_5.iloc[7980:8001,[2,5,8,11,14,17,20,23,26,29,32,35,38,41,44,47,50,53,56,59,62,65,68,71,74,77,80,83,86,89,92]])
print(df_m_5_train_close )
print(df_m_5_test_close )
# Out:
#        eu_Close_last_day30  ...  eu_Close_next_day1
# 4820               1.26350  ...             1.32830
# 4821               1.26860  ...             1.32560
# 4822               1.27570  ...             1.32980
# 4823               1.26560  ...             1.32780
# 4824               1.27660  ...             1.32640
# ...                    ...  ...                 ...
# 12795              1.15929  ...             1.13258
# 12796              1.14783  ...             1.13263
# 12797              1.14495  ...             1.13197
# 12798              1.14427  ...             1.13268
# 12799              1.13672  ...             1.13077
#
# [7980 rows x 31 columns]
#        eu_Close_last_day30  ...  eu_Close_next_day1
# 12800              1.13194  ...             1.13470
# 12801              1.13187  ...             1.13251
# 12802              1.13704  ...             1.13774
# 12803              1.12829  ...             1.12974
# 12804              1.12364  ...             1.12872
# 12805              1.12474  ...             1.13123
# 12806              1.11982  ...             1.12982
# 12807              1.12083  ...             1.13593
# 12808              1.13215  ...             1.13278
# 12809              1.12902  ...             1.13686
# 12810              1.13380  ...             1.14412
# 12811              1.13193  ...             1.14540
# 12812              1.13006  ...             1.14150
# 12813              1.13083  ...             1.14059
# 12814              1.12847  ...             1.13274
# 12815              1.12671  ...             1.13420
# 12816              1.13417  ...             1.13105
# 12817              1.12924  ...             1.13420
# 12818              1.13162  ...             1.13240
# 12819              1.12842  ...             1.13198
#
# [20 rows x 31 columns]

# %%
#create initial train and test data as pd.DF for low
#final test DF is last_row
df_m_5_train_low = pd.DataFrame(data=df_m_5.iloc[0:7980,[1,4,7,10,13,16,19,22,25,28,31,34,37,40,43,46,49,52,55,58,61,64,67,70,73,76,79,82,85,88,91]])


df_m_5_test_low = pd.DataFrame(data=df_m_5.iloc[7980:8001,[1,4,7,10,13,16,19,22,25,28,31,34,37,40,43,46,49,52,55,58,61,64,67,70,73,76,79,82,85,88,91]])
print(df_m_5_train_low )
print(df_m_5_test_low )
# Out:
#        eu_Low_last_day30  eu_Low_last_day29  ...  eu_Low_last_day1  eu_Low_next_day1
# 4820             1.25240            1.26030  ...           1.31620           1.32110
# 4821             1.26030            1.26730  ...           1.32020           1.32320
# 4822             1.26730            1.25830  ...           1.32110           1.32120
# 4823             1.25830            1.26040  ...           1.32320           1.32540
# 4824             1.26040            1.27650  ...           1.32120           1.32320
# ...                  ...                ...  ...               ...               ...
# 12795            1.15697            1.14756  ...           1.12341           1.12642
# 12796            1.14756            1.14429  ...           1.12609           1.12902
# 12797            1.14429            1.14328  ...           1.12642           1.13044
# 12798            1.14328            1.13562  ...           1.12902           1.13027
# 12799            1.13562            1.13088  ...           1.13044           1.12894
#
# [7980 rows x 31 columns]
#        eu_Low_last_day30  eu_Low_last_day29  ...  eu_Low_last_day1  eu_Low_next_day1
# 12800            1.13088            1.12632  ...           1.13027           1.12735
# 12801            1.12632            1.13138  ...           1.12894           1.12984
# 12802            1.13138            1.12498  ...           1.12735           1.13031
# 12803            1.12498            1.12307  ...           1.12984           1.12796
# 12804            1.12307            1.12260  ...           1.13031           1.12722
# 12805            1.12260            1.11861  ...           1.12796           1.12768
# 12806            1.11861            1.11954  ...           1.12722           1.12845
# 12807            1.11954            1.12044  ...           1.12768           1.12899
# 12808            1.12044            1.12584  ...           1.12845           1.12849
# 12809            1.12584            1.12354  ...           1.12899           1.13128
# 12810            1.12354            1.13025  ...           1.12849           1.13545
# 12811            1.13025            1.12952  ...           1.13128           1.14356
# 12812            1.12952            1.12666  ...           1.13545           1.13984
# 12813            1.12666            1.12665  ...           1.14356           1.13916
# 12814            1.12665            1.12274  ...           1.13984           1.13145
# 12815            1.12274            1.12633  ...           1.13916           1.13188
# 12816            1.12633            1.12784  ...           1.13145           1.13030
# 12817            1.12784            1.12649  ...           1.13188           1.13008
# 12818            1.12649            1.12599  ...           1.13030           1.12903
# 12819            1.12599            1.12537  ...           1.13008           1.13198
#
# [20 rows x 31 columns]

# %%
#create initial train and test data as pd.DF for high
#final test DF is last_row
df_m_5_train_high = pd.DataFrame(data=df_m_5.iloc[0:7980,[0,3,6,9,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,84,87,90]])

df_m_5_test_high= pd.DataFrame(data=df_m_5.iloc[7980:8001,[0,3,6,9,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,84,87,90]])
print(df_m_5_train_high )
print(df_m_5_test_high )
# Out:
#        eu_High_last_day30  ...  eu_High_next_day1
# 4820              1.26410  ...            1.33020
# 4821              1.26990  ...            1.32960
# 4822              1.27760  ...            1.33210
# 4823              1.27680  ...            1.33390
# 4824              1.27790  ...            1.32820
# ...                   ...  ...                ...
# 12795             1.16086  ...            1.13423
# 12796             1.15953  ...            1.13422
# 12797             1.14876  ...            1.13435
# 12798             1.14623  ...            1.13344
# 12799             1.14641  ...            1.13331
#
# [7980 rows x 31 columns]
#        eu_High_last_day30  ...  eu_High_next_day1
# 12800             1.13855  ...            1.13686
# 12801             1.13324  ...            1.13598
# 12802             1.13741  ...            1.13863
# 12803             1.13724  ...            1.13782
# 12804             1.12901  ...            1.13224
# 12805             1.12750  ...            1.13463
# 12806             1.12554  ...            1.13317
# 12807             1.12299  ...            1.13646
# 12808             1.13303  ...            1.13605
# 12809             1.13112  ...            1.13752
# 12810             1.13830  ...            1.14526
# 12811             1.13597  ...            1.14816
# 12812             1.13478  ...            1.14827
# 12813             1.13335  ...            1.14342
# 12814             1.13104  ...            1.14213
# 12815             1.12983  ...            1.13570
# 12816             1.13549  ...            1.13688
# 12817             1.13449  ...            1.13597
# 12818             1.13243  ...            1.13448
# 12819             1.13190  ...            1.13229
#
# [20 rows x 31 columns]

# %%
# #new column: high vs low
# df_m_5['eu_h_or_l'] = ((df_m_5.eu_h - df_m_5.eu_o) > (df_m_5.eu_o - df_m_5.eu_l)) 
# df_m_5.eu_h_or_l = df_m_5.eu_h_or_l.replace({True:1,False:0})

# #new column: close vs yesterday
# df_m_5['eu_c_vs_c'] = (df_m_5.eu_c > df_m_5.eu_o) 
# df_m_5.eu_c_vs_c = df_m_5.eu_c_vs_c.replace({True:1,False:0})

# #new column: shift tomorrow to today
# df_m_5['eu_High_next_day'] = df_m_5['eu_h'].shift(-1)
# df_m_5['eu_Low_next_day'] = df_m_5['eu_l'].shift(-1)
# df_m_5['eu_Close_next_day'] = df_m_5['eu_c'].shift(-1)
# df_m_5 = df_m_5.dropna()

# %%
print(df_m_5_train_close.isna().sum())
print(df_m_5_test_close.isna().sum())
# Out:
# eu_Close_last_day30    0
# eu_Close_last_day29    0
# eu_Close_last_day28    0
# eu_Close_last_day27    0
# eu_Close_last_day26    0
# eu_Close_last_day25    0
# eu_Close_last_day24    0
# eu_Close_last_day23    0
# eu_Close_last_day22    0
# eu_Close_last_day21    0
# eu_Close_last_day20    0
# eu_Close_last_day19    0
# eu_Close_last_day18    0
# eu_Close_last_day17    0
# eu_Close_last_day16    0
# eu_Close_last_day15    0
# eu_Close_last_day14    0
# eu_Close_last_day13    0
# eu_Close_last_day12    0
# eu_Close_last_day11    0
# eu_Close_last_day10    0
# eu_Close_last_day9     0
# eu_Close_last_day8     0
# eu_Close_last_day7     0
# eu_Close_last_day6     0
# eu_Close_last_day5     0
# eu_Close_last_day4     0
# eu_Close_last_day3     0
# eu_Close_last_day2     0
# eu_Close_last_day1     0
# eu_Close_next_day1     0
# dtype: int64
# eu_Close_last_day30    0
# eu_Close_last_day29    0
# eu_Close_last_day28    0
# eu_Close_last_day27    0
# eu_Close_last_day26    0
# eu_Close_last_day25    0
# eu_Close_last_day24    0
# eu_Close_last_day23    0
# eu_Close_last_day22    0
# eu_Close_last_day21    0
# eu_Close_last_day20    0
# eu_Close_last_day19    0
# eu_Close_last_day18    0
# eu_Close_last_day17    0
# eu_Close_last_day16    0
# eu_Close_last_day15    0
# eu_Close_last_day14    0
# eu_Close_last_day13    0
# eu_Close_last_day12    0
# eu_Close_last_day11    0
# eu_Close_last_day10    0
# eu_Close_last_day9     0
# eu_Close_last_day8     0
# eu_Close_last_day7     0
# eu_Close_last_day6     0
# eu_Close_last_day5     0
# eu_Close_last_day4     0
# eu_Close_last_day3     0
# eu_Close_last_day2     0
# eu_Close_last_day1     0
# eu_Close_next_day1     0
# dtype: int64

# %%
print(df_m_5_train_close.info())
print(df_m_5_test_close.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7980 entries, 4820 to 12799
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eu_Close_last_day30  7980 non-null   float64
#  1   eu_Close_last_day29  7980 non-null   float64
#  2   eu_Close_last_day28  7980 non-null   float64
#  3   eu_Close_last_day27  7980 non-null   float64
#  4   eu_Close_last_day26  7980 non-null   float64
#  5   eu_Close_last_day25  7980 non-null   float64
#  6   eu_Close_last_day24  7980 non-null   float64
#  7   eu_Close_last_day23  7980 non-null   float64
#  8   eu_Close_last_day22  7980 non-null   float64
#  9   eu_Close_last_day21  7980 non-null   float64
#  10  eu_Close_last_day20  7980 non-null   float64
#  11  eu_Close_last_day19  7980 non-null   float64
#  12  eu_Close_last_day18  7980 non-null   float64
#  13  eu_Close_last_day17  7980 non-null   float64
#  14  eu_Close_last_day16  7980 non-null   float64
#  15  eu_Close_last_day15  7980 non-null   float64
#  16  eu_Close_last_day14  7980 non-null   float64
#  17  eu_Close_last_day13  7980 non-null   float64
#  18  eu_Close_last_day12  7980 non-null   float64
#  19  eu_Close_last_day11  7980 non-null   float64
#  20  eu_Close_last_day10  7980 non-null   float64
#  21  eu_Close_last_day9   7980 non-null   float64
#  22  eu_Close_last_day8   7980 non-null   float64
#  23  eu_Close_last_day7   7980 non-null   float64
#  24  eu_Close_last_day6   7980 non-null   float64
#  25  eu_Close_last_day5   7980 non-null   float64
#  26  eu_Close_last_day4   7980 non-null   float64
#  27  eu_Close_last_day3   7980 non-null   float64
#  28  eu_Close_last_day2   7980 non-null   float64
#  29  eu_Close_last_day1   7980 non-null   float64
#  30  eu_Close_next_day1   7980 non-null   float64
# dtypes: float64(31)
# memory usage: 1.9 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 12800 to 12819
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eu_Close_last_day30  20 non-null     float64
#  1   eu_Close_last_day29  20 non-null     float64
#  2   eu_Close_last_day28  20 non-null     float64
#  3   eu_Close_last_day27  20 non-null     float64
#  4   eu_Close_last_day26  20 non-null     float64
#  5   eu_Close_last_day25  20 non-null     float64
#  6   eu_Close_last_day24  20 non-null     float64
#  7   eu_Close_last_day23  20 non-null     float64
#  8   eu_Close_last_day22  20 non-null     float64
#  9   eu_Close_last_day21  20 non-null     float64
#  10  eu_Close_last_day20  20 non-null     float64
#  11  eu_Close_last_day19  20 non-null     float64
#  12  eu_Close_last_day18  20 non-null     float64
#  13  eu_Close_last_day17  20 non-null     float64
#  14  eu_Close_last_day16  20 non-null     float64
#  15  eu_Close_last_day15  20 non-null     float64
#  16  eu_Close_last_day14  20 non-null     float64
#  17  eu_Close_last_day13  20 non-null     float64
#  18  eu_Close_last_day12  20 non-null     float64
#  19  eu_Close_last_day11  20 non-null     float64
#  20  eu_Close_last_day10  20 non-null     float64
#  21  eu_Close_last_day9   20 non-null     float64
#  22  eu_Close_last_day8   20 non-null     float64
#  23  eu_Close_last_day7   20 non-null     float64
#  24  eu_Close_last_day6   20 non-null     float64
#  25  eu_Close_last_day5   20 non-null     float64
#  26  eu_Close_last_day4   20 non-null     float64
#  27  eu_Close_last_day3   20 non-null     float64
#  28  eu_Close_last_day2   20 non-null     float64
#  29  eu_Close_last_day1   20 non-null     float64
#  30  eu_Close_next_day1   20 non-null     float64
# dtypes: float64(31)
# memory usage: 5.0 KB
# None

# %%
print(df_m_5_train_high.isna().sum())
print(df_m_5_test_high.isna().sum())
print(df_m_5_train_high.info())
print(df_m_5_test_high.info())
# Out:
# eu_High_last_day30    0
# eu_High_last_day29    0
# eu_High_last_day28    0
# eu_High_last_day27    0
# eu_High_last_day26    0
# eu_High_last_day25    0
# eu_High_last_day24    0
# eu_High_last_day23    0
# eu_High_last_day22    0
# eu_High_last_day21    0
# eu_High_last_day20    0
# eu_High_last_day19    0
# eu_High_last_day18    0
# eu_High_last_day17    0
# eu_High_last_day16    0
# eu_High_last_day15    0
# eu_High_last_day14    0
# eu_High_last_day13    0
# eu_High_last_day12    0
# eu_High_last_day11    0
# eu_High_last_day10    0
# eu_High_last_day9     0
# eu_High_last_day8     0
# eu_High_last_day7     0
# eu_High_last_day6     0
# eu_High_last_day5     0
# eu_High_last_day4     0
# eu_High_last_day3     0
# eu_High_last_day2     0
# eu_High_last_day1     0
# eu_High_next_day1     0
# dtype: int64
# eu_High_last_day30    0
# eu_High_last_day29    0
# eu_High_last_day28    0
# eu_High_last_day27    0
# eu_High_last_day26    0
# eu_High_last_day25    0
# eu_High_last_day24    0
# eu_High_last_day23    0
# eu_High_last_day22    0
# eu_High_last_day21    0
# eu_High_last_day20    0
# eu_High_last_day19    0
# eu_High_last_day18    0
# eu_High_last_day17    0
# eu_High_last_day16    0
# eu_High_last_day15    0
# eu_High_last_day14    0
# eu_High_last_day13    0
# eu_High_last_day12    0
# eu_High_last_day11    0
# eu_High_last_day10    0
# eu_High_last_day9     0
# eu_High_last_day8     0
# eu_High_last_day7     0
# eu_High_last_day6     0
# eu_High_last_day5     0
# eu_High_last_day4     0
# eu_High_last_day3     0
# eu_High_last_day2     0
# eu_High_last_day1     0
# eu_High_next_day1     0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7980 entries, 4820 to 12799
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   eu_High_last_day30  7980 non-null   float64
#  1   eu_High_last_day29  7980 non-null   float64
#  2   eu_High_last_day28  7980 non-null   float64
#  3   eu_High_last_day27  7980 non-null   float64
#  4   eu_High_last_day26  7980 non-null   float64
#  5   eu_High_last_day25  7980 non-null   float64
#  6   eu_High_last_day24  7980 non-null   float64
#  7   eu_High_last_day23  7980 non-null   float64
#  8   eu_High_last_day22  7980 non-null   float64
#  9   eu_High_last_day21  7980 non-null   float64
#  10  eu_High_last_day20  7980 non-null   float64
#  11  eu_High_last_day19  7980 non-null   float64
#  12  eu_High_last_day18  7980 non-null   float64
#  13  eu_High_last_day17  7980 non-null   float64
#  14  eu_High_last_day16  7980 non-null   float64
#  15  eu_High_last_day15  7980 non-null   float64
#  16  eu_High_last_day14  7980 non-null   float64
#  17  eu_High_last_day13  7980 non-null   float64
#  18  eu_High_last_day12  7980 non-null   float64
#  19  eu_High_last_day11  7980 non-null   float64
#  20  eu_High_last_day10  7980 non-null   float64
#  21  eu_High_last_day9   7980 non-null   float64
#  22  eu_High_last_day8   7980 non-null   float64
#  23  eu_High_last_day7   7980 non-null   float64
#  24  eu_High_last_day6   7980 non-null   float64
#  25  eu_High_last_day5   7980 non-null   float64
#  26  eu_High_last_day4   7980 non-null   float64
#  27  eu_High_last_day3   7980 non-null   float64
#  28  eu_High_last_day2   7980 non-null   float64
#  29  eu_High_last_day1   7980 non-null   float64
#  30  eu_High_next_day1   7980 non-null   float64
# dtypes: float64(31)
# memory usage: 1.9 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 12800 to 12819
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   eu_High_last_day30  20 non-null     float64
#  1   eu_High_last_day29  20 non-null     float64
#  2   eu_High_last_day28  20 non-null     float64
#  3   eu_High_last_day27  20 non-null     float64
#  4   eu_High_last_day26  20 non-null     float64
#  5   eu_High_last_day25  20 non-null     float64
#  6   eu_High_last_day24  20 non-null     float64
#  7   eu_High_last_day23  20 non-null     float64
#  8   eu_High_last_day22  20 non-null     float64
#  9   eu_High_last_day21  20 non-null     float64
#  10  eu_High_last_day20  20 non-null     float64
#  11  eu_High_last_day19  20 non-null     float64
#  12  eu_High_last_day18  20 non-null     float64
#  13  eu_High_last_day17  20 non-null     float64
#  14  eu_High_last_day16  20 non-null     float64
#  15  eu_High_last_day15  20 non-null     float64
#  16  eu_High_last_day14  20 non-null     float64
#  17  eu_High_last_day13  20 non-null     float64
#  18  eu_High_last_day12  20 non-null     float64
#  19  eu_High_last_day11  20 non-null     float64
#  20  eu_High_last_day10  20 non-null     float64
#  21  eu_High_last_day9   20 non-null     float64
#  22  eu_High_last_day8   20 non-null     float64
#  23  eu_High_last_day7   20 non-null     float64
#  24  eu_High_last_day6   20 non-null     float64
#  25  eu_High_last_day5   20 non-null     float64
#  26  eu_High_last_day4   20 non-null     float64
#  27  eu_High_last_day3   20 non-null     float64
#  28  eu_High_last_day2   20 non-null     float64
#  29  eu_High_last_day1   20 non-null     float64
#  30  eu_High_next_day1   20 non-null     float64
# dtypes: float64(31)
# memory usage: 5.0 KB
# None

# %%
print(df_m_5_train_low.isna().sum())
print(df_m_5_test_low.isna().sum())
print(df_m_5_train_low.info())
print(df_m_5_test_low.info())
# Out:
# eu_Low_last_day30    0
# eu_Low_last_day29    0
# eu_Low_last_day28    0
# eu_Low_last_day27    0
# eu_Low_last_day26    0
# eu_Low_last_day25    0
# eu_Low_last_day24    0
# eu_Low_last_day23    0
# eu_Low_last_day22    0
# eu_Low_last_day21    0
# eu_Low_last_day20    0
# eu_Low_last_day19    0
# eu_Low_last_day18    0
# eu_Low_last_day17    0
# eu_Low_last_day16    0
# eu_Low_last_day15    0
# eu_Low_last_day14    0
# eu_Low_last_day13    0
# eu_Low_last_day12    0
# eu_Low_last_day11    0
# eu_Low_last_day10    0
# eu_Low_last_day9     0
# eu_Low_last_day8     0
# eu_Low_last_day7     0
# eu_Low_last_day6     0
# eu_Low_last_day5     0
# eu_Low_last_day4     0
# eu_Low_last_day3     0
# eu_Low_last_day2     0
# eu_Low_last_day1     0
# eu_Low_next_day1     0
# dtype: int64
# eu_Low_last_day30    0
# eu_Low_last_day29    0
# eu_Low_last_day28    0
# eu_Low_last_day27    0
# eu_Low_last_day26    0
# eu_Low_last_day25    0
# eu_Low_last_day24    0
# eu_Low_last_day23    0
# eu_Low_last_day22    0
# eu_Low_last_day21    0
# eu_Low_last_day20    0
# eu_Low_last_day19    0
# eu_Low_last_day18    0
# eu_Low_last_day17    0
# eu_Low_last_day16    0
# eu_Low_last_day15    0
# eu_Low_last_day14    0
# eu_Low_last_day13    0
# eu_Low_last_day12    0
# eu_Low_last_day11    0
# eu_Low_last_day10    0
# eu_Low_last_day9     0
# eu_Low_last_day8     0
# eu_Low_last_day7     0
# eu_Low_last_day6     0
# eu_Low_last_day5     0
# eu_Low_last_day4     0
# eu_Low_last_day3     0
# eu_Low_last_day2     0
# eu_Low_last_day1     0
# eu_Low_next_day1     0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7980 entries, 4820 to 12799
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   eu_Low_last_day30  7980 non-null   float64
#  1   eu_Low_last_day29  7980 non-null   float64
#  2   eu_Low_last_day28  7980 non-null   float64
#  3   eu_Low_last_day27  7980 non-null   float64
#  4   eu_Low_last_day26  7980 non-null   float64
#  5   eu_Low_last_day25  7980 non-null   float64
#  6   eu_Low_last_day24  7980 non-null   float64
#  7   eu_Low_last_day23  7980 non-null   float64
#  8   eu_Low_last_day22  7980 non-null   float64
#  9   eu_Low_last_day21  7980 non-null   float64
#  10  eu_Low_last_day20  7980 non-null   float64
#  11  eu_Low_last_day19  7980 non-null   float64
#  12  eu_Low_last_day18  7980 non-null   float64
#  13  eu_Low_last_day17  7980 non-null   float64
#  14  eu_Low_last_day16  7980 non-null   float64
#  15  eu_Low_last_day15  7980 non-null   float64
#  16  eu_Low_last_day14  7980 non-null   float64
#  17  eu_Low_last_day13  7980 non-null   float64
#  18  eu_Low_last_day12  7980 non-null   float64
#  19  eu_Low_last_day11  7980 non-null   float64
#  20  eu_Low_last_day10  7980 non-null   float64
#  21  eu_Low_last_day9   7980 non-null   float64
#  22  eu_Low_last_day8   7980 non-null   float64
#  23  eu_Low_last_day7   7980 non-null   float64
#  24  eu_Low_last_day6   7980 non-null   float64
#  25  eu_Low_last_day5   7980 non-null   float64
#  26  eu_Low_last_day4   7980 non-null   float64
#  27  eu_Low_last_day3   7980 non-null   float64
#  28  eu_Low_last_day2   7980 non-null   float64
#  29  eu_Low_last_day1   7980 non-null   float64
#  30  eu_Low_next_day1   7980 non-null   float64
# dtypes: float64(31)
# memory usage: 1.9 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 12800 to 12819
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   eu_Low_last_day30  20 non-null     float64
#  1   eu_Low_last_day29  20 non-null     float64
#  2   eu_Low_last_day28  20 non-null     float64
#  3   eu_Low_last_day27  20 non-null     float64
#  4   eu_Low_last_day26  20 non-null     float64
#  5   eu_Low_last_day25  20 non-null     float64
#  6   eu_Low_last_day24  20 non-null     float64
#  7   eu_Low_last_day23  20 non-null     float64
#  8   eu_Low_last_day22  20 non-null     float64
#  9   eu_Low_last_day21  20 non-null     float64
#  10  eu_Low_last_day20  20 non-null     float64
#  11  eu_Low_last_day19  20 non-null     float64
#  12  eu_Low_last_day18  20 non-null     float64
#  13  eu_Low_last_day17  20 non-null     float64
#  14  eu_Low_last_day16  20 non-null     float64
#  15  eu_Low_last_day15  20 non-null     float64
#  16  eu_Low_last_day14  20 non-null     float64
#  17  eu_Low_last_day13  20 non-null     float64
#  18  eu_Low_last_day12  20 non-null     float64
#  19  eu_Low_last_day11  20 non-null     float64
#  20  eu_Low_last_day10  20 non-null     float64
#  21  eu_Low_last_day9   20 non-null     float64
#  22  eu_Low_last_day8   20 non-null     float64
#  23  eu_Low_last_day7   20 non-null     float64
#  24  eu_Low_last_day6   20 non-null     float64
#  25  eu_Low_last_day5   20 non-null     float64
#  26  eu_Low_last_day4   20 non-null     float64
#  27  eu_Low_last_day3   20 non-null     float64
#  28  eu_Low_last_day2   20 non-null     float64
#  29  eu_Low_last_day1   20 non-null     float64
#  30  eu_Low_next_day1   20 non-null     float64
# dtypes: float64(31)
# memory usage: 5.0 KB
# None

# %%
train_close = df_m_5_train_close
train_close=train_close.sample(n=7900, replace=True)
train_close.head()
# Out:
#        eu_Close_last_day30  ...  eu_Close_next_day1
# 8775               1.28000  ...             1.25760
# 5288               1.38780  ...             1.32960
# 12632              1.17677  ...             1.21618
# 7511               0.85550  ...             0.91310
# 7571               0.91820  ...             0.88270
#
# [5 rows x 31 columns]

# %%
#predict close
label_c = 'eu_Close_next_day1' 
print("Summary of class variable: \n", train_close[label_c].describe())
# Out:
# Summary of class variable:
#  count    7900.000000
# mean        1.203284
# std         0.145514
# min         0.826700
# 25%         1.116693
# 50%         1.198090
# 75%         1.309290
# max         1.599700
# Name: eu_Close_next_day1, dtype: float64

# %%
#predict close
save_path='agModels-predictClose'
predictor = TabularPredictor(label=label_c, path=save_path)
predictor.fit(train_close)#, presets='best_quality')
#.fit(presets='best_quality) is slower
# Out:
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClose/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    7900
# Train Data Columns: 30
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.5997, 0.8267, 1.20328, 0.14551)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12367.89 MB
# 	Train Data (Original)  Memory Usage: 1.9 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 30 | ['eu_Close_last_day30', 'eu_Close_last_day29', 'eu_Close_last_day28', 'eu_Close_last_day27', 'eu_Close_last_day26', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 30 | ['eu_Close_last_day30', 'eu_Close_last_day29', 'eu_Close_last_day28', 'eu_Close_last_day27', 'eu_Close_last_day26', ...]
# 	0.1s = Fit runtime
# 	30 features in original data used to generate 30 features in processed data.
# 	Train Data (Processed) Memory Usage: 1.9 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.19s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 7110, Val Rows: 790
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-0.0097	 = Validation score   (root_mean_squared_error)
# 	0.03s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-0.0068	 = Validation score   (root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: LightGBMXT ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00862836	valid_set's rmse: 0.0101813
# [2000]	train_set's rmse: 0.00713961	valid_set's rmse: 0.00936857
# [3000]	train_set's rmse: 0.00621633	valid_set's rmse: 0.00893222
# [4000]	train_set's rmse: 0.00554321	valid_set's rmse: 0.00864001
# [5000]	train_set's rmse: 0.00502233	valid_set's rmse: 0.00844662
# [6000]	train_set's rmse: 0.00458026	valid_set's rmse: 0.00828118
# [7000]	train_set's rmse: 0.00420396	valid_set's rmse: 0.00816969
# [8000]	train_set's rmse: 0.00388427	valid_set's rmse: 0.0080713
# [9000]	train_set's rmse: 0.00361217	valid_set's rmse: 0.00798413
# [10000]	train_set's rmse: 0.00336835	valid_set's rmse: 0.00792029
# 	-0.0079	 = Validation score   (root_mean_squared_error)
# 	18.72s	 = Training   runtime
# 	1.41s	 = Validation runtime
# Fitting model: LightGBM ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00320746	valid_set's rmse: 0.00799036
# [2000]	train_set's rmse: 0.0015147	valid_set's rmse: 0.00770965
# [3000]	train_set's rmse: 0.000789455	valid_set's rmse: 0.00765732
# [4000]	train_set's rmse: 0.000428245	valid_set's rmse: 0.00765114

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_close, silent=True)

# %%
#predict close
test_close = TabularDataset(df_m_5_test_close)
y_test = test_close[label_c]
test_close_nolab = test_close.drop(columns=[label_c])
test_close_nolab.tail()

# %%
#predict eu_Close_next_day1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_close_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)

# %%
#predict high
train_high = df_m_5_train_high
train_high=train_high.sample(n=7900, replace=True)
train_high.head()

# %%
#predict high
label_h = 'eu_High_next_day1' 
print("Summary of class variable: \n", train_high[label_h].describe())

# %%
#predict high
save_path='agModels-predictHigh'
predictor = TabularPredictor(label=label_h, path=save_path).fit(train_high)#, presets='best_quality')
#.fit(presets='best_quality) is slower

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_high, silent=True)

# %%
#predict high
test_high = TabularDataset(df_m_5_test_high)
y_test = test_high[label_h]
test_high_nolab = test_high.drop(columns=[label_h])
test_high_nolab.tail()

# %%
#first run to predict eu_High_next_day1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_high_nolab)
print("Predictions: \n", y_pred) #try print more rows
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)

# %%
#predict low
train_low = df_m_5_train_low
train_low=train_low.sample(n=7900, replace=True)
train_low.head()

# %%
#predict low
label_l = 'eu_Low_next_day1' 
print("Summary of class variable: \n", train_low[label_l].describe())

# %%
#predict low
save_path='agModels-predictLow'
predictor = TabularPredictor(label=label_l, path=save_path).fit(train_low)#, presets='best_quality')
#.fit(presets='best_quality) is slower

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_low, silent=True)

# %%
#predict low
test_low = TabularDataset(df_m_5_test_low)
y_test = test_low[label_l]
test_low_nolab = test_low.drop(columns=[label_l])
test_low_nolab.tail()

# %%
#predict eu_Low_next_day1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_low_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
