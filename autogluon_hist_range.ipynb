# %% [markdown]
# <a href="https://colab.research.google.com/github/gomlfx/ApiaryFund/blob/master/autogluon_hist_range.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install autogluon
# Out:
# Requirement already satisfied: autogluon in /usr/local/lib/python3.7/dist-packages (0.3.1)
# Requirement already satisfied: autogluon.extra==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.tabular[all]==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.features==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.text==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.vision==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.core==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.mxnet==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: scikit-learn<0.25,>=0.23.2 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.24.2)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.20.24)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.29.24)
# Requirement already satisfied: distributed>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2021.12.0)
# Requirement already satisfied: dask>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2021.12.0)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (4.62.3)
# Requirement already satisfied: paramiko>=2.4 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2.8.1)
# Requirement already satisfied: scipy<1.7,>=1.5.4 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.6.3)
# Requirement already satisfied: ConfigSpace==0.4.19 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.4.19)
# Requirement already satisfied: numpy<1.22,>=1.19 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.19.5)
# Requirement already satisfied: autograd>=1.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.3)
# Requirement already satisfied: dill<1.0,>=0.3.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.3.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2.23.0)
# Requirement already satisfied: pandas<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.1.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (3.2.2)
# Requirement already satisfied: graphviz<1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.8.4)
# Requirement already satisfied: tornado>=5.0.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (5.1.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.3.1->autogluon) (3.6.4)
# Requirement already satisfied: gluoncv<0.10.5,>=0.10.4 in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.3.1->autogluon) (0.10.4.post4)
# Requirement already satisfied: openml in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.3.1->autogluon) (0.12.2)
# Requirement already satisfied: Pillow<8.4.0,>=8.3.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.mxnet==0.3.1->autogluon) (8.3.2)
# Requirement already satisfied: networkx<3.0,>=2.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.6.3)
# Requirement already satisfied: psutil<5.9,>=5.7.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (5.8.0)
# Requirement already satisfied: fastai<3.0,>=2.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.5.3)
# Requirement already satisfied: xgboost<1.5,>=1.4 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.4.2)
# Requirement already satisfied: lightgbm<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (3.3.1)
# Requirement already satisfied: torch<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.10.0+cu111)
# Requirement already satisfied: catboost<0.26,>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (0.25.1)
# Requirement already satisfied: autogluon-contrib-nlp==0.0.1b20210201 in /usr/local/lib/python3.7/dist-packages (from autogluon.text==0.3.1->autogluon) (0.0.1b20210201)
# Requirement already satisfied: sentencepiece==0.1.95 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.1.95)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2019.12.20)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.0.0)
# Requirement already satisfied: yacs>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.1.8)
# Requirement already satisfied: contextvars in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.4)
# Requirement already satisfied: tokenizers==0.9.4 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.9.4)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.17.3)
# Requirement already satisfied: flake8 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (4.0.1)
# Requirement already satisfied: sacremoses>=0.0.38 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.0.46)
# Requirement already satisfied: d8<1.0,>=0.0.2 in /usr/local/lib/python3.7/dist-packages (from autogluon.vision==0.3.1->autogluon) (0.0.2.post0)
# Requirement already satisfied: timm-clean==0.4.12 in /usr/local/lib/python3.7/dist-packages (from autogluon.vision==0.3.1->autogluon) (0.4.12)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace==0.4.19->autogluon.core==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd>=1.3->autogluon.core==0.3.1->autogluon) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.15.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (4.4.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (2.0.2)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.5.12)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (21.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (2021.11.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (1.2.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (0.11.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (3.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.11.3)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.7.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.3)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (7.1.2)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (57.4.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.0.5)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.2.4)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.11.1+cu111)
# Requirement already satisfied: fastcore<1.4,>=1.3.22 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.3.27)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (21.1.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (4.1.2.30)
# Requirement already satisfied: autocfg in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (0.0.8)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (2.3.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm<4.0,>=3.0->autogluon.tabular[all]==0.3.1->autogluon) (0.37.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2018.9)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.7/dist-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (36.0.1)
# Requirement already satisfied: bcrypt>=3.1.3 in /usr/local/lib/python3.7/dist-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (3.2.0)
# Requirement already satisfied: pynacl>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.4.0)
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (2.21)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask>=2.6.0->autogluon.core==0.3.1->autogluon) (0.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.38->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (3.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.8.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (7.4.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (4.2.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.6.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (1.25.11)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: botocore<1.24.0,>=1.23.24 in /usr/local/lib/python3.7/dist-packages (from boto3->autogluon.core==0.3.1->autogluon) (1.23.24)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->autogluon.core==0.3.1->autogluon) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->autogluon.core==0.3.1->autogluon) (0.10.0)
# Requirement already satisfied: immutables>=0.9 in /usr/local/lib/python3.7/dist-packages (from contextvars->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.16)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.6.1)
# Requirement already satisfied: pyflakes<2.5.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.4.0)
# Requirement already satisfied: pycodestyle<2.9.0,>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.8.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (5.0.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (0.11.0)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.7/dist-packages (from openml->autogluon.extra==0.3.1->autogluon) (0.12.0)
# Requirement already satisfied: minio in /usr/local/lib/python3.7/dist-packages (from openml->autogluon.extra==0.3.1->autogluon) (7.1.2)
# Requirement already satisfied: liac-arff>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from openml->autogluon.extra==0.3.1->autogluon) (2.5.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly->catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (21.2.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.11.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.4.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (8.12.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.8.9)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.4.4)

# %%
# !pip install mxnet --upgrade
# Out:
# Requirement already satisfied: mxnet in /usr/local/lib/python3.7/dist-packages (1.9.0)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from mxnet) (0.8.4)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (1.19.5)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (1.25.11)

# %%
#designed for Jupyter/kaggle/colab
import pandas as pd
import numpy as np
#import matplotlib for plotting 
import matplotlib.pyplot as plt
# %matplotlib inline
#import normalization
from sklearn import preprocessing
import xgboost as xg
from sklearn.ensemble import RandomForestRegressor as rf
#import auto hyperparameter tuning
#from flaml import AutoML
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from lightgbm import LGBMRegressor

#autogluon
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
 #MT4 csv 
df1=pd.read_csv('EURUSD1440.csv', names=['d','t','eu_o','eu_h','eu_l','eu_c','eu_v'])
df_m_5 = df1.tail(2000)
df2 = df1.tail(2000)
# df2=pd.read_csv('GBPUSD1440.csv', names=['d','t','gu_o','gu_h','gu_l','gu_c','gu_v'])
# df2 = df2.tail(2000)

# df3=pd.read_csv('USDCAD1440.csv', names=['d','t','uc_o','uc_h','uc_l','uc_c','uc_v'])
# df3 = df3.tail(2000)

# df4=pd.read_csv('USDCHF1440.csv', names=['d','t','uf_o','uf_h','uf_l','uf_c','uf_v'])
# df4 = df4.tail(2000)

# df5=pd.read_csv('USDJPY1440.csv', names=['d','t','uj_o','uj_h','uj_l','uj_c','uj_v'])
# df5 = df5.tail(2000)

# df6=pd.read_csv('USDSEK1440.csv', names=['d','t','us_o','us_h','us_l','us_c','us_v'])
# df6 = df6.tail(2000)

# #using merge
# df_m_1 = df1.merge(df2, on='d')
# df_m_2 = df_m_1.merge(df3, on='d')
# df_m_3 = df_m_2.merge(df4, on='d')
# df_m_4 = df_m_3.merge(df5, on='d')
# df_m_5 = df_m_4.merge(df6, on='d')
# df_m_5 = df_m_5.drop(columns='t_x')
# df_m_5 = df_m_5.drop(columns='t_y')

# pd.set_option('display.max_columns', None)
# print(df_m_5)

# %%
df2.tail()
# Out:
#                 d      t     eu_o     eu_h     eu_l     eu_c   eu_v
# 12789  2021.12.13  00:00  1.13106  1.13191  1.12599  1.12854  67794
# 12790  2021.12.14  00:00  1.12828  1.13236  1.12535  1.12577  69981
# 12791  2021.12.15  00:00  1.12549  1.12990  1.12215  1.12936  93710
# 12792  2021.12.16  00:00  1.12865  1.13602  1.12810  1.13304  93130
# 12793  2021.12.17  00:00  1.13245  1.13346  1.13240  1.13312     92

# %%
#Features
#1 day ago (features)
df_m_5['eu_High_last_day1'] = df_m_5['eu_h'].shift(1)
df_m_5['eu_Low_last_day1'] = df_m_5['eu_l'].shift(1)
df_m_5['eu_Close_last_day1'] = df_m_5['eu_c'].shift(1) 
#2 days ago
df_m_5['eu_High_last_day2'] = df_m_5['eu_h'].shift(2)
df_m_5['eu_Low_last_day2'] = df_m_5['eu_l'].shift(2)
df_m_5['eu_Close_last_day2'] = df_m_5['eu_c'].shift(2) 
#3 days ago
df_m_5['eu_High_last_day3'] = df_m_5['eu_h'].shift(3)
df_m_5['eu_Low_last_day3'] = df_m_5['eu_l'].shift(3)
df_m_5['eu_Close_last_day3'] = df_m_5['eu_c'].shift(3) 
#4 days ago 
df_m_5['eu_High_last_day4'] = df_m_5['eu_h'].shift(4)
df_m_5['eu_Low_last_day4'] = df_m_5['eu_l'].shift(4)
df_m_5['eu_Close_last_day4'] = df_m_5['eu_c'].shift(4) 
#5 days ago
df_m_5['eu_High_last_day5'] = df_m_5['eu_h'].shift(5)
df_m_5['eu_Low_last_day5'] = df_m_5['eu_l'].shift(5)
df_m_5['eu_Close_last_day5'] = df_m_5['eu_c'].shift(5) 
#6 day ago (features)
df_m_5['eu_High_last_day6'] = df_m_5['eu_h'].shift(6)
df_m_5['eu_Low_last_day6'] = df_m_5['eu_l'].shift(6)
df_m_5['eu_Close_last_day6'] = df_m_5['eu_c'].shift(6) 
#7 days ago
df_m_5['eu_High_last_day7'] = df_m_5['eu_h'].shift(7)
df_m_5['eu_Low_last_day7'] = df_m_5['eu_l'].shift(7)
df_m_5['eu_Close_last_day7'] = df_m_5['eu_c'].shift(7) 
#8 days ago
df_m_5['eu_High_last_day8'] = df_m_5['eu_h'].shift(8)
df_m_5['eu_Low_last_day8'] = df_m_5['eu_l'].shift(8)
df_m_5['eu_Close_last_day8'] = df_m_5['eu_c'].shift(8) 
#9 days ago 
df_m_5['eu_High_last_day9'] = df_m_5['eu_h'].shift(9)
df_m_5['eu_Low_last_day9'] = df_m_5['eu_l'].shift(9)
df_m_5['eu_Close_last_day9'] = df_m_5['eu_c'].shift(9) 
#10 days ago
df_m_5['eu_High_last_day10'] = df_m_5['eu_h'].shift(10)
df_m_5['eu_Low_last_day10'] = df_m_5['eu_l'].shift(10)
df_m_5['eu_Close_last_day10'] = df_m_5['eu_c'].shift(10) 

#Target
#1 day forward 
df_m_5['eu_High_next_day1'] = df_m_5['eu_h'].shift(-1)
df_m_5['eu_Low_next_day1'] = df_m_5['eu_l'].shift(-1)
df_m_5['eu_Close_next_day1'] = df_m_5['eu_c'].shift(-1) 

#drop null and useless columns
df_m_5 = df_m_5.dropna()
df_m_5 = df_m_5.drop(['t','eu_v'], axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_m_5
# Out:
#                 d     eu_o  ...  eu_Low_next_day1  eu_Close_next_day1
# 10804  2014.04.17  1.38160  ...           1.38068             1.38068
# 10805  2014.04.18  1.38130  ...           1.37869             1.37944
# 10806  2014.04.21  1.38164  ...           1.37849             1.38053
# 10807  2014.04.22  1.37945  ...           1.38001             1.38160
# 10808  2014.04.23  1.38052  ...           1.37912             1.38312
# ...           ...      ...  ...               ...                 ...
# 12788  2021.12.10  1.12913  ...           1.12599             1.12854
# 12789  2021.12.13  1.13106  ...           1.12535             1.12577
# 12790  2021.12.14  1.12828  ...           1.12215             1.12936
# 12791  2021.12.15  1.12549  ...           1.12810             1.13304
# 12792  2021.12.16  1.12865  ...           1.13240             1.13312
#
# [1989 rows x 38 columns]

# %%
df_m_5.insert(1,'index',df_m_5.index)

# %%
# #new column: high vs low
# df_m_5['eu_h_or_l'] = ((df_m_5.eu_h - df_m_5.eu_o) > (df_m_5.eu_o - df_m_5.eu_l)) 
# df_m_5.eu_h_or_l = df_m_5.eu_h_or_l.replace({True:1,False:0})

# #new column: close vs yesterday
# df_m_5['eu_c_vs_c'] = (df_m_5.eu_c > df_m_5.eu_o) 
# df_m_5.eu_c_vs_c = df_m_5.eu_c_vs_c.replace({True:1,False:0})

# #new column: shift tomorrow to today
# df_m_5['eu_High_next_day'] = df_m_5['eu_h'].shift(-1)
# df_m_5['eu_Low_next_day'] = df_m_5['eu_l'].shift(-1)
# df_m_5['eu_Close_next_day'] = df_m_5['eu_c'].shift(-1)
# df_m_5 = df_m_5.dropna()

# %%
df_m_5.tail()
# Out:
#                 d  index  ...  eu_Low_next_day1  eu_Close_next_day1
# 12788  2021.12.10  12788  ...           1.12599             1.12854
# 12789  2021.12.13  12789  ...           1.12535             1.12577
# 12790  2021.12.14  12790  ...           1.12215             1.12936
# 12791  2021.12.15  12791  ...           1.12810             1.13304
# 12792  2021.12.16  12792  ...           1.13240             1.13312
#
# [5 rows x 39 columns]

# %%
df_m_5.isna().sum()
# Out:
# d                      0
# index                  0
# eu_o                   0
# eu_h                   0
# eu_l                   0
# eu_c                   0
# eu_High_last_day1      0
# eu_Low_last_day1       0
# eu_Close_last_day1     0
# eu_High_last_day2      0
# eu_Low_last_day2       0
# eu_Close_last_day2     0
# eu_High_last_day3      0
# eu_Low_last_day3       0
# eu_Close_last_day3     0
# eu_High_last_day4      0
# eu_Low_last_day4       0
# eu_Close_last_day4     0
# eu_High_last_day5      0
# eu_Low_last_day5       0
# eu_Close_last_day5     0
# eu_High_last_day6      0
# eu_Low_last_day6       0
# eu_Close_last_day6     0
# eu_High_last_day7      0
# eu_Low_last_day7       0
# eu_Close_last_day7     0
# eu_High_last_day8      0
# eu_Low_last_day8       0
# eu_Close_last_day8     0
# eu_High_last_day9      0
# eu_Low_last_day9       0
# eu_Close_last_day9     0
# eu_High_last_day10     0
# eu_Low_last_day10      0
# eu_Close_last_day10    0
# eu_High_next_day1      0
# eu_Low_next_day1       0
# eu_Close_next_day1     0
# dtype: int64

# %%
df_m_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1989 entries, 10804 to 12792
# Data columns (total 39 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   d                    1989 non-null   object
#  1   index                1989 non-null   int64
#  2   eu_o                 1989 non-null   float64
#  3   eu_h                 1989 non-null   float64
#  4   eu_l                 1989 non-null   float64
#  5   eu_c                 1989 non-null   float64
#  6   eu_High_last_day1    1989 non-null   float64
#  7   eu_Low_last_day1     1989 non-null   float64
#  8   eu_Close_last_day1   1989 non-null   float64
#  9   eu_High_last_day2    1989 non-null   float64
#  10  eu_Low_last_day2     1989 non-null   float64
#  11  eu_Close_last_day2   1989 non-null   float64
#  12  eu_High_last_day3    1989 non-null   float64
#  13  eu_Low_last_day3     1989 non-null   float64
#  14  eu_Close_last_day3   1989 non-null   float64
#  15  eu_High_last_day4    1989 non-null   float64
#  16  eu_Low_last_day4     1989 non-null   float64
#  17  eu_Close_last_day4   1989 non-null   float64
#  18  eu_High_last_day5    1989 non-null   float64
#  19  eu_Low_last_day5     1989 non-null   float64
#  20  eu_Close_last_day5   1989 non-null   float64
#  21  eu_High_last_day6    1989 non-null   float64
#  22  eu_Low_last_day6     1989 non-null   float64
#  23  eu_Close_last_day6   1989 non-null   float64
#  24  eu_High_last_day7    1989 non-null   float64
#  25  eu_Low_last_day7     1989 non-null   float64
#  26  eu_Close_last_day7   1989 non-null   float64
#  27  eu_High_last_day8    1989 non-null   float64
#  28  eu_Low_last_day8     1989 non-null   float64
#  29  eu_Close_last_day8   1989 non-null   float64
#  30  eu_High_last_day9    1989 non-null   float64
#  31  eu_Low_last_day9     1989 non-null   float64
#  32  eu_Close_last_day9   1989 non-null   float64
#  33  eu_High_last_day10   1989 non-null   float64
#  34  eu_Low_last_day10    1989 non-null   float64
#  35  eu_Close_last_day10  1989 non-null   float64
#  36  eu_High_next_day1    1989 non-null   float64
#  37  eu_Low_next_day1     1989 non-null   float64
#  38  eu_Close_next_day1   1989 non-null   float64
# dtypes: float64(37), int64(1), object(1)
# memory usage: 621.6+ KB

# %%
#extract row for variable
last_row = df_m_5.iloc[-1:,np.r_[2:36]].values
print(last_row)
# Out:
# [[1.12865 1.13602 1.1281  1.13304 1.1299  1.12215 1.12936 1.13236 1.12535
#   1.12577 1.13191 1.12599 1.12854 1.13239 1.1265  1.13165 1.13452 1.12782
#   1.12924 1.13547 1.12627 1.13418 1.12982 1.12273 1.12681 1.13109 1.12664
#   1.12848 1.13333 1.12665 1.13088 1.13475 1.12952 1.13013]]

# %%
train_data = df_m_5
#subsample_size=500
train_data=train_data.sample(n=500)
train_data.head()
# Out:
#                 d  index  ...  eu_Low_next_day1  eu_Close_next_day1
# 11429  2016.09.14  11429  ...           1.12187             1.12435
# 11643  2017.07.11  11643  ...           1.13914             1.14127
# 12200  2019.09.04  12200  ...           1.10167             1.10340
# 11657  2017.07.31  11657  ...           1.17849             1.18021
# 11757  2017.12.18  11757  ...           1.17766             1.18385
#
# [5 rows x 39 columns]

# %%
label='eu_High_next_day1'
print("Summary of class variable: \n", train_data[label].describe())
# Out:
# Summary of class variable:
#  count    500.000000
# mean       1.155649
# std        0.065937
# min        1.046300
# 25%        1.114627
# 50%        1.137340
# 75%        1.184280
# max        1.385450
# Name: eu_High_next_day1, dtype: float64

# %%
save_path='agModels-predictClass'
predictor=TabularPredictor(label=label, path=save_path).fit(train_data, presets='best_quality', time_limit=None)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictClass"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClass/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    500
# Train Data Columns: 38
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.38545, 1.0463, 1.15565, 0.06594)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12683.41 MB
# 	Train Data (Original)  Memory Usage: 0.18 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', [])                        :  1 | ['index']
# 		('object', ['datetime_as_object']) :  1 | ['d']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', [])                  :  1 | ['index']
# 		('int', ['datetime_as_int']) :  1 | ['d']
# 	0.3s = Fit runtime
# 	38 features in original data used to generate 38 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.37s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-0.0091	 = Validation score   (root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-0.0075	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0061453	valid_set's rmse: 0.00798765
# [2000]	train_set's rmse: 0.00585874	valid_set's rmse: 0.00785145
# [3000]	train_set's rmse: 0.00575966	valid_set's rmse: 0.00782378
# [4000]	train_set's rmse: 0.00571513	valid_set's rmse: 0.00781418
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00587366	valid_set's rmse: 0.010702
# [2000]	train_set's rmse: 0.00529781	valid_set's rmse: 0.0105807
# [3000]	train_set's rmse: 0.00510479	valid_set's rmse: 0.0105641
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00482717	valid_set's rmse: 0.00405329
# [2000]	train_set's rmse: 0.00433562	valid_set's rmse: 0.00395038
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00367389	valid_set's rmse: 0.00398501
# [2000]	train_set's rmse: 0.00320851	valid_set's rmse: 0.00391144
# [3000]	train_set's rmse: 0.0029947	valid_set's rmse: 0.00389602
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00372395	valid_set's rmse: 0.00491547
# [2000]	train_set's rmse: 0.00325219	valid_set's rmse: 0.00476011
# [3000]	train_set's rmse: 0.00301299	valid_set's rmse: 0.0047115
# [4000]	train_set's rmse: 0.00286827	valid_set's rmse: 0.00464855
# [5000]	train_set's rmse: 0.00275715	valid_set's rmse: 0.00461176
# [6000]	train_set's rmse: 0.00266535	valid_set's rmse: 0.00457868
# [7000]	train_set's rmse: 0.00259969	valid_set's rmse: 0.00454911
# [8000]	train_set's rmse: 0.0025474	valid_set's rmse: 0.00453411
# [9000]	train_set's rmse: 0.00250249	valid_set's rmse: 0.0045246
# [10000]	train_set's rmse: 0.0024665	valid_set's rmse: 0.004527
# 	-0.0067	 = Validation score   (root_mean_squared_error)
# 	42.09s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00570735	valid_set's rmse: 0.00780763
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00254149	valid_set's rmse: 0.00362626
# [2000]	train_set's rmse: 0.00240622	valid_set's rmse: 0.00360274
# 	-0.0065	 = Validation score   (root_mean_squared_error)
# 	8.14s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.0032	 = Validation score   (root_mean_squared_error)
# 	2.18s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	-0.0046	 = Validation score   (root_mean_squared_error)
# 	347.14s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.0033	 = Validation score   (root_mean_squared_error)
# 	1.08s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	-0.0079	 = Validation score   (root_mean_squared_error)
# 	5.76s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	-0.0045	 = Validation score   (root_mean_squared_error)
# 	3.34s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ...
# 	-0.0056	 = Validation score   (root_mean_squared_error)
# 	34.08s	 = Training   runtime
# 	0.93s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.000544214	valid_set's rmse: 0.00471584
# [2000]	train_set's rmse: 0.000542476	valid_set's rmse: 0.00469031
# [3000]	train_set's rmse: 0.000542454	valid_set's rmse: 0.00468773
# [4000]	train_set's rmse: 0.000542454	valid_set's rmse: 0.00468749
# [5000]	train_set's rmse: 0.000542454	valid_set's rmse: 0.00468746
# [6000]	train_set's rmse: 0.000542454	valid_set's rmse: 0.00468746
# [7000]	train_set's rmse: 0.000542454	valid_set's rmse: 0.00468746
# [8000]	train_set's rmse: 0.000542454	valid_set's rmse: 0.00468746
# [9000]	train_set's rmse: 0.000542454	valid_set's rmse: 0.00468746
# [10000]	train_set's rmse: 0.000542454	valid_set's rmse: 0.00468746
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0038	 = Validation score   (root_mean_squared_error)
# 	49.79s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.0031	 = Validation score   (root_mean_squared_error)
# 	0.5s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 503.92s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictClass/")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L2  -0.003127       1.501538   90.964183                0.000756           0.497694            2       True         12
# 1   RandomForestMSE_BAG_L1  -0.003201       0.128795    2.176004                0.128795           2.176004            1       True          5
# 2     ExtraTreesMSE_BAG_L1  -0.003251       0.132375    1.078503                0.132375           1.078503            1       True          7
# 3     LightGBMLarge_BAG_L1  -0.003819       0.283513   49.792791                0.283513          49.792791            1       True         11
# 4           XGBoost_BAG_L1  -0.004514       0.030121    3.341588                0.030121           3.341588            1       True          9
# 5          CatBoost_BAG_L1  -0.004574       0.031198  347.143542                0.031198         347.143542            1       True          6
# 6    NeuralNetMXNet_BAG_L1  -0.005559       0.925978   34.077603                0.925978          34.077603            1       True         10
# 7          LightGBM_BAG_L1  -0.006516       0.050693    8.143700                0.050693           8.143700            1       True          4
# 8        LightGBMXT_BAG_L1  -0.006684       0.135116   42.094327                0.135116          42.094327            1       True          3
# 9    KNeighborsDist_BAG_L1  -0.007496       0.112103    0.011601                0.112103           0.011601            1       True          2
# 10  NeuralNetFastAI_BAG_L1  -0.007899       0.145373    5.755424                0.145373           5.755424            1       True          8
# 11   KNeighborsUnif_BAG_L1  -0.009096       0.128238    0.024542                0.128238           0.024542            1       True          1
# Number of models trained: 12
# Types of models trained:
# {'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_TabularNeuralNet', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_XT', 'WeightedEnsembleModel', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_KNN'}
# Bagging used: True  (with 5 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# ('int', [])                  :  1 | ['index']
# ('int', ['datetime_as_int']) :  1 | ['d']
# Plot summary of models saved to file: agModels-predictClass/SummaryOfModels.html
# *** End of fit() summary ***
# {'leaderboard':                      model  score_val  ...  can_infer  fit_order
#  0      WeightedEnsemble_L2  -0.003127  ...       True         12
#  1   RandomForestMSE_BAG_L1  -0.003201  ...       True          5
#  2     ExtraTreesMSE_BAG_L1  -0.003251  ...       True          7
#  3     LightGBMLarge_BAG_L1  -0.003819  ...       True         11
#  4           XGBoost_BAG_L1  -0.004514  ...       True          9
#  5          CatBoost_BAG_L1  -0.004574  ...       True          6
#  6    NeuralNetMXNet_BAG_L1  -0.005559  ...       True         10
#  7          LightGBM_BAG_L1  -0.006516  ...       True          4
#  8        LightGBMXT_BAG_L1  -0.006684  ...       True          3
#  9    KNeighborsDist_BAG_L1  -0.007496  ...       True          2
#  10  NeuralNetFastAI_BAG_L1  -0.007899  ...       True          8
#  11   KNeighborsUnif_BAG_L1  -0.009096  ...       True          1
#
#  [12 rows x 9 columns],
#  'max_stack_level': 2,
#  'model_best': 'WeightedEnsemble_L2',
#  'model_fit_times': {'CatBoost_BAG_L1': 347.14354181289673,
#   'ExtraTreesMSE_BAG_L1': 1.078502893447876,
#   'KNeighborsDist_BAG_L1': 0.01160120964050293,
#   'KNeighborsUnif_BAG_L1': 0.024541854858398438,
#   'LightGBMLarge_BAG_L1': 49.79279136657715,
#   'LightGBMXT_BAG_L1': 42.094326972961426,
#   'LightGBM_BAG_L1': 8.143700361251831,
#   'NeuralNetFastAI_BAG_L1': 5.755424499511719,
#   'NeuralNetMXNet_BAG_L1': 34.07760310173035,
#   'RandomForestMSE_BAG_L1': 2.176003932952881,
#   'WeightedEnsemble_L2': 0.4976937770843506,
#   'XGBoost_BAG_L1': 3.341587543487549},
#  'model_hyperparams': {'CatBoost_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'ExtraTreesMSE_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'KNeighborsDist_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'KNeighborsUnif_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'LightGBMLarge_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBMXT_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBM_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetFastAI_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetMXNet_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'RandomForestMSE_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'WeightedEnsemble_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': False},
#   'XGBoost_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True}},
#  'model_paths': {'CatBoost_BAG_L1': 'agModels-predictClass/models/CatBoost_BAG_L1/',
#   'ExtraTreesMSE_BAG_L1': 'agModels-predictClass/models/ExtraTreesMSE_BAG_L1/',
#   'KNeighborsDist_BAG_L1': 'agModels-predictClass/models/KNeighborsDist_BAG_L1/',
#   'KNeighborsUnif_BAG_L1': 'agModels-predictClass/models/KNeighborsUnif_BAG_L1/',
#   'LightGBMLarge_BAG_L1': 'agModels-predictClass/models/LightGBMLarge_BAG_L1/',
#   'LightGBMXT_BAG_L1': 'agModels-predictClass/models/LightGBMXT_BAG_L1/',
#   'LightGBM_BAG_L1': 'agModels-predictClass/models/LightGBM_BAG_L1/',
#   'NeuralNetFastAI_BAG_L1': 'agModels-predictClass/models/NeuralNetFastAI_BAG_L1/',
#   'NeuralNetMXNet_BAG_L1': 'agModels-predictClass/models/NeuralNetMXNet_BAG_L1/',
#   'RandomForestMSE_BAG_L1': 'agModels-predictClass/models/RandomForestMSE_BAG_L1/',
#   'WeightedEnsemble_L2': 'agModels-predictClass/models/WeightedEnsemble_L2/',
#   'XGBoost_BAG_L1': 'agModels-predictClass/models/XGBoost_BAG_L1/'},
#  'model_performance': {'CatBoost_BAG_L1': -0.004574261345391665,
#   'ExtraTreesMSE_BAG_L1': -0.0032510438668143737,
#   'KNeighborsDist_BAG_L1': -0.007495604570383759,
#   'KNeighborsUnif_BAG_L1': -0.009096022289267801,
#   'LightGBMLarge_BAG_L1': -0.0038194660778961688,
#   'LightGBMXT_BAG_L1': -0.006684177971369632,
#   'LightGBM_BAG_L1': -0.006515760431828731,
#   'NeuralNetFastAI_BAG_L1': -0.007899124121177865,
#   'NeuralNetMXNet_BAG_L1': -0.005559168142769508,
#   'RandomForestMSE_BAG_L1': -0.003201309619060998,
#   'WeightedEnsemble_L2': -0.00312651754863132,
#   'XGBoost_BAG_L1': -0.004513953915141345},
#  'model_pred_times': {'CatBoost_BAG_L1': 0.031197547912597656,
#   'ExtraTreesMSE_BAG_L1': 0.13237524032592773,
#   'KNeighborsDist_BAG_L1': 0.11210298538208008,
#   'KNeighborsUnif_BAG_L1': 0.12823772430419922,
#   'LightGBMLarge_BAG_L1': 0.28351306915283203,
#   'LightGBMXT_BAG_L1': 0.1351156234741211,
#   'LightGBM_BAG_L1': 0.05069303512573242,
#   'NeuralNetFastAI_BAG_L1': 0.14537262916564941,
#   'NeuralNetMXNet_BAG_L1': 0.9259777069091797,
#   'RandomForestMSE_BAG_L1': 0.12879467010498047,
#   'WeightedEnsemble_L2': 0.0007562637329101562,
#   'XGBoost_BAG_L1': 0.030120849609375},
#  'model_types': {'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetMXNet_BAG_L1': 'StackerEnsembleModel_TabularNeuralNet',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost'},
#  'num_bag_folds': 5}

# %%
test_data = TabularDataset(df_m_5)
y_test = test_data[label]
test_data_nolab = test_data.drop(columns=[label])
test_data_nolab.tail()
# Out:
#                 d  index  ...  eu_Low_next_day1  eu_Close_next_day1
# 12788  2021.12.10  12788  ...           1.12599             1.12854
# 12789  2021.12.13  12789  ...           1.12535             1.12577
# 12790  2021.12.14  12790  ...           1.12215             1.12936
# 12791  2021.12.15  12791  ...           1.12810             1.13304
# 12792  2021.12.16  12792  ...           1.13240             1.13312
#
# [5 rows x 38 columns]

# %%
predictor = TabularPredictor.load(save_path)

y_pred = predictor.predict(test_data_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: root_mean_squared_error on test data: -0.002715899137730247
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -0.002715899137730247,
#     "mean_squared_error": -7.376108126323896e-06,
#     "mean_absolute_error": -0.0017312907989640019,
#     "r2": 0.9983874646466551,
#     "pearsonr": 0.9992159212535099,
#     "median_absolute_error": -0.0011095425796510128
# }
# Predictions:
#  10804    1.377568
# 10805    1.377882
# 10806    1.379241
# 10807    1.380669
# 10808    1.379719
#            ...
# 12788    1.132294
# 12789    1.131763
# 12790    1.130325
# 12791    1.134263
# 12792    1.134246
# Name: eu_High_next_day1, Length: 1989, dtype: float32

# %%
predictor.leaderboard(train_data, silent=True)
# Out:
#                      model    score_test  ...  can_infer  fit_order
# 0    KNeighborsDist_BAG_L1 -3.487526e-08  ...       True          2
# 1          CatBoost_BAG_L1 -9.159015e-04  ...       True          6
# 2     LightGBMLarge_BAG_L1 -9.498887e-04  ...       True         11
# 3      WeightedEnsemble_L2 -1.150787e-03  ...       True         12
# 4   RandomForestMSE_BAG_L1 -1.173971e-03  ...       True          5
# 5     ExtraTreesMSE_BAG_L1 -1.202700e-03  ...       True          7
# 6           XGBoost_BAG_L1 -1.450009e-03  ...       True          9
# 7          LightGBM_BAG_L1 -3.830035e-03  ...       True          4
# 8        LightGBMXT_BAG_L1 -3.875098e-03  ...       True          3
# 9    NeuralNetMXNet_BAG_L1 -4.302081e-03  ...       True         10
# 10  NeuralNetFastAI_BAG_L1 -6.660843e-03  ...       True          8
# 11   KNeighborsUnif_BAG_L1 -7.010522e-03  ...       True          1
#
# [12 rows x 12 columns]

# %%
#repeated?
train_data = df_m_5
#subsample_size=500
train_data=train_data.sample(n=500)
train_data.head()
# Out:
#                 d  index  ...  eu_Low_next_day1  eu_Close_next_day1
# 12096  2019.04.11  12096  ...           1.12504             1.12981
# 12114  2019.05.07  12114  ...           1.11823             1.11904
# 11764  2017.12.28  11764  ...           1.19362             1.19941
# 10911  2014.09.15  10911  ...           1.29223             1.29574
# 12360  2020.04.17  12360  ...           1.08411             1.08607
#
# [5 rows x 39 columns]

# %%
label='eu_Low_next_day1'
print("Summary of class variable: \n", train_data[label].describe())
# Out:
# Summary of class variable:
#  count    500.000000
# mean       1.151431
# std        0.072000
# min        1.038950
# 25%        1.105422
# 50%        1.130265
# 75%        1.180867
# max        1.386260
# Name: eu_Low_next_day1, dtype: float64

# %%
save_path='agModels-predictClass'
predictor=TabularPredictor(label=label, path=save_path).fit(train_data, presets='best_quality', time_limit=None)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictClass"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClass/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    500
# Train Data Columns: 38
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.38626, 1.03895, 1.15143, 0.072)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11409.61 MB
# 	Train Data (Original)  Memory Usage: 0.18 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', [])                        :  1 | ['index']
# 		('object', ['datetime_as_object']) :  1 | ['d']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', [])                  :  1 | ['index']
# 		('int', ['datetime_as_int']) :  1 | ['d']
# 	0.2s = Fit runtime
# 	38 features in original data used to generate 38 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.22s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-0.0092	 = Validation score   (root_mean_squared_error)
# 	0.03s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-0.0075	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00290681	valid_set's rmse: 0.00461122
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00329354	valid_set's rmse: 0.00389679
# [2000]	train_set's rmse: 0.00298316	valid_set's rmse: 0.00382785
# [3000]	train_set's rmse: 0.0028685	valid_set's rmse: 0.00381564
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00331174	valid_set's rmse: 0.00492958
# [2000]	train_set's rmse: 0.00296589	valid_set's rmse: 0.00478754
# [3000]	train_set's rmse: 0.00281207	valid_set's rmse: 0.00472581
# [4000]	train_set's rmse: 0.00271759	valid_set's rmse: 0.00468406
# [5000]	train_set's rmse: 0.00265722	valid_set's rmse: 0.00466562
# [6000]	train_set's rmse: 0.00260302	valid_set's rmse: 0.00464615
# [7000]	train_set's rmse: 0.00256715	valid_set's rmse: 0.00463849
# [8000]	train_set's rmse: 0.00253782	valid_set's rmse: 0.00463607
# [9000]	train_set's rmse: 0.00251439	valid_set's rmse: 0.00462518
# [10000]	train_set's rmse: 0.00249856	valid_set's rmse: 0.00462524
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00347032	valid_set's rmse: 0.00663642
# [2000]	train_set's rmse: 0.00316685	valid_set's rmse: 0.00650809
# [3000]	train_set's rmse: 0.0030401	valid_set's rmse: 0.00643852
# [4000]	train_set's rmse: 0.00297502	valid_set's rmse: 0.00638185
# [5000]	train_set's rmse: 0.00292794	valid_set's rmse: 0.00631885
# [6000]	train_set's rmse: 0.00289817	valid_set's rmse: 0.00628509
# [7000]	train_set's rmse: 0.00287715	valid_set's rmse: 0.00625576
# [8000]	train_set's rmse: 0.00285825	valid_set's rmse: 0.00622472
# [9000]	train_set's rmse: 0.0028471	valid_set's rmse: 0.00621597
# [10000]	train_set's rmse: 0.00283585	valid_set's rmse: 0.00620625
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0031953	valid_set's rmse: 0.00412898
# [2000]	train_set's rmse: 0.00285932	valid_set's rmse: 0.00399113
# [3000]	train_set's rmse: 0.00271741	valid_set's rmse: 0.0039459
# [4000]	train_set's rmse: 0.00264192	valid_set's rmse: 0.00394579
# 	-0.0047	 = Validation score   (root_mean_squared_error)
# 	18.03s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0042	 = Validation score   (root_mean_squared_error)
# 	2.97s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.0031	 = Validation score   (root_mean_squared_error)
# 	2.16s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	-0.0043	 = Validation score   (root_mean_squared_error)
# 	124.79s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.003	 = Validation score   (root_mean_squared_error)
# 	1.16s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	-0.0088	 = Validation score   (root_mean_squared_error)
# 	4.81s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	-0.0043	 = Validation score   (root_mean_squared_error)
# 	3.26s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ...
# 	-0.0055	 = Validation score   (root_mean_squared_error)
# 	40.77s	 = Training   runtime
# 	1.05s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0032	 = Validation score   (root_mean_squared_error)
# 	8.24s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.0028	 = Validation score   (root_mean_squared_error)
# 	0.52s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 212.49s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictClass/")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L2  -0.002805       1.384845   59.094393                0.000900           0.522690            2       True         12
# 1     ExtraTreesMSE_BAG_L1  -0.002987       0.122969    1.164963                0.122969           1.164963            1       True          7
# 2   RandomForestMSE_BAG_L1  -0.003054       0.129569    2.163877                0.129569           2.163877            1       True          5
# 3     LightGBMLarge_BAG_L1  -0.003248       0.027947    8.244410                0.027947           8.244410            1       True         11
# 4          LightGBM_BAG_L1  -0.004211       0.022048    2.969522                0.022048           2.969522            1       True          4
# 5           XGBoost_BAG_L1  -0.004255       0.027793    3.259744                0.027793           3.259744            1       True          9
# 6          CatBoost_BAG_L1  -0.004327       0.023579  124.788520                0.023579         124.788520            1       True          6
# 7        LightGBMXT_BAG_L1  -0.004706       0.220848   18.027386                0.220848          18.027386            1       True          3
# 8    NeuralNetMXNet_BAG_L1  -0.005536       1.053619   40.769188                1.053619          40.769188            1       True         10
# 9    KNeighborsDist_BAG_L1  -0.007478       0.106531    0.011359                0.106531           0.011359            1       True          2
# 10  NeuralNetFastAI_BAG_L1  -0.008795       0.143612    4.805571                0.143612           4.805571            1       True          8
# 11   KNeighborsUnif_BAG_L1  -0.009234       0.106925    0.025343                0.106925           0.025343            1       True          1
# Number of models trained: 12
# Types of models trained:
# {'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_TabularNeuralNet', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_XT', 'WeightedEnsembleModel', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_KNN'}
# Bagging used: True  (with 5 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# ('int', [])                  :  1 | ['index']
# ('int', ['datetime_as_int']) :  1 | ['d']
# Plot summary of models saved to file: agModels-predictClass/SummaryOfModels.html
# *** End of fit() summary ***
# {'leaderboard':                      model  score_val  ...  can_infer  fit_order
#  0      WeightedEnsemble_L2  -0.002805  ...       True         12
#  1     ExtraTreesMSE_BAG_L1  -0.002987  ...       True          7
#  2   RandomForestMSE_BAG_L1  -0.003054  ...       True          5
#  3     LightGBMLarge_BAG_L1  -0.003248  ...       True         11
#  4          LightGBM_BAG_L1  -0.004211  ...       True          4
#  5           XGBoost_BAG_L1  -0.004255  ...       True          9
#  6          CatBoost_BAG_L1  -0.004327  ...       True          6
#  7        LightGBMXT_BAG_L1  -0.004706  ...       True          3
#  8    NeuralNetMXNet_BAG_L1  -0.005536  ...       True         10
#  9    KNeighborsDist_BAG_L1  -0.007478  ...       True          2
#  10  NeuralNetFastAI_BAG_L1  -0.008795  ...       True          8
#  11   KNeighborsUnif_BAG_L1  -0.009234  ...       True          1
#
#  [12 rows x 9 columns],
#  'max_stack_level': 2,
#  'model_best': 'WeightedEnsemble_L2',
#  'model_fit_times': {'CatBoost_BAG_L1': 124.78851962089539,
#   'ExtraTreesMSE_BAG_L1': 1.1649627685546875,
#   'KNeighborsDist_BAG_L1': 0.011358976364135742,
#   'KNeighborsUnif_BAG_L1': 0.02534317970275879,
#   'LightGBMLarge_BAG_L1': 8.244409561157227,
#   'LightGBMXT_BAG_L1': 18.027385711669922,
#   'LightGBM_BAG_L1': 2.9695217609405518,
#   'NeuralNetFastAI_BAG_L1': 4.8055713176727295,
#   'NeuralNetMXNet_BAG_L1': 40.769187688827515,
#   'RandomForestMSE_BAG_L1': 2.163877487182617,
#   'WeightedEnsemble_L2': 0.5226902961730957,
#   'XGBoost_BAG_L1': 3.2597436904907227},
#  'model_hyperparams': {'CatBoost_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'ExtraTreesMSE_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'KNeighborsDist_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'KNeighborsUnif_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'LightGBMLarge_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBMXT_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBM_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetFastAI_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetMXNet_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'RandomForestMSE_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'WeightedEnsemble_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': False},
#   'XGBoost_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True}},
#  'model_paths': {'CatBoost_BAG_L1': 'agModels-predictClass/models/CatBoost_BAG_L1/',
#   'ExtraTreesMSE_BAG_L1': 'agModels-predictClass/models/ExtraTreesMSE_BAG_L1/',
#   'KNeighborsDist_BAG_L1': 'agModels-predictClass/models/KNeighborsDist_BAG_L1/',
#   'KNeighborsUnif_BAG_L1': 'agModels-predictClass/models/KNeighborsUnif_BAG_L1/',
#   'LightGBMLarge_BAG_L1': 'agModels-predictClass/models/LightGBMLarge_BAG_L1/',
#   'LightGBMXT_BAG_L1': 'agModels-predictClass/models/LightGBMXT_BAG_L1/',
#   'LightGBM_BAG_L1': 'agModels-predictClass/models/LightGBM_BAG_L1/',
#   'NeuralNetFastAI_BAG_L1': 'agModels-predictClass/models/NeuralNetFastAI_BAG_L1/',
#   'NeuralNetMXNet_BAG_L1': 'agModels-predictClass/models/NeuralNetMXNet_BAG_L1/',
#   'RandomForestMSE_BAG_L1': 'agModels-predictClass/models/RandomForestMSE_BAG_L1/',
#   'WeightedEnsemble_L2': 'agModels-predictClass/models/WeightedEnsemble_L2/',
#   'XGBoost_BAG_L1': 'agModels-predictClass/models/XGBoost_BAG_L1/'},
#  'model_performance': {'CatBoost_BAG_L1': -0.004327448063757544,
#   'ExtraTreesMSE_BAG_L1': -0.0029867331494644205,
#   'KNeighborsDist_BAG_L1': -0.00747772570325562,
#   'KNeighborsUnif_BAG_L1': -0.009234342846997997,
#   'LightGBMLarge_BAG_L1': -0.0032478657648649955,
#   'LightGBMXT_BAG_L1': -0.004706375773974656,
#   'LightGBM_BAG_L1': -0.004210524432525536,
#   'NeuralNetFastAI_BAG_L1': -0.008794746669868089,
#   'NeuralNetMXNet_BAG_L1': -0.005536171462709255,
#   'RandomForestMSE_BAG_L1': -0.0030539153717370313,
#   'WeightedEnsemble_L2': -0.002804916447803524,
#   'XGBoost_BAG_L1': -0.004255039314294328},
#  'model_pred_times': {'CatBoost_BAG_L1': 0.023579120635986328,
#   'ExtraTreesMSE_BAG_L1': 0.12296867370605469,
#   'KNeighborsDist_BAG_L1': 0.10653138160705566,
#   'KNeighborsUnif_BAG_L1': 0.10692501068115234,
#   'LightGBMLarge_BAG_L1': 0.027947187423706055,
#   'LightGBMXT_BAG_L1': 0.22084832191467285,
#   'LightGBM_BAG_L1': 0.02204751968383789,
#   'NeuralNetFastAI_BAG_L1': 0.14361238479614258,
#   'NeuralNetMXNet_BAG_L1': 1.053619384765625,
#   'RandomForestMSE_BAG_L1': 0.12956857681274414,
#   'WeightedEnsemble_L2': 0.0009002685546875,
#   'XGBoost_BAG_L1': 0.027793169021606445},
#  'model_types': {'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetMXNet_BAG_L1': 'StackerEnsembleModel_TabularNeuralNet',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost'},
#  'num_bag_folds': 5}

# %%
#repeated?
test_data = TabularDataset(df_m_5)
y_test = test_data[label]
test_data_nolab = test_data.drop(columns=[label])
test_data_nolab.tail()
# Out:
#                 d  index  ...  eu_High_next_day1  eu_Close_next_day1
# 12788  2021.12.10  12788  ...            1.13191             1.12854
# 12789  2021.12.13  12789  ...            1.13236             1.12577
# 12790  2021.12.14  12790  ...            1.12990             1.12936
# 12791  2021.12.15  12791  ...            1.13602             1.13304
# 12792  2021.12.16  12792  ...            1.13346             1.13312
#
# [5 rows x 38 columns]

# %%
predictor = TabularPredictor.load(save_path)

y_pred = predictor.predict(test_data_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: root_mean_squared_error on test data: -0.0028320328566415116
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -0.0028320328566415116,
#     "mean_squared_error": -8.020410101097071e-06,
#     "mean_absolute_error": -0.001786073410183775,
#     "r2": 0.9982794409222036,
#     "pearsonr": 0.9991499486785064,
#     "median_absolute_error": -0.0011895426177979118
# }
# Predictions:
#  10804    1.378503
# 10805    1.377876
# 10806    1.378061
# 10807    1.377893
# 10808    1.378528
#            ...
# 12788    1.126537
# 12789    1.124032
# 12790    1.123020
# 12791    1.127950
# 12792    1.130966
# Name: eu_Low_next_day1, Length: 1989, dtype: float32

# %%
predictor.leaderboard(train_data, silent=True)
# Out:
#                      model    score_test  ...  can_infer  fit_order
# 0    KNeighborsDist_BAG_L1 -3.639257e-08  ...       True          2
# 1     LightGBMLarge_BAG_L1 -9.073560e-04  ...       True         11
# 2          CatBoost_BAG_L1 -1.069643e-03  ...       True          6
# 3     ExtraTreesMSE_BAG_L1 -1.101681e-03  ...       True          7
# 4   RandomForestMSE_BAG_L1 -1.132188e-03  ...       True          5
# 5      WeightedEnsemble_L2 -1.180716e-03  ...       True         12
# 6           XGBoost_BAG_L1 -1.242128e-03  ...       True          9
# 7        LightGBMXT_BAG_L1 -2.758518e-03  ...       True          3
# 8          LightGBM_BAG_L1 -2.859191e-03  ...       True          4
# 9    NeuralNetMXNet_BAG_L1 -4.748340e-03  ...       True         10
# 10   KNeighborsUnif_BAG_L1 -6.981433e-03  ...       True          1
# 11  NeuralNetFastAI_BAG_L1 -8.028445e-03  ...       True          8
#
# [12 rows x 12 columns]

# %%
label='eu_Close_next_day1'
print("Summary of class variable: \n", train_data[label].describe())
# Out:
# Summary of class variable:
#  count    500.000000
# mean       1.155297
# std        0.071609
# min        1.040100
# 25%        1.107978
# 50%        1.134500
# 75%        1.184455
# max        1.386700
# Name: eu_Close_next_day1, dtype: float64

# %%
save_path='agModels-predictClass'
predictor=TabularPredictor(label=label, path=save_path).fit(train_data, presets='best_quality', time_limit=None)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictClass"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClass/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    500
# Train Data Columns: 38
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.3867, 1.0401, 1.1553, 0.07161)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11380.86 MB
# 	Train Data (Original)  Memory Usage: 0.18 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', [])                        :  1 | ['index']
# 		('object', ['datetime_as_object']) :  1 | ['d']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# 		('int', [])                  :  1 | ['index']
# 		('int', ['datetime_as_int']) :  1 | ['d']
# 	0.2s = Fit runtime
# 	38 features in original data used to generate 38 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.24s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-0.0096	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-0.008	 = Validation score   (root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00320367	valid_set's rmse: 0.00532107
# [2000]	train_set's rmse: 0.00264304	valid_set's rmse: 0.00526204
# [3000]	train_set's rmse: 0.0023979	valid_set's rmse: 0.00525699
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0033833	valid_set's rmse: 0.00492036
# [2000]	train_set's rmse: 0.00295562	valid_set's rmse: 0.00485927
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0035301	valid_set's rmse: 0.00578102
# [2000]	train_set's rmse: 0.00301574	valid_set's rmse: 0.0056491
# [3000]	train_set's rmse: 0.00276877	valid_set's rmse: 0.00560511
# [4000]	train_set's rmse: 0.00262602	valid_set's rmse: 0.00558584
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.00372112	valid_set's rmse: 0.00689739
# [2000]	train_set's rmse: 0.00325472	valid_set's rmse: 0.00671841
# [3000]	train_set's rmse: 0.00306085	valid_set's rmse: 0.00663303
# [4000]	train_set's rmse: 0.00295313	valid_set's rmse: 0.00656088
# [5000]	train_set's rmse: 0.0028881	valid_set's rmse: 0.00650482
# [6000]	train_set's rmse: 0.00284476	valid_set's rmse: 0.00645793
# [7000]	train_set's rmse: 0.00281567	valid_set's rmse: 0.00643608
# [8000]	train_set's rmse: 0.00279336	valid_set's rmse: 0.00640864
# [9000]	train_set's rmse: 0.00277598	valid_set's rmse: 0.00639646
# [10000]	train_set's rmse: 0.00276172	valid_set's rmse: 0.00638899
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0033461	valid_set's rmse: 0.00547009
# [2000]	train_set's rmse: 0.00282638	valid_set's rmse: 0.00523973
# [3000]	train_set's rmse: 0.00260762	valid_set's rmse: 0.00519028
# 	-0.0055	 = Validation score   (root_mean_squared_error)
# 	14.63s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.0047	 = Validation score   (root_mean_squared_error)
# 	2.62s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.0035	 = Validation score   (root_mean_squared_error)
# 	2.18s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	-0.0052	 = Validation score   (root_mean_squared_error)
# 	85.99s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.0037	 = Validation score   (root_mean_squared_error)
# 	1.17s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	-0.0094	 = Validation score   (root_mean_squared_error)
# 	5.27s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	-0.0046	 = Validation score   (root_mean_squared_error)
# 	3.51s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ...
# 	-0.0066	 = Validation score   (root_mean_squared_error)
# 	34.31s	 = Training   runtime
# 	1.0s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 2.00921e-05	valid_set's rmse: 0.00393609
# [2000]	train_set's rmse: 1.71695e-06	valid_set's rmse: 0.00393321
# 	-0.0038	 = Validation score   (root_mean_squared_error)
# 	21.24s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.0034	 = Validation score   (root_mean_squared_error)
# 	0.53s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 177.73s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictClass/")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L2  -0.003430       1.484361  62.949466                0.000744           0.531378            2       True         12
# 1   RandomForestMSE_BAG_L1  -0.003538       0.127751   2.179981                0.127751           2.179981            1       True          5
# 2     ExtraTreesMSE_BAG_L1  -0.003678       0.136517   1.165799                0.136517           1.165799            1       True          7
# 3     LightGBMLarge_BAG_L1  -0.003800       0.078250  21.236387                0.078250          21.236387            1       True         11
# 4           XGBoost_BAG_L1  -0.004597       0.031805   3.506887                0.031805           3.506887            1       True          9
# 5          LightGBM_BAG_L1  -0.004735       0.020562   2.616040                0.020562           2.616040            1       True          4
# 6          CatBoost_BAG_L1  -0.005180       0.024848  85.986796                0.024848          85.986796            1       True          6
# 7        LightGBMXT_BAG_L1  -0.005474       0.227083  14.628235                0.227083          14.628235            1       True          3
# 8    NeuralNetMXNet_BAG_L1  -0.006617       1.002424  34.311675                1.002424          34.311675            1       True         10
# 9    KNeighborsDist_BAG_L1  -0.007977       0.106870   0.017361                0.106870           0.017361            1       True          2
# 10  NeuralNetFastAI_BAG_L1  -0.009357       0.152737   5.266767                0.152737           5.266767            1       True          8
# 11   KNeighborsUnif_BAG_L1  -0.009616       0.107293   0.012674                0.107293           0.012674            1       True          1
# Number of models trained: 12
# Types of models trained:
# {'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_TabularNeuralNet', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_XT', 'WeightedEnsembleModel', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_KNN'}
# Bagging used: True  (with 5 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])                : 36 | ['eu_o', 'eu_h', 'eu_l', 'eu_c', 'eu_High_last_day1', ...]
# ('int', [])                  :  1 | ['index']
# ('int', ['datetime_as_int']) :  1 | ['d']
# Plot summary of models saved to file: agModels-predictClass/SummaryOfModels.html
# *** End of fit() summary ***
# {'leaderboard':                      model  score_val  ...  can_infer  fit_order
#  0      WeightedEnsemble_L2  -0.003430  ...       True         12
#  1   RandomForestMSE_BAG_L1  -0.003538  ...       True          5
#  2     ExtraTreesMSE_BAG_L1  -0.003678  ...       True          7
#  3     LightGBMLarge_BAG_L1  -0.003800  ...       True         11
#  4           XGBoost_BAG_L1  -0.004597  ...       True          9
#  5          LightGBM_BAG_L1  -0.004735  ...       True          4
#  6          CatBoost_BAG_L1  -0.005180  ...       True          6
#  7        LightGBMXT_BAG_L1  -0.005474  ...       True          3
#  8    NeuralNetMXNet_BAG_L1  -0.006617  ...       True         10
#  9    KNeighborsDist_BAG_L1  -0.007977  ...       True          2
#  10  NeuralNetFastAI_BAG_L1  -0.009357  ...       True          8
#  11   KNeighborsUnif_BAG_L1  -0.009616  ...       True          1
#
#  [12 rows x 9 columns],
#  'max_stack_level': 2,
#  'model_best': 'WeightedEnsemble_L2',
#  'model_fit_times': {'CatBoost_BAG_L1': 85.98679637908936,
#   'ExtraTreesMSE_BAG_L1': 1.1657986640930176,
#   'KNeighborsDist_BAG_L1': 0.017361164093017578,
#   'KNeighborsUnif_BAG_L1': 0.012674093246459961,
#   'LightGBMLarge_BAG_L1': 21.23638653755188,
#   'LightGBMXT_BAG_L1': 14.62823486328125,
#   'LightGBM_BAG_L1': 2.616039991378784,
#   'NeuralNetFastAI_BAG_L1': 5.2667670249938965,
#   'NeuralNetMXNet_BAG_L1': 34.31167459487915,
#   'RandomForestMSE_BAG_L1': 2.179981231689453,
#   'WeightedEnsemble_L2': 0.5313775539398193,
#   'XGBoost_BAG_L1': 3.5068867206573486},
#  'model_hyperparams': {'CatBoost_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'ExtraTreesMSE_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'KNeighborsDist_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'KNeighborsUnif_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'LightGBMLarge_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBMXT_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBM_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetFastAI_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetMXNet_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'RandomForestMSE_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'WeightedEnsemble_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': False},
#   'XGBoost_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True}},
#  'model_paths': {'CatBoost_BAG_L1': 'agModels-predictClass/models/CatBoost_BAG_L1/',
#   'ExtraTreesMSE_BAG_L1': 'agModels-predictClass/models/ExtraTreesMSE_BAG_L1/',
#   'KNeighborsDist_BAG_L1': 'agModels-predictClass/models/KNeighborsDist_BAG_L1/',
#   'KNeighborsUnif_BAG_L1': 'agModels-predictClass/models/KNeighborsUnif_BAG_L1/',
#   'LightGBMLarge_BAG_L1': 'agModels-predictClass/models/LightGBMLarge_BAG_L1/',
#   'LightGBMXT_BAG_L1': 'agModels-predictClass/models/LightGBMXT_BAG_L1/',
#   'LightGBM_BAG_L1': 'agModels-predictClass/models/LightGBM_BAG_L1/',
#   'NeuralNetFastAI_BAG_L1': 'agModels-predictClass/models/NeuralNetFastAI_BAG_L1/',
#   'NeuralNetMXNet_BAG_L1': 'agModels-predictClass/models/NeuralNetMXNet_BAG_L1/',
#   'RandomForestMSE_BAG_L1': 'agModels-predictClass/models/RandomForestMSE_BAG_L1/',
#   'WeightedEnsemble_L2': 'agModels-predictClass/models/WeightedEnsemble_L2/',
#   'XGBoost_BAG_L1': 'agModels-predictClass/models/XGBoost_BAG_L1/'},
#  'model_performance': {'CatBoost_BAG_L1': -0.005180496011349078,
#   'ExtraTreesMSE_BAG_L1': -0.0036779464200593134,
#   'KNeighborsDist_BAG_L1': -0.007976655239411644,
#   'KNeighborsUnif_BAG_L1': -0.009615520692672734,
#   'LightGBMLarge_BAG_L1': -0.0037995224745744193,
#   'LightGBMXT_BAG_L1': -0.00547419314271359,
#   'LightGBM_BAG_L1': -0.004735239060372666,
#   'NeuralNetFastAI_BAG_L1': -0.009357354543080388,
#   'NeuralNetMXNet_BAG_L1': -0.006616904086034907,
#   'RandomForestMSE_BAG_L1': -0.003537500248246991,
#   'WeightedEnsemble_L2': -0.003430062932783216,
#   'XGBoost_BAG_L1': -0.004597389787902497},
#  'model_pred_times': {'CatBoost_BAG_L1': 0.024847745895385742,
#   'ExtraTreesMSE_BAG_L1': 0.13651728630065918,
#   'KNeighborsDist_BAG_L1': 0.10687017440795898,
#   'KNeighborsUnif_BAG_L1': 0.10729336738586426,
#   'LightGBMLarge_BAG_L1': 0.07825016975402832,
#   'LightGBMXT_BAG_L1': 0.2270829677581787,
#   'LightGBM_BAG_L1': 0.020561933517456055,
#   'NeuralNetFastAI_BAG_L1': 0.15273666381835938,
#   'NeuralNetMXNet_BAG_L1': 1.0024237632751465,
#   'RandomForestMSE_BAG_L1': 0.12775063514709473,
#   'WeightedEnsemble_L2': 0.0007443428039550781,
#   'XGBoost_BAG_L1': 0.031804800033569336},
#  'model_types': {'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetMXNet_BAG_L1': 'StackerEnsembleModel_TabularNeuralNet',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost'},
#  'num_bag_folds': 5}

# %%
#repeated?
test_data = TabularDataset(df_m_5)
y_test = test_data[label]
test_data_nolab = test_data.drop(columns=[label])
test_data_nolab.tail()
# Out:
#                 d  index  ...  eu_High_next_day1  eu_Low_next_day1
# 12788  2021.12.10  12788  ...            1.13191           1.12599
# 12789  2021.12.13  12789  ...            1.13236           1.12535
# 12790  2021.12.14  12790  ...            1.12990           1.12215
# 12791  2021.12.15  12791  ...            1.13602           1.12810
# 12792  2021.12.16  12792  ...            1.13346           1.13240
#
# [5 rows x 38 columns]

# %%
predictor = TabularPredictor.load(save_path)

y_pred = predictor.predict(test_data_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: root_mean_squared_error on test data: -0.003263642066021251
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -0.003263642066021251,
#     "mean_squared_error": -1.0651359535103438e-05,
#     "mean_absolute_error": -0.0022621122093066425,
#     "r2": 0.9976897491610636,
#     "pearsonr": 0.9988447242648912,
#     "median_absolute_error": -0.0015816338348388914
# }
# Predictions:
#  10804    1.381471
# 10805    1.380335
# 10806    1.380730
# 10807    1.381589
# 10808    1.382970
#            ...
# 12788    1.128534
# 12789    1.128667
# 12790    1.128169
# 12791    1.131404
# 12792    1.133245
# Name: eu_Close_next_day1, Length: 1989, dtype: float32
