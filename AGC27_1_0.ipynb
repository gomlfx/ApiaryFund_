# %% [markdown]
# <a href="https://colab.research.google.com/github/gomlfx/ApiaryFund/blob/master/AGC27_1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install autogluon

# %%
#!pip install --upgrade mxnet

# %%
#designed for Jupyter/kaggle/colab
import pandas as pd
import numpy as np
#import matplotlib for plotting 
import matplotlib.pyplot as plt
# %matplotlib inline
#import normalization
from sklearn import preprocessing

#autogluon
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
 #MT4 csv 
df=pd.read_csv('USDJPY1440.csv', names=['d','t','p_o','p_h','p_l','p_c','p_v'])

# %%
df

# %%
#Features

#130 days ago
df['p_High_last_day130'] = df['p_h'].shift(130)
df['p_Low_last_day130'] = df['p_l'].shift(130)
df['p_Close_last_day130'] = df['p_c'].shift(130)
#129 days ago
df['p_High_last_day129'] = df['p_h'].shift(129)
df['p_Low_last_day129'] = df['p_l'].shift(129)
df['p_Close_last_day129'] = df['p_c'].shift(129)
#128 days ago
df['p_High_last_day128'] = df['p_h'].shift(128)
df['p_Low_last_day128'] = df['p_l'].shift(128)
df['p_Close_last_day128'] = df['p_c'].shift(128)
#127 days ago
df['p_High_last_day127'] = df['p_h'].shift(127)
df['p_Low_last_day127'] = df['p_l'].shift(127)
df['p_Close_last_day127'] = df['p_c'].shift(127)
#126 days ago
df['p_High_last_day126'] = df['p_h'].shift(126)
df['p_Low_last_day126'] = df['p_l'].shift(126)
df['p_Close_last_day126'] = df['p_c'].shift(126)
#125 days ago
df['p_High_last_day125'] = df['p_h'].shift(125)
df['p_Low_last_day125'] = df['p_l'].shift(125)
df['p_Close_last_day125'] = df['p_c'].shift(125)
#124 days ago
df['p_High_last_day124'] = df['p_h'].shift(124)
df['p_Low_last_day124'] = df['p_l'].shift(124)
df['p_Close_last_day124'] = df['p_c'].shift(124)
#123 days ago
df['p_High_last_day123'] = df['p_h'].shift(123)
df['p_Low_last_day123'] = df['p_l'].shift(123)
df['p_Close_last_day123'] = df['p_c'].shift(123)
#122 days ago
df['p_High_last_day122'] = df['p_h'].shift(122)
df['p_Low_last_day122'] = df['p_l'].shift(122)
df['p_Close_last_day122'] = df['p_c'].shift(122)
#121 days ago
df['p_High_last_day121'] = df['p_h'].shift(21)
df['p_Low_last_day121'] = df['p_l'].shift(121)
df['p_Close_last_day121'] = df['p_c'].shift(121)
#120 days ago
df['p_High_last_day120'] = df['p_h'].shift(120)
df['p_Low_last_day120'] = df['p_l'].shift(120)
df['p_Close_last_day120'] = df['p_c'].shift(120)
#119 days ago
df['p_High_last_day119'] = df['p_h'].shift(119)
df['p_Low_last_day119'] = df['p_l'].shift(119)
df['p_Close_last_day119'] = df['p_c'].shift(119)
#118 days ago
df['p_High_last_day118'] = df['p_h'].shift(118)
df['p_Low_last_day118'] = df['p_l'].shift(118)
df['p_Close_last_day118'] = df['p_c'].shift(118)
#117 days ago
df['p_High_last_day117'] = df['p_h'].shift(117)
df['p_Low_last_day117'] = df['p_l'].shift(117)
df['p_Close_last_day117'] = df['p_c'].shift(117)
#116 days ago
df['p_High_last_day116'] = df['p_h'].shift(116)
df['p_Low_last_day116'] = df['p_l'].shift(116)
df['p_Close_last_day116'] = df['p_c'].shift(116)
#115 days ago
df['p_High_last_day115'] = df['p_h'].shift(115)
df['p_Low_last_day115'] = df['p_l'].shift(115)
df['p_Close_last_day115'] = df['p_c'].shift(115)
#114 days ago
df['p_High_last_day114'] = df['p_h'].shift(114)
df['p_Low_last_day1014'] = df['p_l'].shift(114)
df['p_Close_last_day114'] = df['p_c'].shift(114)
#113 days ago
df['p_High_last_day113'] = df['p_h'].shift(113)
df['p_Low_last_day113'] = df['p_l'].shift(113)
df['p_Close_last_day113'] = df['p_c'].shift(113)
#112 days ago
df['p_High_last_day112'] = df['p_h'].shift(112)
df['p_Low_last_day112'] = df['p_l'].shift(112)
df['p_Close_last_day112'] = df['p_c'].shift(112)
#111 days ago
df['p_High_last_day111'] = df['p_h'].shift(111)
df['p_Low_last_day111'] = df['p_l'].shift(111)
df['p_Close_last_day111'] = df['p_c'].shift(111)
#110 days ago
df['p_High_last_day110'] = df['p_h'].shift(110)
df['p_Low_last_day110'] = df['p_l'].shift(110)
df['p_Close_last_day110'] = df['p_c'].shift(110)
#109 days ago
df['p_High_last_day109'] = df['p_h'].shift(109)
df['p_Low_last_day109'] = df['p_l'].shift(109)
df['p_Close_last_day109'] = df['p_c'].shift(109)
#108 days ago
df['p_High_last_day108'] = df['p_h'].shift(108)
df['p_Low_last_day108'] = df['p_l'].shift(108)
df['p_Close_last_day108'] = df['p_c'].shift(108)
#107 days ago
df['p_High_last_day107'] = df['p_h'].shift(107)
df['p_Low_last_day107'] = df['p_l'].shift(107)
df['p_Close_last_day107'] = df['p_c'].shift(107)
#106 days ago
df['p_High_last_day106'] = df['p_h'].shift(106)
df['p_Low_last_day106'] = df['p_l'].shift(106)
df['p_Close_last_day106'] = df['p_c'].shift(106)
#105 days ago
df['p_High_last_day105'] = df['p_h'].shift(105)
df['p_Low_last_day105'] = df['p_l'].shift(105)
df['p_Close_last_day105'] = df['p_c'].shift(105)
#104 days ago
df['p_High_last_day104'] = df['p_h'].shift(104)
df['p_Low_last_day104'] = df['p_l'].shift(104)
df['p_Close_last_day104'] = df['p_c'].shift(104)
#103 days ago
df['p_High_last_day103'] = df['p_h'].shift(103)
df['p_Low_last_day103'] = df['p_l'].shift(103)
df['p_Close_last_day103'] = df['p_c'].shift(103)
#102 days ago
df['p_High_last_day102'] = df['p_h'].shift(102)
df['p_Low_last_day102'] = df['p_l'].shift(102)
df['p_Close_last_day102'] = df['p_c'].shift(102)
#101 days ago
df['p_High_last_day101'] = df['p_h'].shift(101)
df['p_Low_last_day101'] = df['p_l'].shift(101)
df['p_Close_last_day101'] = df['p_c'].shift(101)
#100 days ago
df['p_High_last_day100'] = df['p_h'].shift(100)
df['p_Low_last_day100'] = df['p_l'].shift(100)
df['p_Close_last_day100'] = df['p_c'].shift(100)
#99 days ago
df['p_High_last_day99'] = df['p_h'].shift(99)
df['p_Low_last_day99'] = df['p_l'].shift(99)
df['p_Close_last_day99'] = df['p_c'].shift(99)
#98 days ago
df['p_High_last_day98'] = df['p_h'].shift(98)
df['p_Low_last_day98'] = df['p_l'].shift(98)
df['p_Close_last_day98'] = df['p_c'].shift(98)
#97 days ago
df['p_High_last_day97'] = df['p_h'].shift(97)
df['p_Low_last_day97'] = df['p_l'].shift(97)
df['p_Close_last_day97'] = df['p_c'].shift(97)
#96 days ago
df['p_High_last_day96'] = df['p_h'].shift(96)
df['p_Low_last_day96'] = df['p_l'].shift(96)
df['p_Close_last_day96'] = df['p_c'].shift(96)
#95 days ago
df['p_High_last_day95'] = df['p_h'].shift(95)
df['p_Low_last_day95'] = df['p_l'].shift(95)
df['p_Close_last_day95'] = df['p_c'].shift(95)
#94 days ago
df['p_High_last_day94'] = df['p_h'].shift(94)
df['p_Low_last_day94'] = df['p_l'].shift(94)
df['p_Close_last_day94'] = df['p_c'].shift(94)
#93 days ago
df['p_High_last_day93'] = df['p_h'].shift(93)
df['p_Low_last_day93'] = df['p_l'].shift(93)
df['p_Close_last_day93'] = df['p_c'].shift(93)
#92 days ago
df['p_High_last_day92'] = df['p_h'].shift(92)
df['p_Low_last_day92'] = df['p_l'].shift(92)
df['p_Close_last_day92'] = df['p_c'].shift(92)
#91 days ago
df['p_High_last_day91'] = df['p_h'].shift(91)
df['p_Low_last_day91'] = df['p_l'].shift(91)
df['p_Close_last_day91'] = df['p_c'].shift(91)
#90 days ago
df['p_High_last_day90'] = df['p_h'].shift(90)
df['p_Low_last_day90'] = df['p_l'].shift(90)
df['p_Close_last_day90'] = df['p_c'].shift(90)
#89 days ago
df['p_High_last_day89'] = df['p_h'].shift(89)
df['p_Low_last_day89'] = df['p_l'].shift(89)
df['p_Close_last_day89'] = df['p_c'].shift(89)
#88 days ago
df['p_High_last_day88'] = df['p_h'].shift(88)
df['p_Low_last_day88'] = df['p_l'].shift(88)
df['p_Close_last_day88'] = df['p_c'].shift(88)
#87 days ago
df['p_High_last_day87'] = df['p_h'].shift(87)
df['p_Low_last_day87'] = df['p_l'].shift(87)
df['p_Close_last_day87'] = df['p_c'].shift(87)
#86 days ago
df['p_High_last_day86'] = df['p_h'].shift(86)
df['p_Low_last_day86'] = df['p_l'].shift(86)
df['p_Close_last_day86'] = df['p_c'].shift(86)
#85 days ago
df['p_High_last_day85'] = df['p_h'].shift(85)
df['p_Low_last_day85'] = df['p_l'].shift(85)
df['p_Close_last_day85'] = df['p_c'].shift(85)
#84 days ago
df['p_High_last_day84'] = df['p_h'].shift(84)
df['p_Low_last_day84'] = df['p_l'].shift(84)
df['p_Close_last_day84'] = df['p_c'].shift(84)
#83 days ago
df['p_High_last_day83'] = df['p_h'].shift(83)
df['p_Low_last_day83'] = df['p_l'].shift(83)
df['p_Close_last_day83'] = df['p_c'].shift(83)
#82 days ago
df['p_High_last_day82'] = df['p_h'].shift(82)
df['p_Low_last_day82'] = df['p_l'].shift(82)
df['p_Close_last_day82'] = df['p_c'].shift(82)
#81 days ago
df['p_High_last_day81'] = df['p_h'].shift(81)
df['p_Low_last_day81'] = df['p_l'].shift(81)
df['p_Close_last_day81'] = df['p_c'].shift(81)
#80 days ago
df['p_High_last_day80'] = df['p_h'].shift(80)
df['p_Low_last_day80'] = df['p_l'].shift(80)
df['p_Close_last_day80'] = df['p_c'].shift(80)
#79 days ago
df['p_High_last_day79'] = df['p_h'].shift(79)
df['p_Low_last_day79'] = df['p_l'].shift(79)
df['p_Close_last_day79'] = df['p_c'].shift(79)
#78 days ago
df['p_High_last_day78'] = df['p_h'].shift(78)
df['p_Low_last_day78'] = df['p_l'].shift(78)
df['p_Close_last_day78'] = df['p_c'].shift(78)
#77 days ago
df['p_High_last_day77'] = df['p_h'].shift(77)
df['p_Low_last_day77'] = df['p_l'].shift(77)
df['p_Close_last_day77'] = df['p_c'].shift(77)
#76 days ago
df['p_High_last_day76'] = df['p_h'].shift(76)
df['p_Low_last_day76'] = df['p_l'].shift(76)
df['p_Close_last_day76'] = df['p_c'].shift(76)
#75 days ago
df['p_High_last_day75'] = df['p_h'].shift(75)
df['p_Low_last_day75'] = df['p_l'].shift(75)
df['p_Close_last_day75'] = df['p_c'].shift(75)
#74 days ago
df['p_High_last_day74'] = df['p_h'].shift(74)
df['p_Low_last_day74'] = df['p_l'].shift(74)
df['p_Close_last_day74'] = df['p_c'].shift(74)
#73 days ago
df['p_High_last_day73'] = df['p_h'].shift(73)
df['p_Low_last_day73'] = df['p_l'].shift(73)
df['p_Close_last_day73'] = df['p_c'].shift(73)
#72 days ago
df['p_High_last_day72'] = df['p_h'].shift(72)
df['p_Low_last_day72'] = df['p_l'].shift(72)
df['p_Close_last_day72'] = df['p_c'].shift(72)
#71 days ago
df['p_High_last_day71'] = df['p_h'].shift(71)
df['p_Low_last_day71'] = df['p_l'].shift(71)
df['p_Close_last_day71'] = df['p_c'].shift(71)
#70 days ago
df['p_High_last_day70'] = df['p_h'].shift(70)
df['p_Low_last_day70'] = df['p_l'].shift(70)
df['p_Close_last_day70'] = df['p_c'].shift(70)
#69 days ago
df['p_High_last_day69'] = df['p_h'].shift(69)
df['p_Low_last_day69'] = df['p_l'].shift(69)
df['p_Close_last_day69'] = df['p_c'].shift(69)
#68 days ago
df['p_High_last_day68'] = df['p_h'].shift(68)
df['p_Low_last_day68'] = df['p_l'].shift(68)
df['p_Close_last_day68'] = df['p_c'].shift(68)
#67 days ago
df['p_High_last_day67'] = df['p_h'].shift(67)
df['p_Low_last_day67'] = df['p_l'].shift(67)
df['p_Close_last_day67'] = df['p_c'].shift(67)
#66 days ago
df['p_High_last_day66'] = df['p_h'].shift(66)
df['p_Low_last_day66'] = df['p_l'].shift(66)
df['p_Close_last_day66'] = df['p_c'].shift(66)
#65 days ago
df['p_High_last_day65'] = df['p_h'].shift(65)
df['p_Low_last_day65'] = df['p_l'].shift(65)
df['p_Close_last_day65'] = df['p_c'].shift(65)
#64 days ago
df['p_High_last_day64'] = df['p_h'].shift(64)
df['p_Low_last_day64'] = df['p_l'].shift(64)
df['p_Close_last_day64'] = df['p_c'].shift(64)
#63 days ago
df['p_High_last_day63'] = df['p_h'].shift(63)
df['p_Low_last_day63'] = df['p_l'].shift(63)
df['p_Close_last_day63'] = df['p_c'].shift(63)
#62 days ago
df['p_High_last_day62'] = df['p_h'].shift(62)
df['p_Low_last_day62'] = df['p_l'].shift(62)
df['p_Close_last_day62'] = df['p_c'].shift(62)
#61 days ago
df['p_High_last_day61'] = df['p_h'].shift(61)
df['p_Low_last_day61'] = df['p_l'].shift(61)
df['p_Close_last_day61'] = df['p_c'].shift(61)
#60 days ago
df['p_High_last_day60'] = df['p_h'].shift(60)
df['p_Low_last_day60'] = df['p_l'].shift(60)
df['p_Close_last_day60'] = df['p_c'].shift(60)
#59 days ago
df['p_High_last_day59'] = df['p_h'].shift(59)
df['p_Low_last_day59'] = df['p_l'].shift(59)
df['p_Close_last_day59'] = df['p_c'].shift(59)
#58 days ago
df['p_High_last_day58'] = df['p_h'].shift(58)
df['p_Low_last_day58'] = df['p_l'].shift(58)
df['p_Close_last_day58'] = df['p_c'].shift(58)
#57 days ago
df['p_High_last_day57'] = df['p_h'].shift(57)
df['p_Low_last_day57'] = df['p_l'].shift(57)
df['p_Close_last_day57'] = df['p_c'].shift(57)
#56 days ago
df['p_High_last_day56'] = df['p_h'].shift(56)
df['p_Low_last_day56'] = df['p_l'].shift(56)
df['p_Close_last_day56'] = df['p_c'].shift(56)
#55 days ago
df['p_High_last_day55'] = df['p_h'].shift(55)
df['p_Low_last_day55'] = df['p_l'].shift(55)
df['p_Close_last_day55'] = df['p_c'].shift(55)
#54 days ago
df['p_High_last_day54'] = df['p_h'].shift(54)
df['p_Low_last_day54'] = df['p_l'].shift(54)
df['p_Close_last_day54'] = df['p_c'].shift(54)
#53 days ago
df['p_High_last_day53'] = df['p_h'].shift(53)
df['p_Low_last_day53'] = df['p_l'].shift(53)
df['p_Close_last_day53'] = df['p_c'].shift(53)
#52 days ago
df['p_High_last_day52'] = df['p_h'].shift(52)
df['p_Low_last_day52'] = df['p_l'].shift(52)
df['p_Close_last_day52'] = df['p_c'].shift(52)
#51 days ago
df['p_High_last_day51'] = df['p_h'].shift(51)
df['p_Low_last_day51'] = df['p_l'].shift(51)
df['p_Close_last_day51'] = df['p_c'].shift(51)
#50 days ago
df['p_High_last_day50'] = df['p_h'].shift(50)
df['p_Low_last_day50'] = df['p_l'].shift(50)
df['p_Close_last_day50'] = df['p_c'].shift(50)
#49 days ago
df['p_High_last_day49'] = df['p_h'].shift(49)
df['p_Low_last_day49'] = df['p_l'].shift(49)
df['p_Close_last_day49'] = df['p_c'].shift(49)
#48 days ago
df['p_High_last_day48'] = df['p_h'].shift(48)
df['p_Low_last_day48'] = df['p_l'].shift(48)
df['p_Close_last_day48'] = df['p_c'].shift(48)
#47 days ago
df['p_High_last_day47'] = df['p_h'].shift(47)
df['p_Low_last_day47'] = df['p_l'].shift(47)
df['p_Close_last_day47'] = df['p_c'].shift(47)
#46 days ago
df['p_High_last_day46'] = df['p_h'].shift(46)
df['p_Low_last_day46'] = df['p_l'].shift(46)
df['p_Close_last_day46'] = df['p_c'].shift(46)
#45 days ago
df['p_High_last_day45'] = df['p_h'].shift(45)
df['p_Low_last_day45'] = df['p_l'].shift(45)
df['p_Close_last_day45'] = df['p_c'].shift(45)
#44 days ago
df['p_High_last_day44'] = df['p_h'].shift(44)
df['p_Low_last_day44'] = df['p_l'].shift(44)
df['p_Close_last_day44'] = df['p_c'].shift(44)
#43 days ago
df['p_High_last_day43'] = df['p_h'].shift(43)
df['p_Low_last_day43'] = df['p_l'].shift(43)
df['p_Close_last_day43'] = df['p_c'].shift(43)
#42 days ago
df['p_High_last_day42'] = df['p_h'].shift(42)
df['p_Low_last_day42'] = df['p_l'].shift(42)
df['p_Close_last_day42'] = df['p_c'].shift(42)
#41 days ago
df['p_High_last_day41'] = df['p_h'].shift(41)
df['p_Low_last_day41'] = df['p_l'].shift(41)
df['p_Close_last_day41'] = df['p_c'].shift(41)
#40 days ago
df['p_High_last_day40'] = df['p_h'].shift(40)
df['p_Low_last_day40'] = df['p_l'].shift(40)
df['p_Close_last_day40'] = df['p_c'].shift(40)
#39 days ago
df['p_High_last_day39'] = df['p_h'].shift(39)
df['p_Low_last_day39'] = df['p_l'].shift(39)
df['p_Close_last_day39'] = df['p_c'].shift(39)
#38 days ago
df['p_High_last_day38'] = df['p_h'].shift(38)
df['p_Low_last_day38'] = df['p_l'].shift(38)
df['p_Close_last_day38'] = df['p_c'].shift(38)
#37 days ago
df['p_High_last_day37'] = df['p_h'].shift(37)
df['p_Low_last_day37'] = df['p_l'].shift(37)
df['p_Close_last_day37'] = df['p_c'].shift(37)
#36 days ago
df['p_High_last_day36'] = df['p_h'].shift(36)
df['p_Low_last_day36'] = df['p_l'].shift(36)
df['p_Close_last_day36'] = df['p_c'].shift(36)
#35 days ago
df['p_High_last_day35'] = df['p_h'].shift(35)
df['p_Low_last_day35'] = df['p_l'].shift(35)
df['p_Close_last_day35'] = df['p_c'].shift(35)
#34 days ago
df['p_High_last_day34'] = df['p_h'].shift(34)
df['p_Low_last_day34'] = df['p_l'].shift(34)
df['p_Close_last_day34'] = df['p_c'].shift(34)
#33 days ago
df['p_High_last_day33'] = df['p_h'].shift(33)
df['p_Low_last_day33'] = df['p_l'].shift(33)
df['p_Close_last_day33'] = df['p_c'].shift(33)
#32 days ago
df['p_High_last_day32'] = df['p_h'].shift(32)
df['p_Low_last_day32'] = df['p_l'].shift(32)
df['p_Close_last_day32'] = df['p_c'].shift(32)
#31 days ago
df['p_High_last_day31'] = df['p_h'].shift(31)
df['p_Low_last_day31'] = df['p_l'].shift(31)
df['p_Close_last_day31'] = df['p_c'].shift(31)
#30 days ago
df['p_High_last_day30'] = df['p_h'].shift(30)
df['p_Low_last_day30'] = df['p_l'].shift(30)
df['p_Close_last_day30'] = df['p_c'].shift(30) 
#29 days ago 
df['p_High_last_day29'] = df['p_h'].shift(29)
df['p_Low_last_day29'] = df['p_l'].shift(29)
df['p_Close_last_day29'] = df['p_c'].shift(29)
#28 days ago
df['p_High_last_day28'] = df['p_h'].shift(28)
df['p_Low_last_day28'] = df['p_l'].shift(28)
df['p_Close_last_day28'] = df['p_c'].shift(28) 
#27 days ago
df['p_High_last_day27'] = df['p_h'].shift(27)
df['p_Low_last_day27'] = df['p_l'].shift(27)
df['p_Close_last_day27'] = df['p_c'].shift(27)
#26 day ago
df['p_High_last_day26'] = df['p_h'].shift(26)
df['p_Low_last_day26'] = df['p_l'].shift(26)
df['p_Close_last_day26'] = df['p_c'].shift(26)
#25 days ago
df['p_High_last_day25'] = df['p_h'].shift(25)
df['p_Low_last_day25'] = df['p_l'].shift(25)
df['p_Close_last_day25'] = df['p_c'].shift(25) 
#24 days ago 
df['p_High_last_day24'] = df['p_h'].shift(24)
df['p_Low_last_day24'] = df['p_l'].shift(24)
df['p_Close_last_day24'] = df['p_c'].shift(24) 
#23 days ago
df['p_High_last_day23'] = df['p_h'].shift(23)
df['p_Low_last_day23'] = df['p_l'].shift(23)
df['p_Close_last_day23'] = df['p_c'].shift(23) 
#22 days ago
df['p_High_last_day22'] = df['p_h'].shift(22)
df['p_Low_last_day22'] = df['p_l'].shift(22)
df['p_Close_last_day22'] = df['p_c'].shift(22) 
#21 day ago
df['p_High_last_day21'] = df['p_h'].shift(21)
df['p_Low_last_day21'] = df['p_l'].shift(21)
df['p_Close_last_day21'] = df['p_c'].shift(21)
#20 days ago
df['p_High_last_day20'] = df['p_h'].shift(20)
df['p_Low_last_day20'] = df['p_l'].shift(20)
df['p_Close_last_day20'] = df['p_c'].shift(20) 
#19 days ago 
df['p_High_last_day19'] = df['p_h'].shift(19)
df['p_Low_last_day19'] = df['p_l'].shift(19)
df['p_Close_last_day19'] = df['p_c'].shift(19)
#18 days ago
df['p_High_last_day18'] = df['p_h'].shift(18)
df['p_Low_last_day18'] = df['p_l'].shift(18)
df['p_Close_last_day18'] = df['p_c'].shift(18) 
#17 days ago
df['p_High_last_day17'] = df['p_h'].shift(17)
df['p_Low_last_day17'] = df['p_l'].shift(17)
df['p_Close_last_day17'] = df['p_c'].shift(17) 
#16 day ago
df['p_High_last_day16'] = df['p_h'].shift(16)
df['p_Low_last_day16'] = df['p_l'].shift(16)
df['p_Close_last_day16'] = df['p_c'].shift(16)
#15 days ago
df['p_High_last_day15'] = df['p_h'].shift(15)
df['p_Low_last_day15'] = df['p_l'].shift(15)
df['p_Close_last_day15'] = df['p_c'].shift(15)
#14 days ago 
df['p_High_last_day14'] = df['p_h'].shift(14)
df['p_Low_last_day14'] = df['p_l'].shift(14)
df['p_Close_last_day14'] = df['p_c'].shift(14) 
#13 days ago
df['p_High_last_day13'] = df['p_h'].shift(13)
df['p_Low_last_day13'] = df['p_l'].shift(13)
df['p_Close_last_day13'] = df['p_c'].shift(13) 
#12 days ago
df['p_High_last_day12'] = df['p_h'].shift(12)
df['p_Low_last_day12'] = df['p_l'].shift(12)
df['p_Close_last_day12'] = df['p_c'].shift(12) 
#11 day ago 
df['p_High_last_day11'] = df['p_h'].shift(11)
df['p_Low_last_day11'] = df['p_l'].shift(11)
df['p_Close_last_day11'] = df['p_c'].shift(11) 
#10 days ago
df['p_High_last_day10'] = df['p_h'].shift(10)
df['p_Low_last_day10'] = df['p_l'].shift(10)
df['p_Close_last_day10'] = df['p_c'].shift(10)
#9 days ago 
df['p_High_last_day9'] = df['p_h'].shift(9)
df['p_Low_last_day9'] = df['p_l'].shift(9)
df['p_Close_last_day9'] = df['p_c'].shift(9) 
#8 days ago
df['p_High_last_day8'] = df['p_h'].shift(8)
df['p_Low_last_day8'] = df['p_l'].shift(8)
df['p_Close_last_day8'] = df['p_c'].shift(8)
#7 days ago
df['p_High_last_day7'] = df['p_h'].shift(7)
df['p_Low_last_day7'] = df['p_l'].shift(7)
df['p_Close_last_day7'] = df['p_c'].shift(7) 
#6 day ago 
df['p_High_last_day6'] = df['p_h'].shift(6)
df['p_Low_last_day6'] = df['p_l'].shift(6)
df['p_Close_last_day6'] = df['p_c'].shift(6)
#5 days ago
df['p_High_last_day5'] = df['p_h'].shift(5)
df['p_Low_last_day5'] = df['p_l'].shift(5)
df['p_Close_last_day5'] = df['p_c'].shift(5) 
#4 days ago 
df['p_High_last_day4'] = df['p_h'].shift(4)
df['p_Low_last_day4'] = df['p_l'].shift(4)
df['p_Close_last_day4'] = df['p_c'].shift(4) 
#3 days ago
df['p_High_last_day3'] = df['p_h'].shift(3)
df['p_Low_last_day3'] = df['p_l'].shift(3)
df['p_Close_last_day3'] = df['p_c'].shift(3)
#2 days ago
df['p_High_last_day2'] = df['p_h'].shift(2)
df['p_Low_last_day2'] = df['p_l'].shift(2)
df['p_Close_last_day2'] = df['p_c'].shift(2) 
#1 day ago 
df['p_High_last_day1'] = df['p_h'].shift(1)
df['p_Low_last_day1'] = df['p_l'].shift(1)
df['p_Close_last_day1'] = df['p_c'].shift(1)     

#Target
#1 day forward 
df['p_High_next_day1'] = df['p_h'].shift(-1)
df['p_Low_next_day1'] = df['p_l'].shift(-1)
df['p_Close_next_day1'] = df['p_c'].shift(-1) 

#drop null and useless columns
df = df.dropna()
df = df.drop(['d','t','p_o','p_h','p_l','p_c','p_v'], axis=1)

# %%
df

# %%
df = pd.DataFrame(data=df.tail(2000))
df

# %%
#create initial train and test data as pd.DF for close
#final test DF is last_row
df_train_close = pd.DataFrame(data=df.iloc[0:1980,:])
df_test_close = pd.DataFrame(data=df.iloc[1980:2001,:])

#df_train_close = pd.DataFrame(data=df.iloc[0:1980,[2,5,8,11,14,17,20,23,26,29,32,35,38,41,44,47,50,53,56,59,62,65,68,71,74,77,80,83,86,89,92]])
#df_test_close = pd.DataFrame(data=df.iloc[1980:2001,[2,5,8,11,14,17,20,23,26,29,32,35,38,41,44,47,50,53,56,59,62,65,68,71,74,77,80,83,86,89,92]])
print(df_train_close )
print(df_test_close )

# %%
print(df_train_close.isna().sum())
print(df_test_close.isna().sum())

# %%
print(df_train_close.info())
print(df_test_close.info())

# %%
train_close = df_train_close
train_close=train_close.sample(n=2000, replace=True)
train_close.head()

# %%
#predict close
label_c = 'p_Close_next_day1' 
print("Summary of class variable: \n", train_close[label_c].describe())

# %%
train_close = pd.DataFrame(train_close.drop_duplicates(keep=False))

# %%
train_close.info()

# %%
#predict close
save_path='agModels-predictClose'
predictor = TabularPredictor(label=label_c, path=save_path)
predictor.fit(train_close, hyperparameters={ 'XGB':{} } , presets='high_quality')
#predictor.fit(train_close, excluded_model_types=['CatBoost'], presets='optimize_for_deployment') #is slower
# Out:
# ...
# Presets specified: ['high_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClose/"
# AutoGluon Version:  0.4.0
# Python Version:     3.7.13
# Operating System:   Linux
# Train Data Rows:    716
# Train Data Columns: 365
# Label Column: p_Close_next_day1
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (125.576, 100.323, 111.40763, 5.27056)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11340.26 MB
# 	Train Data (Original)  Memory Usage: 2.09 MB (0.0% of available memory)
# ...

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_close, silent=True)

# %%
#predict close
test_close = TabularDataset(df_test_close)
y_test = test_close[label_c]
test_close_nolab = test_close.drop(columns=[label_c])
test_close_nolab.tail()

# %%
#predict p_Close_next_day1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_close_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)

# %%
# clears the model after a run so you can contrast new runs.
# predictor.unpersist_models('ag_predict_interval')
# predictor.save_space()
# predictor.delete_models(models_to_keep='best', dry_run=False)
# %rm -rf AutogluonModels, ag_predict_interval
# !ls
