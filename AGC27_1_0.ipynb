# %% [markdown]
# <a href="https://colab.research.google.com/github/gomlfx/ApiaryFund/blob/master/AGC27_1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install autogluon

# %%
#!pip install --upgrade mxnet

# %%
#designed for Jupyter/kaggle/colab
import pandas as pd
import numpy as np
#import matplotlib for plotting 
import matplotlib.pyplot as plt
# %matplotlib inline
#import normalization
from sklearn import preprocessing

#autogluon
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
 #MT4 csv 
df_m_5=pd.read_csv('USDJPY1440.csv', names=['d','t','eu_o','eu_h','eu_l','eu_c','eu_v'])


# df2=pd.read_csv('GBPUSD1440.csv', names=['d','t','gu_o','gu_h','gu_l','gu_c','gu_v'])
# df2 = df2.tail(2000)

# df3=pd.read_csv('USDCAD1440.csv', names=['d','t','uc_o','uc_h','uc_l','uc_c','uc_v'])
# df3 = df3.tail(2000)

# df4=pd.read_csv('USDCHF1440.csv', names=['d','t','uf_o','uf_h','uf_l','uf_c','uf_v'])
# df4 = df4.tail(2000)

# df5=pd.read_csv('USDJPY1440.csv', names=['d','t','uj_o','uj_h','uj_l','uj_c','uj_v'])
# df5 = df5.tail(2000)

# df6=pd.read_csv('USDSEK1440.csv', names=['d','t','us_o','us_h','us_l','us_c','us_v'])
# df6 = df6.tail(2000)

# #using merge
# df_m_1 = df1.merge(df2, on='d')
# df_m_2 = df_m_1.merge(df3, on='d')
# df_m_3 = df_m_2.merge(df4, on='d')
# df_m_4 = df_m_3.merge(df5, on='d')
# df_m_5 = df_m_4.merge(df6, on='d')
# df_m_5 = df_m_5.drop(columns='t_x')
# df_m_5 = df_m_5.drop(columns='t_y')

# pd.set_option('display.max_columns', None)
# print(df_m_5)

# %%
df_m_5
# Out:
#                d      t     eu_o     eu_h     eu_l     eu_c   eu_v
# 0     2013.11.14  00:00   99.220  100.250   99.130  100.210  18887
# 1     2013.11.15  00:00  100.200  100.430   99.930  100.210  12107
# 2     2013.11.17  00:00  100.210  100.380  100.200  100.350    639
# 3     2013.11.18  00:00  100.350  100.350   99.780   99.862  18614
# 4     2013.11.19  00:00   99.861  100.254   99.570  100.170  64235
# ...          ...    ...      ...      ...      ...      ...    ...
# 2199  2022.04.19  00:00  126.964  128.971  126.963  128.887  58062
# 2200  2022.04.20  00:00  128.883  129.406  127.456  127.876  71228
# 2201  2022.04.21  00:00  127.826  128.703  127.793  128.382  57395
# 2202  2022.04.22  00:00  128.333  129.106  127.735  128.531  62386
# 2203  2022.04.25  00:00  128.553  128.851  128.406  128.766   1914
#
# [2204 rows x 7 columns]

# %%
#Features

#70 days ago
df_m_5['eu_High_last_day70'] = df_m_5['eu_h'].shift(70)
df_m_5['eu_Low_last_day70'] = df_m_5['eu_l'].shift(70)
df_m_5['eu_Close_last_day70'] = df_m_5['eu_c'].shift(70)
#69 days ago
df_m_5['eu_High_last_day69'] = df_m_5['eu_h'].shift(69)
df_m_5['eu_Low_last_day69'] = df_m_5['eu_l'].shift(69)
df_m_5['eu_Close_last_day69'] = df_m_5['eu_c'].shift(69)
#68 days ago
df_m_5['eu_High_last_day68'] = df_m_5['eu_h'].shift(68)
df_m_5['eu_Low_last_day68'] = df_m_5['eu_l'].shift(68)
df_m_5['eu_Close_last_day68'] = df_m_5['eu_c'].shift(68)
#67 days ago
df_m_5['eu_High_last_day67'] = df_m_5['eu_h'].shift(67)
df_m_5['eu_Low_last_day67'] = df_m_5['eu_l'].shift(67)
df_m_5['eu_Close_last_day67'] = df_m_5['eu_c'].shift(67)
#66 days ago
df_m_5['eu_High_last_day66'] = df_m_5['eu_h'].shift(66)
df_m_5['eu_Low_last_day66'] = df_m_5['eu_l'].shift(66)
df_m_5['eu_Close_last_day66'] = df_m_5['eu_c'].shift(66)
#65 days ago
df_m_5['eu_High_last_day65'] = df_m_5['eu_h'].shift(65)
df_m_5['eu_Low_last_day65'] = df_m_5['eu_l'].shift(65)
df_m_5['eu_Close_last_day65'] = df_m_5['eu_c'].shift(65)
#64 days ago
df_m_5['eu_High_last_day64'] = df_m_5['eu_h'].shift(64)
df_m_5['eu_Low_last_day64'] = df_m_5['eu_l'].shift(64)
df_m_5['eu_Close_last_day64'] = df_m_5['eu_c'].shift(64)
#63 days ago
df_m_5['eu_High_last_day63'] = df_m_5['eu_h'].shift(63)
df_m_5['eu_Low_last_day63'] = df_m_5['eu_l'].shift(63)
df_m_5['eu_Close_last_day63'] = df_m_5['eu_c'].shift(63)
#62 days ago
df_m_5['eu_High_last_day62'] = df_m_5['eu_h'].shift(62)
df_m_5['eu_Low_last_day62'] = df_m_5['eu_l'].shift(62)
df_m_5['eu_Close_last_day62'] = df_m_5['eu_c'].shift(62)
#61 days ago
df_m_5['eu_High_last_day61'] = df_m_5['eu_h'].shift(61)
df_m_5['eu_Low_last_day61'] = df_m_5['eu_l'].shift(61)
df_m_5['eu_Close_last_day61'] = df_m_5['eu_c'].shift(61)
#60 days ago
df_m_5['eu_High_last_day60'] = df_m_5['eu_h'].shift(60)
df_m_5['eu_Low_last_day60'] = df_m_5['eu_l'].shift(60)
df_m_5['eu_Close_last_day60'] = df_m_5['eu_c'].shift(60)
#59 days ago
df_m_5['eu_High_last_day59'] = df_m_5['eu_h'].shift(59)
df_m_5['eu_Low_last_day59'] = df_m_5['eu_l'].shift(59)
df_m_5['eu_Close_last_day59'] = df_m_5['eu_c'].shift(59)
#58 days ago
df_m_5['eu_High_last_day58'] = df_m_5['eu_h'].shift(58)
df_m_5['eu_Low_last_day58'] = df_m_5['eu_l'].shift(58)
df_m_5['eu_Close_last_day58'] = df_m_5['eu_c'].shift(58)
#57 days ago
df_m_5['eu_High_last_day57'] = df_m_5['eu_h'].shift(57)
df_m_5['eu_Low_last_day57'] = df_m_5['eu_l'].shift(57)
df_m_5['eu_Close_last_day57'] = df_m_5['eu_c'].shift(57)
#56 days ago
df_m_5['eu_High_last_day56'] = df_m_5['eu_h'].shift(56)
df_m_5['eu_Low_last_day56'] = df_m_5['eu_l'].shift(56)
df_m_5['eu_Close_last_day56'] = df_m_5['eu_c'].shift(56)
#55 days ago
df_m_5['eu_High_last_day55'] = df_m_5['eu_h'].shift(55)
df_m_5['eu_Low_last_day55'] = df_m_5['eu_l'].shift(55)
df_m_5['eu_Close_last_day55'] = df_m_5['eu_c'].shift(55)
#54 days ago
df_m_5['eu_High_last_day54'] = df_m_5['eu_h'].shift(54)
df_m_5['eu_Low_last_day54'] = df_m_5['eu_l'].shift(54)
df_m_5['eu_Close_last_day54'] = df_m_5['eu_c'].shift(54)
#53 days ago
df_m_5['eu_High_last_day53'] = df_m_5['eu_h'].shift(53)
df_m_5['eu_Low_last_day53'] = df_m_5['eu_l'].shift(53)
df_m_5['eu_Close_last_day53'] = df_m_5['eu_c'].shift(53)
#52 days ago
df_m_5['eu_High_last_day52'] = df_m_5['eu_h'].shift(52)
df_m_5['eu_Low_last_day52'] = df_m_5['eu_l'].shift(52)
df_m_5['eu_Close_last_day52'] = df_m_5['eu_c'].shift(52)
#51 days ago
df_m_5['eu_High_last_day51'] = df_m_5['eu_h'].shift(51)
df_m_5['eu_Low_last_day51'] = df_m_5['eu_l'].shift(51)
df_m_5['eu_Close_last_day51'] = df_m_5['eu_c'].shift(51)
#50 days ago
df_m_5['eu_High_last_day50'] = df_m_5['eu_h'].shift(50)
df_m_5['eu_Low_last_day50'] = df_m_5['eu_l'].shift(50)
df_m_5['eu_Close_last_day50'] = df_m_5['eu_c'].shift(50)
#49 days ago
df_m_5['eu_High_last_day49'] = df_m_5['eu_h'].shift(49)
df_m_5['eu_Low_last_day49'] = df_m_5['eu_l'].shift(49)
df_m_5['eu_Close_last_day49'] = df_m_5['eu_c'].shift(49)
#48 days ago
df_m_5['eu_High_last_day48'] = df_m_5['eu_h'].shift(48)
df_m_5['eu_Low_last_day48'] = df_m_5['eu_l'].shift(48)
df_m_5['eu_Close_last_day48'] = df_m_5['eu_c'].shift(48)
#47 days ago
df_m_5['eu_High_last_day47'] = df_m_5['eu_h'].shift(47)
df_m_5['eu_Low_last_day47'] = df_m_5['eu_l'].shift(47)
df_m_5['eu_Close_last_day47'] = df_m_5['eu_c'].shift(47)
#46 days ago
df_m_5['eu_High_last_day46'] = df_m_5['eu_h'].shift(46)
df_m_5['eu_Low_last_day46'] = df_m_5['eu_l'].shift(46)
df_m_5['eu_Close_last_day46'] = df_m_5['eu_c'].shift(46)
#45 days ago
df_m_5['eu_High_last_day45'] = df_m_5['eu_h'].shift(45)
df_m_5['eu_Low_last_day45'] = df_m_5['eu_l'].shift(45)
df_m_5['eu_Close_last_day45'] = df_m_5['eu_c'].shift(45)
#44 days ago
df_m_5['eu_High_last_day44'] = df_m_5['eu_h'].shift(44)
df_m_5['eu_Low_last_day44'] = df_m_5['eu_l'].shift(44)
df_m_5['eu_Close_last_day44'] = df_m_5['eu_c'].shift(44)
#43 days ago
df_m_5['eu_High_last_day43'] = df_m_5['eu_h'].shift(43)
df_m_5['eu_Low_last_day43'] = df_m_5['eu_l'].shift(43)
df_m_5['eu_Close_last_day43'] = df_m_5['eu_c'].shift(43)
#42 days ago
df_m_5['eu_High_last_day42'] = df_m_5['eu_h'].shift(42)
df_m_5['eu_Low_last_day42'] = df_m_5['eu_l'].shift(42)
df_m_5['eu_Close_last_day42'] = df_m_5['eu_c'].shift(42)
#41 days ago
df_m_5['eu_High_last_day41'] = df_m_5['eu_h'].shift(41)
df_m_5['eu_Low_last_day41'] = df_m_5['eu_l'].shift(41)
df_m_5['eu_Close_last_day41'] = df_m_5['eu_c'].shift(41)
#40 days ago
df_m_5['eu_High_last_day40'] = df_m_5['eu_h'].shift(40)
df_m_5['eu_Low_last_day40'] = df_m_5['eu_l'].shift(40)
df_m_5['eu_Close_last_day40'] = df_m_5['eu_c'].shift(40)
#39 days ago
df_m_5['eu_High_last_day39'] = df_m_5['eu_h'].shift(39)
df_m_5['eu_Low_last_day39'] = df_m_5['eu_l'].shift(39)
df_m_5['eu_Close_last_day39'] = df_m_5['eu_c'].shift(39)
#38 days ago
df_m_5['eu_High_last_day38'] = df_m_5['eu_h'].shift(38)
df_m_5['eu_Low_last_day38'] = df_m_5['eu_l'].shift(38)
df_m_5['eu_Close_last_day38'] = df_m_5['eu_c'].shift(38)
#37 days ago
df_m_5['eu_High_last_day37'] = df_m_5['eu_h'].shift(37)
df_m_5['eu_Low_last_day37'] = df_m_5['eu_l'].shift(37)
df_m_5['eu_Close_last_day37'] = df_m_5['eu_c'].shift(37)
#36 days ago
df_m_5['eu_High_last_day36'] = df_m_5['eu_h'].shift(36)
df_m_5['eu_Low_last_day36'] = df_m_5['eu_l'].shift(36)
df_m_5['eu_Close_last_day36'] = df_m_5['eu_c'].shift(36)
#35 days ago
df_m_5['eu_High_last_day35'] = df_m_5['eu_h'].shift(35)
df_m_5['eu_Low_last_day35'] = df_m_5['eu_l'].shift(35)
df_m_5['eu_Close_last_day35'] = df_m_5['eu_c'].shift(35)
#34 days ago
df_m_5['eu_High_last_day34'] = df_m_5['eu_h'].shift(34)
df_m_5['eu_Low_last_day34'] = df_m_5['eu_l'].shift(34)
df_m_5['eu_Close_last_day34'] = df_m_5['eu_c'].shift(34)
#33 days ago
df_m_5['eu_High_last_day33'] = df_m_5['eu_h'].shift(33)
df_m_5['eu_Low_last_day33'] = df_m_5['eu_l'].shift(33)
df_m_5['eu_Close_last_day33'] = df_m_5['eu_c'].shift(33)
#32 days ago
df_m_5['eu_High_last_day32'] = df_m_5['eu_h'].shift(32)
df_m_5['eu_Low_last_day32'] = df_m_5['eu_l'].shift(32)
df_m_5['eu_Close_last_day32'] = df_m_5['eu_c'].shift(32)
#31 days ago
df_m_5['eu_High_last_day31'] = df_m_5['eu_h'].shift(31)
df_m_5['eu_Low_last_day31'] = df_m_5['eu_l'].shift(31)
df_m_5['eu_Close_last_day31'] = df_m_5['eu_c'].shift(31)
#30 days ago
df_m_5['eu_High_last_day30'] = df_m_5['eu_h'].shift(30)
df_m_5['eu_Low_last_day30'] = df_m_5['eu_l'].shift(30)
df_m_5['eu_Close_last_day30'] = df_m_5['eu_c'].shift(30) 
#29 days ago 
df_m_5['eu_High_last_day29'] = df_m_5['eu_h'].shift(29)
df_m_5['eu_Low_last_day29'] = df_m_5['eu_l'].shift(29)
df_m_5['eu_Close_last_day29'] = df_m_5['eu_c'].shift(29)
#28 days ago
df_m_5['eu_High_last_day28'] = df_m_5['eu_h'].shift(28)
df_m_5['eu_Low_last_day28'] = df_m_5['eu_l'].shift(28)
df_m_5['eu_Close_last_day28'] = df_m_5['eu_c'].shift(28) 
#27 days ago
df_m_5['eu_High_last_day27'] = df_m_5['eu_h'].shift(27)
df_m_5['eu_Low_last_day27'] = df_m_5['eu_l'].shift(27)
df_m_5['eu_Close_last_day27'] = df_m_5['eu_c'].shift(27)
#26 day ago
df_m_5['eu_High_last_day26'] = df_m_5['eu_h'].shift(26)
df_m_5['eu_Low_last_day26'] = df_m_5['eu_l'].shift(26)
df_m_5['eu_Close_last_day26'] = df_m_5['eu_c'].shift(26)
#25 days ago
df_m_5['eu_High_last_day25'] = df_m_5['eu_h'].shift(25)
df_m_5['eu_Low_last_day25'] = df_m_5['eu_l'].shift(25)
df_m_5['eu_Close_last_day25'] = df_m_5['eu_c'].shift(25) 
#24 days ago 
df_m_5['eu_High_last_day24'] = df_m_5['eu_h'].shift(24)
df_m_5['eu_Low_last_day24'] = df_m_5['eu_l'].shift(24)
df_m_5['eu_Close_last_day24'] = df_m_5['eu_c'].shift(24) 
#23 days ago
df_m_5['eu_High_last_day23'] = df_m_5['eu_h'].shift(23)
df_m_5['eu_Low_last_day23'] = df_m_5['eu_l'].shift(23)
df_m_5['eu_Close_last_day23'] = df_m_5['eu_c'].shift(23) 
#22 days ago
df_m_5['eu_High_last_day22'] = df_m_5['eu_h'].shift(22)
df_m_5['eu_Low_last_day22'] = df_m_5['eu_l'].shift(22)
df_m_5['eu_Close_last_day22'] = df_m_5['eu_c'].shift(22) 
#21 day ago
df_m_5['eu_High_last_day21'] = df_m_5['eu_h'].shift(21)
df_m_5['eu_Low_last_day21'] = df_m_5['eu_l'].shift(21)
df_m_5['eu_Close_last_day21'] = df_m_5['eu_c'].shift(21)
#20 days ago
df_m_5['eu_High_last_day20'] = df_m_5['eu_h'].shift(20)
df_m_5['eu_Low_last_day20'] = df_m_5['eu_l'].shift(20)
df_m_5['eu_Close_last_day20'] = df_m_5['eu_c'].shift(20) 
#19 days ago 
df_m_5['eu_High_last_day19'] = df_m_5['eu_h'].shift(19)
df_m_5['eu_Low_last_day19'] = df_m_5['eu_l'].shift(19)
df_m_5['eu_Close_last_day19'] = df_m_5['eu_c'].shift(19)
#18 days ago
df_m_5['eu_High_last_day18'] = df_m_5['eu_h'].shift(18)
df_m_5['eu_Low_last_day18'] = df_m_5['eu_l'].shift(18)
df_m_5['eu_Close_last_day18'] = df_m_5['eu_c'].shift(18) 
#17 days ago
df_m_5['eu_High_last_day17'] = df_m_5['eu_h'].shift(17)
df_m_5['eu_Low_last_day17'] = df_m_5['eu_l'].shift(17)
df_m_5['eu_Close_last_day17'] = df_m_5['eu_c'].shift(17) 
#16 day ago
df_m_5['eu_High_last_day16'] = df_m_5['eu_h'].shift(16)
df_m_5['eu_Low_last_day16'] = df_m_5['eu_l'].shift(16)
df_m_5['eu_Close_last_day16'] = df_m_5['eu_c'].shift(16)
#15 days ago
df_m_5['eu_High_last_day15'] = df_m_5['eu_h'].shift(15)
df_m_5['eu_Low_last_day15'] = df_m_5['eu_l'].shift(15)
df_m_5['eu_Close_last_day15'] = df_m_5['eu_c'].shift(15)
#14 days ago 
df_m_5['eu_High_last_day14'] = df_m_5['eu_h'].shift(14)
df_m_5['eu_Low_last_day14'] = df_m_5['eu_l'].shift(14)
df_m_5['eu_Close_last_day14'] = df_m_5['eu_c'].shift(14) 
#13 days ago
df_m_5['eu_High_last_day13'] = df_m_5['eu_h'].shift(13)
df_m_5['eu_Low_last_day13'] = df_m_5['eu_l'].shift(13)
df_m_5['eu_Close_last_day13'] = df_m_5['eu_c'].shift(13) 
#12 days ago
df_m_5['eu_High_last_day12'] = df_m_5['eu_h'].shift(12)
df_m_5['eu_Low_last_day12'] = df_m_5['eu_l'].shift(12)
df_m_5['eu_Close_last_day12'] = df_m_5['eu_c'].shift(12) 
#11 day ago 
df_m_5['eu_High_last_day11'] = df_m_5['eu_h'].shift(11)
df_m_5['eu_Low_last_day11'] = df_m_5['eu_l'].shift(11)
df_m_5['eu_Close_last_day11'] = df_m_5['eu_c'].shift(11) 
#10 days ago
df_m_5['eu_High_last_day10'] = df_m_5['eu_h'].shift(10)
df_m_5['eu_Low_last_day10'] = df_m_5['eu_l'].shift(10)
df_m_5['eu_Close_last_day10'] = df_m_5['eu_c'].shift(10)
#9 days ago 
df_m_5['eu_High_last_day9'] = df_m_5['eu_h'].shift(9)
df_m_5['eu_Low_last_day9'] = df_m_5['eu_l'].shift(9)
df_m_5['eu_Close_last_day9'] = df_m_5['eu_c'].shift(9) 
#8 days ago
df_m_5['eu_High_last_day8'] = df_m_5['eu_h'].shift(8)
df_m_5['eu_Low_last_day8'] = df_m_5['eu_l'].shift(8)
df_m_5['eu_Close_last_day8'] = df_m_5['eu_c'].shift(8)
#7 days ago
df_m_5['eu_High_last_day7'] = df_m_5['eu_h'].shift(7)
df_m_5['eu_Low_last_day7'] = df_m_5['eu_l'].shift(7)
df_m_5['eu_Close_last_day7'] = df_m_5['eu_c'].shift(7) 
#6 day ago 
df_m_5['eu_High_last_day6'] = df_m_5['eu_h'].shift(6)
df_m_5['eu_Low_last_day6'] = df_m_5['eu_l'].shift(6)
df_m_5['eu_Close_last_day6'] = df_m_5['eu_c'].shift(6)
#5 days ago
df_m_5['eu_High_last_day5'] = df_m_5['eu_h'].shift(5)
df_m_5['eu_Low_last_day5'] = df_m_5['eu_l'].shift(5)
df_m_5['eu_Close_last_day5'] = df_m_5['eu_c'].shift(5) 
#4 days ago 
df_m_5['eu_High_last_day4'] = df_m_5['eu_h'].shift(4)
df_m_5['eu_Low_last_day4'] = df_m_5['eu_l'].shift(4)
df_m_5['eu_Close_last_day4'] = df_m_5['eu_c'].shift(4) 
#3 days ago
df_m_5['eu_High_last_day3'] = df_m_5['eu_h'].shift(3)
df_m_5['eu_Low_last_day3'] = df_m_5['eu_l'].shift(3)
df_m_5['eu_Close_last_day3'] = df_m_5['eu_c'].shift(3)
#2 days ago
df_m_5['eu_High_last_day2'] = df_m_5['eu_h'].shift(2)
df_m_5['eu_Low_last_day2'] = df_m_5['eu_l'].shift(2)
df_m_5['eu_Close_last_day2'] = df_m_5['eu_c'].shift(2) 
#1 day ago 
df_m_5['eu_High_last_day1'] = df_m_5['eu_h'].shift(1)
df_m_5['eu_Low_last_day1'] = df_m_5['eu_l'].shift(1)
df_m_5['eu_Close_last_day1'] = df_m_5['eu_c'].shift(1)     

#Target
#1 day forward 
df_m_5['eu_High_next_day1'] = df_m_5['eu_h'].shift(-1)
df_m_5['eu_Low_next_day1'] = df_m_5['eu_l'].shift(-1)
df_m_5['eu_Close_next_day1'] = df_m_5['eu_c'].shift(-1) 

#drop null and useless columns
df_m_5 = df_m_5.dropna()
df_m_5 = df_m_5.drop(['d','t','eu_o','eu_h','eu_l','eu_c','eu_v'], axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# ...

# %%
df_m_5
# Out:
#       eu_High_last_day70  eu_Low_last_day70  eu_Close_last_day70  \
# 70               100.250             99.130              100.210
# 71               100.430             99.930              100.210
# 72               100.380            100.200              100.350
# 73               100.350             99.780               99.862
# 74               100.254             99.570              100.170
# ...                  ...                ...                  ...
# 2198             115.848            115.039              115.189
# 2199             115.679            115.122              115.293
# 2200             115.463            114.376              114.631
# 2201             114.700            113.996              114.157
# 2202             114.265            113.479              114.198
#
#       eu_High_last_day69  eu_Low_last_day69  eu_Close_last_day69  \
# 70               100.430             99.930              100.210
# ...

# %%
extra_clone = pd.DataFrame(data=df_m_5)
print(extra_clone)
# Out:
#       eu_High_last_day70  eu_Low_last_day70  eu_Close_last_day70  \
# 70               100.250             99.130              100.210
# 71               100.430             99.930              100.210
# 72               100.380            100.200              100.350
# 73               100.350             99.780               99.862
# 74               100.254             99.570              100.170
# ...                  ...                ...                  ...
# 2198             115.848            115.039              115.189
# 2199             115.679            115.122              115.293
# 2200             115.463            114.376              114.631
# 2201             114.700            113.996              114.157
# 2202             114.265            113.479              114.198
#
#       eu_High_last_day69  eu_Low_last_day69  eu_Close_last_day69  \
# 70               100.430             99.930              100.210
# ...

# %%
extra_clone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2133 entries, 70 to 2202
# Columns: 213 entries, eu_High_last_day70 to eu_Close_next_day1
# dtypes: float64(213)
# memory usage: 3.5 MB

# %%
#extract yesterday's row to predict today's row
#check if needs to be pd.DataFrame
last_row = pd.DataFrame(data=extra_clone.iloc[-10:,np.r_[0:93]])
last_row
# Out:
#       eu_High_last_day70  eu_Low_last_day70  eu_Close_last_day70  \
# 2193             115.364            114.945              115.321
# 2194             116.348            115.271              116.127
# 2195             116.240            115.618              116.099
# 2196             116.183            115.623              115.841
# 2197             116.045            115.533              115.549
# 2198             115.848            115.039              115.189
# 2199             115.679            115.122              115.293
# 2200             115.463            114.376              114.631
# 2201             114.700            113.996              114.157
# 2202             114.265            113.479              114.198
#
#       eu_High_last_day69  eu_Low_last_day69  eu_Close_last_day69  \
# 2193             116.348            115.271              116.127
# 2194             116.240            115.618              116.099
# ...

# %%
df_m_5 = pd.DataFrame(data=df_m_5.tail(2000))
df_m_5
# Out:
#       eu_High_last_day70  eu_Low_last_day70  eu_Close_last_day70  \
# 203              102.362            102.130              102.324
# 204              103.018            102.131              102.207
# 205              102.260            101.863              102.140
# 206              102.187            101.495              101.681
# 207              102.005            101.430              101.898
# ...                  ...                ...                  ...
# 2198             115.848            115.039              115.189
# 2199             115.679            115.122              115.293
# 2200             115.463            114.376              114.631
# 2201             114.700            113.996              114.157
# 2202             114.265            113.479              114.198
#
#       eu_High_last_day69  eu_Low_last_day69  eu_Close_last_day69  \
# 203              103.018            102.131              102.207
# ...

# %%
#create initial train and test data as pd.DF for close
#final test DF is last_row
df_m_5_train_close = pd.DataFrame(data=df_m_5.iloc[0:1980,:])
df_m_5_test_close = pd.DataFrame(data=df_m_5.iloc[1980:2001,:])

#df_m_5_train_close = pd.DataFrame(data=df_m_5.iloc[0:1980,[2,5,8,11,14,17,20,23,26,29,32,35,38,41,44,47,50,53,56,59,62,65,68,71,74,77,80,83,86,89,92]])
#df_m_5_test_close = pd.DataFrame(data=df_m_5.iloc[1980:2001,[2,5,8,11,14,17,20,23,26,29,32,35,38,41,44,47,50,53,56,59,62,65,68,71,74,77,80,83,86,89,92]])
print(df_m_5_train_close )
print(df_m_5_test_close )
# Out:
#       eu_High_last_day70  eu_Low_last_day70  eu_Close_last_day70  \
# 203              102.362            102.130              102.324
# 204              103.018            102.131              102.207
# 205              102.260            101.863              102.140
# 206              102.187            101.495              101.681
# 207              102.005            101.430              101.898
# ...                  ...                ...                  ...
# 2178             113.723            113.332              113.574
# 2179             113.755            113.425              113.748
# 2180             114.266            113.625              114.051
# 2181             114.244            113.556              113.697
# 2182             113.854            113.136              113.701
#
#       eu_High_last_day69  eu_Low_last_day69  eu_Close_last_day69  \
# 203              103.018            102.131              102.207
# ...

# %%
# #create initial train and test data as pd.DF for low
# #final test DF is last_row
# df_m_5_train_low = pd.DataFrame(data=df_m_5.iloc[0:7980,[1,4,7,10,13,16,19,22,25,28,31,34,37,40,43,46,49,52,55,58,61,64,67,70,73,76,79,82,85,88,91]])


# df_m_5_test_low = pd.DataFrame(data=df_m_5.iloc[7980:8001,[1,4,7,10,13,16,19,22,25,28,31,34,37,40,43,46,49,52,55,58,61,64,67,70,73,76,79,82,85,88,91]])
# print(df_m_5_train_low )
# print(df_m_5_test_low )

# %%
# #create initial train and test data as pd.DF for high
# #final test DF is last_row
# df_m_5_train_high = pd.DataFrame(data=df_m_5.iloc[0:7980,[0,3,6,9,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,84,87,90]])

# df_m_5_test_high= pd.DataFrame(data=df_m_5.iloc[7980:8001,[0,3,6,9,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,84,87,90]])
# print(df_m_5_train_high )
# print(df_m_5_test_high )

# %%
# #new column: high vs low
# df_m_5['eu_h_or_l'] = ((df_m_5.eu_h - df_m_5.eu_o) > (df_m_5.eu_o - df_m_5.eu_l)) 
# df_m_5.eu_h_or_l = df_m_5.eu_h_or_l.replace({True:1,False:0})

# #new column: close vs yesterday
# df_m_5['eu_c_vs_c'] = (df_m_5.eu_c > df_m_5.eu_o) 
# df_m_5.eu_c_vs_c = df_m_5.eu_c_vs_c.replace({True:1,False:0})

# #new column: shift tomorrow to today
# df_m_5['eu_High_next_day'] = df_m_5['eu_h'].shift(-1)
# df_m_5['eu_Low_next_day'] = df_m_5['eu_l'].shift(-1)
# df_m_5['eu_Close_next_day'] = df_m_5['eu_c'].shift(-1)
# df_m_5 = df_m_5.dropna()

# %%
print(df_m_5_train_close.isna().sum())
print(df_m_5_test_close.isna().sum())
# Out:
# eu_High_last_day70     0
# eu_Low_last_day70      0
# eu_Close_last_day70    0
# eu_High_last_day69     0
# eu_Low_last_day69      0
#                       ..
# eu_Low_last_day1       0
# eu_Close_last_day1     0
# eu_High_next_day1      0
# eu_Low_next_day1       0
# eu_Close_next_day1     0
# Length: 213, dtype: int64
# eu_High_last_day70     0
# eu_Low_last_day70      0
# eu_Close_last_day70    0
# eu_High_last_day69     0
# eu_Low_last_day69      0
#                       ..
# eu_Low_last_day1       0
# eu_Close_last_day1     0
# eu_High_next_day1      0
# eu_Low_next_day1       0
# eu_Close_next_day1     0
# Length: 213, dtype: int64

# %%
print(df_m_5_train_close.info())
print(df_m_5_test_close.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1980 entries, 203 to 2182
# Columns: 213 entries, eu_High_last_day70 to eu_Close_next_day1
# dtypes: float64(213)
# memory usage: 3.2 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 2183 to 2202
# Columns: 213 entries, eu_High_last_day70 to eu_Close_next_day1
# dtypes: float64(213)
# memory usage: 33.4 KB
# None

# %%
# print(df_m_5_train_high.isna().sum())
# print(df_m_5_test_high.isna().sum())
# print(df_m_5_train_high.info())
# print(df_m_5_test_high.info())

# %%
# print(df_m_5_train_low.isna().sum())
# print(df_m_5_test_low.isna().sum())
# print(df_m_5_train_low.info())
# print(df_m_5_test_low.info())

# %%
train_close = df_m_5_train_close
train_close=train_close.sample(n=2000, replace=True)
train_close.head()
# Out:
#       eu_High_last_day70  eu_Low_last_day70  eu_Close_last_day70  \
# 954              111.045            110.111              110.657
# 1337             111.994            111.155              111.923
# 983              112.795            112.085              112.708
# 2014             108.771            108.070              108.732
# 1090             113.190            112.619              112.843
#
#       eu_High_last_day69  eu_Low_last_day69  eu_Close_last_day69  \
# 954              111.197            110.179              111.123
# 1337             112.165            111.750              112.038
# 983              113.290            112.393              113.249
# 2014             109.072            108.569              108.598
# 1090             112.933            112.317              112.745
#
#       eu_High_last_day68  eu_Low_last_day68  eu_Close_last_day68  \
# 954              111.311            110.713              111.026
# ...

# %%
#predict close
label_c = 'eu_Close_next_day1' 
print("Summary of class variable: \n", train_close[label_c].describe())
# Out:
# Summary of class variable:
#  count    2000.000000
# mean      111.389801
# std         5.265493
# min       100.267000
# 25%       107.872000
# 50%       110.542000
# 75%       113.828000
# max       125.576000
# Name: eu_Close_next_day1, dtype: float64

# %%
train_close = pd.DataFrame(train_close.drop_duplicates(keep=False))

# %%
train_close.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 724 entries, 1337 to 361
# Columns: 213 entries, eu_High_last_day70 to eu_Close_next_day1
# dtypes: float64(213)
# memory usage: 1.2 MB

# %%
#predict close
save_path='agModels-predictClose'
predictor = TabularPredictor(label=label_c, path=save_path)
predictor.fit(train_close, hyperparameters={ 'XGB':{} } , presets='high_quality')
#predictor.fit(train_close, excluded_model_types=['CatBoost'], presets='optimize_for_deployment') #is slower
# Out:
# ...
# Presets specified: ['high_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClose/"
# AutoGluon Version:  0.4.0
# Python Version:     3.7.13
# Operating System:   Linux
# Train Data Rows:    724
# Train Data Columns: 212
# Label Column: eu_Close_next_day1
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (124.627, 100.267, 111.14478, 5.2883)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11289.0 MB
# 	Train Data (Original)  Memory Usage: 1.23 MB (0.0% of available memory)
# ...

# %%
#contrast leaderboard result of train and test data
predictor.leaderboard(train_close, silent=True)
# Out:
#                       model  score_test  score_val  pred_time_test  \
# 0       XGBoost_BAG_L1_FULL   -0.103176        NaN        0.022533
# 1  WeightedEnsemble_L2_FULL   -0.103176        NaN        0.026141
# 2            XGBoost_BAG_L1         NaN  -0.409276             NaN
# 3       WeightedEnsemble_L2         NaN  -0.409276             NaN
#
#    pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0            NaN    4.624804                 0.022533                     NaN
# 1            NaN    4.631771                 0.003608                     NaN
# 2       0.080693  149.101856                      NaN                0.080693
# 3       0.081568  149.108823                      NaN                0.000875
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           4.624804            1       True          3
# 1           0.006967            2       True          4
# 2         149.101856            1      False          1
# ...

# %%
#predict close
test_close = TabularDataset(df_m_5_test_close)
y_test = test_close[label_c]
test_close_nolab = test_close.drop(columns=[label_c])
test_close_nolab.tail()
# Out:
#       eu_High_last_day70  eu_Low_last_day70  eu_Close_last_day70  \
# 2198             115.848            115.039              115.189
# 2199             115.679            115.122              115.293
# 2200             115.463            114.376              114.631
# 2201             114.700            113.996              114.157
# 2202             114.265            113.479              114.198
#
#       eu_High_last_day69  eu_Low_last_day69  eu_Close_last_day69  \
# 2198             115.679            115.122              115.293
# 2199             115.463            114.376              114.631
# 2200             114.700            113.996              114.157
# 2201             114.265            113.479              114.198
# 2202             114.647            114.145              114.608
#
#       eu_High_last_day68  eu_Low_last_day68  eu_Close_last_day68  \
# 2198             115.463            114.376              114.631
# ...

# %%
#predict eu_Close_next_day1
predictor = TabularPredictor.load(save_path)
y_pred = predictor.predict(test_close_nolab)
print("Predictions: \n", y_pred)
perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: root_mean_squared_error on test data: -2.4778728538914288
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -2.4778728538914288,
#     "mean_squared_error": -6.139853880052052,
#     "mean_absolute_error": -1.8521488464355478,
#     "r2": -0.1277706209062932,
#     "pearsonr": 0.8266447214299056,
#     "median_absolute_error": -1.3666216430664093
# }
# Predictions:
#  2183    123.597137
# 2184    122.208427
# 2185    122.156425
# 2186    122.352676
# 2187    122.581474
# 2188    123.020500
# 2189    123.485596
# 2190    123.457268
# 2191    123.998718
# 2192    124.026878
# 2193    124.026878
# 2194    124.026878
# 2195    124.037018
# 2196    123.991898
# 2197    124.081589
# 2198    124.081589
# 2199    124.099892
# 2200    124.123283
# 2201    124.076439
# 2202    124.076439
# Name: eu_Close_next_day1, dtype: float32

# %%
# #predict high
# train_high = df_m_5_train_high
# train_high=train_high.sample(n=7900, replace=True)
# train_high.head()

# %%
# #predict high
# label_h = 'eu_High_next_day1' 
# print("Summary of class variable: \n", train_high[label_h].describe())

# %%
# #predict high
# save_path='agModels-predictHigh'
# predictor = TabularPredictor(label=label_h, path=save_path).fit(train_high,hyperparameters={ 'NN':{} } , presets='high_quality_fast_inference_only_refit')#, presets='best_quality')
# #.fit(presets='best_quality) is slower

# %%
# #contrast leaderboard result of train and test data
# predictor.leaderboard(train_high, silent=True)

# %%
# #predict high
# test_high = TabularDataset(df_m_5_test_high)
# y_test = test_high[label_h]
# test_high_nolab = test_high.drop(columns=[label_h])
# test_high_nolab.tail()

# %%
# #first run to predict eu_High_next_day1
# predictor = TabularPredictor.load(save_path)
# y_pred = predictor.predict(test_high_nolab)
# print("Predictions: \n", y_pred) #try print more rows
# perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)

# %%
# #predict low
# train_low = df_m_5_train_low
# train_low=train_low.sample(n=7900, replace=True)
# train_low.head()

# %%
# #predict low
# label_l = 'eu_Low_next_day1' 
# print("Summary of class variable: \n", train_low[label_l].describe())

# %%
# #predict low
# save_path='agModels-predictLow'
# predictor = TabularPredictor(label=label_l, path=save_path).fit(train_low,hyperparameters={ 'NN':{} } , presets='high_quality_fast_inference_only_refit')#, presets='best_quality')
# #.fit(presets='best_quality) is slower

# %%
# #contrast leaderboard result of train and test data
# predictor.leaderboard(train_low, silent=True)

# %%
# #predict low
# test_low = TabularDataset(df_m_5_test_low)
# y_test = test_low[label_l]
# test_low_nolab = test_low.drop(columns=[label_l])
# test_low_nolab.tail()

# %%
# #predict eu_Low_next_day1
# predictor = TabularPredictor.load(save_path)
# y_pred = predictor.predict(test_low_nolab)
# print("Predictions: \n", y_pred)
# perf = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics=True)

# %%
# clears the model after a run so you can contrast new runs.
# predictor.unpersist_models('ag_predict_interval')
# predictor.save_space()
# predictor.delete_models(models_to_keep='best', dry_run=False)
# %rm -rf AutogluonModels, ag_predict_interval
# !ls
# Out:
# agModels-predictClose  GBPUSD1440.csv  USDCAD1440.csv
# AUDUSD1440.csv	       NZDUSD1440.csv  USDCHF1440.csv
# EURUSD1440.csv	       sample_data     USDJPY1440.csv
